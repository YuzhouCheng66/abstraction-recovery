# %%
import g2o
import numpy as np
from tqdm import tqdm

class GraphSLAM2D:
    def __init__(self, verbose=False) -> None:
        self.verbose = verbose
        self.optimizer = g2o.SparseOptimizer()
        self.solver = self._make_solver()          # ✅ 换成自动选择稀疏 solver
        self.algorithm = g2o.OptimizationAlgorithmLevenberg(self.solver)
        self.optimizer.set_algorithm(self.algorithm)

        self.vertex_count = 0
        self.edge_count = 0

    # ---------- 新增：根据可用类型自动选 solver ----------
    def _make_solver(self):
        """
        优先用稀疏：
          1) LinearSolverCSparseX
          2) LinearSolverCholmodX
          3) 最后兜底：LinearSolverDenseX
        """
        # 依次尝试这些名字
        candidates = [
            "LinearSolverCSparseX",
            "LinearSolverCholmodX",
            "LinearSolverDenseX",
        ]

        for name in candidates:
            if hasattr(g2o, name):
                LinearSolverCls = getattr(g2o, name)
                if self.verbose:
                    print(f"[GraphSLAM2D] Using solver: {name} + BlockSolverX")
                return g2o.BlockSolverX(LinearSolverCls())

        # 理论上不会走到这里，除非绑定太残
        raise RuntimeError("No suitable LinearSolverX found in g2o bindings!")

    # ------------------------------------------------------

    def vertex_pose(self, id):
        return self.optimizer.vertex(id).estimate()

    def vertex(self, id):
        return self.optimizer.vertex(id)

    def edge(self, id):
        return self.optimizer.edge(id)

    def add_fixed_pose(self, pose, vertex_id=None):
        v_se2 = g2o.VertexSE2()
        if vertex_id is None:
            vertex_id = self.vertex_count
        v_se2.set_id(vertex_id)
        if self.verbose:
            print("Adding fixed pose vertex with ID", vertex_id)
        v_se2.set_estimate(pose)
        v_se2.set_fixed(True)
        self.optimizer.add_vertex(v_se2)
        self.vertex_count = max(self.vertex_count, vertex_id + 1)

    def optimize(self, iterations=10, verbose=None):
        self.optimizer.initialize_optimization()
        if verbose is None:
            verbose = self.verbose
        self.optimizer.set_verbose(verbose)
        self.optimizer.optimize(iterations)
        return self.optimizer.chi2()


def load_posegraph_g2o(graph_slam: GraphSLAM2D, filename: str, fix_first: bool = True):
    opt = graph_slam.optimizer
    num_vertices = 0
    num_edges = 0

    with open(filename, "r") as f:
        for line in f:
            if not line.strip() or line.startswith("#"):
                continue

            parts = line.split()
            tag = parts[0]

            if tag == "VERTEX_SE2":
                _, vid, x, y, th = parts
                vid = int(vid); x = float(x); y = float(y); th = float(th)

                v = g2o.VertexSE2()
                v.set_id(vid)
                v.set_estimate(g2o.SE2(x, y, th))

                if fix_first and vid == 0:
                    v.set_fixed(True)

                opt.add_vertex(v)
                num_vertices += 1
                graph_slam.vertex_count = max(graph_slam.vertex_count, vid + 1)

            elif tag == "EDGE_SE2":
                (
                    _,
                    i, j,
                    dx, dy, dth,
                    I11, I12, I13, I22, I23, I33,
                ) = parts

                i = int(i); j = int(j)
                dx = float(dx); dy = float(dy); dth = float(dth)
                I11 = float(I11); I12 = float(I12); I13 = float(I13)
                I22 = float(I22); I23 = float(I23); I33 = float(I33)

                info = np.zeros((3, 3))
                info[0, 0] = I11
                info[0, 1] = info[1, 0] = I12
                info[0, 2] = info[2, 0] = I13
                info[1, 1] = I22
                info[1, 2] = info[2, 1] = I23
                info[2, 2] = I33

                e = g2o.EdgeSE2()
                e.set_vertex(0, opt.vertex(i))
                e.set_vertex(1, opt.vertex(j))
                e.set_measurement(g2o.SE2(dx, dy, dth))
                e.set_information(info)
                opt.add_edge(e)

                num_edges += 1
                graph_slam.edge_count += 1

    if graph_slam.verbose:
        print(f"Loaded {num_vertices} vertices, {num_edges} edges from {filename}")

# %%
# 1) 实例化
graph_slam = GraphSLAM2D(verbose=True)

# 2) 读 Intel g2o 文件（把路径改成你本地的）
g2o_file = "/home/yuzhou/Desktop/input_INTEL_g2o.g2o"  # 或你自己的路径
load_posegraph_g2o(graph_slam, g2o_file, fix_first=True)


opt = graph_slam.optimizer
# Out:
# [GraphSLAM2D] Using solver: LinearSolverCSparseX + BlockSolverX
# Loaded 1228 vertices, 1483 edges from /home/yuzhou/Desktop/input_INTEL_g2o.g2o

# %%
# 3) 保存一份优化前的位姿（就是 VERTEX_SE2 里的值）
vertices = opt.vertices()
pose_ids = sorted(
    vid for vid, v in vertices.items()
    if isinstance(v, g2o.VertexSE2)
)
poses_before = {
    vid: vertices[vid].estimate()
    for vid in pose_ids
}

print("=== Before optimization ===")
print("chi2 =", opt.chi2())
print("num poses:", len(pose_ids), "num edges:", len(opt.edges()))

print("First 5 poses (file init):")
for vid in pose_ids[-5:]:
    est = poses_before[vid]
    print(
        f"id={vid:3d}: "
        f"x={est.translation()[0]:.6f}, "
        f"y={est.translation()[1]:.6f}, "
        f"theta={est.rotation().angle():.6f}"
    )

# 4) 以这些 VERTEX_SE2 为初始值跑 LM
chi2_after = graph_slam.optimize(iterations=10000, verbose=True)

print("\n=== After optimization ===")
print("chi2 =", chi2_after)

#print("First 5 poses (after LM):")
for vid in pose_ids[-5:]:
    est0 = poses_before[vid]
    est1 = opt.vertex(vid).estimate()
    print(
        f"id={vid:3d}: "
        f"before=({est0.translation()[0]:.6f},{est0.translation()[1]:.6f},{est0.rotation().angle():.6f}), "
        f"after =({est1.translation()[0]:.6f},{est1.translation()[1]:.6f},{est1.rotation().angle():.6f})"
    )
# Out:
# === Before optimization ===
# chi2 = 0.0
# num poses: 1228 num edges: 1483
# First 5 poses (file init):
# id=1223: x=-7.226028, y=-31.904243, theta=2.038302
# id=1224: x=-7.405412, y=-31.351278, theta=1.855394
# id=1225: x=-7.584838, y=-30.751843, theta=1.869158
# id=1226: x=-7.616041, y=-30.650012, theta=1.852427
# id=1227: x=-7.616041, y=-30.650012, theta=1.851765
# iteration= 0	 chi2= 5094164.106934	 time= 0.00178789	 cumTime= 0.00178789	 edges= 1483	 schur= 0	 lambda= 8006867.459158	 levenbergIter= 1
# iteration= 1	 chi2= 4939391.845232	 time= 0.000630942	 cumTime= 0.00241883	 edges= 1483	 schur= 0	 lambda= 2668955.819719	 levenbergIter= 1
# iteration= 2	 chi2= 4568818.318794	 time= 0.000615993	 cumTime= 0.00303483	 edges= 1483	 schur= 0	 lambda= 889651.939906	 levenbergIter= 1
# iteration= 3	 chi2= 3919775.040460	 time= 0.000599239	 cumTime= 0.00363407	 edges= 1483	 schur= 0	 lambda= 296550.646635	 levenbergIter= 1
# iteration= 4	 chi2= 2722096.327529	 time= 0.000597647	 cumTime= 0.00423171	 edges= 1483	 schur= 0	 lambda= 98850.215545	 levenbergIter= 1
# iteration= 5	 chi2= 2080862.025973	 time= 0.000600232	 cumTime= 0.00483194	 edges= 1483	 schur= 0	 lambda= 32950.071848	 levenbergIter= 1
# iteration= 6	 chi2= 1798082.421968	 time= 0.000578694	 cumTime= 0.00541064	 edges= 1483	 schur= 0	 lambda= 10983.357283	 levenbergIter= 1
# iteration= 7	 chi2= 1610390.637615	 time= 0.00059196	 cumTime= 0.0060026	 edges= 1483	 schur= 0	 lambda= 3661.119094	 levenbergIter= 1
# iteration= 8	 chi2= 1507555.302077	 time= 0.00057831	 cumTime= 0.00658091	 edges= 1483	 schur= 0	 lambda= 2440.746063	 levenbergIter= 1
# iteration= 9	 chi2= 1292292.434040	 time= 0.000976765	 cumTime= 0.00755767	 edges= 1483	 schur= 0	 lambda= 3254.328084	 levenbergIter= 2
# iteration= 10	 chi2= 1258376.853909	 time= 0.000582602	 cumTime= 0.00814028	 edges= 1483	 schur= 0	 lambda= 2169.552056	 levenbergIter= 1
# iteration= 11	 chi2= 1236064.944691	 time= 0.000661018	 cumTime= 0.00880129	 edges= 1483	 schur= 0	 lambda= 1446.368037	 levenbergIter= 1
# iteration= 12	 chi2= 932705.686225	 time= 0.00106016	 cumTime= 0.00986145	 edges= 1483	 schur= 0	 lambda= 1595.563668	 levenbergIter= 2
# iteration= 13	 chi2= 854118.297237	 time= 0.00100781	 cumTime= 0.0108693	 edges= 1483	 schur= 0	 lambda= 2127.418223	 levenbergIter= 2
# iteration= 14	 chi2= 846776.632481	 time= 0.000672678	 cumTime= 0.0115419	 edges= 1483	 schur= 0	 lambda= 1418.278816	 levenbergIter= 1
# iteration= 15	 chi2= 727380.406715	 time= 0.000962567	 cumTime= 0.0125045	 edges= 1483	 schur= 0	 lambda= 1795.382602	 levenbergIter= 2
# iteration= 16	 chi2= 680975.881531	 time= 0.000962695	 cumTime= 0.0134672	 edges= 1483	 schur= 0	 lambda= 2038.803674	 levenbergIter= 2
# iteration= 17	 chi2= 676834.762366	 time= 0.000571433	 cumTime= 0.0140386	 edges= 1483	 schur= 0	 lambda= 1359.202449	 levenbergIter= 1
# iteration= 18	 chi2= 608195.034604	 time= 0.000960014	 cumTime= 0.0149986	 edges= 1483	 schur= 0	 lambda= 1713.898072	 levenbergIter= 2
# iteration= 19	 chi2= 579049.967460	 time= 0.000951755	 cumTime= 0.0159504	 edges= 1483	 schur= 0	 lambda= 1807.510471	 levenbergIter= 2
# iteration= 20	 chi2= 575800.934905	 time= 0.000571044	 cumTime= 0.0165214	 edges= 1483	 schur= 0	 lambda= 1205.006981	 levenbergIter= 1
# iteration= 21	 chi2= 527146.645648	 time= 0.000954442	 cumTime= 0.0174759	 edges= 1483	 schur= 0	 lambda= 1475.264877	 levenbergIter= 2
# iteration= 22	 chi2= 524426.275197	 time= 0.000566036	 cumTime= 0.0180419	 edges= 1483	 schur= 0	 lambda= 983.509918	 levenbergIter= 1
# iteration= 23	 chi2= 477511.955386	 time= 0.000953963	 cumTime= 0.0189959	 edges= 1483	 schur= 0	 lambda= 1187.135456	 levenbergIter= 2
# iteration= 24	 chi2= 472617.037287	 time= 0.000566789	 cumTime= 0.0195627	 edges= 1483	 schur= 0	 lambda= 791.423638	 levenbergIter= 1
# iteration= 25	 chi2= 465093.606381	 time= 0.000571102	 cumTime= 0.0201338	 edges= 1483	 schur= 0	 lambda= 527.615758	 levenbergIter= 1
# iteration= 26	 chi2= 427176.647109	 time= 0.00056808	 cumTime= 0.0207019	 edges= 1483	 schur= 0	 lambda= 351.743839	 levenbergIter= 1
# iteration= 27	 chi2= 371987.034062	 time= 0.000619262	 cumTime= 0.0213211	 edges= 1483	 schur= 0	 lambda= 234.495893	 levenbergIter= 1
# iteration= 28	 chi2= 342077.789284	 time= 0.000955787	 cumTime= 0.0222769	 edges= 1483	 schur= 0	 lambda= 312.661190	 levenbergIter= 2
# iteration= 29	 chi2= 317977.958559	 time= 0.000955166	 cumTime= 0.0232321	 edges= 1483	 schur= 0	 lambda= 416.881587	 levenbergIter= 2
# iteration= 30	 chi2= 302805.855495	 time= 0.000997865	 cumTime= 0.0242299	 edges= 1483	 schur= 0	 lambda= 555.842116	 levenbergIter= 2
# iteration= 31	 chi2= 293915.698478	 time= 0.00105319	 cumTime= 0.0252831	 edges= 1483	 schur= 0	 lambda= 698.287184	 levenbergIter= 2
# iteration= 32	 chi2= 288363.810554	 time= 0.00100845	 cumTime= 0.0262916	 edges= 1483	 schur= 0	 lambda= 695.055439	 levenbergIter= 2
# iteration= 33	 chi2= 283939.961402	 time= 0.000966495	 cumTime= 0.0272581	 edges= 1483	 schur= 0	 lambda= 859.250979	 levenbergIter= 2
# iteration= 34	 chi2= 281843.779549	 time= 0.000566106	 cumTime= 0.0278242	 edges= 1483	 schur= 0	 lambda= 572.833986	 levenbergIter= 1
# iteration= 35	 chi2= 273402.605417	 time= 0.000963672	 cumTime= 0.0287878	 edges= 1483	 schur= 0	 lambda= 763.778648	 levenbergIter= 2
# iteration= 36	 chi2= 268862.100257	 time= 0.000950493	 cumTime= 0.0297383	 edges= 1483	 schur= 0	 lambda= 747.610437	 levenbergIter= 2
# iteration= 37	 chi2= 265575.818400	 time= 0.00095158	 cumTime= 0.0306899	 edges= 1483	 schur= 0	 lambda= 964.057363	 levenbergIter= 2
# iteration= 38	 chi2= 263503.877467	 time= 0.000568635	 cumTime= 0.0312586	 edges= 1483	 schur= 0	 lambda= 642.704909	 levenbergIter= 1
# iteration= 39	 chi2= 257655.994217	 time= 0.00095249	 cumTime= 0.032211	 edges= 1483	 schur= 0	 lambda= 838.092851	 levenbergIter= 2
# iteration= 40	 chi2= 257328.140308	 time= 0.000563282	 cumTime= 0.0327743	 edges= 1483	 schur= 0	 lambda= 558.728567	 levenbergIter= 1
# iteration= 41	 chi2= 249712.329532	 time= 0.000949476	 cumTime= 0.0337238	 edges= 1483	 schur= 0	 lambda= 744.971423	 levenbergIter= 2
# iteration= 42	 chi2= 245915.214937	 time= 0.000989058	 cumTime= 0.0347129	 edges= 1483	 schur= 0	 lambda= 846.202998	 levenbergIter= 2
# iteration= 43	 chi2= 243474.573037	 time= 0.000955171	 cumTime= 0.035668	 edges= 1483	 schur= 0	 lambda= 916.705818	 levenbergIter= 2
# iteration= 44	 chi2= 243070.883801	 time= 0.000565411	 cumTime= 0.0362334	 edges= 1483	 schur= 0	 lambda= 611.137212	 levenbergIter= 1
# iteration= 45	 chi2= 237585.368917	 time= 0.000951215	 cumTime= 0.0371847	 edges= 1483	 schur= 0	 lambda= 814.849616	 levenbergIter= 2
# iteration= 46	 chi2= 234727.212290	 time= 0.000995076	 cumTime= 0.0381797	 edges= 1483	 schur= 0	 lambda= 863.911083	 levenbergIter= 2
# iteration= 47	 chi2= 232762.157047	 time= 0.00104288	 cumTime= 0.0392226	 edges= 1483	 schur= 0	 lambda= 1004.514652	 levenbergIter= 2
# iteration= 48	 chi2= 231916.670554	 time= 0.000624117	 cumTime= 0.0398467	 edges= 1483	 schur= 0	 lambda= 669.676435	 levenbergIter= 1
# iteration= 49	 chi2= 227872.330935	 time= 0.000959229	 cumTime= 0.040806	 edges= 1483	 schur= 0	 lambda= 892.901913	 levenbergIter= 2
# iteration= 50	 chi2= 227832.910622	 time= 0.000567903	 cumTime= 0.0413739	 edges= 1483	 schur= 0	 lambda= 595.267942	 levenbergIter= 1
# iteration= 51	 chi2= 222684.019544	 time= 0.000959766	 cumTime= 0.0423336	 edges= 1483	 schur= 0	 lambda= 793.690590	 levenbergIter= 2
# iteration= 52	 chi2= 220116.888067	 time= 0.000952121	 cumTime= 0.0432857	 edges= 1483	 schur= 0	 lambda= 932.003147	 levenbergIter= 2
# iteration= 53	 chi2= 218494.363379	 time= 0.000958493	 cumTime= 0.0442442	 edges= 1483	 schur= 0	 lambda= 965.734553	 levenbergIter= 2
# iteration= 54	 chi2= 218430.762880	 time= 0.000586482	 cumTime= 0.0448307	 edges= 1483	 schur= 0	 lambda= 643.823035	 levenbergIter= 1
# iteration= 55	 chi2= 214514.803373	 time= 0.000950625	 cumTime= 0.0457813	 edges= 1483	 schur= 0	 lambda= 858.430714	 levenbergIter= 2
# iteration= 56	 chi2= 212479.108391	 time= 0.000997305	 cumTime= 0.0467786	 edges= 1483	 schur= 0	 lambda= 941.970557	 levenbergIter= 2
# iteration= 57	 chi2= 211106.502350	 time= 0.000952807	 cumTime= 0.0477315	 edges= 1483	 schur= 0	 lambda= 1046.972851	 levenbergIter= 2
# iteration= 58	 chi2= 210654.754322	 time= 0.000564849	 cumTime= 0.0482963	 edges= 1483	 schur= 0	 lambda= 697.981901	 levenbergIter= 1
# iteration= 59	 chi2= 207634.052693	 time= 0.000950142	 cumTime= 0.0492464	 edges= 1483	 schur= 0	 lambda= 930.642535	 levenbergIter= 2
# iteration= 60	 chi2= 205998.905443	 time= 0.000945129	 cumTime= 0.0501916	 edges= 1483	 schur= 0	 lambda= 936.340539	 levenbergIter= 2
# iteration= 61	 chi2= 204806.985494	 time= 0.000965734	 cumTime= 0.0511573	 edges= 1483	 schur= 0	 lambda= 1140.381023	 levenbergIter= 2
# iteration= 62	 chi2= 204089.379699	 time= 0.000564093	 cumTime= 0.0517214	 edges= 1483	 schur= 0	 lambda= 760.254016	 levenbergIter= 1
# iteration= 63	 chi2= 201747.099637	 time= 0.00107462	 cumTime= 0.052796	 edges= 1483	 schur= 0	 lambda= 1010.458680	 levenbergIter= 2
# iteration= 64	 chi2= 201456.397301	 time= 0.000576712	 cumTime= 0.0533727	 edges= 1483	 schur= 0	 lambda= 673.639120	 levenbergIter= 1
# iteration= 65	 chi2= 198447.595137	 time= 0.00106693	 cumTime= 0.0544397	 edges= 1483	 schur= 0	 lambda= 898.185494	 levenbergIter= 2
# iteration= 66	 chi2= 196880.033671	 time= 0.000982066	 cumTime= 0.0554217	 edges= 1483	 schur= 0	 lambda= 987.611716	 levenbergIter= 2
# iteration= 67	 chi2= 195820.665369	 time= 0.000984168	 cumTime= 0.0564059	 edges= 1483	 schur= 0	 lambda= 1090.239975	 levenbergIter= 2
# iteration= 68	 chi2= 195464.815667	 time= 0.000588003	 cumTime= 0.0569939	 edges= 1483	 schur= 0	 lambda= 726.826650	 levenbergIter= 1
# iteration= 69	 chi2= 193105.944487	 time= 0.00100355	 cumTime= 0.0579975	 edges= 1483	 schur= 0	 lambda= 969.102200	 levenbergIter= 2
# iteration= 70	 chi2= 191822.277692	 time= 0.00102899	 cumTime= 0.0590264	 edges= 1483	 schur= 0	 lambda= 970.214695	 levenbergIter= 2
# iteration= 71	 chi2= 190878.804134	 time= 0.000978817	 cumTime= 0.0600053	 edges= 1483	 schur= 0	 lambda= 1182.786459	 levenbergIter= 2
# iteration= 72	 chi2= 190289.608760	 time= 0.000588691	 cumTime= 0.060594	 edges= 1483	 schur= 0	 lambda= 788.524306	 levenbergIter= 1
# iteration= 73	 chi2= 188432.111041	 time= 0.000978685	 cumTime= 0.0615726	 edges= 1483	 schur= 0	 lambda= 1041.306632	 levenbergIter= 2
# iteration= 74	 chi2= 188186.903917	 time= 0.000566507	 cumTime= 0.0621391	 edges= 1483	 schur= 0	 lambda= 694.204421	 levenbergIter= 1
# iteration= 75	 chi2= 185763.515394	 time= 0.000947292	 cumTime= 0.0630864	 edges= 1483	 schur= 0	 lambda= 925.605895	 levenbergIter= 2
# iteration= 76	 chi2= 184493.923743	 time= 0.000958402	 cumTime= 0.0640448	 edges= 1483	 schur= 0	 lambda= 1008.729815	 levenbergIter= 2
# iteration= 77	 chi2= 183627.258225	 time= 0.000942528	 cumTime= 0.0649874	 edges= 1483	 schur= 0	 lambda= 1120.452029	 levenbergIter= 2
# iteration= 78	 chi2= 183298.262892	 time= 0.000562951	 cumTime= 0.0655503	 edges= 1483	 schur= 0	 lambda= 746.968019	 levenbergIter= 1
# iteration= 79	 chi2= 181382.604255	 time= 0.000944009	 cumTime= 0.0664943	 edges= 1483	 schur= 0	 lambda= 995.957359	 levenbergIter= 2
# iteration= 80	 chi2= 181343.453126	 time= 0.000612584	 cumTime= 0.0671069	 edges= 1483	 schur= 0	 lambda= 663.971573	 levenbergIter= 1
# iteration= 81	 chi2= 178871.999048	 time= 0.00103724	 cumTime= 0.0681441	 edges= 1483	 schur= 0	 lambda= 885.295430	 levenbergIter= 2
# iteration= 82	 chi2= 177617.833035	 time= 0.00100011	 cumTime= 0.0691443	 edges= 1483	 schur= 0	 lambda= 1026.935734	 levenbergIter= 2
# iteration= 83	 chi2= 177582.912474	 time= 0.000566842	 cumTime= 0.0697111	 edges= 1483	 schur= 0	 lambda= 684.623823	 levenbergIter= 1
# iteration= 84	 chi2= 175420.217546	 time= 0.000948419	 cumTime= 0.0706595	 edges= 1483	 schur= 0	 lambda= 912.831763	 levenbergIter= 2
# iteration= 85	 chi2= 174297.514010	 time= 0.000946166	 cumTime= 0.0716057	 edges= 1483	 schur= 0	 lambda= 1012.239741	 levenbergIter= 2
# iteration= 86	 chi2= 173542.519823	 time= 0.000936179	 cumTime= 0.0725419	 edges= 1483	 schur= 0	 lambda= 1101.087061	 levenbergIter= 2
# iteration= 87	 chi2= 173294.831457	 time= 0.000562721	 cumTime= 0.0731046	 edges= 1483	 schur= 0	 lambda= 734.058041	 levenbergIter= 1
# iteration= 88	 chi2= 171581.058073	 time= 0.000944961	 cumTime= 0.0740495	 edges= 1483	 schur= 0	 lambda= 978.744055	 levenbergIter= 2
# iteration= 89	 chi2= 171567.484847	 time= 0.000566075	 cumTime= 0.0746156	 edges= 1483	 schur= 0	 lambda= 652.496036	 levenbergIter= 1
# iteration= 90	 chi2= 169361.443834	 time= 0.000940799	 cumTime= 0.0755564	 edges= 1483	 schur= 0	 lambda= 869.994715	 levenbergIter= 2
# iteration= 91	 chi2= 168247.411079	 time= 0.000942263	 cumTime= 0.0764987	 edges= 1483	 schur= 0	 lambda= 1011.002073	 levenbergIter= 2
# iteration= 92	 chi2= 168200.638549	 time= 0.000558454	 cumTime= 0.0770571	 edges= 1483	 schur= 0	 lambda= 674.001382	 levenbergIter= 1
# iteration= 93	 chi2= 166293.848526	 time= 0.000937377	 cumTime= 0.0779945	 edges= 1483	 schur= 0	 lambda= 898.668510	 levenbergIter= 2
# iteration= 94	 chi2= 165303.151915	 time= 0.000955093	 cumTime= 0.0789496	 edges= 1483	 schur= 0	 lambda= 984.973458	 levenbergIter= 2
# iteration= 95	 chi2= 164630.595287	 time= 0.000937646	 cumTime= 0.0798873	 edges= 1483	 schur= 0	 lambda= 1082.282138	 levenbergIter= 2
# iteration= 96	 chi2= 164374.260989	 time= 0.000567273	 cumTime= 0.0804545	 edges= 1483	 schur= 0	 lambda= 721.521426	 levenbergIter= 1
# iteration= 97	 chi2= 162869.970839	 time= 0.000937778	 cumTime= 0.0813923	 edges= 1483	 schur= 0	 lambda= 962.028567	 levenbergIter= 2
# iteration= 98	 chi2= 162790.351885	 time= 0.000565869	 cumTime= 0.0819582	 edges= 1483	 schur= 0	 lambda= 641.352378	 levenbergIter= 1
# iteration= 99	 chi2= 160873.683156	 time= 0.000947347	 cumTime= 0.0829055	 edges= 1483	 schur= 0	 lambda= 855.136504	 levenbergIter= 2
# iteration= 100	 chi2= 159896.293896	 time= 0.000941178	 cumTime= 0.0838467	 edges= 1483	 schur= 0	 lambda= 963.243813	 levenbergIter= 2
# iteration= 101	 chi2= 159884.507016	 time= 0.000564872	 cumTime= 0.0844116	 edges= 1483	 schur= 0	 lambda= 642.162542	 levenbergIter= 1
# iteration= 102	 chi2= 158107.679488	 time= 0.000952731	 cumTime= 0.0853643	 edges= 1483	 schur= 0	 lambda= 856.216722	 levenbergIter= 2
# iteration= 103	 chi2= 157190.029334	 time= 0.000957867	 cumTime= 0.0863222	 edges= 1483	 schur= 0	 lambda= 935.882242	 levenbergIter= 2
# iteration= 104	 chi2= 156566.930588	 time= 0.000951021	 cumTime= 0.0872732	 edges= 1483	 schur= 0	 lambda= 1028.831702	 levenbergIter= 2
# iteration= 105	 chi2= 156315.979941	 time= 0.00058221	 cumTime= 0.0878554	 edges= 1483	 schur= 0	 lambda= 685.887801	 levenbergIter= 1
# iteration= 106	 chi2= 154926.993200	 time= 0.000943861	 cumTime= 0.0887993	 edges= 1483	 schur= 0	 lambda= 914.517068	 levenbergIter= 2
# iteration= 107	 chi2= 154809.785367	 time= 0.000558527	 cumTime= 0.0893578	 edges= 1483	 schur= 0	 lambda= 609.678045	 levenbergIter= 1
# iteration= 108	 chi2= 153060.062550	 time= 0.000942731	 cumTime= 0.0903005	 edges= 1483	 schur= 0	 lambda= 812.904061	 levenbergIter= 2
# iteration= 109	 chi2= 152163.629736	 time= 0.00095688	 cumTime= 0.0912574	 edges= 1483	 schur= 0	 lambda= 891.342834	 levenbergIter= 2
# iteration= 110	 chi2= 151558.145625	 time= 0.00095302	 cumTime= 0.0922104	 edges= 1483	 schur= 0	 lambda= 974.954462	 levenbergIter= 2
# iteration= 111	 chi2= 151315.148243	 time= 0.00057762	 cumTime= 0.092788	 edges= 1483	 schur= 0	 lambda= 649.969641	 levenbergIter= 1
# iteration= 112	 chi2= 149960.234783	 time= 0.000948491	 cumTime= 0.0937365	 edges= 1483	 schur= 0	 lambda= 866.626188	 levenbergIter= 2
# iteration= 113	 chi2= 149825.780458	 time= 0.000576788	 cumTime= 0.0943133	 edges= 1483	 schur= 0	 lambda= 577.750792	 levenbergIter= 1
# iteration= 114	 chi2= 148133.864596	 time= 0.000982345	 cumTime= 0.0952957	 edges= 1483	 schur= 0	 lambda= 770.334389	 levenbergIter= 2
# iteration= 115	 chi2= 147266.551250	 time= 0.000945557	 cumTime= 0.0962412	 edges= 1483	 schur= 0	 lambda= 830.896149	 levenbergIter= 2
# iteration= 116	 chi2= 146673.360011	 time= 0.00103995	 cumTime= 0.0972812	 edges= 1483	 schur= 0	 lambda= 922.860001	 levenbergIter= 2
# iteration= 117	 chi2= 146397.657838	 time= 0.000650859	 cumTime= 0.097932	 edges= 1483	 schur= 0	 lambda= 615.240001	 levenbergIter= 1
# iteration= 118	 chi2= 145099.452200	 time= 0.00102493	 cumTime= 0.098957	 edges= 1483	 schur= 0	 lambda= 820.320001	 levenbergIter= 2
# iteration= 119	 chi2= 144905.766929	 time= 0.00058507	 cumTime= 0.099542	 edges= 1483	 schur= 0	 lambda= 546.880001	 levenbergIter= 1
# iteration= 120	 chi2= 143304.574369	 time= 0.000983459	 cumTime= 0.100525	 edges= 1483	 schur= 0	 lambda= 729.173334	 levenbergIter= 2
# iteration= 121	 chi2= 142475.007448	 time= 0.000988078	 cumTime= 0.101514	 edges= 1483	 schur= 0	 lambda= 755.366005	 levenbergIter= 2
# iteration= 122	 chi2= 141887.934691	 time= 0.000951104	 cumTime= 0.102465	 edges= 1483	 schur= 0	 lambda= 873.005200	 levenbergIter= 2
# iteration= 123	 chi2= 141540.410975	 time= 0.000575849	 cumTime= 0.103041	 edges= 1483	 schur= 0	 lambda= 582.003466	 levenbergIter= 1
# iteration= 124	 chi2= 140321.119576	 time= 0.000947839	 cumTime= 0.103988	 edges= 1483	 schur= 0	 lambda= 751.872453	 levenbergIter= 2
# iteration= 125	 chi2= 140127.509972	 time= 0.000565923	 cumTime= 0.104554	 edges= 1483	 schur= 0	 lambda= 501.248302	 levenbergIter= 1
# iteration= 126	 chi2= 138530.041454	 time= 0.000947177	 cumTime= 0.105501	 edges= 1483	 schur= 0	 lambda= 668.331069	 levenbergIter= 2
# iteration= 127	 chi2= 138503.424179	 time= 0.000566849	 cumTime= 0.106068	 edges= 1483	 schur= 0	 lambda= 445.554046	 levenbergIter= 1
# iteration= 128	 chi2= 136562.163484	 time= 0.000955917	 cumTime= 0.107024	 edges= 1483	 schur= 0	 lambda= 594.072061	 levenbergIter= 2
# iteration= 129	 chi2= 135607.994513	 time= 0.000945207	 cumTime= 0.107969	 edges= 1483	 schur= 0	 lambda= 654.916890	 levenbergIter= 2
# iteration= 130	 chi2= 135566.505459	 time= 0.00057856	 cumTime= 0.108548	 edges= 1483	 schur= 0	 lambda= 436.611260	 levenbergIter= 1
# iteration= 131	 chi2= 133816.227876	 time= 0.000949796	 cumTime= 0.109498	 edges= 1483	 schur= 0	 lambda= 582.148346	 levenbergIter= 2
# iteration= 132	 chi2= 133796.968398	 time= 0.000572529	 cumTime= 0.11007	 edges= 1483	 schur= 0	 lambda= 388.098898	 levenbergIter= 1
# iteration= 133	 chi2= 131715.663360	 time= 0.000939664	 cumTime= 0.11101	 edges= 1483	 schur= 0	 lambda= 517.465197	 levenbergIter= 2
# iteration= 134	 chi2= 130705.925696	 time= 0.000973429	 cumTime= 0.111983	 edges= 1483	 schur= 0	 lambda= 563.023840	 levenbergIter= 2
# iteration= 135	 chi2= 130654.689783	 time= 0.000566058	 cumTime= 0.112549	 edges= 1483	 schur= 0	 lambda= 375.349227	 levenbergIter= 1
# iteration= 136	 chi2= 128781.490560	 time= 0.000942953	 cumTime= 0.113492	 edges= 1483	 schur= 0	 lambda= 500.465636	 levenbergIter= 2
# iteration= 137	 chi2= 128663.571346	 time= 0.000588621	 cumTime= 0.114081	 edges= 1483	 schur= 0	 lambda= 333.643757	 levenbergIter= 1
# iteration= 138	 chi2= 126508.781453	 time= 0.000955458	 cumTime= 0.115036	 edges= 1483	 schur= 0	 lambda= 444.858343	 levenbergIter= 2
# iteration= 139	 chi2= 126457.883303	 time= 0.000562889	 cumTime= 0.115599	 edges= 1483	 schur= 0	 lambda= 296.572229	 levenbergIter= 1
# iteration= 140	 chi2= 124037.527065	 time= 0.000939972	 cumTime= 0.116539	 edges= 1483	 schur= 0	 lambda= 395.429638	 levenbergIter= 2
# iteration= 141	 chi2= 123984.845990	 time= 0.000560563	 cumTime= 0.1171	 edges= 1483	 schur= 0	 lambda= 263.619759	 levenbergIter= 1
# iteration= 142	 chi2= 121349.791202	 time= 0.000937554	 cumTime= 0.118037	 edges= 1483	 schur= 0	 lambda= 351.493012	 levenbergIter= 2
# iteration= 143	 chi2= 121192.852089	 time= 0.000564774	 cumTime= 0.118602	 edges= 1483	 schur= 0	 lambda= 234.328674	 levenbergIter= 1
# iteration= 144	 chi2= 118430.141391	 time= 0.00107474	 cumTime= 0.119677	 edges= 1483	 schur= 0	 lambda= 312.438233	 levenbergIter= 2
# iteration= 145	 chi2= 118046.895412	 time= 0.000598179	 cumTime= 0.120275	 edges= 1483	 schur= 0	 lambda= 208.292155	 levenbergIter= 1
# iteration= 146	 chi2= 115270.602045	 time= 0.000954691	 cumTime= 0.12123	 edges= 1483	 schur= 0	 lambda= 269.345133	 levenbergIter= 2
# iteration= 147	 chi2= 114685.070780	 time= 0.000561875	 cumTime= 0.121792	 edges= 1483	 schur= 0	 lambda= 179.563422	 levenbergIter= 1
# iteration= 148	 chi2= 111819.286959	 time= 0.000944835	 cumTime= 0.122737	 edges= 1483	 schur= 0	 lambda= 217.384209	 levenbergIter= 2
# iteration= 149	 chi2= 111074.371373	 time= 0.000560152	 cumTime= 0.123297	 edges= 1483	 schur= 0	 lambda= 144.922806	 levenbergIter= 1
# iteration= 150	 chi2= 110542.805429	 time= 0.000566056	 cumTime= 0.123863	 edges= 1483	 schur= 0	 lambda= 96.615204	 levenbergIter= 1
# iteration= 151	 chi2= 109991.466286	 time= 0.000568332	 cumTime= 0.124431	 edges= 1483	 schur= 0	 lambda= 64.410136	 levenbergIter= 1
# iteration= 152	 chi2= 100176.142375	 time= 0.000959659	 cumTime= 0.125391	 edges= 1483	 schur= 0	 lambda= 85.880181	 levenbergIter= 2
# iteration= 153	 chi2= 99099.877812	 time= 0.000565524	 cumTime= 0.125956	 edges= 1483	 schur= 0	 lambda= 57.253454	 levenbergIter= 1
# iteration= 154	 chi2= 92210.044201	 time= 0.000954044	 cumTime= 0.12691	 edges= 1483	 schur= 0	 lambda= 76.337939	 levenbergIter= 2
# iteration= 155	 chi2= 90566.138864	 time= 0.000568536	 cumTime= 0.127479	 edges= 1483	 schur= 0	 lambda= 50.891959	 levenbergIter= 1
# iteration= 156	 chi2= 84560.424610	 time= 0.000952048	 cumTime= 0.128431	 edges= 1483	 schur= 0	 lambda= 67.855946	 levenbergIter= 2
# iteration= 157	 chi2= 81450.924619	 time= 0.000945421	 cumTime= 0.129376	 edges= 1483	 schur= 0	 lambda= 86.409059	 levenbergIter= 2
# iteration= 158	 chi2= 79524.516325	 time= 0.000951168	 cumTime= 0.130328	 edges= 1483	 schur= 0	 lambda= 95.171371	 levenbergIter= 2
# iteration= 159	 chi2= 78040.571736	 time= 0.000948621	 cumTime= 0.131276	 edges= 1483	 schur= 0	 lambda= 116.375488	 levenbergIter= 2
# iteration= 160	 chi2= 77968.322353	 time= 0.000617404	 cumTime= 0.131894	 edges= 1483	 schur= 0	 lambda= 77.583659	 levenbergIter= 1
# iteration= 161	 chi2= 74942.350969	 time= 0.000972029	 cumTime= 0.132866	 edges= 1483	 schur= 0	 lambda= 103.444878	 levenbergIter= 2
# iteration= 162	 chi2= 73108.941182	 time= 0.000950041	 cumTime= 0.133816	 edges= 1483	 schur= 0	 lambda= 137.926504	 levenbergIter= 2
# iteration= 163	 chi2= 71965.137292	 time= 0.000967192	 cumTime= 0.134783	 edges= 1483	 schur= 0	 lambda= 156.022396	 levenbergIter= 2
# iteration= 164	 chi2= 71152.892051	 time= 0.000941975	 cumTime= 0.135725	 edges= 1483	 schur= 0	 lambda= 175.596128	 levenbergIter= 2
# iteration= 165	 chi2= 71032.476099	 time= 0.000565769	 cumTime= 0.136291	 edges= 1483	 schur= 0	 lambda= 117.064086	 levenbergIter= 1
# iteration= 166	 chi2= 69224.163334	 time= 0.000941491	 cumTime= 0.137232	 edges= 1483	 schur= 0	 lambda= 156.085448	 levenbergIter= 2
# iteration= 167	 chi2= 68205.837454	 time= 0.000962674	 cumTime= 0.138195	 edges= 1483	 schur= 0	 lambda= 193.296015	 levenbergIter= 2
# iteration= 168	 chi2= 68154.369735	 time= 0.000564914	 cumTime= 0.13876	 edges= 1483	 schur= 0	 lambda= 128.864010	 levenbergIter= 1
# iteration= 169	 chi2= 66525.158073	 time= 0.000941044	 cumTime= 0.139701	 edges= 1483	 schur= 0	 lambda= 171.818680	 levenbergIter= 2
# iteration= 170	 chi2= 65636.210756	 time= 0.000945465	 cumTime= 0.140646	 edges= 1483	 schur= 0	 lambda= 214.349915	 levenbergIter= 2
# iteration= 171	 chi2= 65561.717492	 time= 0.000561931	 cumTime= 0.141208	 edges= 1483	 schur= 0	 lambda= 142.899944	 levenbergIter= 1
# iteration= 172	 chi2= 64183.503619	 time= 0.000946105	 cumTime= 0.142154	 edges= 1483	 schur= 0	 lambda= 190.533258	 levenbergIter= 2
# iteration= 173	 chi2= 63435.858531	 time= 0.000938	 cumTime= 0.143092	 edges= 1483	 schur= 0	 lambda= 229.079454	 levenbergIter= 2
# iteration= 174	 chi2= 63393.423497	 time= 0.000567535	 cumTime= 0.14366	 edges= 1483	 schur= 0	 lambda= 152.719636	 levenbergIter= 1
# iteration= 175	 chi2= 62158.249207	 time= 0.000956191	 cumTime= 0.144616	 edges= 1483	 schur= 0	 lambda= 203.626181	 levenbergIter= 2
# iteration= 176	 chi2= 61494.208320	 time= 0.000952994	 cumTime= 0.145569	 edges= 1483	 schur= 0	 lambda= 241.647348	 levenbergIter= 2
# iteration= 177	 chi2= 61459.484918	 time= 0.000565896	 cumTime= 0.146135	 edges= 1483	 schur= 0	 lambda= 161.098232	 levenbergIter= 1
# iteration= 178	 chi2= 60341.378454	 time= 0.000986988	 cumTime= 0.147122	 edges= 1483	 schur= 0	 lambda= 214.797643	 levenbergIter= 2
# iteration= 179	 chi2= 59742.969618	 time= 0.00105343	 cumTime= 0.148175	 edges= 1483	 schur= 0	 lambda= 251.783156	 levenbergIter= 2
# iteration= 180	 chi2= 59715.841094	 time= 0.000585437	 cumTime= 0.148761	 edges= 1483	 schur= 0	 lambda= 167.855437	 levenbergIter= 1
# iteration= 181	 chi2= 58687.883397	 time= 0.00102391	 cumTime= 0.149785	 edges= 1483	 schur= 0	 lambda= 223.807249	 levenbergIter= 2
# iteration= 182	 chi2= 58139.730613	 time= 0.000982879	 cumTime= 0.150767	 edges= 1483	 schur= 0	 lambda= 260.243902	 levenbergIter= 2
# iteration= 183	 chi2= 58116.804941	 time= 0.000562124	 cumTime= 0.15133	 edges= 1483	 schur= 0	 lambda= 173.495934	 levenbergIter= 1
# iteration= 184	 chi2= 57163.113039	 time= 0.000960288	 cumTime= 0.15229	 edges= 1483	 schur= 0	 lambda= 231.327913	 levenbergIter= 2
# iteration= 185	 chi2= 56655.849606	 time= 0.000947182	 cumTime= 0.153237	 edges= 1483	 schur= 0	 lambda= 267.252921	 levenbergIter= 2
# iteration= 186	 chi2= 56636.106549	 time= 0.00057236	 cumTime= 0.153809	 edges= 1483	 schur= 0	 lambda= 178.168614	 levenbergIter= 1
# iteration= 187	 chi2= 55744.255544	 time= 0.000977039	 cumTime= 0.154786	 edges= 1483	 schur= 0	 lambda= 237.558152	 levenbergIter= 2
# iteration= 188	 chi2= 55270.814134	 time= 0.000954353	 cumTime= 0.155741	 edges= 1483	 schur= 0	 lambda= 273.076954	 levenbergIter= 2
# iteration= 189	 chi2= 55253.326441	 time= 0.00056459	 cumTime= 0.156305	 edges= 1483	 schur= 0	 lambda= 182.051303	 levenbergIter= 1
# iteration= 190	 chi2= 54414.167173	 time= 0.00101098	 cumTime= 0.157316	 edges= 1483	 schur= 0	 lambda= 242.735071	 levenbergIter= 2
# iteration= 191	 chi2= 53969.371460	 time= 0.00095186	 cumTime= 0.158268	 edges= 1483	 schur= 0	 lambda= 277.892243	 levenbergIter= 2
# iteration= 192	 chi2= 53953.599718	 time= 0.000569617	 cumTime= 0.158838	 edges= 1483	 schur= 0	 lambda= 185.261495	 levenbergIter= 1
# iteration= 193	 chi2= 53159.962411	 time= 0.000945766	 cumTime= 0.159784	 edges= 1483	 schur= 0	 lambda= 247.015327	 levenbergIter= 2
# iteration= 194	 chi2= 52739.817425	 time= 0.000949906	 cumTime= 0.160733	 edges= 1483	 schur= 0	 lambda= 281.842635	 levenbergIter= 2
# iteration= 195	 chi2= 52725.327615	 time= 0.00058456	 cumTime= 0.161318	 edges= 1483	 schur= 0	 lambda= 187.895090	 levenbergIter= 1
# iteration= 196	 chi2= 51971.577438	 time= 0.000970148	 cumTime= 0.162288	 edges= 1483	 schur= 0	 lambda= 250.526786	 levenbergIter= 2
# iteration= 197	 chi2= 51572.932154	 time= 0.000949375	 cumTime= 0.163238	 edges= 1483	 schur= 0	 lambda= 285.034971	 levenbergIter= 2
# iteration= 198	 chi2= 51559.455058	 time= 0.00056607	 cumTime= 0.163804	 edges= 1483	 schur= 0	 lambda= 190.023314	 levenbergIter= 1
# iteration= 199	 chi2= 50840.968172	 time= 0.0010005	 cumTime= 0.164804	 edges= 1483	 schur= 0	 lambda= 253.364419	 levenbergIter= 2
# iteration= 200	 chi2= 50461.276886	 time= 0.00095163	 cumTime= 0.165756	 edges= 1483	 schur= 0	 lambda= 287.560593	 levenbergIter= 2
# iteration= 201	 chi2= 50448.601577	 time= 0.00056879	 cumTime= 0.166325	 edges= 1483	 schur= 0	 lambda= 191.707062	 levenbergIter= 1
# iteration= 202	 chi2= 49761.572107	 time= 0.000948599	 cumTime= 0.167273	 edges= 1483	 schur= 0	 lambda= 255.609416	 levenbergIter= 2
# iteration= 203	 chi2= 49398.750947	 time= 0.00095164	 cumTime= 0.168225	 edges= 1483	 schur= 0	 lambda= 289.490729	 levenbergIter= 2
# iteration= 204	 chi2= 49386.713122	 time= 0.000563952	 cumTime= 0.168789	 edges= 1483	 schur= 0	 lambda= 192.993819	 levenbergIter= 1
# iteration= 205	 chi2= 48727.958529	 time= 0.000936817	 cumTime= 0.169726	 edges= 1483	 schur= 0	 lambda= 257.325092	 levenbergIter= 2
# iteration= 206	 chi2= 48380.266469	 time= 0.000971554	 cumTime= 0.170697	 edges= 1483	 schur= 0	 lambda= 290.885642	 levenbergIter= 2
# iteration= 207	 chi2= 48368.739465	 time= 0.000573019	 cumTime= 0.17127	 edges= 1483	 schur= 0	 lambda= 193.923761	 levenbergIter= 1
# iteration= 208	 chi2= 47735.558753	 time= 0.000960481	 cumTime= 0.172231	 edges= 1483	 schur= 0	 lambda= 258.565015	 levenbergIter= 2
# iteration= 209	 chi2= 47401.523102	 time= 0.000960247	 cumTime= 0.173191	 edges= 1483	 schur= 0	 lambda= 291.791763	 levenbergIter= 2
# iteration= 210	 chi2= 47390.418709	 time= 0.000567347	 cumTime= 0.173758	 edges= 1483	 schur= 0	 lambda= 194.527842	 levenbergIter= 1
# iteration= 211	 chi2= 46780.476952	 time= 0.000983413	 cumTime= 0.174742	 edges= 1483	 schur= 0	 lambda= 259.370456	 levenbergIter= 2
# iteration= 212	 chi2= 46458.835387	 time= 0.000956641	 cumTime= 0.175698	 edges= 1483	 schur= 0	 lambda= 292.258627	 levenbergIter= 2
# iteration= 213	 chi2= 46448.041949	 time= 0.000568989	 cumTime= 0.176267	 edges= 1483	 schur= 0	 lambda= 194.839085	 levenbergIter= 1
# iteration= 214	 chi2= 45859.360331	 time= 0.000959664	 cumTime= 0.177227	 edges= 1483	 schur= 0	 lambda= 259.785446	 levenbergIter= 2
# iteration= 215	 chi2= 45549.032468	 time= 0.000965247	 cumTime= 0.178192	 edges= 1483	 schur= 0	 lambda= 292.313321	 levenbergIter= 2
# iteration= 216	 chi2= 45538.509365	 time= 0.000573029	 cumTime= 0.178765	 edges= 1483	 schur= 0	 lambda= 194.875547	 levenbergIter= 1
# iteration= 217	 chi2= 44969.305018	 time= 0.000960347	 cumTime= 0.179726	 edges= 1483	 schur= 0	 lambda= 259.834063	 levenbergIter= 2
# iteration= 218	 chi2= 44669.332730	 time= 0.000957478	 cumTime= 0.180683	 edges= 1483	 schur= 0	 lambda= 291.994102	 levenbergIter= 2
# iteration= 219	 chi2= 44659.005294	 time= 0.000559947	 cumTime= 0.181243	 edges= 1483	 schur= 0	 lambda= 194.662735	 levenbergIter= 1
# iteration= 220	 chi2= 44107.749786	 time= 0.000949542	 cumTime= 0.182193	 edges= 1483	 schur= 0	 lambda= 259.550313	 levenbergIter= 2
# iteration= 221	 chi2= 43817.300401	 time= 0.000950229	 cumTime= 0.183143	 edges= 1483	 schur= 0	 lambda= 291.321207	 levenbergIter= 2
# iteration= 222	 chi2= 43807.150947	 time= 0.000560201	 cumTime= 0.183703	 edges= 1483	 schur= 0	 lambda= 194.214138	 levenbergIter= 1
# iteration= 223	 chi2= 43272.438690	 time= 0.000934946	 cumTime= 0.184638	 edges= 1483	 schur= 0	 lambda= 258.952184	 levenbergIter= 2
# iteration= 224	 chi2= 42990.768009	 time= 0.000955857	 cumTime= 0.185594	 edges= 1483	 schur= 0	 lambda= 290.333267	 levenbergIter= 2
# iteration= 225	 chi2= 42980.710979	 time= 0.000570991	 cumTime= 0.186165	 edges= 1483	 schur= 0	 lambda= 193.555511	 levenbergIter= 1
# iteration= 226	 chi2= 42461.366721	 time= 0.000960044	 cumTime= 0.187125	 edges= 1483	 schur= 0	 lambda= 258.074015	 levenbergIter= 2
# iteration= 227	 chi2= 42187.828683	 time= 0.000941591	 cumTime= 0.188066	 edges= 1483	 schur= 0	 lambda= 289.033780	 levenbergIter= 2
# iteration= 228	 chi2= 42177.878456	 time= 0.000572499	 cumTime= 0.188639	 edges= 1483	 schur= 0	 lambda= 192.689187	 levenbergIter= 1
# iteration= 229	 chi2= 41672.755470	 time= 0.000950345	 cumTime= 0.189589	 edges= 1483	 schur= 0	 lambda= 256.918916	 levenbergIter= 2
# iteration= 230	 chi2= 41406.744862	 time= 0.00096191	 cumTime= 0.190551	 edges= 1483	 schur= 0	 lambda= 287.463068	 levenbergIter= 2
# iteration= 231	 chi2= 41396.832963	 time= 0.000569341	 cumTime= 0.19112	 edges= 1483	 schur= 0	 lambda= 191.642045	 levenbergIter= 1
# iteration= 232	 chi2= 40904.983394	 time= 0.000960199	 cumTime= 0.192081	 edges= 1483	 schur= 0	 lambda= 255.522727	 levenbergIter= 2
# iteration= 233	 chi2= 40645.984096	 time= 0.000968663	 cumTime= 0.193049	 edges= 1483	 schur= 0	 lambda= 285.628660	 levenbergIter= 2
# iteration= 234	 chi2= 40636.101916	 time= 0.000575636	 cumTime= 0.193625	 edges= 1483	 schur= 0	 lambda= 190.419107	 levenbergIter= 1
# iteration= 235	 chi2= 40156.617348	 time= 0.00095359	 cumTime= 0.194579	 edges= 1483	 schur= 0	 lambda= 253.892142	 levenbergIter= 2
# iteration= 236	 chi2= 39904.148140	 time= 0.000935621	 cumTime= 0.195514	 edges= 1483	 schur= 0	 lambda= 283.553553	 levenbergIter= 2
# iteration= 237	 chi2= 39894.261778	 time= 0.000581667	 cumTime= 0.196096	 edges= 1483	 schur= 0	 lambda= 189.035702	 levenbergIter= 1
# iteration= 238	 chi2= 39426.347768	 time= 0.00093351	 cumTime= 0.197029	 edges= 1483	 schur= 0	 lambda= 252.047602	 levenbergIter= 2
# iteration= 239	 chi2= 39179.976320	 time= 0.00103704	 cumTime= 0.198066	 edges= 1483	 schur= 0	 lambda= 281.254299	 levenbergIter= 2
# iteration= 240	 chi2= 39170.069418	 time= 0.000647128	 cumTime= 0.198714	 edges= 1483	 schur= 0	 lambda= 187.502866	 levenbergIter= 1
# iteration= 241	 chi2= 38712.989103	 time= 0.000980493	 cumTime= 0.199694	 edges= 1483	 schur= 0	 lambda= 250.003821	 levenbergIter= 2
# iteration= 242	 chi2= 38472.323668	 time= 0.000939169	 cumTime= 0.200633	 edges= 1483	 schur= 0	 lambda= 278.746830	 levenbergIter= 2
# iteration= 243	 chi2= 38462.379812	 time= 0.000571458	 cumTime= 0.201205	 edges= 1483	 schur= 0	 lambda= 185.831220	 levenbergIter= 1
# iteration= 244	 chi2= 38015.464855	 time= 0.000945475	 cumTime= 0.20215	 edges= 1483	 schur= 0	 lambda= 247.774960	 levenbergIter= 2
# iteration= 245	 chi2= 37780.148174	 time= 0.000941572	 cumTime= 0.203092	 edges= 1483	 schur= 0	 lambda= 276.052447	 levenbergIter= 2
# iteration= 246	 chi2= 37770.135345	 time= 0.000561552	 cumTime= 0.203653	 edges= 1483	 schur= 0	 lambda= 184.034964	 levenbergIter= 1
# iteration= 247	 chi2= 37332.797398	 time= 0.000948033	 cumTime= 0.204601	 edges= 1483	 schur= 0	 lambda= 245.379953	 levenbergIter= 2
# iteration= 248	 chi2= 37102.509210	 time= 0.000933846	 cumTime= 0.205535	 edges= 1483	 schur= 0	 lambda= 273.180746	 levenbergIter= 2
# iteration= 249	 chi2= 37092.427412	 time= 0.000565998	 cumTime= 0.206101	 edges= 1483	 schur= 0	 lambda= 182.120497	 levenbergIter= 1
# iteration= 250	 chi2= 36664.100122	 time= 0.000942711	 cumTime= 0.207044	 edges= 1483	 schur= 0	 lambda= 242.827330	 levenbergIter= 2
# iteration= 251	 chi2= 36438.540428	 time= 0.000962421	 cumTime= 0.208006	 edges= 1483	 schur= 0	 lambda= 270.152833	 levenbergIter= 2
# iteration= 252	 chi2= 36428.363277	 time= 0.000566303	 cumTime= 0.208573	 edges= 1483	 schur= 0	 lambda= 180.101889	 levenbergIter= 1
# iteration= 253	 chi2= 36008.556513	 time= 0.000938306	 cumTime= 0.209511	 edges= 1483	 schur= 0	 lambda= 240.135851	 levenbergIter= 2
# iteration= 254	 chi2= 35787.459791	 time= 0.000947169	 cumTime= 0.210458	 edges= 1483	 schur= 0	 lambda= 266.983693	 levenbergIter= 2
# iteration= 255	 chi2= 35777.170294	 time= 0.000558601	 cumTime= 0.211017	 edges= 1483	 schur= 0	 lambda= 177.989129	 levenbergIter= 1
# iteration= 256	 chi2= 35365.432799	 time= 0.000935768	 cumTime= 0.211952	 edges= 1483	 schur= 0	 lambda= 237.318838	 levenbergIter= 2
# iteration= 257	 chi2= 35148.555517	 time= 0.000931582	 cumTime= 0.212884	 edges= 1483	 schur= 0	 lambda= 263.684152	 levenbergIter= 2
# iteration= 258	 chi2= 35138.149987	 time= 0.000560304	 cumTime= 0.213444	 edges= 1483	 schur= 0	 lambda= 175.789434	 levenbergIter= 1
# iteration= 259	 chi2= 34734.057835	 time= 0.000941596	 cumTime= 0.214386	 edges= 1483	 schur= 0	 lambda= 234.385912	 levenbergIter= 2
# iteration= 260	 chi2= 34521.172363	 time= 0.000943842	 cumTime= 0.21533	 edges= 1483	 schur= 0	 lambda= 260.273830	 levenbergIter= 2
# iteration= 261	 chi2= 34510.636113	 time= 0.000565215	 cumTime= 0.215895	 edges= 1483	 schur= 0	 lambda= 173.515887	 levenbergIter= 1
# iteration= 262	 chi2= 34113.815498	 time= 0.000933542	 cumTime= 0.216828	 edges= 1483	 schur= 0	 lambda= 231.354515	 levenbergIter= 2
# iteration= 263	 chi2= 33904.720946	 time= 0.000944469	 cumTime= 0.217773	 edges= 1483	 schur= 0	 lambda= 256.764531	 levenbergIter= 2
# iteration= 264	 chi2= 33894.043718	 time= 0.000560453	 cumTime= 0.218333	 edges= 1483	 schur= 0	 lambda= 171.176354	 levenbergIter= 1
# iteration= 265	 chi2= 33504.152286	 time= 0.000935842	 cumTime= 0.219269	 edges= 1483	 schur= 0	 lambda= 228.235138	 levenbergIter= 2
# iteration= 266	 chi2= 33298.662858	 time= 0.000941552	 cumTime= 0.220211	 edges= 1483	 schur= 0	 lambda= 253.169992	 levenbergIter= 2
# iteration= 267	 chi2= 33287.840438	 time= 0.00055927	 cumTime= 0.22077	 edges= 1483	 schur= 0	 lambda= 168.779995	 levenbergIter= 1
# iteration= 268	 chi2= 32904.563554	 time= 0.000947056	 cumTime= 0.221717	 edges= 1483	 schur= 0	 lambda= 225.039993	 levenbergIter= 2
# iteration= 269	 chi2= 32702.509062	 time= 0.000947179	 cumTime= 0.222664	 edges= 1483	 schur= 0	 lambda= 249.506390	 levenbergIter= 2
# iteration= 270	 chi2= 32691.530732	 time= 0.000578162	 cumTime= 0.223242	 edges= 1483	 schur= 0	 lambda= 166.337593	 levenbergIter= 1
# iteration= 271	 chi2= 32314.589662	 time= 0.000947517	 cumTime= 0.22419	 edges= 1483	 schur= 0	 lambda= 221.783457	 levenbergIter= 2
# iteration= 272	 chi2= 32115.821247	 time= 0.000939618	 cumTime= 0.22513	 edges= 1483	 schur= 0	 lambda= 245.787334	 levenbergIter= 2
# iteration= 273	 chi2= 32104.678735	 time= 0.000568949	 cumTime= 0.225699	 edges= 1483	 schur= 0	 lambda= 163.858223	 levenbergIter= 1
# iteration= 274	 chi2= 31733.825215	 time= 0.000945965	 cumTime= 0.226645	 edges= 1483	 schur= 0	 lambda= 218.477631	 levenbergIter= 2
# iteration= 275	 chi2= 31538.206108	 time= 0.000962936	 cumTime= 0.227607	 edges= 1483	 schur= 0	 lambda= 242.022549	 levenbergIter= 2
# iteration= 276	 chi2= 31526.899789	 time= 0.000565773	 cumTime= 0.228173	 edges= 1483	 schur= 0	 lambda= 161.348366	 levenbergIter= 1
# iteration= 277	 chi2= 31161.900581	 time= 0.00095427	 cumTime= 0.229127	 edges= 1483	 schur= 0	 lambda= 215.131154	 levenbergIter= 2
# iteration= 278	 chi2= 30969.305116	 time= 0.000958484	 cumTime= 0.230086	 edges= 1483	 schur= 0	 lambda= 238.226954	 levenbergIter= 2
# iteration= 279	 chi2= 30957.832568	 time= 0.000571982	 cumTime= 0.230658	 edges= 1483	 schur= 0	 lambda= 158.817969	 levenbergIter= 1
# iteration= 280	 chi2= 30598.483772	 time= 0.000934542	 cumTime= 0.231592	 edges= 1483	 schur= 0	 lambda= 211.757292	 levenbergIter= 2
# iteration= 281	 chi2= 30408.801539	 time= 0.000946489	 cumTime= 0.232539	 edges= 1483	 schur= 0	 lambda= 234.411709	 levenbergIter= 2
# iteration= 282	 chi2= 30397.161161	 time= 0.00057077	 cumTime= 0.23311	 edges= 1483	 schur= 0	 lambda= 156.274473	 levenbergIter= 1
# iteration= 283	 chi2= 30043.281683	 time= 0.000941172	 cumTime= 0.234051	 edges= 1483	 schur= 0	 lambda= 208.365964	 levenbergIter= 2
# iteration= 284	 chi2= 29856.413686	 time= 0.000941979	 cumTime= 0.234993	 edges= 1483	 schur= 0	 lambda= 230.589073	 levenbergIter= 2
# iteration= 285	 chi2= 29844.606714	 time= 0.000564181	 cumTime= 0.235557	 edges= 1483	 schur= 0	 lambda= 153.726048	 levenbergIter= 1
# iteration= 286	 chi2= 29496.035714	 time= 0.00094883	 cumTime= 0.236506	 edges= 1483	 schur= 0	 lambda= 204.968064	 levenbergIter= 2
# iteration= 287	 chi2= 29311.894712	 time= 0.000950653	 cumTime= 0.237457	 edges= 1483	 schur= 0	 lambda= 226.769735	 levenbergIter= 2
# iteration= 288	 chi2= 29299.928170	 time= 0.000589234	 cumTime= 0.238046	 edges= 1483	 schur= 0	 lambda= 151.179823	 levenbergIter= 1
# iteration= 289	 chi2= 28956.519063	 time= 0.000972033	 cumTime= 0.239018	 edges= 1483	 schur= 0	 lambda= 201.573097	 levenbergIter= 2
# iteration= 290	 chi2= 28775.029126	 time= 0.000971909	 cumTime= 0.23999	 edges= 1483	 schur= 0	 lambda= 222.965273	 levenbergIter= 2
# iteration= 291	 chi2= 28762.901159	 time= 0.000587054	 cumTime= 0.240577	 edges= 1483	 schur= 0	 lambda= 148.643515	 levenbergIter= 1
# iteration= 292	 chi2= 28424.538783	 time= 0.0009731	 cumTime= 0.24155	 edges= 1483	 schur= 0	 lambda= 198.191354	 levenbergIter= 2
# iteration= 293	 chi2= 28245.633438	 time= 0.000965693	 cumTime= 0.242516	 edges= 1483	 schur= 0	 lambda= 219.184329	 levenbergIter= 2
# iteration= 294	 chi2= 28233.354628	 time= 0.000561515	 cumTime= 0.243077	 edges= 1483	 schur= 0	 lambda= 146.122886	 levenbergIter= 1
# iteration= 295	 chi2= 27899.928473	 time= 0.000959401	 cumTime= 0.244037	 edges= 1483	 schur= 0	 lambda= 194.830514	 levenbergIter= 2
# iteration= 296	 chi2= 27723.550224	 time= 0.000979092	 cumTime= 0.245016	 edges= 1483	 schur= 0	 lambda= 215.438224	 levenbergIter= 2
# iteration= 297	 chi2= 27711.125781	 time= 0.000589562	 cumTime= 0.245605	 edges= 1483	 schur= 0	 lambda= 143.625482	 levenbergIter= 1
# iteration= 298	 chi2= 27382.551091	 time= 0.000966584	 cumTime= 0.246572	 edges= 1483	 schur= 0	 lambda= 191.500643	 levenbergIter= 2
# iteration= 299	 chi2= 27208.651542	 time= 0.000947114	 cumTime= 0.247519	 edges= 1483	 schur= 0	 lambda= 211.730990	 levenbergIter= 2
# iteration= 300	 chi2= 27196.104825	 time= 0.000666801	 cumTime= 0.248186	 edges= 1483	 schur= 0	 lambda= 141.153993	 levenbergIter= 1
# iteration= 301	 chi2= 26872.291681	 time= 0.0010335	 cumTime= 0.249219	 edges= 1483	 schur= 0	 lambda= 188.205325	 levenbergIter= 2
# iteration= 302	 chi2= 26700.827114	 time= 0.000995492	 cumTime= 0.250215	 edges= 1483	 schur= 0	 lambda= 208.079106	 levenbergIter= 2
# iteration= 303	 chi2= 26688.158415	 time= 0.000558992	 cumTime= 0.250774	 edges= 1483	 schur= 0	 lambda= 138.719404	 levenbergIter= 1
# iteration= 304	 chi2= 26369.060226	 time= 0.000945485	 cumTime= 0.251719	 edges= 1483	 schur= 0	 lambda= 184.959205	 levenbergIter= 2
# iteration= 305	 chi2= 26200.003824	 time= 0.000940707	 cumTime= 0.25266	 edges= 1483	 schur= 0	 lambda= 204.484213	 levenbergIter= 2
# iteration= 306	 chi2= 26187.237719	 time= 0.000587005	 cumTime= 0.253247	 edges= 1483	 schur= 0	 lambda= 136.322809	 levenbergIter= 1
# iteration= 307	 chi2= 25872.798703	 time= 0.000941995	 cumTime= 0.254189	 edges= 1483	 schur= 0	 lambda= 181.763745	 levenbergIter= 2
# iteration= 308	 chi2= 25706.123006	 time= 0.000954898	 cumTime= 0.255144	 edges= 1483	 schur= 0	 lambda= 200.957959	 levenbergIter= 2
# iteration= 309	 chi2= 25693.273190	 time= 0.000567445	 cumTime= 0.255711	 edges= 1483	 schur= 0	 lambda= 133.971973	 levenbergIter= 1
# iteration= 310	 chi2= 25383.463349	 time= 0.000948216	 cumTime= 0.256659	 edges= 1483	 schur= 0	 lambda= 178.629297	 levenbergIter= 2
# iteration= 311	 chi2= 25219.153496	 time= 0.000971678	 cumTime= 0.257631	 edges= 1483	 schur= 0	 lambda= 197.504483	 levenbergIter= 2
# iteration= 312	 chi2= 25206.247813	 time= 0.000560974	 cumTime= 0.258192	 edges= 1483	 schur= 0	 lambda= 131.669656	 levenbergIter= 1
# iteration= 313	 chi2= 24901.038970	 time= 0.000937363	 cumTime= 0.259129	 edges= 1483	 schur= 0	 lambda= 175.559541	 levenbergIter= 2
# iteration= 314	 chi2= 24739.082455	 time= 0.000946766	 cumTime= 0.260076	 edges= 1483	 schur= 0	 lambda= 194.135565	 levenbergIter= 2
# iteration= 315	 chi2= 24726.138277	 time= 0.000617681	 cumTime= 0.260694	 edges= 1483	 schur= 0	 lambda= 129.423710	 levenbergIter= 1
# iteration= 316	 chi2= 24425.527921	 time= 0.000946868	 cumTime= 0.261641	 edges= 1483	 schur= 0	 lambda= 172.564946	 levenbergIter= 2
# iteration= 317	 chi2= 24265.925928	 time= 0.000987048	 cumTime= 0.262628	 edges= 1483	 schur= 0	 lambda= 190.853970	 levenbergIter= 2
# iteration= 318	 chi2= 24252.980461	 time= 0.000654295	 cumTime= 0.263282	 edges= 1483	 schur= 0	 lambda= 127.235980	 levenbergIter= 1
# iteration= 319	 chi2= 23956.962109	 time= 0.000946941	 cumTime= 0.264229	 edges= 1483	 schur= 0	 lambda= 169.647974	 levenbergIter= 2
# iteration= 320	 chi2= 23799.716648	 time= 0.000987213	 cumTime= 0.265216	 edges= 1483	 schur= 0	 lambda= 187.671708	 levenbergIter= 2
# iteration= 321	 chi2= 23786.790580	 time= 0.000562661	 cumTime= 0.265779	 edges= 1483	 schur= 0	 lambda= 125.114472	 levenbergIter= 1
# iteration= 322	 chi2= 23495.390792	 time= 0.00094033	 cumTime= 0.266719	 edges= 1483	 schur= 0	 lambda= 166.819296	 levenbergIter= 2
# iteration= 323	 chi2= 23340.517990	 time= 0.000939785	 cumTime= 0.267659	 edges= 1483	 schur= 0	 lambda= 184.595480	 levenbergIter= 2
# iteration= 324	 chi2= 23327.644818	 time= 0.000576241	 cumTime= 0.268235	 edges= 1483	 schur= 0	 lambda= 123.063653	 levenbergIter= 1
# iteration= 325	 chi2= 23040.895598	 time= 0.000949105	 cumTime= 0.269184	 edges= 1483	 schur= 0	 lambda= 164.084871	 levenbergIter= 2
# iteration= 326	 chi2= 22888.418033	 time= 0.000947284	 cumTime= 0.270132	 edges= 1483	 schur= 0	 lambda= 181.633479	 levenbergIter= 2
# iteration= 327	 chi2= 22875.634827	 time= 0.000564062	 cumTime= 0.270696	 edges= 1483	 schur= 0	 lambda= 121.088986	 levenbergIter= 1
# iteration= 328	 chi2= 22593.583871	 time= 0.000945854	 cumTime= 0.271642	 edges= 1483	 schur= 0	 lambda= 161.451981	 levenbergIter= 2
# iteration= 329	 chi2= 22443.531971	 time= 0.000945247	 cumTime= 0.272587	 edges= 1483	 schur= 0	 lambda= 178.797557	 levenbergIter= 2
# iteration= 330	 chi2= 22430.870195	 time= 0.00056688	 cumTime= 0.273154	 edges= 1483	 schur= 0	 lambda= 119.198371	 levenbergIter= 1
# iteration= 331	 chi2= 22153.591493	 time= 0.000945109	 cumTime= 0.274099	 edges= 1483	 schur= 0	 lambda= 158.931162	 levenbergIter= 2
# iteration= 332	 chi2= 22006.009709	 time= 0.000944347	 cumTime= 0.275043	 edges= 1483	 schur= 0	 lambda= 176.097646	 levenbergIter= 2
# iteration= 333	 chi2= 21993.509101	 time= 0.000565989	 cumTime= 0.275609	 edges= 1483	 schur= 0	 lambda= 117.398431	 levenbergIter= 1
# iteration= 334	 chi2= 21721.093064	 time= 0.000950447	 cumTime= 0.27656	 edges= 1483	 schur= 0	 lambda= 156.531241	 levenbergIter= 2
# iteration= 335	 chi2= 21576.035205	 time= 0.000944875	 cumTime= 0.277504	 edges= 1483	 schur= 0	 lambda= 173.547833	 levenbergIter= 2
# iteration= 336	 chi2= 21563.733532	 time= 0.000558185	 cumTime= 0.278063	 edges= 1483	 schur= 0	 lambda= 115.698555	 levenbergIter= 1
# iteration= 337	 chi2= 21296.298383	 time= 0.000938998	 cumTime= 0.279002	 edges= 1483	 schur= 0	 lambda= 154.264740	 levenbergIter= 2
# iteration= 338	 chi2= 21153.833765	 time= 0.000954255	 cumTime= 0.279956	 edges= 1483	 schur= 0	 lambda= 171.162049	 levenbergIter= 2
# iteration= 339	 chi2= 21141.771138	 time= 0.000579684	 cumTime= 0.280536	 edges= 1483	 schur= 0	 lambda= 114.108033	 levenbergIter= 1
# iteration= 340	 chi2= 20879.461322	 time= 0.000941323	 cumTime= 0.281477	 edges= 1483	 schur= 0	 lambda= 152.144044	 levenbergIter= 2
# iteration= 341	 chi2= 20739.674188	 time= 0.000948929	 cumTime= 0.282426	 edges= 1483	 schur= 0	 lambda= 168.959540	 levenbergIter= 2
# iteration= 342	 chi2= 20727.884007	 time= 0.000566141	 cumTime= 0.282992	 edges= 1483	 schur= 0	 lambda= 112.639693	 levenbergIter= 1
# iteration= 343	 chi2= 20470.884103	 time= 0.00096222	 cumTime= 0.283954	 edges= 1483	 schur= 0	 lambda= 150.186258	 levenbergIter= 2
# iteration= 344	 chi2= 20333.877758	 time= 0.000948057	 cumTime= 0.284902	 edges= 1483	 schur= 0	 lambda= 166.956374	 levenbergIter= 2
# iteration= 345	 chi2= 20322.400145	 time= 0.000561829	 cumTime= 0.285464	 edges= 1483	 schur= 0	 lambda= 111.304250	 levenbergIter= 1
# iteration= 346	 chi2= 20070.920424	 time= 0.00106857	 cumTime= 0.286533	 edges= 1483	 schur= 0	 lambda= 148.405666	 levenbergIter= 2
# iteration= 347	 chi2= 19936.813293	 time= 0.000987698	 cumTime= 0.28752	 edges= 1483	 schur= 0	 lambda= 165.177112	 levenbergIter= 2
# iteration= 348	 chi2= 19925.674613	 time= 0.000614549	 cumTime= 0.288135	 edges= 1483	 schur= 0	 lambda= 110.118074	 levenbergIter= 1
# iteration= 349	 chi2= 19679.972524	 time= 0.000946419	 cumTime= 0.289081	 edges= 1483	 schur= 0	 lambda= 146.824099	 levenbergIter= 2
# iteration= 350	 chi2= 19548.907726	 time= 0.000944265	 cumTime= 0.290026	 edges= 1483	 schur= 0	 lambda= 163.641178	 levenbergIter= 2
# iteration= 351	 chi2= 19538.137431	 time= 0.000565815	 cumTime= 0.290591	 edges= 1483	 schur= 0	 lambda= 109.094119	 levenbergIter= 1
# iteration= 352	 chi2= 19298.499339	 time= 0.000956621	 cumTime= 0.291548	 edges= 1483	 schur= 0	 lambda= 145.458825	 levenbergIter= 2
# iteration= 353	 chi2= 19170.634612	 time= 0.000954395	 cumTime= 0.292502	 edges= 1483	 schur= 0	 lambda= 162.371825	 levenbergIter= 2
# ...
# iteration= 375	 chi2= 16827.184641	 time= 0.000579451	 cumTime= 0.310541	 edges= 1483	 schur= 0	 lambda= 107.652611	 levenbergIter= 1
# iteration= 376	 chi2= 16646.719460	 time= 0.000979642	 cumTime= 0.31152	 edges= 1483	 schur= 0	 lambda= 143.536815	 levenbergIter= 2
# iteration= 377	 chi2= 16550.345123	 time= 0.000936445	 cumTime= 0.312457	 edges= 1483	 schur= 0	 lambda= 162.163191	 levenbergIter= 2
# iteration= 378	 chi2= 16542.793945	 time= 0.000556035	 cumTime= 0.313013	 edges= 1483	 schur= 0	 lambda= 108.108794	 levenbergIter= 1
# iteration= 379	 chi2= 16370.141291	 time= 0.000945455	 cumTime= 0.313958	 edges= 1483	 schur= 0	 lambda= 144.145059	 levenbergIter= 2
# iteration= 380	 chi2= 16277.958242	 time= 0.000950314	 cumTime= 0.314909	 edges= 1483	 schur= 0	 lambda= 162.839606	 levenbergIter= 2
# iteration= 381	 chi2= 16270.682954	 time= 0.000655282	 cumTime= 0.315564	 edges= 1483	 schur= 0	 lambda= 108.559738	 levenbergIter= 1
# iteration= 382	 chi2= 16105.548642	 time= 0.000981294	 cumTime= 0.316545	 edges= 1483	 schur= 0	 lambda= 144.746317	 levenbergIter= 2
# iteration= 383	 chi2= 16017.407548	 time= 0.000978433	 cumTime= 0.317524	 edges= 1483	 schur= 0	 lambda= 163.410919	 levenbergIter= 2
# iteration= 384	 chi2= 16010.393643	 time= 0.000575233	 cumTime= 0.318099	 edges= 1483	 schur= 0	 lambda= 108.940612	 levenbergIter= 1
# iteration= 385	 chi2= 15852.372878	 time= 0.000945676	 cumTime= 0.319045	 edges= 1483	 schur= 0	 lambda= 145.254150	 levenbergIter= 2
# iteration= 386	 chi2= 15768.065264	 time= 0.000954517	 cumTime= 0.319999	 edges= 1483	 schur= 0	 lambda= 163.781568	 levenbergIter= 2
# iteration= 387	 chi2= 15761.296574	 time= 0.000564812	 cumTime= 0.320564	 edges= 1483	 schur= 0	 lambda= 109.187712	 levenbergIter= 1
# iteration= 388	 chi2= 15609.901785	 time= 0.000949215	 cumTime= 0.321513	 edges= 1483	 schur= 0	 lambda= 145.583616	 levenbergIter= 2
# iteration= 389	 chi2= 15529.172114	 time= 0.0009394	 cumTime= 0.322453	 edges= 1483	 schur= 0	 lambda= 163.865073	 levenbergIter= 2
# iteration= 390	 chi2= 15522.630550	 time= 0.000566047	 cumTime= 0.323019	 edges= 1483	 schur= 0	 lambda= 109.243382	 levenbergIter= 1
# iteration= 391	 chi2= 15377.318240	 time= 0.000958724	 cumTime= 0.323977	 edges= 1483	 schur= 0	 lambda= 145.657843	 levenbergIter= 2
# iteration= 392	 chi2= 15299.880188	 time= 0.000936091	 cumTime= 0.324913	 edges= 1483	 schur= 0	 lambda= 163.588409	 levenbergIter= 2
# iteration= 393	 chi2= 15293.544141	 time= 0.000561141	 cumTime= 0.325475	 edges= 1483	 schur= 0	 lambda= 109.058939	 levenbergIter= 1
# iteration= 394	 chi2= 15153.743797	 time= 0.000936937	 cumTime= 0.326412	 edges= 1483	 schur= 0	 lambda= 145.411919	 levenbergIter= 2
# iteration= 395	 chi2= 15079.294285	 time= 0.00093712	 cumTime= 0.327349	 edges= 1483	 schur= 0	 lambda= 162.895329	 levenbergIter= 2
# iteration= 396	 chi2= 15073.140310	 time= 0.000562961	 cumTime= 0.327912	 edges= 1483	 schur= 0	 lambda= 108.596886	 levenbergIter= 1
# iteration= 397	 chi2= 14938.274791	 time= 0.000951044	 cumTime= 0.328863	 edges= 1483	 schur= 0	 lambda= 144.795848	 levenbergIter= 2
# iteration= 398	 chi2= 14866.507000	 time= 0.000950035	 cumTime= 0.329813	 edges= 1483	 schur= 0	 lambda= 161.743221	 levenbergIter= 2
# iteration= 399	 chi2= 14860.509296	 time= 0.000578668	 cumTime= 0.330391	 edges= 1483	 schur= 0	 lambda= 107.828814	 levenbergIter= 1
# iteration= 400	 chi2= 14730.011572	 time= 0.000949883	 cumTime= 0.331341	 edges= 1483	 schur= 0	 lambda= 143.771752	 levenbergIter= 2
# iteration= 401	 chi2= 14660.622390	 time= 0.000935407	 cumTime= 0.332277	 edges= 1483	 schur= 0	 lambda= 160.107743	 levenbergIter= 2
# iteration= 402	 chi2= 14654.749882	 time= 0.000562817	 cumTime= 0.332839	 edges= 1483	 schur= 0	 lambda= 106.738496	 levenbergIter= 1
# iteration= 403	 chi2= 14528.077358	 time= 0.00095583	 cumTime= 0.333795	 edges= 1483	 schur= 0	 lambda= 142.317994	 levenbergIter= 2
# iteration= 404	 chi2= 14460.775491	 time= 0.000935359	 cumTime= 0.334731	 edges= 1483	 schur= 0	 lambda= 157.974864	 levenbergIter= 2
# iteration= 405	 chi2= 14454.997088	 time= 0.000565004	 cumTime= 0.335296	 edges= 1483	 schur= 0	 lambda= 105.316576	 levenbergIter= 1
# iteration= 406	 chi2= 14331.632253	 time= 0.00102366	 cumTime= 0.336319	 edges= 1483	 schur= 0	 lambda= 140.422101	 levenbergIter= 2
# iteration= 407	 chi2= 14266.139509	 time= 0.00103951	 cumTime= 0.337359	 edges= 1483	 schur= 0	 lambda= 155.343446	 levenbergIter= 2
# iteration= 408	 chi2= 14260.423232	 time= 0.000561803	 cumTime= 0.337921	 edges= 1483	 schur= 0	 lambda= 103.562297	 levenbergIter= 1
# iteration= 409	 chi2= 14139.876211	 time= 0.0009876	 cumTime= 0.338908	 edges= 1483	 schur= 0	 lambda= 138.083063	 levenbergIter= 2
# iteration= 410	 chi2= 14075.930248	 time= 0.000946078	 cumTime= 0.339854	 edges= 1483	 schur= 0	 lambda= 152.218698	 levenbergIter= 2
# iteration= 411	 chi2= 14070.244378	 time= 0.000559226	 cumTime= 0.340414	 edges= 1483	 schur= 0	 lambda= 101.479132	 levenbergIter= 1
# iteration= 412	 chi2= 13952.051817	 time= 0.000933172	 cumTime= 0.341347	 edges= 1483	 schur= 0	 lambda= 135.305509	 levenbergIter= 2
# iteration= 413	 chi2= 13889.403512	 time= 0.000934323	 cumTime= 0.342281	 edges= 1483	 schur= 0	 lambda= 148.617564	 levenbergIter= 2
# iteration= 414	 chi2= 13883.712889	 time= 0.000561057	 cumTime= 0.342842	 edges= 1483	 schur= 0	 lambda= 99.078376	 levenbergIter= 1
# iteration= 415	 chi2= 13767.439149	 time= 0.00094241	 cumTime= 0.343785	 edges= 1483	 schur= 0	 lambda= 132.104502	 levenbergIter= 2
# iteration= 416	 chi2= 13705.854727	 time= 0.000948762	 cumTime= 0.344733	 edges= 1483	 schur= 0	 lambda= 144.558361	 levenbergIter= 2
# iteration= 417	 chi2= 13700.126817	 time= 0.000567647	 cumTime= 0.345301	 edges= 1483	 schur= 0	 lambda= 96.372241	 levenbergIter= 1
# iteration= 418	 chi2= 13585.354544	 time= 0.000943229	 cumTime= 0.346244	 edges= 1483	 schur= 0	 lambda= 128.496321	 levenbergIter= 2
# iteration= 419	 chi2= 13524.610570	 time= 0.000935256	 cumTime= 0.347179	 edges= 1483	 schur= 0	 lambda= 140.070574	 levenbergIter= 2
# iteration= 420	 chi2= 13518.805840	 time= 0.000567838	 cumTime= 0.347747	 edges= 1483	 schur= 0	 lambda= 93.380383	 levenbergIter= 1
# iteration= 421	 chi2= 13405.142286	 time= 0.000982698	 cumTime= 0.34873	 edges= 1483	 schur= 0	 lambda= 124.507177	 levenbergIter= 2
# iteration= 422	 chi2= 13345.027602	 time= 0.000940553	 cumTime= 0.34967	 edges= 1483	 schur= 0	 lambda= 135.181431	 levenbergIter= 2
# iteration= 423	 chi2= 13339.111415	 time= 0.00056472	 cumTime= 0.350235	 edges= 1483	 schur= 0	 lambda= 90.120954	 levenbergIter= 1
# iteration= 424	 chi2= 13226.172320	 time= 0.00108088	 cumTime= 0.351316	 edges= 1483	 schur= 0	 lambda= 120.161272	 levenbergIter= 2
# iteration= 425	 chi2= 13166.481117	 time= 0.000990548	 cumTime= 0.352307	 edges= 1483	 schur= 0	 lambda= 129.928467	 levenbergIter= 2
# iteration= 426	 chi2= 13160.412402	 time= 0.000569128	 cumTime= 0.352876	 edges= 1483	 schur= 0	 lambda= 86.618978	 levenbergIter= 1
# iteration= 427	 chi2= 13047.828792	 time= 0.000944409	 cumTime= 0.35382	 edges= 1483	 schur= 0	 lambda= 115.491971	 levenbergIter= 2
# iteration= 428	 chi2= 12988.364003	 time= 0.000941969	 cumTime= 0.354762	 edges= 1483	 schur= 0	 lambda= 124.348527	 levenbergIter= 2
# iteration= 429	 chi2= 12982.101605	 time= 0.000570398	 cumTime= 0.355333	 edges= 1483	 schur= 0	 lambda= 82.899018	 levenbergIter= 1
# iteration= 430	 chi2= 12869.510839	 time= 0.000950285	 cumTime= 0.356283	 edges= 1483	 schur= 0	 lambda= 110.532024	 levenbergIter= 2
# iteration= 431	 chi2= 12868.540499	 time= 0.000570181	 cumTime= 0.356853	 edges= 1483	 schur= 0	 lambda= 73.688016	 levenbergIter= 1
# iteration= 432	 chi2= 12731.186491	 time= 0.000946205	 cumTime= 0.357799	 edges= 1483	 schur= 0	 lambda= 98.250688	 levenbergIter= 2
# iteration= 433	 chi2= 12662.031755	 time= 0.00094804	 cumTime= 0.358747	 edges= 1483	 schur= 0	 lambda= 116.641946	 levenbergIter= 2
# iteration= 434	 chi2= 12647.056953	 time= 0.000557636	 cumTime= 0.359305	 edges= 1483	 schur= 0	 lambda= 77.761297	 levenbergIter= 1
# iteration= 435	 chi2= 12540.410228	 time= 0.000963295	 cumTime= 0.360268	 edges= 1483	 schur= 0	 lambda= 103.681729	 levenbergIter= 2
# iteration= 436	 chi2= 12531.305800	 time= 0.000569163	 cumTime= 0.360837	 edges= 1483	 schur= 0	 lambda= 69.121153	 levenbergIter= 1
# iteration= 437	 chi2= 12403.208287	 time= 0.000934562	 cumTime= 0.361772	 edges= 1483	 schur= 0	 lambda= 92.161537	 levenbergIter= 2
# iteration= 438	 chi2= 12337.522984	 time= 0.000945714	 cumTime= 0.362718	 edges= 1483	 schur= 0	 lambda= 104.098318	 levenbergIter= 2
# iteration= 439	 chi2= 12324.801709	 time= 0.000567855	 cumTime= 0.363285	 edges= 1483	 schur= 0	 lambda= 69.398879	 levenbergIter= 1
# iteration= 440	 chi2= 12214.072385	 time= 0.000943766	 cumTime= 0.364229	 edges= 1483	 schur= 0	 lambda= 92.531838	 levenbergIter= 2
# iteration= 441	 chi2= 12204.040585	 time= 0.000565742	 cumTime= 0.364795	 edges= 1483	 schur= 0	 lambda= 61.687892	 levenbergIter= 1
# iteration= 442	 chi2= 12072.604621	 time= 0.000941932	 cumTime= 0.365737	 edges= 1483	 schur= 0	 lambda= 82.250523	 levenbergIter= 2
# iteration= 443	 chi2= 12005.343601	 time= 0.000938791	 cumTime= 0.366676	 edges= 1483	 schur= 0	 lambda= 92.244928	 levenbergIter= 2
# iteration= 444	 chi2= 11991.544524	 time= 0.00056674	 cumTime= 0.367242	 edges= 1483	 schur= 0	 lambda= 61.496619	 levenbergIter= 1
# iteration= 445	 chi2= 11877.956676	 time= 0.00095096	 cumTime= 0.368193	 edges= 1483	 schur= 0	 lambda= 81.995492	 levenbergIter= 2
# iteration= 446	 chi2= 11864.874075	 time= 0.000562443	 cumTime= 0.368756	 edges= 1483	 schur= 0	 lambda= 54.663661	 levenbergIter= 1
# iteration= 447	 chi2= 11731.884340	 time= 0.000941168	 cumTime= 0.369697	 edges= 1483	 schur= 0	 lambda= 72.884881	 levenbergIter= 2
# iteration= 448	 chi2= 11730.531668	 time= 0.000562565	 cumTime= 0.37026	 edges= 1483	 schur= 0	 lambda= 48.589921	 levenbergIter= 1
# iteration= 449	 chi2= 11575.369302	 time= 0.000945361	 cumTime= 0.371205	 edges= 1483	 schur= 0	 lambda= 64.786561	 levenbergIter= 2
# iteration= 450	 chi2= 11498.571012	 time= 0.000941665	 cumTime= 0.372147	 edges= 1483	 schur= 0	 lambda= 75.794127	 levenbergIter= 2
# iteration= 451	 chi2= 11478.739696	 time= 0.000560956	 cumTime= 0.372708	 edges= 1483	 schur= 0	 lambda= 50.529418	 levenbergIter= 1
# iteration= 452	 chi2= 11362.237436	 time= 0.000968567	 cumTime= 0.373676	 edges= 1483	 schur= 0	 lambda= 67.372558	 levenbergIter= 2
# iteration= 453	 chi2= 11342.064460	 time= 0.0005602	 cumTime= 0.374236	 edges= 1483	 schur= 0	 lambda= 44.915038	 levenbergIter= 1
# iteration= 454	 chi2= 11208.755745	 time= 0.00094048	 cumTime= 0.375177	 edges= 1483	 schur= 0	 lambda= 59.886718	 levenbergIter= 2
# iteration= 455	 chi2= 11196.689703	 time= 0.000562782	 cumTime= 0.37574	 edges= 1483	 schur= 0	 lambda= 39.924479	 levenbergIter= 1
# iteration= 456	 chi2= 11045.070146	 time= 0.000967068	 cumTime= 0.376707	 edges= 1483	 schur= 0	 lambda= 53.232638	 levenbergIter= 2
# iteration= 457	 chi2= 11041.501225	 time= 0.00056722	 cumTime= 0.377274	 edges= 1483	 schur= 0	 lambda= 35.488425	 levenbergIter= 1
# iteration= 458	 chi2= 10871.210465	 time= 0.000963358	 cumTime= 0.378237	 edges= 1483	 schur= 0	 lambda= 47.317900	 levenbergIter= 2
# iteration= 459	 chi2= 10787.560892	 time= 0.000988427	 cumTime= 0.379226	 edges= 1483	 schur= 0	 lambda= 54.625210	 levenbergIter= 2
# iteration= 460	 chi2= 10764.176347	 time= 0.000588264	 cumTime= 0.379814	 edges= 1483	 schur= 0	 lambda= 36.416807	 levenbergIter= 1
# iteration= 461	 chi2= 10638.113607	 time= 0.000959035	 cumTime= 0.380773	 edges= 1483	 schur= 0	 lambda= 48.555743	 levenbergIter= 2
# iteration= 462	 chi2= 10611.077126	 time= 0.000566189	 cumTime= 0.381339	 edges= 1483	 schur= 0	 lambda= 32.370495	 levenbergIter= 1
# iteration= 463	 chi2= 10471.022678	 time= 0.00093774	 cumTime= 0.382277	 edges= 1483	 schur= 0	 lambda= 43.160660	 levenbergIter= 2
# iteration= 464	 chi2= 10449.153648	 time= 0.000559658	 cumTime= 0.382837	 edges= 1483	 schur= 0	 lambda= 28.773773	 levenbergIter= 1
# iteration= 465	 chi2= 10295.132551	 time= 0.000948698	 cumTime= 0.383785	 edges= 1483	 schur= 0	 lambda= 38.365031	 levenbergIter= 2
# iteration= 466	 chi2= 10278.462793	 time= 0.000563697	 cumTime= 0.384349	 edges= 1483	 schur= 0	 lambda= 25.576687	 levenbergIter= 1
# iteration= 467	 chi2= 10111.224488	 time= 0.000948981	 cumTime= 0.385298	 edges= 1483	 schur= 0	 lambda= 34.102250	 levenbergIter= 2
# iteration= 468	 chi2= 10099.756145	 time= 0.000569256	 cumTime= 0.385867	 edges= 1483	 schur= 0	 lambda= 22.734833	 levenbergIter= 1
# iteration= 469	 chi2= 9920.346370	 time= 0.00102381	 cumTime= 0.386891	 edges= 1483	 schur= 0	 lambda= 30.313111	 levenbergIter= 2
# iteration= 470	 chi2= 9914.072063	 time= 0.000645833	 cumTime= 0.387537	 edges= 1483	 schur= 0	 lambda= 20.208741	 levenbergIter= 1
# iteration= 471	 chi2= 9723.831268	 time= 0.000989088	 cumTime= 0.388526	 edges= 1483	 schur= 0	 lambda= 26.944988	 levenbergIter= 2
# iteration= 472	 chi2= 9722.727253	 time= 0.000561749	 cumTime= 0.389088	 edges= 1483	 schur= 0	 lambda= 17.963325	 levenbergIter= 1
# iteration= 473	 chi2= 9523.272586	 time= 0.00096076	 cumTime= 0.390048	 edges= 1483	 schur= 0	 lambda= 23.951100	 levenbergIter= 2
# iteration= 474	 chi2= 9427.688169	 time= 0.000942219	 cumTime= 0.390991	 edges= 1483	 schur= 0	 lambda= 28.460125	 levenbergIter= 2
# iteration= 475	 chi2= 9396.928518	 time= 0.000559268	 cumTime= 0.39155	 edges= 1483	 schur= 0	 lambda= 18.973417	 levenbergIter= 1
# iteration= 476	 chi2= 9268.496871	 time= 0.000953098	 cumTime= 0.392503	 edges= 1483	 schur= 0	 lambda= 25.297889	 levenbergIter= 2
# iteration= 477	 chi2= 9234.345635	 time= 0.000562967	 cumTime= 0.393066	 edges= 1483	 schur= 0	 lambda= 16.865259	 levenbergIter= 1
# iteration= 478	 chi2= 9098.522837	 time= 0.000943794	 cumTime= 0.39401	 edges= 1483	 schur= 0	 lambda= 22.487012	 levenbergIter= 2
# iteration= 479	 chi2= 9068.745148	 time= 0.000571314	 cumTime= 0.394581	 edges= 1483	 schur= 0	 lambda= 14.991342	 levenbergIter= 1
# iteration= 480	 chi2= 8927.019317	 time= 0.000946965	 cumTime= 0.395528	 edges= 1483	 schur= 0	 lambda= 19.988455	 levenbergIter= 2
# iteration= 481	 chi2= 8902.268061	 time= 0.000565411	 cumTime= 0.396093	 edges= 1483	 schur= 0	 lambda= 13.325637	 levenbergIter= 1
# iteration= 482	 chi2= 8755.763264	 time= 0.000951779	 cumTime= 0.397045	 edges= 1483	 schur= 0	 lambda= 17.767516	 levenbergIter= 2
# iteration= 483	 chi2= 8736.406766	 time= 0.000576252	 cumTime= 0.397621	 edges= 1483	 schur= 0	 lambda= 11.845011	 levenbergIter= 1
# iteration= 484	 chi2= 8586.389681	 time= 0.000966167	 cumTime= 0.398588	 edges= 1483	 schur= 0	 lambda= 15.793348	 levenbergIter= 2
# iteration= 485	 chi2= 8572.336208	 time= 0.000608427	 cumTime= 0.399196	 edges= 1483	 schur= 0	 lambda= 10.528898	 levenbergIter= 1
# iteration= 486	 chi2= 8420.450593	 time= 0.00093828	 cumTime= 0.400134	 edges= 1483	 schur= 0	 lambda= 14.038531	 levenbergIter= 2
# iteration= 487	 chi2= 8411.174598	 time= 0.000652523	 cumTime= 0.400787	 edges= 1483	 schur= 0	 lambda= 9.359021	 levenbergIter= 1
# iteration= 488	 chi2= 8259.347580	 time= 0.00102413	 cumTime= 0.401811	 edges=
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 27
#      19     print(
#      20         f"id={vid:3d}: "
#      21         f"x={est.translation()[0]:.6f}, "
#      22         f"y={est.translation()[1]:.6f}, "
#      23         f"theta={est.rotation().angle():.6f}"
#      24     )
#      26 # 4) 以这些 VERTEX_SE2 为初始值跑 LM
# ---> 27 chi2_after = graph_slam.optimize(iterations=10000, verbose=True)
#      29 print("\n=== After optimization ===")
#      30 print("chi2 =", chi2_after)
#
# Cell In[1], line 69, in GraphSLAM2D.optimize(self, iterations, verbose)
#      67     verbose = self.verbose
#      68 self.optimizer.set_verbose(verbose)
# ---> 69 self.optimizer.optimize(iterations)
#      70 return self.optimizer.chi2()
#
# KeyboardInterrupt:

# %%
from g2o import SparseBlockMatrixX

vertices = graph_slam.optimizer.vertices()
print("len(vertices):", len(vertices))

cov_vertices = []
covariances = SparseBlockMatrixX()
for vertex_idx in vertices:
    v = vertices[vertex_idx]
    if type(v) == g2o.VertexSE2 and not v.fixed():
        cov_vertices.append((v.hessian_index(), v.hessian_index()))
print("Sparse pattern contains", len(cov_vertices), "blocks")
print(cov_vertices)
# Out:
# len(vertices): 6
# Sparse pattern contains 2 blocks
# [(3, 3), (1, 1)]

# %%
print("Computing covariance matrix...")
covariances, ok = graph_slam.optimizer.compute_marginals(cov_vertices)
print("Done, success =", ok)

print("rows:", covariances.rows())
print("cols:", covariances.cols())
# Out:
# Computing covariance matrix...
# Done, success = False
# rows: 0
# cols: 0

# %%
print("Covariance matrix:")
for vertex_idx in vertices:
    v = vertices[vertex_idx]
    if type(v) == g2o.VertexSE2 and not v.fixed():
        print(" Working on vertex idx:", vertex_idx)
        print("  Hessian idx is:", v.hessian_index())
        if covariances.rows() > v.hessian_index() and covariances.cols() > v.hessian_index():
            covariance = covariances.block(v.hessian_index(), v.hessian_index());
            print("  Covariance is:", covariance)
        else:
            print("  ERROR: The covariance matrix is not big enough. Something is wrong.")
# Out:
# Covariance matrix:
#  Working on vertex idx: 4
#   Hessian idx is: 3
#   ERROR: The covariance matrix is not big enough. Something is wrong.
#  Working on vertex idx: 2
#   Hessian idx is: 1
#   ERROR: The covariance matrix is not big enough. Something is wrong.

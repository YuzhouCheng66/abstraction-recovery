# %%
import numpy as np
from gbp.gbp import FactorGraph, VariableNode, Factor

# -----------------------
# SLAM-like base graph
# -----------------------
def make_slam_like_graph(N=100, step_size=25, loop_prob=0.05, loop_radius=50, prior_prop=0.0, rng=None,):
    nodes, edges = [], []
    positions = []
    x, y = 0.0, 0.0
    positions.append((x, y))
    for _ in range(1, int(N)):
        dx, dy = np.random.randn(2)
        norm = np.sqrt(dx**2 + dy**2) + 1e-6
        dx, dy = dx / norm * float(step_size), dy / norm * float(step_size)
        x, y = x + dx, y + dy
        positions.append((x, y))
    for i, (px, py) in enumerate(positions):
        nodes.append({
            "data": {"id": f"{i}", "layer": 0, "dim": 2},
            "position": {"x": float(px), "y": float(py)}
        })
    for i in range(int(N) - 1):
        edges.append({"data": {"source": f"{i}", "target": f"{i+1}"}})
    for i in range(int(N)):
        for j in range(i + 5, int(N)):
            if np.random.rand() < float(loop_prob):
                xi, yi = positions[i]; xj, yj = positions[j]
                if np.hypot(xi-xj, yi-yj) < float(loop_radius):
                    edges.append({"data": {"source": f"{i}", "target": f"{j}"}})

    # 确定强先验的节点集合
    if rng is None:
        rng = np.random.default_rng()

    if prior_prop <= 0.0:
        strong_ids = {0}
    elif prior_prop >= 1.0:
        strong_ids = set(range(N))
    else:
        k = max(1, int(np.floor(prior_prop * N)))
        strong_ids = set(rng.choice(N, size=k, replace=False).tolist())

    # 给 strong prior 节点加 edge
    for i in strong_ids:
        edges.append({
            "data": {"source": f"{i}", "target": "prior"}
        })


    return nodes, edges

# -----------------------
# GBP Graph 构建
# -----------------------
def build_noisy_pose_graph(
    nodes,
    edges,
    prior_sigma: float = 10,
    odom_sigma: float = 10,
    tiny_prior: float = 1e-10,
    rng=None,
):
    
    """
    构造二维 pose-only 因子图（线性，高斯），并注入噪声。
    参数:
      prior_sigma : 强先验的标准差（小=强）
      odom_sigma  : 里程计测量噪声标准差
      prior_prop  : 0.0=仅 anchor；(0,1)=按比例随机选；>=1.0=全体
      tiny_prior  : 所有节点默认加的极小先验，防止奇异
      seed        : 随机种子（可复现）
    """

    fg = FactorGraph(nonlinear_factors=False, eta_damping=0)

    var_nodes = []
    I2 = np.eye(2, dtype=float)
    N = len(nodes)

    # ---- 预生成噪声 ----
    prior_noises = {}
    odom_noises = {}

    if rng is None:
        rng = np.random.default_rng()

    # 为所有边生成噪声
    for e in edges:
        src = e["data"]["source"]; dst = e["data"]["target"]
        # 二元边
        if dst != "prior":
            odom_noises[(int(src[:]), int(dst[:]))] = rng.normal(0.0, odom_sigma, size=2)
        # 一元边（强先验）
        elif dst == "prior":
            prior_noises[int(src[:])] = rng.normal(0.0, prior_sigma, size=2)


    # ---- variable nodes ----
    for i, n in enumerate(nodes):
        v = VariableNode(i, dofs=2)
        v.GT = np.array([n["position"]["x"], n["position"]["y"]], dtype=float)

        # 极小先验
        v.prior.lam = tiny_prior * I2
        v.prior.eta = np.zeros(2, dtype=float)

        var_nodes.append(v)

    fg.var_nodes = var_nodes
    fg.n_var_nodes = len(var_nodes)


    # ---- prior factors ----
    def meas_fn_unary(x, *args):
        return x
    def jac_fn_unary(x, *args):
        return np.eye(2)
    # ---- odometry factors ----
    def meas_fn(xy, *args):
        return xy[2:] - xy[:2]
    def jac_fn(xy, *args):
        return np.array([[-1, 0, 1, 0],
                         [ 0,-1, 0, 1]], dtype=float)
    
    factors = []
    fid = 0

    for e in edges:
        src = e["data"]["source"]; dst = e["data"]["target"]
        if dst != "prior":
            i, j = int(src[:]), int(dst[:])
            vi, vj = var_nodes[i], var_nodes[j]

            meas = (vj.GT - vi.GT) + odom_noises[(i, j)]

            f = Factor(fid, [vi, vj], meas, odom_sigma, meas_fn, jac_fn)
            f.type = "base"
            linpoint = np.r_[vi.GT, vj.GT]
            f.compute_factor(linpoint=linpoint, update_self=True)

            factors.append(f)
            vi.adj_factors.append(f)
            vj.adj_factors.append(f)
            fid += 1

        else:
            i = int(src[:])
            vi = var_nodes[i]
            z = vi.GT + prior_noises[i]

            f = Factor(fid, [vi], z, prior_sigma, meas_fn_unary, jac_fn_unary)
            f.type = "prior"
            f.compute_factor(linpoint=z, update_self=True)

            factors.append(f)
            vi.adj_factors.append(f)
            fid += 1

    fg.factors = factors
    fg.n_factor_nodes = len(factors)
    return fg


# -----------------------
# 主程序：跑 100 次迭代
# -----------------------
if __name__ == "__main__":
    rng = np.random.default_rng(42)  # 固定随机种子

    # 1. 造一个图
    nodes, edges = make_slam_like_graph(N=50, step_size=25, loop_prob=0.1, loop_radius=50, prior_prop=0.1, rng=rng)

    # 2. 构建 GBP 图
    fg = build_noisy_pose_graph(nodes, edges, prior_sigma=10.0, odom_sigma=10.0, rng=rng)

    # 3. 跑迭代
    for it in range(1000):
        fg.synchronous_iteration()
        energy = fg.energy_map(include_priors=True, include_factors=True)
        print(f"Iter {it+1:03d} | Energy = {energy:.6f}")
# Out:
# Iter 001 | Energy = 2369.161048
# Iter 002 | Energy = 3986.615150
# Iter 003 | Energy = 3324.004533
# Iter 004 | Energy = 566.721129
# Iter 005 | Energy = 132.210661
# Iter 006 | Energy = 20.097019
# Iter 007 | Energy = 16.872097
# Iter 008 | Energy = 15.367758
# Iter 009 | Energy = 13.939157
# Iter 010 | Energy = 12.852675
# Iter 011 | Energy = 12.641398
# Iter 012 | Energy = 12.543380
# Iter 013 | Energy = 12.415041
# Iter 014 | Energy = 12.373256
# Iter 015 | Energy = 12.298882
# Iter 016 | Energy = 12.260500
# Iter 017 | Energy = 12.253695
# Iter 018 | Energy = 12.237201
# Iter 019 | Energy = 12.225076
# Iter 020 | Energy = 12.224447
# Iter 021 | Energy = 12.220110
# Iter 022 | Energy = 12.215296
# Iter 023 | Energy = 12.214032
# Iter 024 | Energy = 12.212595
# Iter 025 | Energy = 12.211027
# Iter 026 | Energy = 12.210319
# Iter 027 | Energy = 12.209609
# Iter 028 | Energy = 12.208938
# Iter 029 | Energy = 12.208613
# Iter 030 | Energy = 12.208311
# Iter 031 | Energy = 12.207961
# Iter 032 | Energy = 12.207747
# Iter 033 | Energy = 12.207592
# Iter 034 | Energy = 12.207440
# Iter 035 | Energy = 12.207327
# Iter 036 | Energy = 12.207239
# Iter 037 | Energy = 12.207164
# Iter 038 | Energy = 12.207105
# Iter 039 | Energy = 12.207060
# Iter 040 | Energy = 12.207020
# Iter 041 | Energy = 12.206988
# Iter 042 | Energy = 12.206963
# Iter 043 | Energy = 12.206942
# Iter 044 | Energy = 12.206925
# Iter 045 | Energy = 12.206911
# Iter 046 | Energy = 12.206900
# Iter 047 | Energy = 12.206891
# Iter 048 | Energy = 12.206884
# Iter 049 | Energy = 12.206878
# Iter 050 | Energy = 12.206873
# Iter 051 | Energy = 12.206869
# Iter 052 | Energy = 12.206866
# Iter 053 | Energy = 12.206863
# Iter 054 | Energy = 12.206861
# Iter 055 | Energy = 12.206859
# Iter 056 | Energy = 12.206857
# Iter 057 | Energy = 12.206856
# Iter 058 | Energy = 12.206855
# Iter 059 | Energy = 12.206855
# Iter 060 | Energy = 12.206854
# Iter 061 | Energy = 12.206853
# Iter 062 | Energy = 12.206853
# Iter 063 | Energy = 12.206853
# Iter 064 | Energy = 12.206852
# Iter 065 | Energy = 12.206852
# Iter 066 | Energy = 12.206852
# Iter 067 | Energy = 12.206852
# Iter 068 | Energy = 12.206852
# Iter 069 | Energy = 12.206852
# Iter 070 | Energy = 12.206852
# Iter 071 | Energy = 12.206851
# Iter 072 | Energy = 12.206851
# Iter 073 | Energy = 12.206851
# Iter 074 | Energy = 12.206851
# Iter 075 | Energy = 12.206851
# Iter 076 | Energy = 12.206851
# Iter 077 | Energy = 12.206851
# Iter 078 | Energy = 12.206851
# Iter 079 | Energy = 12.206851
# Iter 080 | Energy = 12.206851
# Iter 081 | Energy = 12.206851
# Iter 082 | Energy = 12.206851
# Iter 083 | Energy = 12.206851
# Iter 084 | Energy = 12.206851
# Iter 085 | Energy = 12.206851
# Iter 086 | Energy = 12.206851
# Iter 087 | Energy = 12.206851
# Iter 088 | Energy = 12.206851
# Iter 089 | Energy = 12.206851
# Iter 090 | Energy = 12.206851
# Iter 091 | Energy = 12.206851
# Iter 092 | Energy = 12.206851
# Iter 093 | Energy = 12.206851
# Iter 094 | Energy = 12.206851
# Iter 095 | Energy = 12.206851
# Iter 096 | Energy = 12.206851
# Iter 097 | Energy = 12.206851
# Iter 098 | Energy = 12.206851
# Iter 099 | Energy = 12.206851
# Iter 100 | Energy = 12.206851
# Iter 101 | Energy = 12.206851
# Iter 102 | Energy = 12.206851
# Iter 103 | Energy = 12.206851
# Iter 104 | Energy = 12.206851
# Iter 105 | Energy = 12.206851
# Iter 106 | Energy = 12.206851
# Iter 107 | Energy = 12.206851
# Iter 108 | Energy = 12.206851
# Iter 109 | Energy = 12.206851
# Iter 110 | Energy = 12.206851
# Iter 111 | Energy = 12.206851
# Iter 112 | Energy = 12.206851
# Iter 113 | Energy = 12.206851
# Iter 114 | Energy = 12.206851
# Iter 115 | Energy = 12.206851
# Iter 116 | Energy = 12.206851
# Iter 117 | Energy = 12.206851
# Iter 118 | Energy = 12.206851
# Iter 119 | Energy = 12.206851
# Iter 120 | Energy = 12.206851
# Iter 121 | Energy = 12.206851
# Iter 122 | Energy = 12.206851
# Iter 123 | Energy = 12.206851
# Iter 124 | Energy = 12.206851
# Iter 125 | Energy = 12.206851
# Iter 126 | Energy = 12.206851
# Iter 127 | Energy = 12.206851
# Iter 128 | Energy = 12.206851
# Iter 129 | Energy = 12.206851
# Iter 130 | Energy = 12.206851
# Iter 131 | Energy = 12.206851
# Iter 132 | Energy = 12.206851
# Iter 133 | Energy = 12.206851
# Iter 134 | Energy = 12.206851
# Iter 135 | Energy = 12.206851
# Iter 136 | Energy = 12.206851
# Iter 137 | Energy = 12.206851
# Iter 138 | Energy = 12.206851
# Iter 139 | Energy = 12.206851
# Iter 140 | Energy = 12.206851
# Iter 141 | Energy = 12.206851
# Iter 142 | Energy = 12.206851
# Iter 143 | Energy = 12.206851
# Iter 144 | Energy = 12.206851
# Iter 145 | Energy = 12.206851
# Iter 146 | Energy = 12.206851
# Iter 147 | Energy = 12.206851
# Iter 148 | Energy = 12.206851
# Iter 149 | Energy = 12.206851
# Iter 150 | Energy = 12.206851
# Iter 151 | Energy = 12.206851
# Iter 152 | Energy = 12.206851
# Iter 153 | Energy = 12.206851
# Iter 154 | Energy = 12.206851
# Iter 155 | Energy = 12.206851
# Iter 156 | Energy = 12.206851
# Iter 157 | Energy = 12.206851
# Iter 158 | Energy = 12.206851
# Iter 159 | Energy = 12.206851
# Iter 160 | Energy = 12.206851
# Iter 161 | Energy = 12.206851
# Iter 162 | Energy = 12.206851
# Iter 163 | Energy = 12.206851
# Iter 164 | Energy = 12.206851
# Iter 165 | Energy = 12.206851
# Iter 166 | Energy = 12.206851
# Iter 167 | Energy = 12.206851
# Iter 168 | Energy = 12.206851
# Iter 169 | Energy = 12.206851
# Iter 170 | Energy = 12.206851
# Iter 171 | Energy = 12.206851
# Iter 172 | Energy = 12.206851
# Iter 173 | Energy = 12.206851
# Iter 174 | Energy = 12.206851
# Iter 175 | Energy = 12.206851
# Iter 176 | Energy = 12.206851
# Iter 177 | Energy = 12.206851
# Iter 178 | Energy = 12.206851
# Iter 179 | Energy = 12.206851
# Iter 180 | Energy = 12.206851
# Iter 181 | Energy = 12.206851
# Iter 182 | Energy = 12.206851
# Iter 183 | Energy = 12.206851
# Iter 184 | Energy = 12.206851
# Iter 185 | Energy = 12.206851
# Iter 186 | Energy = 12.206851
# Iter 187 | Energy = 12.206851
# Iter 188 | Energy = 12.206851
# Iter 189 | Energy = 12.206851
# Iter 190 | Energy = 12.206851
# Iter 191 | Energy = 12.206851
# Iter 192 | Energy = 12.206851
# Iter 193 | Energy = 12.206851
# Iter 194 | Energy = 12.206851
# Iter 195 | Energy = 12.206851
# Iter 196 | Energy = 12.206851
# Iter 197 | Energy = 12.206851
# Iter 198 | Energy = 12.206851
# Iter 199 | Energy = 12.206851
# Iter 200 | Energy = 12.206851
# Iter 201 | Energy = 12.206851
# Iter 202 | Energy = 12.206851
# Iter 203 | Energy = 12.206851
# Iter 204 | Energy = 12.206851
# Iter 205 | Energy = 12.206851
# Iter 206 | Energy = 12.206851
# Iter 207 | Energy = 12.206851
# Iter 208 | Energy = 12.206851
# Iter 209 | Energy = 12.206851
# Iter 210 | Energy = 12.206851
# Iter 211 | Energy = 12.206851
# Iter 212 | Energy = 12.206851
# Iter 213 | Energy = 12.206851
# Iter 214 | Energy = 12.206851
# Iter 215 | Energy = 12.206851
# Iter 216 | Energy = 12.206851
# Iter 217 | Energy = 12.206851
# Iter 218 | Energy = 12.206851
# Iter 219 | Energy = 12.206851
# Iter 220 | Energy = 12.206851
# Iter 221 | Energy = 12.206851
# Iter 222 | Energy = 12.206851
# Iter 223 | Energy = 12.206851
# Iter 224 | Energy = 12.206851
# Iter 225 | Energy = 12.206851
# Iter 226 | Energy = 12.206851
# Iter 227 | Energy = 12.206851
# Iter 228 | Energy = 12.206851
# Iter 229 | Energy = 12.206851
# Iter 230 | Energy = 12.206851
# Iter 231 | Energy = 12.206851
# Iter 232 | Energy = 12.206851
# Iter 233 | Energy = 12.206851
# Iter 234 | Energy = 12.206851
# Iter 235 | Energy = 12.206851
# Iter 236 | Energy = 12.206851
# Iter 237 | Energy = 12.206851
# Iter 238 | Energy = 12.206851
# Iter 239 | Energy = 12.206851
# Iter 240 | Energy = 12.206851
# Iter 241 | Energy = 12.206851
# Iter 242 | Energy = 12.206851
# Iter 243 | Energy = 12.206851
# Iter 244 | Energy = 12.206851
# Iter 245 | Energy = 12.206851
# Iter 246 | Energy = 12.206851
# Iter 247 | Energy = 12.206851
# Iter 248 | Energy = 12.206851
# Iter 249 | Energy = 12.206851
# Iter 250 | Energy = 12.206851
# Iter 251 | Energy = 12.206851
# Iter 252 | Energy = 12.206851
# Iter 253 | Energy = 12.206851
# Iter 254 | Energy = 12.206851
# Iter 255 | Energy = 12.206851
# Iter 256 | Energy = 12.206851
# Iter 257 | Energy = 12.206851
# Iter 258 | Energy = 12.206851
# Iter 259 | Energy = 12.206851
# Iter 260 | Energy = 12.206851
# Iter 261 | Energy = 12.206851
# Iter 262 | Energy = 12.206851
# Iter 263 | Energy = 12.206851
# Iter 264 | Energy = 12.206851
# Iter 265 | Energy = 12.206851
# Iter 266 | Energy = 12.206851
# Iter 267 | Energy = 12.206851
# Iter 268 | Energy = 12.206851
# Iter 269 | Energy = 12.206851
# Iter 270 | Energy = 12.206851
# Iter 271 | Energy = 12.206851
# Iter 272 | Energy = 12.206851
# Iter 273 | Energy = 12.206851
# Iter 274 | Energy = 12.206851
# Iter 275 | Energy = 12.206851
# Iter 276 | Energy = 12.206851
# Iter 277 | Energy = 12.206851
# Iter 278 | Energy = 12.206851
# Iter 279 | Energy = 12.206851
# Iter 280 | Energy = 12.206851
# Iter 281 | Energy = 12.206851
# Iter 282 | Energy = 12.206851
# Iter 283 | Energy = 12.206851
# Iter 284 | Energy = 12.206851
# Iter 285 | Energy = 12.206851
# Iter 286 | Energy = 12.206851
# Iter 287 | Energy = 12.206851
# Iter 288 | Energy = 12.206851
# Iter 289 | Energy = 12.206851
# Iter 290 | Energy = 12.206851
# Iter 291 | Energy = 12.206851
# Iter 292 | Energy = 12.206851
# Iter 293 | Energy = 12.206851
# Iter 294 | Energy = 12.206851
# Iter 295 | Energy = 12.206851
# Iter 296 | Energy = 12.206851
# Iter 297 | Energy = 12.206851
# Iter 298 | Energy = 12.206851
# Iter 299 | Energy = 12.206851
# Iter 300 | Energy = 12.206851
# Iter 301 | Energy = 12.206851
# Iter 302 | Energy = 12.206851
# Iter 303 | Energy = 12.206851
# Iter 304 | Energy = 12.206851
# Iter 305 | Energy = 12.206851
# Iter 306 | Energy = 12.206851
# Iter 307 | Energy = 12.206851
# Iter 308 | Energy = 12.206851
# Iter 309 | Energy = 12.206851
# Iter 310 | Energy = 12.206851
# Iter 311 | Energy = 12.206851
# Iter 312 | Energy = 12.206851
# Iter 313 | Energy = 12.206851
# Iter 314 | Energy = 12.206851
# Iter 315 | Energy = 12.206851
# Iter 316 | Energy = 12.206851
# Iter 317 | Energy = 12.206851
# Iter 318 | Energy = 12.206851
# Iter 319 | Energy = 12.206851
# Iter 320 | Energy = 12.206851
# Iter 321 | Energy = 12.206851
# Iter 322 | Energy = 12.206851
# Iter 323 | Energy = 12.206851
# Iter 324 | Energy = 12.206851
# Iter 325 | Energy = 12.206851
# Iter 326 | Energy = 12.206851
# Iter 327 | Energy = 12.206851
# Iter 328 | Energy = 12.206851
# Iter 329 | Energy = 12.206851
# Iter 330 | Energy = 12.206851
# Iter 331 | Energy = 12.206851
# Iter 332 | Energy = 12.206851
# Iter 333 | Energy = 12.206851
# Iter 334 | Energy = 12.206851
# Iter 335 | Energy = 12.206851
# Iter 336 | Energy = 12.206851
# Iter 337 | Energy = 12.206851
# Iter 338 | Energy = 12.206851
# Iter 339 | Energy = 12.206851
# Iter 340 | Energy = 12.206851
# Iter 341 | Energy = 12.206851
# Iter 342 | Energy = 12.206851
# Iter 343 | Energy = 12.206851
# Iter 344 | Energy = 12.206851
# Iter 345 | Energy = 12.206851
# Iter 346 | Energy = 12.206851
# Iter 347 | Energy = 12.206851
# Iter 348 | Energy = 12.206851
# Iter 349 | Energy = 12.206851
# Iter 350 | Energy = 12.206851
# Iter 351 | Energy = 12.206851
# Iter 352 | Energy = 12.206851
# Iter 353 | Energy = 12.206851
# Iter 354 | Energy = 12.206851
# Iter 355 | Energy = 12.206851
# Iter 356 | Energy = 12.206851
# Iter 357 | Energy = 12.206851
# Iter 358 | Energy = 12.206851
# Iter 359 | Energy = 12.206851
# Iter 360 | Energy = 12.206851
# Iter 361 | Energy = 12.206851
# Iter 362 | Energy = 12.206851
# Iter 363 | Energy = 12.206851
# Iter 364 | Energy = 12.206851
# Iter 365 | Energy = 12.206851
# Iter 366 | Energy = 12.206851
# Iter 367 | Energy = 12.206851
# Iter 368 | Energy = 12.206851
# Iter 369 | Energy = 12.206851
# Iter 370 | Energy = 12.206851
# Iter 371 | Energy = 12.206851
# Iter 372 | Energy = 12.206851
# Iter 373 | Energy = 12.206851
# Iter 374 | Energy = 12.206851
# Iter 375 | Energy = 12.206851
# Iter 376 | Energy = 12.206851
# Iter 377 | Energy = 12.206851
# Iter 378 | Energy = 12.206851
# Iter 379 | Energy = 12.206851
# Iter 380 | Energy = 12.206851
# Iter 381 | Energy = 12.206851
# Iter 382 | Energy = 12.206851
# Iter 383 | Energy = 12.206851
# Iter 384 | Energy = 12.206851
# Iter 385 | Energy = 12.206851
# Iter 386 | Energy = 12.206851
# Iter 387 | Energy = 12.206851
# Iter 388 | Energy = 12.206851
# Iter 389 | Energy = 12.206851
# Iter 390 | Energy = 12.206851
# Iter 391 | Energy = 12.206851
# Iter 392 | Energy = 12.206851
# Iter 393 | Energy = 12.206851
# Iter 394 | Energy = 12.206851
# Iter 395 | Energy = 12.206851
# Iter 396 | Energy = 12.206851
# Iter 397 | Energy = 12.206851
# Iter 398 | Energy = 12.206851
# Iter 399 | Energy = 12.206851
# Iter 400 | Energy = 12.206851
# Iter 401 | Energy = 12.206851
# Iter 402 | Energy = 12.206851
# Iter 403 | Energy = 12.206851
# Iter 404 | Energy = 12.206851
# Iter 405 | Energy = 12.206851
# Iter 406 | Energy = 12.206851
# Iter 407 | Energy = 12.206851
# Iter 408 | Energy = 12.206851
# Iter 409 | Energy = 12.206851
# Iter 410 | Energy = 12.206851
# Iter 411 | Energy = 12.206851
# Iter 412 | Energy = 12.206851
# Iter 413 | Energy = 12.206851
# Iter 414 | Energy = 12.206851
# Iter 415 | Energy = 12.206851
# Iter 416 | Energy = 12.206851
# Iter 417 | Energy = 12.206851
# Iter 418 | Energy = 12.206851
# Iter 419 | Energy = 12.206851
# Iter 420 | Energy = 12.206851
# Iter 421 | Energy = 12.206851
# Iter 422 | Energy = 12.206851
# Iter 423 | Energy = 12.206851
# Iter 424 | Energy = 12.206851
# Iter 425 | Energy = 12.206851
# Iter 426 | Energy = 12.206851
# Iter 427 | Energy = 12.206851
# Iter 428 | Energy = 12.206851
# Iter 429 | Energy = 12.206851
# Iter 430 | Energy = 12.206851
# Iter 431 | Energy = 12.206851
# Iter 432 | Energy = 12.206851
# Iter 433 | Energy = 12.206851
# Iter 434 | Energy = 12.206851
# Iter 435 | Energy = 12.206851
# Iter 436 | Energy = 12.206851
# Iter 437 | Energy = 12.206851
# Iter 438 | Energy = 12.206851
# Iter 439 | Energy = 12.206851
# Iter 440 | Energy = 12.206851
# Iter 441 | Energy = 12.206851
# Iter 442 | Energy = 12.206851
# Iter 443 | Energy = 12.206851
# Iter 444 | Energy = 12.206851
# Iter 445 | Energy = 12.206851
# Iter 446 | Energy = 12.206851
# Iter 447 | Energy = 12.206851
# Iter 448 | Energy = 12.206851
# Iter 449 | Energy = 12.206851
# Iter 450 | Energy = 12.206851
# Iter 451 | Energy = 12.206851
# Iter 452 | Energy = 12.206851
# Iter 453 | Energy = 12.206851
# Iter 454 | Energy = 12.206851
# Iter 455 | Energy = 12.206851
# Iter 456 | Energy = 12.206851
# Iter 457 | Energy = 12.206851
# Iter 458 | Energy = 12.206851
# Iter 459 | Energy = 12.206851
# Iter 460 | Energy = 12.206851
# Iter 461 | Energy = 12.206851
# Iter 462 | Energy = 12.206851
# Iter 463 | Energy = 12.206851
# Iter 464 | Energy = 12.206851
# Iter 465 | Energy = 12.206851
# Iter 466 | Energy = 12.206851
# Iter 467 | Energy = 12.206851
# Iter 468 | Energy = 12.206851
# Iter 469 | Energy = 12.206851
# Iter 470 | Energy = 12.206851
# Iter 471 | Energy = 12.206851
# Iter 472 | Energy = 12.206851
# Iter 473 | Energy = 12.206851
# Iter 474 | Energy = 12.206851
# Iter 475 | Energy = 12.206851
# Iter 476 | Energy = 12.206851
# Iter 477 | Energy = 12.206851
# Iter 478 | Energy = 12.206851
# Iter 479 | Energy = 12.206851
# Iter 480 | Energy = 12.206851
# Iter 481 | Energy = 12.206851
# Iter 482 | Energy = 12.206851
# Iter 483 | Energy = 12.206851
# Iter 484 | Energy = 12.206851
# Iter 485 | Energy = 12.206851
# Iter 486 | Energy = 12.206851
# Iter 487 | Energy = 12.206851
# Iter 488 | Energy = 12.206851
# Iter 489 | Energy = 12.206851
# Iter 490 | Energy = 12.206851
# Iter 491 | Energy = 12.206851
# Iter 492 | Energy = 12.206851
# Iter 493 | Energy = 12.206851
# Iter 494 | Energy = 12.206851
# Iter 495 | Energy = 12.206851
# Iter 496 | Energy = 12.206851
# Iter 497 | Energy = 12.206851
# Iter 498 | Energy = 12.206851
# Iter 499 | Energy = 12.206851
# Iter 500 | Energy = 12.206851
# Iter 501 | Energy = 12.206851
# Iter 502 | Energy = 12.206851
# Iter 503 | Energy = 12.206851
# Iter 504 | Energy = 12.206851
# Iter 505 | Energy = 12.206851
# Iter 506 | Energy = 12.206851
# Iter 507 | Energy = 12.206851
# Iter 508 | Energy = 12.206851
# Iter 509 | Energy = 12.206851
# Iter 510 | Energy = 12.206851
# Iter 511 | Energy = 12.206851
# Iter 512 | Energy = 12.206851
# Iter 513 | Energy = 12.206851
# Iter 514 | Energy = 12.206851
# Iter 515 | Energy = 12.206851
# Iter 516 | Energy = 12.206851
# Iter 517 | Energy = 12.206851
# Iter 518 | Energy = 12.206851
# Iter 519 | Energy = 12.206851
# Iter 520 | Energy = 12.206851
# Iter 521 | Energy = 12.206851
# Iter 522 | Energy = 12.206851
# Iter 523 | Energy = 12.206851
# Iter 524 | Energy = 12.206851
# Iter 525 | Energy = 12.206851
# Iter 526 | Energy = 12.206851
# Iter 527 | Energy = 12.206851
# Iter 528 | Energy = 12.206851
# Iter 529 | Energy = 12.206851
# Iter 530 | Energy = 12.206851
# Iter 531 | Energy = 12.206851
# Iter 532 | Energy = 12.206851
# Iter 533 | Energy = 12.206851
# Iter 534 | Energy = 12.206851
# Iter 535 | Energy = 12.206851
# Iter 536 | Energy = 12.206851
# Iter 537 | Energy = 12.206851
# Iter 538 | Energy = 12.206851
# Iter 539 | Energy = 12.206851
# Iter 540 | Energy = 12.206851
# Iter 541 | Energy = 12.206851
# Iter 542 | Energy = 12.206851
# Iter 543 | Energy = 12.206851
# Iter 544 | Energy = 12.206851
# Iter 545 | Energy = 12.206851
# Iter 546 | Energy = 12.206851
# Iter 547 | Energy = 12.206851
# Iter 548 | Energy = 12.206851
# Iter 549 | Energy = 12.206851
# Iter 550 | Energy = 12.206851
# Iter 551 | Energy = 12.206851
# Iter 552 | Energy = 12.206851
# Iter 553 | Energy = 12.206851
# Iter 554 | Energy = 12.206851
# Iter 555 | Energy = 12.206851
# Iter 556 | Energy = 12.206851
# Iter 557 | Energy = 12.206851
# Iter 558 | Energy = 12.206851
# Iter 559 | Energy = 12.206851
# Iter 560 | Energy = 12.206851
# Iter 561 | Energy = 12.206851
# Iter 562 | Energy = 12.206851
# Iter 563 | Energy = 12.206851
# Iter 564 | Energy = 12.206851
# Iter 565 | Energy = 12.206851
# Iter 566 | Energy = 12.206851
# Iter 567 | Energy = 12.206851
# Iter 568 | Energy = 12.206851
# Iter 569 | Energy = 12.206851
# Iter 570 | Energy = 12.206851
# Iter 571 | Energy = 12.206851
# Iter 572 | Energy = 12.206851
# Iter 573 | Energy = 12.206851
# Iter 574 | Energy = 12.206851
# Iter 575 | Energy = 12.206851
# Iter 576 | Energy = 12.206851
# Iter 577 | Energy = 12.206851
# Iter 578 | Energy = 12.206851
# Iter 579 | Energy = 12.206851
# Iter 580 | Energy = 12.206851
# Iter 581 | Energy = 12.206851
# Iter 582 | Energy = 12.206851
# Iter 583 | Energy = 12.206851
# Iter 584 | Energy = 12.206851
# Iter 585 | Energy = 12.206851
# Iter 586 | Energy = 12.206851
# Iter 587 | Energy = 12.206851
# Iter 588 | Energy = 12.206851
# Iter 589 | Energy = 12.206851
# Iter 590 | Energy = 12.206851
# Iter 591 | Energy = 12.206851
# Iter 592 | Energy = 12.206851
# Iter 593 | Energy = 12.206851
# Iter 594 | Energy = 12.206851
# Iter 595 | Energy = 12.206851
# Iter 596 | Energy = 12.206851
# Iter 597 | Energy = 12.206851
# Iter 598 | Energy = 12.206851
# Iter 599 | Energy = 12.206851
# Iter 600 | Energy = 12.206851
# Iter 601 | Energy = 12.206851
# Iter 602 | Energy = 12.206851
# Iter 603 | Energy = 12.206851
# Iter 604 | Energy = 12.206851
# Iter 605 | Energy = 12.206851
# Iter 606 | Energy = 12.206851
# Iter 607 | Energy = 12.206851
# Iter 608 | Energy = 12.206851
# Iter 609 | Energy = 12.206851
# Iter 610 | Energy = 12.206851
# Iter 611 | Energy = 12.206851
# Iter 612 | Energy = 12.206851
# Iter 613 | Energy = 12.206851
# Iter 614 | Energy = 12.206851
# Iter 615 | Energy = 12.206851
# Iter 616 | Energy = 12.206851
# Iter 617 | Energy = 12.206851
# Iter 618 | Energy = 12.206851
# Iter 619 | Energy = 12.206851
# Iter 620 | Energy = 12.206851
# Iter 621 | Energy = 12.206851
# Iter 622 | Energy = 12.206851
# Iter 623 | Energy = 12.206851
# Iter 624 | Energy = 12.206851
# Iter 625 | Energy = 12.206851
# Iter 626 | Energy = 12.206851
# Iter 627 | Energy = 12.206851
# Iter 628 | Energy = 12.206851
# Iter 629 | Energy = 12.206851
# Iter 630 | Energy = 12.206851
# Iter 631 | Energy = 12.206851
# Iter 632 | Energy = 12.206851
# Iter 633 | Energy = 12.206851
# Iter 634 | Energy = 12.206851
# Iter 635 | Energy = 12.206851
# Iter 636 | Energy = 12.206851
# Iter 637 | Energy = 12.206851
# Iter 638 | Energy = 12.206851
# Iter 639 | Energy = 12.206851
# Iter 640 | Energy = 12.206851
# Iter 641 | Energy = 12.206851
# Iter 642 | Energy = 12.206851
# Iter 643 | Energy = 12.206851
# Iter 644 | Energy = 12.206851
# Iter 645 | Energy = 12.206851
# Iter 646 | Energy = 12.206851
# Iter 647 | Energy = 12.206851
# Iter 648 | Energy = 12.206851
# Iter 649 | Energy = 12.206851
# Iter 650 | Energy = 12.206851
# Iter 651 | Energy = 12.206851
# Iter 652 | Energy = 12.206851
# Iter 653 | Energy = 12.206851
# Iter 654 | Energy = 12.206851
# Iter 655 | Energy = 12.206851
# Iter 656 | Energy = 12.206851
# Iter 657 | Energy = 12.206851
# Iter 658 | Energy = 12.206851
# Iter 659 | Energy = 12.206851
# Iter 660 | Energy = 12.206851
# Iter 661 | Energy = 12.206851
# Iter 662 | Energy = 12.206851
# Iter 663 | Energy = 12.206851
# Iter 664 | Energy = 12.206851
# Iter 665 | Energy = 12.206851
# Iter 666 | Energy = 12.206851
# Iter 667 | Energy = 12.206851
# Iter 668 | Energy = 12.206851
# Iter 669 | Energy = 12.206851
# Iter 670 | Energy = 12.206851
# Iter 671 | Energy = 12.206851
# Iter 672 | Energy = 12.206851
# Iter 673 | Energy = 12.206851
# Iter 674 | Energy = 12.206851
# Iter 675 | Energy = 12.206851
# Iter 676 | Energy = 12.206851
# Iter 677 | Energy = 12.206851
# Iter 678 | Energy = 12.206851
# Iter 679 | Energy = 12.206851
# Iter 680 | Energy = 12.206851
# Iter 681 | Energy = 12.206851
# Iter 682 | Energy = 12.206851
# Iter 683 | Energy = 12.206851
# Iter 684 | Energy = 12.206851
# Iter 685 | Energy = 12.206851
# Iter 686 | Energy = 12.206851
# Iter 687 | Energy = 12.206851
# Iter 688 | Energy = 12.206851
# Iter 689 | Energy = 12.206851
# Iter 690 | Energy = 12.206851
# Iter 691 | Energy = 12.206851
# Iter 692 | Energy = 12.206851
# Iter 693 | Energy = 12.206851
# Iter 694 | Energy = 12.206851
# Iter 695 | Energy = 12.206851
# Iter 696 | Energy = 12.206851
# Iter 697 | Energy = 12.206851
# Iter 698 | Energy = 12.206851
# Iter 699 | Energy = 12.206851
# Iter 700 | Energy = 12.206851
# Iter 701 | Energy = 12.206851
# Iter 702 | Energy = 12.206851
# Iter 703 | Energy = 12.206851
# Iter 704 | Energy = 12.206851
# Iter 705 | Energy = 12.206851
# Iter 706 | Energy = 12.206851
# Iter 707 | Energy = 12.206851
# Iter 708 | Energy = 12.206851
# Iter 709 | Energy = 12.206851
# Iter 710 | Energy = 12.206851
# Iter 711 | Energy = 12.206851
# Iter 712 | Energy = 12.206851
# Iter 713 | Energy = 12.206851
# Iter 714 | Energy = 12.206851
# Iter 715 | Energy = 12.206851
# Iter 716 | Energy = 12.206851
# Iter 717 | Energy = 12.206851
# Iter 718 | Energy = 12.206851
# Iter 719 | Energy = 12.206851
# Iter 720 | Energy = 12.206851
# Iter 721 | Energy = 12.206851
# Iter 722 | Energy = 12.206851
# Iter 723 | Energy = 12.206851
# Iter 724 | Energy = 12.206851
# Iter 725 | Energy = 12.206851
# Iter 726 | Energy = 12.206851
# Iter 727 | Energy = 12.206851
# Iter 728 | Energy = 12.206851
# Iter 729 | Energy = 12.206851
# Iter 730 | Energy = 12.206851
# Iter 731 | Energy = 12.206851
# Iter 732 | Energy = 12.206851
# Iter 733 | Energy = 12.206851
# Iter 734 | Energy = 12.206851
# Iter 735 | Energy = 12.206851
# Iter 736 | Energy = 12.206851
# Iter 737 | Energy = 12.206851
# Iter 738 | Energy = 12.206851
# Iter 739 | Energy = 12.206851
# Iter 740 | Energy = 12.206851
# Iter 741 | Energy = 12.206851
# Iter 742 | Energy = 12.206851
# Iter 743 | Energy = 12.206851
# Iter 744 | Energy = 12.206851
# Iter 745 | Energy = 12.206851
# Iter 746 | Energy = 12.206851
# Iter 747 | Energy = 12.206851
# Iter 748 | Energy = 12.206851
# Iter 749 | Energy = 12.206851
# Iter 750 | Energy = 12.206851
# Iter 751 | Energy = 12.206851
# Iter 752 | Energy = 12.206851
# Iter 753 | Energy = 12.206851
# Iter 754 | Energy = 12.206851
# Iter 755 | Energy = 12.206851
# Iter 756 | Energy = 12.206851
# Iter 757 | Energy = 12.206851
# Iter 758 | Energy = 12.206851
# Iter 759 | Energy = 12.206851
# Iter 760 | Energy = 12.206851
# Iter 761 | Energy = 12.206851
# Iter 762 | Energy = 12.206851
# Iter 763 | Energy = 12.206851
# Iter 764 | Energy = 12.206851
# Iter 765 | Energy = 12.206851
# Iter 766 | Energy = 12.206851
# Iter 767 | Energy = 12.206851
# Iter 768 | Energy = 12.206851
# Iter 769 | Energy = 12.206851
# Iter 770 | Energy = 12.206851
# Iter 771 | Energy = 12.206851
# Iter 772 | Energy = 12.206851
# Iter 773 | Energy = 12.206851
# Iter 774 | Energy = 12.206851
# Iter 775 | Energy = 12.206851
# Iter 776 | Energy = 12.206851
# Iter 777 | Energy = 12.206851
# Iter 778 | Energy = 12.206851
# Iter 779 | Energy = 12.206851
# Iter 780 | Energy = 12.206851
# Iter 781 | Energy = 12.206851
# Iter 782 | Energy = 12.206851
# Iter 783 | Energy = 12.206851
# Iter 784 | Energy = 12.206851
# Iter 785 | Energy = 12.206851
# Iter 786 | Energy = 12.206851
# Iter 787 | Energy = 12.206851
# Iter 788 | Energy = 12.206851
# Iter 789 | Energy = 12.206851
# Iter 790 | Energy = 12.206851
# Iter 791 | Energy = 12.206851
# Iter 792 | Energy = 12.206851
# Iter 793 | Energy = 12.206851
# Iter 794 | Energy = 12.206851
# Iter 795 | Energy = 12.206851
# Iter 796 | Energy = 12.206851
# Iter 797 | Energy = 12.206851
# Iter 798 | Energy = 12.206851
# Iter 799 | Energy = 12.206851
# Iter 800 | Energy = 12.206851
# Iter 801 | Energy = 12.206851
# Iter 802 | Energy = 12.206851
# Iter 803 | Energy = 12.206851
# Iter 804 | Energy = 12.206851
# Iter 805 | Energy = 12.206851
# Iter 806 | Energy = 12.206851
# Iter 807 | Energy = 12.206851
# Iter 808 | Energy = 12.206851
# Iter 809 | Energy = 12.206851
# Iter 810 | Energy = 12.206851
# Iter 811 | Energy = 12.206851
# Iter 812 | Energy = 12.206851
# Iter 813 | Energy = 12.206851
# Iter 814 | Energy = 12.206851
# Iter 815 | Energy = 12.206851
# Iter 816 | Energy = 12.206851
# Iter 817 | Energy = 12.206851
# Iter 818 | Energy = 12.206851
# Iter 819 | Energy = 12.206851
# Iter 820 | Energy = 12.206851
# Iter 821 | Energy = 12.206851
# Iter 822 | Energy = 12.206851
# Iter 823 | Energy = 12.206851
# Iter 824 | Energy = 12.206851
# Iter 825 | Energy = 12.206851
# Iter 826 | Energy = 12.206851
# Iter 827 | Energy = 12.206851
# Iter 828 | Energy = 12.206851
# Iter 829 | Energy = 12.206851
# Iter 830 | Energy = 12.206851
# Iter 831 | Energy = 12.206851
# Iter 832 | Energy = 12.206851
# Iter 833 | Energy = 12.206851
# Iter 834 | Energy = 12.206851
# Iter 835 | Energy = 12.206851
# Iter 836 | Energy = 12.206851
# Iter 837 | Energy = 12.206851
# Iter 838 | Energy = 12.206851
# Iter 839 | Energy = 12.206851
# Iter 840 | Energy = 12.206851
# Iter 841 | Energy = 12.206851
# Iter 842 | Energy = 12.206851
# Iter 843 | Energy = 12.206851
# Iter 844 | Energy = 12.206851
# Iter 845 | Energy = 12.206851
# Iter 846 | Energy = 12.206851
# Iter 847 | Energy = 12.206851
# Iter 848 | Energy = 12.206851
# Iter 849 | Energy = 12.206851
# Iter 850 | Energy = 12.206851
# Iter 851 | Energy = 12.206851
# Iter 852 | Energy = 12.206851
# Iter 853 | Energy = 12.206851
# Iter 854 | Energy = 12.206851
# Iter 855 | Energy = 12.206851
# Iter 856 | Energy = 12.206851
# Iter 857 | Energy = 12.206851
# Iter 858 | Energy = 12.206851
# Iter 859 | Energy = 12.206851
# Iter 860 | Energy = 12.206851
# Iter 861 | Energy = 12.206851
# Iter 862 | Energy = 12.206851
# Iter 863 | Energy = 12.206851
# Iter 864 | Energy = 12.206851
# Iter 865 | Energy = 12.206851
# Iter 866 | Energy = 12.206851
# Iter 867 | Energy = 12.206851
# Iter 868 | Energy = 12.206851
# Iter 869 | Energy = 12.206851
# Iter 870 | Energy = 12.206851
# Iter 871 | Energy = 12.206851
# Iter 872 | Energy = 12.206851
# Iter 873 | Energy = 12.206851
# Iter 874 | Energy = 12.206851
# Iter 875 | Energy = 12.206851
# Iter 876 | Energy = 12.206851
# Iter 877 | Energy = 12.206851
# Iter 878 | Energy = 12.206851
# Iter 879 | Energy = 12.206851
# Iter 880 | Energy = 12.206851
# Iter 881 | Energy = 12.206851
# Iter 882 | Energy = 12.206851
# Iter 883 | Energy = 12.206851
# Iter 884 | Energy = 12.206851
# Iter 885 | Energy = 12.206851
# Iter 886 | Energy = 12.206851
# Iter 887 | Energy = 12.206851
# Iter 888 | Energy = 12.206851
# Iter 889 | Energy = 12.206851
# Iter 890 | Energy = 12.206851
# Iter 891 | Energy = 12.206851
# Iter 892 | Energy = 12.206851
# Iter 893 | Energy = 12.206851
# Iter 894 | Energy = 12.206851
# Iter 895 | Energy = 12.206851
# Iter 896 | Energy = 12.206851
# Iter 897 | Energy = 12.206851
# Iter 898 | Energy = 12.206851
# Iter 899 | Energy = 12.206851
# Iter 900 | Energy = 12.206851
# Iter 901 | Energy = 12.206851
# Iter 902 | Energy = 12.206851
# Iter 903 | Energy = 12.206851
# Iter 904 | Energy = 12.206851
# Iter 905 | Energy = 12.206851
# Iter 906 | Energy = 12.206851
# Iter 907 | Energy = 12.206851
# Iter 908 | Energy = 12.206851
# Iter 909 | Energy = 12.206851
# Iter 910 | Energy = 12.206851
# Iter 911 | Energy = 12.206851
# Iter 912 | Energy = 12.206851
# Iter 913 | Energy = 12.206851
# Iter 914 | Energy = 12.206851
# Iter 915 | Energy = 12.206851
# Iter 916 | Energy = 12.206851
# Iter 917 | Energy = 12.206851
# Iter 918 | Energy = 12.206851
# Iter 919 | Energy = 12.206851
# Iter 920 | Energy = 12.206851
# Iter 921 | Energy = 12.206851
# Iter 922 | Energy = 12.206851
# Iter 923 | Energy = 12.206851
# Iter 924 | Energy = 12.206851
# Iter 925 | Energy = 12.206851
# Iter 926 | Energy = 12.206851
# Iter 927 | Energy = 12.206851
# Iter 928 | Energy = 12.206851
# Iter 929 | Energy = 12.206851
# Iter 930 | Energy = 12.206851
# Iter 931 | Energy = 12.206851
# Iter 932 | Energy = 12.206851
# Iter 933 | Energy = 12.206851
# Iter 934 | Energy = 12.206851
# Iter 935 | Energy = 12.206851
# Iter 936 | Energy = 12.206851
# Iter 937 | Energy = 12.206851
# Iter 938 | Energy = 12.206851
# Iter 939 | Energy = 12.206851
# Iter 940 | Energy = 12.206851
# Iter 941 | Energy = 12.206851
# Iter 942 | Energy = 12.206851
# Iter 943 | Energy = 12.206851
# Iter 944 | Energy = 12.206851
# Iter 945 | Energy = 12.206851
# Iter 946 | Energy = 12.206851
# Iter 947 | Energy = 12.206851
# Iter 948 | Energy = 12.206851
# Iter 949 | Energy = 12.206851
# Iter 950 | Energy = 12.206851
# Iter 951 | Energy = 12.206851
# Iter 952 | Energy = 12.206851
# Iter 953 | Energy = 12.206851
# Iter 954 | Energy = 12.206851
# Iter 955 | Energy = 12.206851
# Iter 956 | Energy = 12.206851
# Iter 957 | Energy = 12.206851
# Iter 958 | Energy = 12.206851
# Iter 959 | Energy = 12.206851
# Iter 960 | Energy = 12.206851
# Iter 961 | Energy = 12.206851
# Iter 962 | Energy = 12.206851
# Iter 963 | Energy = 12.206851
# Iter 964 | Energy = 12.206851
# Iter 965 | Energy = 12.206851
# Iter 966 | Energy = 12.206851
# Iter 967 | Energy = 12.206851
# Iter 968 | Energy = 12.206851
# Iter 969 | Energy = 12.206851
# Iter 970 | Energy = 12.206851
# Iter 971 | Energy = 12.206851
# Iter 972 | Energy = 12.206851
# Iter 973 | Energy = 12.206851
# Iter 974 | Energy = 12.206851
# Iter 975 | Energy = 12.206851
# Iter 976 | Energy = 12.206851
# Iter 977 | Energy = 12.206851
# Iter 978 | Energy = 12.206851
# Iter 979 | Energy = 12.206851
# Iter 980 | Energy = 12.206851
# Iter 981 | Energy = 12.206851
# Iter 982 | Energy = 12.206851
# Iter 983 | Energy = 12.206851
# Iter 984 | Energy = 12.206851
# Iter 985 | Energy = 12.206851
# Iter 986 | Energy = 12.206851
# Iter 987 | Energy = 12.206851
# Iter 988 | Energy = 12.206851
# Iter 989 | Energy = 12.206851
# Iter 990 | Energy = 12.206851
# Iter 991 | Energy = 12.206851
# Iter 992 | Energy = 12.206851
# Iter 993 | Energy = 12.206851
# Iter 994 | Energy = 12.206851
# Iter 995 | Energy = 12.206851
# Iter 996 | Energy = 12.206851
# Iter 997 | Energy = 12.206851
# Iter 998 | Energy = 12.206851
# Iter 999 | Energy = 12.206851
# Iter 1000 | Energy = 12.206851

# %%
# -----------------------
# K-Means 聚合
# -----------------------
def fuse_to_super_knn(prev_nodes, prev_edges, k, layer_idx, max_iters=20, tol=1e-6, seed=0):
    positions = np.array([[n["position"]["x"], n["position"]["y"]] for n in prev_nodes], dtype=float)
    n = positions.shape[0]
    if k <= 0: k = 1
    k = min(k, n)
    rng = np.random.default_rng(seed)

    # k-means++ init
    centers = np.empty((k, 2), dtype=float)
    first = rng.integers(0, n)
    centers[0] = positions[first]
    closest_d2 = np.sum((positions - centers[0])**2, axis=1)
    for i in range(1, k):
        denom = float(closest_d2.sum()) + 1e-12
        probs = closest_d2 / denom
        idx = rng.choice(n, p=probs)
        centers[i] = positions[idx]
        d2_new = np.sum((positions - centers[i])**2, axis=1)
        closest_d2 = np.minimum(closest_d2, d2_new)

    # Lloyd iterations
    for _ in range(max_iters):
        d2 = ((positions[:, None, :] - centers[None, :, :]) ** 2).sum(axis=2)
        assign = np.argmin(d2, axis=1)
        moved = 0.0
        for ci in range(k):
            idxs = np.where(assign == ci)[0]
            if idxs.size == 0:
                far_idx = int(np.argmax(np.min(d2, axis=1)))
                new_c = positions[far_idx]
            else:
                new_c = positions[idxs].mean(axis=0)
            moved = max(moved, float(np.linalg.norm(new_c - centers[ci])))
            centers[ci] = new_c
        if moved < tol:
            break

    # final assign
    d2 = ((positions[:, None, :] - centers[None, :, :]) ** 2).sum(axis=2)
    assign = np.argmin(d2, axis=1)

    super_nodes, node_map = [], {}
    for ci in range(k):
        idxs = np.where(assign == ci)[0]
        if idxs.size == 0:
            continue
        pts = positions[idxs]
        mean_x, mean_y = pts.mean(axis=0)
        child_dims = [prev_nodes[i]["data"]["dim"] for i in idxs]
        dim_val = int(max(1, sum(child_dims)))
        nid = f"{ci}"
        super_nodes.append({
            "data": {"id": nid, "layer": layer_idx, "dim": dim_val},
            "position": {"x": float(mean_x), "y": float(mean_y)}
        })
        for i in idxs:
            node_map[prev_nodes[i]["data"]["id"]] = nid
    super_edges, seen = [], set()
    for e in prev_edges:
        u, v = e["data"]["source"], e["data"]["target"]
        if v != "prior":
            su, sv = node_map[u], node_map[v]
            if su != sv:
                eid = tuple(sorted((su, sv)))
                if eid not in seen:
                    super_edges.append({"data": {"source": su, "target": sv}})
                    seen.add(eid)
            elif su == sv:
                eid = tuple(sorted((su, su)))
                if eid not in seen:
                    super_edges.append({"data": {"source": su, "target": "prior"}})
                    seen.add(eid)

        elif v == "prior":
            eid = tuple(sorted((su, su)))
            if eid not in seen:
                super_edges.append({"data": {"source": su, "target": "prior"}})
                seen.add(eid)

    return super_nodes, super_edges, node_map

# %%
def build_super_graph(layers, prior_sigma=1.0, odom_sigma=1.0):
    """
    基于 layers[-2] 的 base graph, 和 layers[-1] 的 super 分组，构造 super graph。
    要求: layers[-2]["graph"] 已经是构建好的基图（含 unary/binary 因子）。
    layers[-1]["node_map"]: { base_node_id(str, 如 'b12') -> super_node_id(str) }
    """
    # ---------- 取出 base & super ----------
    base_graph = layers[-2]["graph"]
    super_nodes = layers[-1]["nodes"]
    super_edges = layers[-1]["edges"]
    node_map    = layers[-1]["node_map"]   # 'bN' -> 'sX_...'

    # base: id(int)->VariableNode，方便查 dofs 和 mu
    id2var = {vn.variableID: vn for vn in base_graph.var_nodes}

    # ---------- super_id -> [base_id(int)] ----------
    super_groups = {}
    for b_str, s_id in node_map.items():
        b_int = int(b_str)
        super_groups.setdefault(s_id, []).append(b_int)


    # ---------- 为每个 super 组建立 (start, dofs) 表 ----------
    # local_idx[sid][bid] = (start, dofs), total_dofs[sid] = sum(dofs)
    local_idx   = {}
    total_dofs  = {}
    for sid, group in super_groups.items():
        off = 0
        local_idx[sid] = {}
        for bid in group:
            d = id2var[bid].dofs
            local_idx[sid][bid] = (off, d)
            off += d
        total_dofs[sid] = off


    # ---------- 创建 super VariableNodes ----------
    fg = FactorGraph(nonlinear_factors=False, eta_damping=0)

    super_var_nodes = {}
    for i, sn in enumerate(super_nodes):
        sid = sn["data"]["id"]
        dofs = total_dofs.get(sid, 0)
        v = VariableNode(i, dofs=dofs)
        super_var_nodes[sid] = v
        fg.var_nodes.append(v)
    fg.n_var_nodes = len(fg.var_nodes)

    # ---------- 工具：拼接某组的 linpoint（用 base belief 均值） ----------
    def make_linpoint_for_group(sid):
        x = np.zeros(total_dofs[sid])
        for bid, (st, d) in local_idx[sid].items():
            mu = getattr(id2var[bid], "mu", None)
            if mu is None or len(mu) != d:
                mu = np.zeros(d)
            x[st:st+d] = mu
        return x

    # ---------- 3) super prior（组内 unary + 组内 binary） ----------
    def make_super_prior_factor(sid, base_factors):
        group = super_groups[sid]
        idx_map = local_idx[sid]
        ncols = total_dofs[sid]

        # 选出：所有变量都在组内的因子（unary 或 binary）
        in_group = []
        for f in base_factors:
            vids = [v.variableID for v in f.adj_var_nodes]
            if all(vid in group for vid in vids):
                in_group.append(f)

        def meas_fn_super_prior(x_super, *args):
            meas_fn = []
            for f in in_group:
                vids = [v.variableID for v in f.adj_var_nodes]
                # 拼本因子的局部 x
                x_loc_list = []
                for vid in vids:
                    st, d = idx_map[vid]
                    x_loc_list.append(x_super[st:st+d])
                x_loc = np.concatenate(x_loc_list) if x_loc_list else np.zeros(0)
                meas_fn.append(f.meas_fn(x_loc))
            return np.concatenate(meas_fn) if meas_fn else np.zeros(0)

        def jac_fn_super_prior(x_super, *args):
            Jrows = []
            for f in in_group:
                vids = [v.variableID for v in f.adj_var_nodes]
                # 构造本因子的局部 x，用于（潜在）非线性雅可比
                x_loc_list = []
                dims = []
                for vid in vids:
                    st, d = idx_map[vid]
                    dims.append(d)
                    x_loc_list.append(x_super[st:st+d])
                x_loc = np.concatenate(x_loc_list) if x_loc_list else np.zeros(0)

                Jloc = f.jac_fn(x_loc)
                # 将 Jloc 列块映射回 super 变量的列
                row = np.zeros((Jloc.shape[0], ncols))
                c0 = 0
                for vid, d in zip(vids, dims):
                    st, _ = idx_map[vid]
                    row[:, st:st+d] = Jloc[:, c0:c0+d]
                    c0 += d
                Jrows.append(row)
            return np.vstack(Jrows) if Jrows else np.zeros((0, ncols))

        # z_super：拼各 base 因子的 z
        z_list = [f.measurement for f in in_group]
        z_super = np.concatenate(z_list) if z_list else np.zeros(0)

        return meas_fn_super_prior, jac_fn_super_prior, z_super

    # 为每个 super node 加 prior 因子
    for sid in super_groups.keys():
        meas_fn, jac_fn, z = make_super_prior_factor(sid, base_graph.factors)
        f = Factor(len(fg.factors), [super_var_nodes[sid]], z, prior_sigma, meas_fn, jac_fn)
        f.type = "super_prior"
        lin0 = make_linpoint_for_group(sid)
        f.compute_factor(linpoint=lin0, update_self=True)
        fg.factors.append(f)
        super_var_nodes[sid].adj_factors.append(f)

    # ---------- 4) super between（只取跨组 binary） ----------
    def make_super_between_factor(sidA, sidB, base_factors):
        groupA, groupB = super_groups[sidA], super_groups[sidB]
        idxA, idxB = local_idx[sidA], local_idx[sidB]
        nA, nB = total_dofs[sidA], total_dofs[sidB]

        cross = []
        for f in base_factors:
            vids = [v.variableID for v in f.adj_var_nodes]
            if len(vids) != 2:
                continue
            i, j = vids
            # 恰有一端在 A，一端在 B
            if (i in groupA and j in groupB) or (i in groupB and j in groupA):
                cross.append(f)

        def meas_fn_super_between(xAB, *args):
            xA, xB = xAB[:nA], xAB[nA:]
            meas_fn = []
            for f in cross:
                i, j = [v.variableID for v in f.adj_var_nodes]
                if i in groupA:
                    si, di = idxA[i]
                    sj, dj = idxB[j]
                    xi = xA[si:si+di]
                    xj = xB[sj:sj+dj]
                else:
                    si, di = idxB[i]
                    sj, dj = idxA[j]
                    xi = xB[si:si+di]
                    xj = xA[sj:sj+dj]
                x_loc = np.concatenate([xi, xj])
                meas_fn.append(f.meas_fn(x_loc))
            return np.concatenate(meas_fn) if meas_fn else np.zeros(0)

        def jac_fn_super_between(xAB, *args):
            xA, xB = xAB[:nA], xAB[nA:]
            Jrows = []
            for f in cross:
                i, j = [v.variableID for v in f.adj_var_nodes]
                if i in groupA:
                    si, di = idxA[i]
                    sj, dj = idxB[j]
                    xi = xA[si:si+di]
                    xj = xB[sj:sj+dj]
                    left_start, right_start = si, nA + sj
                else:
                    si, di = idxB[i]
                    sj, dj = idxA[j]
                    xi = xB[si:si+di]
                    xj = xA[sj:sj+dj]
                    left_start, right_start = nA + si, sj
                x_loc = np.concatenate([xi, xj])
                Jloc = f.jac_fn(x_loc)

                row = np.zeros((Jloc.shape[0], nA + nB))
                row[:, left_start:left_start+di]   = Jloc[:, :di]
                row[:, right_start:right_start+dj] = Jloc[:, di:di+dj]
                Jrows.append(row)
            return np.vstack(Jrows) if Jrows else np.zeros((0, nA + nB))

        z_super = np.concatenate([f.measurement for f in cross]) if cross else np.zeros(0)
        return meas_fn_super_between, jac_fn_super_between, z_super

    for e in super_edges:
        u, v = e["data"]["source"], e["data"]["target"]
        if u == "prior" or v == "prior":
            continue
        if (u not in super_groups) or (v not in super_groups):
            continue
        meas_fn, jac_fn, z = make_super_between_factor(u, v, base_graph.factors)
        f = Factor(len(fg.factors), [super_var_nodes[u], super_var_nodes[v]], z, odom_sigma, meas_fn, jac_fn)
        f.type = "super_between"
        lin0 = np.concatenate([make_linpoint_for_group(u), make_linpoint_for_group(v)])
        f.compute_factor(linpoint=lin0, update_self=True)
        fg.factors.append(f)
        super_var_nodes[u].adj_factors.append(f)
        super_var_nodes[v].adj_factors.append(f)

    fg.n_factor_nodes = len(fg.factors)
    return fg

# %%
N=500 
step=25
prob=0.1
radius=50 
prior_prop=0.1
prior_sigma=10.0
odom_sigma=10.0
layers = []


# -----------------------
# 初始化 & 边界
# -----------------------
def init_layers(N=100, step_size=25, loop_prob=0.05, loop_radius=50, prior_prop=0.0):
    base_nodes, base_edges = make_slam_like_graph(N, step_size, loop_prob, loop_radius, prior_prop)
    return [{"name": "base", "nodes": base_nodes, "edges": base_edges}]

layers = init_layers(N=N, step_size=step, loop_prob=prob, loop_radius=radius, prior_prop=prior_prop)
pair_idx = 0



# 构建 GBP 图
gbp_graph = build_noisy_pose_graph(layers[0]["nodes"], layers[0]["edges"],
                                    prior_sigma=prior_sigma,
                                    odom_sigma=odom_sigma
                                    )
layers[0]["graph"] = gbp_graph
opts=[{"label":"base","value":"base"}]


last = layers[-1]
super_layer_idx = 1

super_nodes, super_edges, node_map = fuse_to_super_knn(last["nodes"], last["edges"], 100, super_layer_idx)
layers.append({"name":f"super{1}", "nodes":super_nodes, "edges":super_edges, "node_map":node_map})
layers[-1]["graph"] = build_super_graph(layers)
# Out:
# local_idx {'0': {425: (0, 2), 457: (2, 2), 460: (4, 2)}, '1': {1: (0, 2), 9: (2, 2), 10: (4, 2), 15: (6, 2), 42: (8, 2), 43: (10, 2), 44: (12, 2)}, '2': {98: (0, 2), 100: (2, 2), 101: (4, 2), 118: (6, 2), 121: (8, 2)}, '3': {22: (0, 2), 27: (2, 2), 29: (4, 2), 65: (6, 2), 70: (8, 2), 71: (10, 2), 75: (12, 2), 76: (14, 2)}, '4': {341: (0, 2), 347: (2, 2)}, '5': {470: (0, 2), 473: (2, 2), 475: (4, 2), 487: (6, 2), 489: (8, 2)}, '6': {210: (0, 2), 226: (2, 2), 229: (4, 2), 230: (6, 2), 231: (8, 2), 232: (10, 2)}, '7': {309: (0, 2), 311: (2, 2), 315: (4, 2), 316: (6, 2), 321: (8, 2), 324: (10, 2), 325: (12, 2), 327: (14, 2)}, '8': {237: (0, 2), 238: (2, 2), 239: (4, 2), 240: (6, 2), 241: (8, 2), 244: (10, 2), 245: (12, 2), 249: (14, 2), 250: (16, 2), 255: (18, 2), 256: (20, 2), 257: (22, 2)}, '9': {416: (0, 2), 417: (2, 2), 418: (4, 2)}, '10': {351: (0, 2), 352: (2, 2), 358: (4, 2), 361: (6, 2), 384: (8, 2), 386: (10, 2)}, '11': {3: (0, 2), 5: (2, 2), 6: (4, 2), 7: (6, 2), 8: (8, 2)}, '12': {300: (0, 2), 350: (2, 2), 363: (4, 2), 388: (6, 2)}, '13': {33: (0, 2), 34: (2, 2), 35: (4, 2)}, '14': {267: (0, 2), 278: (2, 2), 280: (4, 2)}, '15': {130: (0, 2), 132: (2, 2), 133: (4, 2), 135: (6, 2), 180: (8, 2)}, '16': {296: (0, 2), 332: (2, 2), 334: (4, 2), 335: (6, 2), 336: (8, 2), 338: (10, 2), 343: (12, 2), 344: (14, 2), 345: (16, 2), 396: (18, 2), 404: (20, 2), 407: (22, 2)}, '17': {137: (0, 2), 139: (2, 2), 176: (4, 2), 178: (6, 2), 179: (8, 2), 187: (10, 2), 188: (12, 2), 189: (14, 2), 190: (16, 2), 191: (18, 2), 192: (20, 2), 193: (22, 2), 194: (24, 2)}, '18': {153: (0, 2), 155: (2, 2)}, '19': {140: (0, 2), 150: (2, 2), 169: (4, 2), 171: (6, 2), 173: (8, 2), 174: (10, 2), 177: (12, 2)}, '20': {18: (0, 2), 19: (2, 2), 20: (4, 2)}, '21': {66: (0, 2), 77: (2, 2), 81: (4, 2), 90: (6, 2), 92: (8, 2)}, '22': {318: (0, 2), 331: (2, 2), 339: (4, 2), 349: (6, 2), 395: (8, 2), 406: (10, 2), 408: (12, 2)}, '23': {305: (0, 2)}, '24': {293: (0, 2), 295: (2, 2), 401: (4, 2)}, '25': {158: (0, 2), 159: (2, 2), 160: (4, 2), 161: (6, 2), 162: (8, 2), 163: (10, 2), 164: (12, 2), 165: (14, 2), 166: (16, 2)}, '26': {477: (0, 2), 492: (2, 2), 493: (4, 2), 494: (6, 2), 495: (8, 2), 497: (10, 2)}, '27': {483: (0, 2)}, '28': {360: (0, 2)}, '29': {310: (0, 2), 317: (2, 2), 319: (4, 2), 326: (6, 2), 328: (8, 2), 330: (10, 2), 393: (12, 2)}, '30': {299: (0, 2), 362: (2, 2), 364: (4, 2), 365: (6, 2), 409: (8, 2)}, '31': {181: (0, 2), 182: (2, 2), 183: (4, 2), 184: (6, 2), 185: (8, 2), 186: (10, 2)}, '32': {25: (0, 2), 37: (2, 2), 39: (4, 2), 61: (6, 2), 62: (8, 2), 73: (10, 2)}, '33': {374: (0, 2), 378: (2, 2), 379: (4, 2), 380: (6, 2), 422: (8, 2), 423: (10, 2)}, '34': {207: (0, 2), 220: (2, 2), 222: (4, 2), 235: (6, 2), 251: (8, 2), 254: (10, 2)}, '35': {119: (0, 2), 120: (2, 2), 122: (4, 2), 124: (6, 2), 126: (8, 2)}, '36': {212: (0, 2), 217: (2, 2), 224: (4, 2)}, '37': {432: (0, 2), 434: (2, 2), 442: (4, 2), 443: (6, 2)}, '38': {375: (0, 2), 458: (2, 2)}, '39': {131: (0, 2), 136: (2, 2), 138: (4, 2), 141: (6, 2), 142: (8, 2), 143: (10, 2), 172: (12, 2), 175: (14, 2)}, '40': {263: (0, 2), 264: (2, 2)}, '41': {112: (0, 2), 113: (2, 2), 114: (4, 2), 115: (6, 2), 116: (8, 2), 117: (10, 2)}, '42': {285: (0, 2), 286: (2, 2)}, '43': {144: (0, 2), 145: (2, 2), 146: (4, 2), 147: (6, 2), 148: (8, 2), 149: (10, 2), 167: (12, 2), 168: (14, 2), 170: (16, 2)}, '44': {195: (0, 2), 196: (2, 2), 197: (4, 2), 198: (6, 2), 199: (8, 2), 201: (10, 2), 202: (12, 2), 203: (14, 2), 204: (16, 2)}, '45': {447: (0, 2), 449: (2, 2), 451: (4, 2), 452: (6, 2), 453: (8, 2)}, '46': {85: (0, 2), 87: (2, 2), 89: (4, 2), 99: (6, 2)}, '47': {297: (0, 2), 298: (2, 2), 410: (4, 2)}, '48': {31: (0, 2), 32: (2, 2), 69: (4, 2), 106: (6, 2), 107: (8, 2), 109: (10, 2)}, '49': {428: (0, 2), 430: (2, 2), 437: (4, 2), 463: (6, 2)}, '50': {270: (0, 2), 274: (2, 2), 333: (4, 2), 397: (6, 2), 398: (8, 2), 403: (10, 2)}, '51': {91: (0, 2)}, '52': {431: (0, 2), 433: (2, 2), 438: (4, 2), 439: (6, 2), 441: ( ...

# %%
layers[-2]["graph"].n_var_nodes
# Out:
# 500

# %%
layers[-1]["graph"].n_var_nodes
# Out:
# 100

# %%
import numpy as np
from gbp.gbp import FactorGraph, VariableNode, Factor

# -----------------------
# SLAM-like base graph
# -----------------------
def make_slam_like_graph(N=100, step_size=25, loop_prob=0.05, loop_radius=50, prior_prop=0.0, rng=None,):
    nodes, edges = [], []
    positions = []
    x, y = 0.0, 0.0
    positions.append((x, y))
    for _ in range(1, int(N)):
        dx, dy = np.random.randn(2)
        norm = np.sqrt(dx**2 + dy**2) + 1e-6
        dx, dy = dx / norm * float(step_size), dy / norm * float(step_size)
        x, y = x + dx, y + dy
        positions.append((x, y))
    for i, (px, py) in enumerate(positions):
        nodes.append({
            "data": {"id": f"{i}", "layer": 0, "dim": 2},
            "position": {"x": float(px), "y": float(py)}
        })
    for i in range(int(N) - 1):
        edges.append({"data": {"source": f"{i}", "target": f"{i+1}"}})
    for i in range(int(N)):
        for j in range(i + 5, int(N)):
            if np.random.rand() < float(loop_prob):
                xi, yi = positions[i]; xj, yj = positions[j]
                if np.hypot(xi-xj, yi-yj) < float(loop_radius):
                    edges.append({"data": {"source": f"{i}", "target": f"{j}"}})

    # 确定强先验的节点集合
    if rng is None:
        rng = np.random.default_rng()

    if prior_prop <= 0.0:
        strong_ids = {0}
    elif prior_prop >= 1.0:
        strong_ids = set(range(N))
    else:
        k = max(1, int(np.floor(prior_prop * N)))
        strong_ids = set(rng.choice(N, size=k, replace=False).tolist())

    # 给 strong prior 节点加 edge
    for i in strong_ids:
        edges.append({
            "data": {"source": f"{i}", "target": "prior"}
        })


    return nodes, edges

# -----------------------
# GBP Graph 构建
# -----------------------
def build_noisy_pose_graph(
    nodes,
    edges,
    prior_sigma: float = 10,
    odom_sigma: float = 10,
    tiny_prior: float = 1e-10,
    rng=None,
):
    
    """
    构造二维 pose-only 因子图（线性，高斯），并注入噪声。
    参数:
      prior_sigma : 强先验的标准差（小=强）
      odom_sigma  : 里程计测量噪声标准差
      prior_prop  : 0.0=仅 anchor；(0,1)=按比例随机选；>=1.0=全体
      tiny_prior  : 所有节点默认加的极小先验，防止奇异
      seed        : 随机种子（可复现）
    """

    fg = FactorGraph(nonlinear_factors=False, eta_damping=0)

    var_nodes = []
    I2 = np.eye(2, dtype=float)
    N = len(nodes)

    # ---- 预生成噪声 ----
    prior_noises = {}
    odom_noises = {}

    if rng is None:
        rng = np.random.default_rng()

    # 为所有边生成噪声
    for e in edges:
        src = e["data"]["source"]; dst = e["data"]["target"]
        # 二元边
        if dst != "prior":
            odom_noises[(int(src[:]), int(dst[:]))] = rng.normal(0.0, odom_sigma, size=2)
        # 一元边（强先验）
        elif dst == "prior":
            prior_noises[int(src[:])] = rng.normal(0.0, prior_sigma, size=2)


    # ---- variable nodes ----
    for i, n in enumerate(nodes):
        v = VariableNode(i, dofs=2)
        v.GT = np.array([n["position"]["x"], n["position"]["y"]], dtype=float)

        # 极小先验
        v.prior.lam = tiny_prior * I2
        v.prior.eta = np.zeros(2, dtype=float)

        var_nodes.append(v)

    fg.var_nodes = var_nodes
    fg.n_var_nodes = len(var_nodes)


    # ---- prior factors ----
    def meas_fn_unary(x, *args):
        return x
    def jac_fn_unary(x, *args):
        return np.eye(2)
    # ---- odometry factors ----
    def meas_fn(xy, *args):
        return xy[2:] - xy[:2]
    def jac_fn(xy, *args):
        return np.array([[-1, 0, 1, 0],
                         [ 0,-1, 0, 1]], dtype=float)
    
    factors = []
    fid = 0

    for e in edges:
        src = e["data"]["source"]; dst = e["data"]["target"]
        if dst != "prior":
            i, j = int(src[:]), int(dst[:])
            vi, vj = var_nodes[i], var_nodes[j]

            meas = (vj.GT - vi.GT) + odom_noises[(i, j)]

            f = Factor(fid, [vi, vj], meas, odom_sigma, meas_fn, jac_fn)
            f.type = "base"
            linpoint = np.r_[vi.GT, vj.GT]
            f.compute_factor(linpoint=linpoint, update_self=True)

            factors.append(f)
            vi.adj_factors.append(f)
            vj.adj_factors.append(f)
            fid += 1

        else:
            i = int(src[:])
            vi = var_nodes[i]
            z = vi.GT + prior_noises[i]

            f = Factor(fid, [vi], z, prior_sigma, meas_fn_unary, jac_fn_unary)
            f.type = "prior"
            f.compute_factor(linpoint=z, update_self=True)

            factors.append(f)
            vi.adj_factors.append(f)
            fid += 1

    fg.factors = factors
    fg.n_factor_nodes = len(factors)
    return fg


# -----------------------
# 主程序：跑 100 次迭代
# -----------------------
if __name__ == "__main__":
    rng = np.random.default_rng(42)  # 固定随机种子

    # 1. 造一个图
    nodes, edges = make_slam_like_graph(N=50, step_size=25, loop_prob=0.1, loop_radius=50, prior_prop=0.01, rng=rng)

    # 2. 构建 GBP 图
    fg = build_noisy_pose_graph(nodes, edges, prior_sigma=1, odom_sigma=1, rng=rng)

    # 3. 跑迭代
    for it in range(1000):
        fg.synchronous_iteration()
        energy = fg.energy_map(include_priors=True, include_factors=True)
        print(f"Iter {it+1:03d} | Energy = {energy:.6f}")
# Out:
# Iter 001 | Energy = 189397.587819
# Iter 002 | Energy = 180825.842042
# Iter 003 | Energy = 172701.339265
# Iter 004 | Energy = 163923.905032
# Iter 005 | Energy = 156169.360553
# Iter 006 | Energy = 151191.240394
# Iter 007 | Energy = 148864.585251
# Iter 008 | Energy = 149348.943376
# Iter 009 | Energy = 151734.743664
# Iter 010 | Energy = 155366.770018
# Iter 011 | Energy = 160238.785396
# Iter 012 | Energy = 165510.843051
# Iter 013 | Energy = 170261.041356
# Iter 014 | Energy = 172644.566384
# Iter 015 | Energy = 171467.028123
# Iter 016 | Energy = 167878.609880
# Iter 017 | Energy = 162998.795829
# Iter 018 | Energy = 157644.239295
# Iter 019 | Energy = 152132.273612
# Iter 020 | Energy = 141052.100713
# Iter 021 | Energy = 124335.664539
# Iter 022 | Energy = 113060.300234
# Iter 023 | Energy = 101819.531403
# Iter 024 | Energy = 90583.550608
# Iter 025 | Energy = 79274.548001
# Iter 026 | Energy = 56817.577426
# Iter 027 | Energy = 34441.819793
# Iter 028 | Energy = 17645.576868
# Iter 029 | Energy = 6603.885158
# Iter 030 | Energy = 1094.963737
# Iter 031 | Energy = 1082.095895
# Iter 032 | Energy = 1089.798008
# Iter 033 | Energy = 1091.879890
# Iter 034 | Energy = 1099.834279
# Iter 035 | Energy = 1109.755321
# Iter 036 | Energy = 1118.703150
# Iter 037 | Energy = 1122.931064
# Iter 038 | Energy = 1130.174081
# Iter 039 | Energy = 1134.509031
# Iter 040 | Energy = 1137.291353
# Iter 041 | Energy = 1140.550388
# Iter 042 | Energy = 1142.081295
# Iter 043 | Energy = 1144.002833
# Iter 044 | Energy = 1145.286878
# Iter 045 | Energy = 1146.119326
# Iter 046 | Energy = 1145.735716
# Iter 047 | Energy = 1145.700085
# Iter 048 | Energy = 1144.845718
# Iter 049 | Energy = 1144.332188
# Iter 050 | Energy = 1143.024446
# Iter 051 | Energy = 1142.043833
# Iter 052 | Energy = 1140.796293
# Iter 053 | Energy = 1139.623355
# Iter 054 | Energy = 1138.156672
# Iter 055 | Energy = 1136.699582
# Iter 056 | Energy = 1135.098152
# Iter 057 | Energy = 1133.587467
# Iter 058 | Energy = 1131.994051
# Iter 059 | Energy = 1130.467569
# Iter 060 | Energy = 1128.862250
# Iter 061 | Energy = 1127.297489
# Iter 062 | Energy = 1125.677674
# Iter 063 | Energy = 1124.099911
# Iter 064 | Energy = 1122.454775
# Iter 065 | Energy = 1120.879096
# Iter 066 | Energy = 1119.256422
# Iter 067 | Energy = 1117.683773
# Iter 068 | Energy = 1116.081716
# Iter 069 | Energy = 1114.511817
# Iter 070 | Energy = 1112.916998
# Iter 071 | Energy = 1111.354481
# Iter 072 | Energy = 1109.771891
# Iter 073 | Energy = 1108.217756
# Iter 074 | Energy = 1106.651732
# Iter 075 | Energy = 1105.107632
# Iter 076 | Energy = 1103.556968
# Iter 077 | Energy = 1102.023518
# Iter 078 | Energy = 1100.484973
# Iter 079 | Energy = 1098.962796
# Iter 080 | Energy = 1097.437032
# Iter 081 | Energy = 1095.926364
# Iter 082 | Energy = 1094.414552
# Iter 083 | Energy = 1092.915534
# Iter 084 | Energy = 1091.416850
# Iter 085 | Energy = 1089.929467
# Iter 086 | Energy = 1088.443168
# Iter 087 | Energy = 1086.967444
# Iter 088 | Energy = 1085.493708
# Iter 089 | Energy = 1084.029666
# Iter 090 | Energy = 1082.568515
# Iter 091 | Energy = 1081.116095
# Iter 092 | Energy = 1079.667197
# Iter 093 | Energy = 1078.226399
# Iter 094 | Energy = 1076.789465
# Iter 095 | Energy = 1075.360228
# Iter 096 | Energy = 1073.935204
# Iter 097 | Energy = 1072.517460
# Iter 098 | Energy = 1071.104245
# Iter 099 | Energy = 1069.697928
# Iter 100 | Energy = 1068.296329
# Iter 101 | Energy = 1066.901366
# Iter 102 | Energy = 1065.511248
# Iter 103 | Energy = 1064.127550
# Iter 104 | Energy = 1062.748813
# Iter 105 | Energy = 1061.376292
# Iter 106 | Energy = 1060.008825
# Iter 107 | Energy = 1058.647395
# Iter 108 | Energy = 1057.291071
# Iter 109 | Energy = 1055.940642
# Iter 110 | Energy = 1054.595350
# Iter 111 | Energy = 1053.255830
# Iter 112 | Energy = 1051.921468
# Iter 113 | Energy = 1050.592766
# Iter 114 | Energy = 1049.269229
# Iter 115 | Energy = 1047.951252
# Iter 116 | Energy = 1046.638435
# Iter 117 | Energy = 1045.331091
# Iter 118 | Energy = 1044.028893
# Iter 119 | Energy = 1042.732090
# Iter 120 | Energy = 1041.440414
# Iter 121 | Energy = 1040.154059
# Iter 122 | Energy = 1038.872808
# Iter 123 | Energy = 1037.596810
# Iter 124 | Energy = 1036.325886
# Iter 125 | Energy = 1035.060154
# Iter 126 | Energy = 1033.799464
# Iter 127 | Energy = 1032.543906
# Iter 128 | Energy = 1031.293357
# Iter 129 | Energy = 1030.047884
# Iter 130 | Energy = 1028.807384
# Iter 131 | Energy = 1027.571906
# Iter 132 | Energy = 1026.341364
# Iter 133 | Energy = 1025.115794
# Iter 134 | Energy = 1023.895120
# Iter 135 | Energy = 1022.679368
# Iter 136 | Energy = 1021.468474
# Iter 137 | Energy = 1020.262453
# Iter 138 | Energy = 1019.061251
# Iter 139 | Energy = 1017.864876
# Iter 140 | Energy = 1016.673279
# Iter 141 | Energy = 1015.486464
# Iter 142 | Energy = 1014.304387
# Iter 143 | Energy = 1013.127046
# Iter 144 | Energy = 1011.954403
# Iter 145 | Energy = 1010.786453
# Iter 146 | Energy = 1009.623161
# Iter 147 | Energy = 1008.464519
# Iter 148 | Energy = 1007.310495
# Iter 149 | Energy = 1006.161078
# Iter 150 | Energy = 1005.016239
# Iter 151 | Energy = 1003.875966
# Iter 152 | Energy = 1002.740230
# Iter 153 | Energy = 1001.609020
# Iter 154 | Energy = 1000.482308
# Iter 155 | Energy = 999.360080
# Iter 156 | Energy = 998.242312
# Iter 157 | Energy = 997.128988
# Iter 158 | Energy = 996.020085
# Iter 159 | Energy = 994.915585
# Iter 160 | Energy = 993.815468
# Iter 161 | Energy = 992.719717
# Iter 162 | Energy = 991.628309
# Iter 163 | Energy = 990.541227
# Iter 164 | Energy = 989.458452
# Iter 165 | Energy = 988.379965
# Iter 166 | Energy = 987.305746
# Iter 167 | Energy = 986.235778
# Iter 168 | Energy = 985.170040
# Iter 169 | Energy = 984.108516
# Iter 170 | Energy = 983.051186
# Iter 171 | Energy = 981.998032
# Iter 172 | Energy = 980.949035
# Iter 173 | Energy = 979.904178
# Iter 174 | Energy = 978.863442
# Iter 175 | Energy = 977.826810
# Iter 176 | Energy = 976.794262
# Iter 177 | Energy = 975.765782
# Iter 178 | Energy = 974.741351
# Iter 179 | Energy = 973.720953
# Iter 180 | Energy = 972.704569
# Iter 181 | Energy = 971.692181
# Iter 182 | Energy = 970.683773
# Iter 183 | Energy = 969.679327
# Iter 184 | Energy = 968.678826
# Iter 185 | Energy = 967.682252
# Iter 186 | Energy = 966.689589
# Iter 187 | Energy = 965.700819
# Iter 188 | Energy = 964.715926
# Iter 189 | Energy = 963.734893
# Iter 190 | Energy = 962.757702
# Iter 191 | Energy = 961.784338
# Iter 192 | Energy = 960.814783
# Iter 193 | Energy = 959.849022
# Iter 194 | Energy = 958.887038
# Iter 195 | Energy = 957.928813
# Iter 196 | Energy = 956.974333
# Iter 197 | Energy = 956.023581
# Iter 198 | Energy = 955.076541
# Iter 199 | Energy = 954.133196
# Iter 200 | Energy = 953.193531
# Iter 201 | Energy = 952.257531
# Iter 202 | Energy = 951.325178
# Iter 203 | Energy = 950.396457
# Iter 204 | Energy = 949.471354
# Iter 205 | Energy = 948.549851
# Iter 206 | Energy = 947.631934
# Iter 207 | Energy = 946.717588
# Iter 208 | Energy = 945.806796
# Iter 209 | Energy = 944.899544
# Iter 210 | Energy = 943.995816
# Iter 211 | Energy = 943.095597
# Iter 212 | Energy = 942.198873
# Iter 213 | Energy = 941.305628
# Iter 214 | Energy = 940.415847
# Iter 215 | Energy = 939.529515
# Iter 216 | Energy = 938.646619
# Iter 217 | Energy = 937.767142
# Iter 218 | Energy = 936.891071
# Iter 219 | Energy = 936.018390
# Iter 220 | Energy = 935.149086
# Iter 221 | Energy = 934.283143
# Iter 222 | Energy = 933.420548
# Iter 223 | Energy = 932.561287
# Iter 224 | Energy = 931.705344
# Iter 225 | Energy = 930.852707
# Iter 226 | Energy = 930.003360
# Iter 227 | Energy = 929.157290
# Iter 228 | Energy = 928.314482
# Iter 229 | Energy = 927.474924
# Iter 230 | Energy = 926.638601
# Iter 231 | Energy = 925.805500
# Iter 232 | Energy = 924.975606
# Iter 233 | Energy = 924.148907
# Iter 234 | Energy = 923.325388
# Iter 235 | Energy = 922.505036
# Iter 236 | Energy = 921.687838
# Iter 237 | Energy = 920.873780
# Iter 238 | Energy = 920.062849
# Iter 239 | Energy = 919.255032
# Iter 240 | Energy = 918.450316
# Iter 241 | Energy = 917.648687
# Iter 242 | Energy = 916.850133
# Iter 243 | Energy = 916.054641
# Iter 244 | Energy = 915.262197
# Iter 245 | Energy = 914.472788
# Iter 246 | Energy = 913.686403
# Iter 247 | Energy = 912.903028
# Iter 248 | Energy = 912.122651
# Iter 249 | Energy = 911.345258
# Iter 250 | Energy = 910.570838
# Iter 251 | Energy = 909.799378
# Iter 252 | Energy = 909.030865
# Iter 253 | Energy = 908.265288
# Iter 254 | Energy = 907.502633
# Iter 255 | Energy = 906.742888
# Iter 256 | Energy = 905.986042
# Iter 257 | Energy = 905.232082
# Iter 258 | Energy = 904.480996
# Iter 259 | Energy = 903.732773
# Iter 260 | Energy = 902.987399
# Iter 261 | Energy = 902.244863
# Iter 262 | Energy = 901.505154
# Iter 263 | Energy = 900.768259
# Iter 264 | Energy = 900.034166
# Iter 265 | Energy = 899.302865
# Iter 266 | Energy = 898.574343
# Iter 267 | Energy = 897.848589
# Iter 268 | Energy = 897.125591
# Iter 269 | Energy = 896.405338
# Iter 270 | Energy = 895.687818
# Iter 271 | Energy = 894.973021
# Iter 272 | Energy = 894.260933
# Iter 273 | Energy = 893.551545
# Iter 274 | Energy = 892.844846
# Iter 275 | Energy = 892.140823
# Iter 276 | Energy = 891.439466
# Iter 277 | Energy = 890.740764
# Iter 278 | Energy = 890.044706
# Iter 279 | Energy = 889.351281
# Iter 280 | Energy = 888.660477
# Iter 281 | Energy = 887.972285
# Iter 282 | Energy = 887.286693
# Iter 283 | Energy = 886.603690
# Iter 284 | Energy = 885.923266
# Iter 285 | Energy = 885.245411
# Iter 286 | Energy = 884.570113
# Iter 287 | Energy = 883.897362
# Iter 288 | Energy = 883.227147
# Iter 289 | Energy = 882.559459
# Iter 290 | Energy = 881.894286
# Iter 291 | Energy = 881.231618
# Iter 292 | Energy = 880.571445
# Iter 293 | Energy = 879.913757
# Iter 294 | Energy = 879.258544
# Iter 295 | Energy = 878.605794
# Iter 296 | Energy = 877.955499
# Iter 297 | Energy = 877.307648
# Iter 298 | Energy = 876.662231
# Iter 299 | Energy = 876.019238
# Iter 300 | Energy = 875.378659
# Iter 301 | Energy = 874.740484
# Iter 302 | Energy = 874.104703
# Iter 303 | Energy = 873.471308
# Iter 304 | Energy = 872.840286
# Iter 305 | Energy = 872.211630
# Iter 306 | Energy = 871.585330
# Iter 307 | Energy = 870.961375
# Iter 308 | Energy = 870.339756
# Iter 309 | Energy = 869.720464
# Iter 310 | Energy = 869.103489
# Iter 311 | Energy = 868.488822
# Iter 312 | Energy = 867.876453
# Iter 313 | Energy = 867.266373
# Iter 314 | Energy = 866.658572
# Iter 315 | Energy = 866.053042
# Iter 316 | Energy = 865.449773
# Iter 317 | Energy = 864.848756
# Iter 318 | Energy = 864.249981
# Iter 319 | Energy = 863.653440
# Iter 320 | Energy = 863.059124
# Iter 321 | Energy = 862.467023
# Iter 322 | Energy = 861.877128
# Iter 323 | Energy = 861.289431
# Iter 324 | Energy = 860.703923
# Iter 325 | Energy = 860.120595
# Iter 326 | Energy = 859.539437
# Iter 327 | Energy = 858.960442
# Iter 328 | Energy = 858.383600
# Iter 329 | Energy = 857.808902
# Iter 330 | Energy = 857.236341
# Iter 331 | Energy = 856.665907
# Iter 332 | Energy = 856.097592
# Iter 333 | Energy = 855.531387
# Iter 334 | Energy = 854.967284
# Iter 335 | Energy = 854.405274
# Iter 336 | Energy = 853.845349
# Iter 337 | Energy = 853.287500
# Iter 338 | Energy = 852.731719
# Iter 339 | Energy = 852.177998
# Iter 340 | Energy = 851.626329
# Iter 341 | Energy = 851.076703
# Iter 342 | Energy = 850.529111
# Iter 343 | Energy = 849.983547
# Iter 344 | Energy = 849.440001
# Iter 345 | Energy = 848.898465
# Iter 346 | Energy = 848.358932
# Iter 347 | Energy = 847.821394
# Iter 348 | Energy = 847.285842
# Iter 349 | Energy = 846.752268
# Iter 350 | Energy = 846.220665
# Iter 351 | Energy = 845.691025
# Iter 352 | Energy = 845.163339
# Iter 353 | Energy = 844.637600
# Iter 354 | Energy = 844.113801
# Iter 355 | Energy = 843.591933
# Iter 356 | Energy = 843.071989
# Iter 357 | Energy = 842.553961
# Iter 358 | Energy = 842.037841
# Iter 359 | Energy = 841.523622
# Iter 360 | Energy = 841.011297
# Iter 361 | Energy = 840.500857
# Iter 362 | Energy = 839.992295
# Iter 363 | Energy = 839.485604
# Iter 364 | Energy = 838.980776
# Iter 365 | Energy = 838.477804
# Iter 366 | Energy = 837.976680
# Iter 367 | Energy = 837.477398
# Iter 368 | Energy = 836.979949
# Iter 369 | Energy = 836.484327
# Iter 370 | Energy = 835.990524
# Iter 371 | Energy = 835.498533
# Iter 372 | Energy = 835.008347
# Iter 373 | Energy = 834.519959
# Iter 374 | Energy = 834.033361
# Iter 375 | Energy = 833.548546
# Iter 376 | Energy = 833.065509
# Iter 377 | Energy = 832.584240
# Iter 378 | Energy = 832.104734
# Iter 379 | Energy = 831.626983
# Iter 380 | Energy = 831.150981
# Iter 381 | Energy = 830.676720
# Iter 382 | Energy = 830.204194
# Iter 383 | Energy = 829.733396
# Iter 384 | Energy = 829.264319
# Iter 385 | Energy = 828.796957
# Iter 386 | Energy = 828.331301
# Iter 387 | Energy = 827.867347
# Iter 388 | Energy = 827.405086
# Iter 389 | Energy = 826.944513
# Iter 390 | Energy = 826.485621
# Iter 391 | Energy = 826.028403
# Iter 392 | Energy = 825.572852
# Iter 393 | Energy = 825.118963
# Iter 394 | Energy = 824.666728
# Iter 395 | Energy = 824.216140
# Iter 396 | Energy = 823.767195
# Iter 397 | Energy = 823.319884
# Iter 398 | Energy = 822.874203
# Iter 399 | Energy = 822.430143
# Iter 400 | Energy = 821.987699
# Iter 401 | Energy = 821.546866
# Iter 402 | Energy = 821.107635
# Iter 403 | Energy = 820.670001
# Iter 404 | Energy = 820.233958
# Iter 405 | Energy = 819.799500
# Iter 406 | Energy = 819.366620
# Iter 407 | Energy = 818.935312
# Iter 408 | Energy = 818.505571
# Iter 409 | Energy = 818.077389
# Iter 410 | Energy = 817.650761
# Iter 411 | Energy = 817.225681
# Iter 412 | Energy = 816.802143
# Iter 413 | Energy = 816.380141
# Iter 414 | Energy = 815.959668
# Iter 415 | Energy = 815.540719
# Iter 416 | Energy = 815.123288
# Iter 417 | Energy = 814.707369
# Iter 418 | Energy = 814.292956
# Iter 419 | Energy = 813.880044
# Iter 420 | Energy = 813.468626
# Iter 421 | Energy = 813.058696
# Iter 422 | Energy = 812.650249
# Iter 423 | Energy = 812.243280
# Iter 424 | Energy = 811.837782
# Iter 425 | Energy = 811.433749
# Iter 426 | Energy = 811.031176
# Iter 427 | Energy = 810.630058
# Iter 428 | Energy = 810.230388
# Iter 429 | Energy = 809.832162
# Iter 430 | Energy = 809.435373
# Iter 431 | Energy = 809.040016
# Iter 432 | Energy = 808.646085
# Iter 433 | Energy = 808.253575
# Iter 434 | Energy = 807.862481
# Iter 435 | Energy = 807.472797
# Iter 436 | Energy = 807.084517
# Iter 437 | Energy = 806.697636
# Iter 438 | Energy = 806.312148
# Iter 439 | Energy = 805.928050
# Iter 440 | Energy = 805.545334
# Iter 441 | Energy = 805.163995
# Iter 442 | Energy = 804.784029
# Iter 443 | Energy = 804.405430
# Iter 444 | Energy = 804.028193
# Iter 445 | Energy = 803.652312
# Iter 446 | Energy = 803.277783
# Iter 447 | Energy = 802.904599
# Iter 448 | Energy = 802.532757
# Iter 449 | Energy = 802.162251
# Iter 450 | Energy = 801.793075
# Iter 451 | Energy = 801.425225
# Iter 452 | Energy = 801.058695
# Iter 453 | Energy = 800.693480
# Iter 454 | Energy = 800.329576
# Iter 455 | Energy = 799.966978
# Iter 456 | Energy = 799.605679
# Iter 457 | Energy = 799.245676
# Iter 458 | Energy = 798.886964
# Iter 459 | Energy = 798.529537
# Iter 460 | Energy = 798.173391
# Iter 461 | Energy = 797.818520
# Iter 462 | Energy = 797.464920
# Iter 463 | Energy = 797.112586
# Iter 464 | Energy = 796.761513
# Iter 465 | Energy = 796.411696
# Iter 466 | Energy = 796.063131
# Iter 467 | Energy = 795.715813
# Iter 468 | Energy = 795.369736
# Iter 469 | Energy = 795.024897
# Iter 470 | Energy = 794.681290
# Iter 471 | Energy = 794.338912
# Iter 472 | Energy = 793.997756
# Iter 473 | Energy = 793.657819
# Iter 474 | Energy = 793.319096
# Iter 475 | Energy = 792.981582
# Iter 476 | Energy = 792.645272
# Iter 477 | Energy = 792.310163
# Iter 478 | Energy = 791.976249
# Iter 479 | Energy = 791.643526
# Iter 480 | Energy = 791.311990
# Iter 481 | Energy = 790.981636
# Iter 482 | Energy = 790.652459
# Iter 483 | Energy = 790.324455
# Iter 484 | Energy = 789.997620
# Iter 485 | Energy = 789.671949
# Iter 486 | Energy = 789.347437
# Iter 487 | Energy = 789.024081
# Iter 488 | Energy = 788.701876
# Iter 489 | Energy = 788.380817
# Iter 490 | Energy = 788.060901
# Iter 491 | Energy = 787.742123
# Iter 492 | Energy = 787.424478
# Iter 493 | Energy = 787.107963
# Iter 494 | Energy = 786.792573
# Iter 495 | Energy = 786.478304
# Iter 496 | Energy = 786.165151
# Iter 497 | Energy = 785.853111
# Iter 498 | Energy = 785.542179
# Iter 499 | Energy = 785.232351
# Iter 500 | Energy = 784.923623
# Iter 501 | Energy = 784.615991
# Iter 502 | Energy = 784.309450
# Iter 503 | Energy = 784.003997
# Iter 504 | Energy = 783.699627
# Iter 505 | Energy = 783.396337
# Iter 506 | Energy = 783.094122
# Iter 507 | Energy = 782.792978
# Iter 508 | Energy = 782.492901
# Iter 509 | Energy = 782.193888
# Iter 510 | Energy = 781.895934
# Iter 511 | Energy = 781.599035
# Iter 512 | Energy = 781.303187
# Iter 513 | Energy = 781.008387
# Iter 514 | Energy = 780.714630
# Iter 515 | Energy = 780.421913
# Iter 516 | Energy = 780.130231
# Iter 517 | Energy = 779.839581
# Iter 518 | Energy = 779.549958
# Iter 519 | Energy = 779.261360
# Iter 520 | Energy = 778.973782
# Iter 521 | Energy = 778.687220
# Iter 522 | Energy = 778.401671
# Iter 523 | Energy = 778.117131
# Iter 524 | Energy = 777.833596
# Iter 525 | Energy = 777.551061
# Iter 526 | Energy = 777.269525
# Iter 527 | Energy = 776.988982
# Iter 528 | Energy = 776.709429
# Iter 529 | Energy = 776.430863
# Iter 530 | Energy = 776.153279
# Iter 531 | Energy = 775.876675
# Iter 532 | Energy = 775.601046
# Iter 533 | Energy = 775.326388
# Iter 534 | Energy = 775.052699
# Iter 535 | Energy = 774.779974
# Iter 536 | Energy = 774.508211
# Iter 537 | Energy = 774.237404
# Iter 538 | Energy = 773.967552
# Iter 539 | Energy = 773.698649
# Iter 540 | Energy = 773.430694
# Iter 541 | Energy = 773.163681
# Iter 542 | Energy = 772.897609
# Iter 543 | Energy = 772.632472
# Iter 544 | Energy = 772.368268
# Iter 545 | Energy = 772.104994
# Iter 546 | Energy = 771.842645
# Iter 547 | Energy = 771.581219
# Iter 548 | Energy = 771.320712
# Iter 549 | Energy = 771.061120
# Iter 550 | Energy = 770.802441
# Iter 551 | Energy = 770.544670
# Iter 552 | Energy = 770.287805
# Iter 553 | Energy = 770.031842
# Iter 554 | Energy = 769.776777
# Iter 555 | Energy = 769.522608
# Iter 556 | Energy = 769.269332
# Iter 557 | Energy = 769.016944
# Iter 558 | Energy = 768.765441
# Iter 559 | Energy = 768.514821
# Iter 560 | Energy = 768.265079
# Iter 561 | Energy = 768.016214
# Iter 562 | Energy = 767.768221
# Iter 563 | Energy = 767.521097
# Iter 564 | Energy = 767.274840
# Iter 565 | Energy = 767.029445
# Iter 566 | Energy = 766.784910
# Iter 567 | Energy = 766.541232
# Iter 568 | Energy = 766.298406
# Iter 569 | Energy = 766.056432
# Iter 570 | Energy = 765.815304
# Iter 571 | Energy = 765.575020
# Iter 572 | Energy = 765.335578
# Iter 573 | Energy = 765.096973
# Iter 574 | Energy = 764.859202
# Iter 575 | Energy = 764.622264
# Iter 576 | Energy = 764.386154
# Iter 577 | Energy = 764.150869
# Iter 578 | Energy = 763.916407
# Iter 579 | Energy = 763.682765
# Iter 580 | Energy = 763.449939
# Iter 581 | Energy = 763.217926
# Iter 582 | Energy = 762.986724
# Iter 583 | Energy = 762.756330
# Iter 584 | Energy = 762.526740
# Iter 585 | Energy = 762.297952
# Iter 586 | Energy = 762.069962
# Iter 587 | Energy = 761.842768
# Iter 588 | Energy = 761.616367
# Iter 589 | Energy = 761.390756
# Iter 590 | Energy = 761.165932
# Iter 591 | Energy = 760.941892
# Iter 592 | Energy = 760.718634
# Iter 593 | Energy = 760.496154
# Iter 594 | Energy = 760.274449
# Iter 595 | Energy = 760.053518
# Iter 596 | Energy = 759.833356
# Iter 597 | Energy = 759.613961
# Iter 598 | Energy = 759.395331
# Iter 599 | Energy = 759.177462
# Iter 600 | Energy = 758.960352
# Iter 601 | Energy = 758.743998
# Iter 602 | Energy = 758.528397
# Iter 603 | Energy = 758.313547
# Iter 604 | Energy = 758.099444
# Iter 605 | Energy = 757.886087
# Iter 606 | Energy = 757.673471
# Iter 607 | Energy = 757.461596
# Iter 608 | Energy = 757.250457
# Iter 609 | Energy = 757.040052
# Iter 610 | Energy = 756.830380
# Iter 611 | Energy = 756.621435
# Iter 612 | Energy = 756.413218
# Iter 613 | Energy = 756.205723
# Iter 614 | Energy = 755.998950
# Iter 615 | Energy = 755.792895
# Iter 616 | Energy = 755.587556
# Iter 617 | Energy = 755.382930
# Iter 618 | Energy = 755.179015
# Iter 619 | Energy = 754.975807
# Iter 620 | Energy = 754.773305
# Iter 621 | Energy = 754.571506
# Iter 622 | Energy = 754.370407
# Iter 623 | Energy = 754.170006
# Iter 624 | Energy = 753.970300
# Iter 625 | Energy = 753.771286
# Iter 626 | Energy = 753.572963
# Iter 627 | Energy = 753.375328
# Iter 628 | Energy = 753.178378
# Iter 629 | Energy = 752.982110
# Iter 630 | Energy = 752.786523
# Iter 631 | Energy = 752.591613
# Iter 632 | Energy = 752.397379
# Iter 633 | Energy = 752.203818
# Iter 634 | Energy = 752.010927
# Iter 635 | Energy = 751.818705
# Iter 636 | Energy = 751.627148
# Iter 637 | Energy = 751.436254
# Iter 638 | Energy = 751.246021
# Iter 639 | Energy = 751.056446
# Iter 640 | Energy = 750.867528
# Iter 641 | Energy = 750.679263
# Iter 642 | Energy = 750.491649
# Iter 643 | Energy = 750.304685
# Iter 644 | Energy = 750.118367
# Iter 645 | Energy = 749.932693
# Iter 646 | Energy = 749.747661
# Iter 647 | Energy = 749.563270
# Iter 648 | Energy = 749.379515
# Iter 649 | Energy = 749.196395
# Iter 650 | Energy = 749.013909
# Iter 651 | Energy = 748.832053
# Iter 652 | Energy = 748.650825
# Iter 653 | Energy = 748.470223
# Iter 654 | Energy = 748.290244
# Iter 655 | Energy = 748.110888
# Iter 656 | Energy = 747.932150
# Iter 657 | Energy = 747.754030
# Iter 658 | Energy = 747.576524
# Iter 659 | Energy = 747.399631
# Iter 660 | Energy = 747.223348
# Iter 661 | Energy = 747.047674
# Iter 662 | Energy = 746.872605
# Iter 663 | Energy = 746.698141
# Iter 664 | Energy = 746.524278
# Iter 665 | Energy = 746.351014
# Iter 666 | Energy = 746.178348
# Iter 667 | Energy = 746.006278
# Iter 668 | Energy = 745.834800
# Iter 669 | Energy = 745.663913
# Iter 670 | Energy = 745.493615
# Iter 671 | Energy = 745.323904
# Iter 672 | Energy = 745.154778
# Iter 673 | Energy = 744.986234
# Iter 674 | Energy = 744.818270
# Iter 675 | Energy = 744.650885
# Iter 676 | Energy = 744.484076
# Iter 677 | Energy = 744.317842
# Iter 678 | Energy = 744.152180
# Iter 679 | Energy = 743.987087
# Iter 680 | Energy = 743.822563
# Iter 681 | Energy = 743.658605
# Iter 682 | Energy = 743.495211
# Iter 683 | Energy = 743.332380
# Iter 684 | Energy = 743.170108
# Iter 685 | Energy = 743.008394
# Iter 686 | Energy = 742.847236
# Iter 687 | Energy = 742.686633
# Iter 688 | Energy = 742.526581
# Iter 689 | Energy = 742.367080
# Iter 690 | Energy = 742.208126
# Iter 691 | Energy = 742.049719
# Iter 692 | Energy = 741.891856
# Iter 693 | Energy = 741.734536
# Iter 694 | Energy = 741.577756
# Iter 695 | Energy = 741.421514
# Iter 696 | Energy = 741.265809
# Iter 697 | Energy = 741.110638
# Iter 698 | Energy = 740.956001
# Iter 699 | Energy = 740.801894
# Iter 700 | Energy = 740.648316
# Iter 701 | Energy = 740.495265
# Iter 702 | Energy = 740.342739
# Iter 703 | Energy = 740.190737
# Iter 704 | Energy = 740.039256
# Iter 705 | Energy = 739.888294
# Iter 706 | Energy = 739.737851
# Iter 707 | Energy = 739.587923
# Iter 708 | Energy = 739.438510
# Iter 709 | Energy = 739.289608
# Iter 710 | Energy = 739.141217
# Iter 711 | Energy = 738.993335
# Iter 712 | Energy = 738.845960
# Iter 713 | Energy = 738.699089
# Iter 714 | Energy = 738.552722
# Iter 715 | Energy = 738.406856
# Iter 716 | Energy = 738.261490
# Iter 717 | Energy = 738.116622
# Iter 718 | Energy = 737.972250
# Iter 719 | Energy = 737.828373
# Iter 720 | Energy = 737.684988
# Iter 721 | Energy = 737.542094
# Iter 722 | Energy = 737.399689
# Iter 723 | Energy = 737.257771
# Iter 724 | Energy = 737.116339
# Iter 725 | Energy = 736.975391
# Iter 726 | Energy = 736.834926
# Iter 727 | Energy = 736.694941
# Iter 728 | Energy = 736.555434
# Iter 729 | Energy = 736.416405
# Iter 730 | Energy = 736.277852
# Iter 731 | Energy = 736.139772
# Iter 732 | Energy = 736.002164
# Iter 733 | Energy = 735.865027
# Iter 734 | Energy = 735.728358
# Iter 735 | Energy = 735.592157
# Iter 736 | Energy = 735.456421
# Iter 737 | Energy = 735.321149
# Iter 738 | Energy = 735.186339
# Iter 739 | Energy = 735.051990
# Iter 740 | Energy = 734.918100
# Iter 741 | Energy = 734.784667
# Iter 742 | Energy = 734.651690
# Iter 743 | Energy = 734.519167
# Iter 744 | Energy = 734.387096
# Iter 745 | Energy = 734.255476
# Iter 746 | Energy = 734.124306
# Iter 747 | Energy = 733.993583
# Iter 748 | Energy = 733.863307
# Iter 749 | Energy = 733.733475
# Iter 750 | Energy = 733.604086
# Iter 751 | Energy = 733.475138
# Iter 752 | Energy = 733.346631
# Iter 753 | Energy = 733.218562
# Iter 754 | Energy = 733.090929
# Iter 755 | Energy = 732.963732
# Iter 756 | Energy = 732.836969
# Iter 757 | Energy = 732.710638
# Iter 758 | Energy = 732.584738
# Iter 759 | Energy = 732.459267
# Iter 760 | Energy = 732.334223
# Iter 761 | Energy = 732.209606
# Iter 762 | Energy = 732.085413
# Iter 763 | Energy = 731.961644
# Iter 764 | Energy = 731.838296
# Iter 765 | Energy = 731.715369
# Iter 766 | Energy = 731.592860
# Iter 767 | Energy = 731.470768
# Iter 768 | Energy = 731.349093
# Iter 769 | Energy = 731.227832
# Iter 770 | Energy = 731.106983
# Iter 771 | Energy = 730.986546
# Iter 772 | Energy = 730.866520
# Iter 773 | Energy = 730.746901
# Iter 774 | Energy = 730.627690
# Iter 775 | Energy = 730.508885
# Iter 776 | Energy = 730.390484
# Iter 777 | Energy = 730.272485
# Iter 778 | Energy = 730.154889
# Iter 779 | Energy = 730.037692
# Iter 780 | Energy = 729.920894
# Iter 781 | Energy = 729.804493
# Iter 782 | Energy = 729.688488
# Iter 783 | Energy = 729.572878
# Iter 784 | Energy = 729.457661
# Iter 785 | Energy = 729.342835
# Iter 786 | Energy = 729.228400
# Iter 787 | Energy = 729.114354
# Iter 788 | Energy = 729.000695
# Iter 789 | Energy = 728.887423
# Iter 790 | Energy = 728.774536
# Iter 791 | Energy = 728.662032
# Iter 792 | Energy = 728.549911
# Iter 793 | Energy = 728.438170
# Iter 794 | Energy = 728.326809
# Iter 795 | Energy = 728.215827
# Iter 796 | Energy = 728.105221
# Iter 797 | Energy = 727.994991
# Iter 798 | Energy = 727.885135
# Iter 799 | Energy = 727.775652
# Iter 800 | Energy = 727.666541
# Iter 801 | Energy = 727.557801
# Iter 802 | Energy = 727.449429
# Iter 803 | Energy = 727.341425
# Iter 804 | Energy = 727.233788
# Iter 805 | Energy = 727.126516
# Iter 806 | Energy = 727.019608
# Iter 807 | Energy = 726.913063
# Iter 808 | Energy = 726.806880
# Iter 809 | Energy = 726.701056
# Iter 810 | Energy = 726.595592
# Iter 811 | Energy = 726.490485
# Iter 812 | Energy = 726.385734
# Iter 813 | Energy = 726.281339
# Iter 814 | Energy = 726.177298
# Iter 815 | Energy = 726.073610
# Iter 816 | Energy = 725.970273
# Iter 817 | Energy = 725.867286
# Iter 818 | Energy = 725.764649
# Iter 819 | Energy = 725.662359
# Iter 820 | Energy = 725.560416
# Iter 821 | Energy = 725.458819
# Iter 822 | Energy = 725.357565
# Iter 823 | Energy = 725.256655
# Iter 824 | Energy = 725.156087
# Iter 825 | Energy = 725.055859
# Iter 826 | Energy = 724.955971
# Iter 827 | Energy = 724.856421
# Iter 828 | Energy = 724.757208
# Iter 829 | Energy = 724.658331
# Iter 830 | Energy = 724.559789
# Iter 831 | Energy = 724.461581
# Iter 832 | Energy = 724.363705
# Iter 833 | Energy = 724.266161
# Iter 834 | Energy = 724.168946
# Iter 835 | Energy = 724.072061
# Iter 836 | Energy = 723.975503
# Iter 837 | Energy = 723.879273
# Iter 838 | Energy = 723.783368
# Iter 839 | Energy = 723.687787
# Iter 840 | Energy = 723.592530
# Iter 841 | Energy = 723.497595
# Iter 842 | Energy = 723.402981
# Iter 843 | Energy = 723.308687
# Iter 844 | Energy = 723.214712
# Iter 845 | Energy = 723.121055
# Iter 846 | Energy = 723.027715
# Iter 847 | Energy = 722.934690
# Iter 848 | Energy = 722.841980
# Iter 849 | Energy = 722.749583
# Iter 850 | Energy = 722.657498
# Iter 851 | Energy = 722.565725
# Iter 852 | Energy = 722.474262
# Iter 853 | Energy = 722.383108
# Iter 854 | Energy = 722.292262
# Iter 855 | Energy = 722.201723
# Iter 856 | Energy = 722.111490
# Iter 857 | Energy = 722.021562
# Iter 858 | Energy = 721.931937
# Iter 859 | Energy = 721.842616
# Iter 860 | Energy = 721.753596
# Iter 861 | Energy = 721.664877
# Iter 862 | Energy = 721.576457
# Iter 863 | Energy = 721.488336
# Iter 864 | Energy = 721.400512
# Iter 865 | Energy = 721.312985
# Iter 866 | Energy = 721.225754
# Iter 867 | Energy = 721.138817
# Iter 868 | Energy = 721.052173
# Iter 869 | Energy = 720.965822
# Iter 870 | Energy = 720.879763
# Iter 871 | Energy = 720.793994
# Iter 872 | Energy = 720.708514
# Iter 873 | Energy = 720.623323
# Iter 874 | Energy = 720.538419
# Iter 875 | Energy = 720.453802
# Iter 876 | Energy = 720.369470
# Iter 877 | Energy = 720.285422
# Iter 878 | Energy = 720.201658
# Iter 879 | Energy = 720.118177
# Iter 880 | Energy = 720.034977
# Iter 881 | Energy = 719.952058
# Iter 882 | Energy = 719.869418
# Iter 883 | Energy = 719.787057
# Iter 884 | Energy = 719.704974
# Iter 885 | Energy = 719.623167
# Iter 886 | Energy = 719.541637
# Iter 887 | Energy = 719.460381
# Iter 888 | Energy = 719.379399
# Iter 889 | Energy = 719.298690
# Iter 890 | Energy = 719.218253
# Iter 891 | Energy = 719.138086
# Iter 892 | Energy = 719.058191
# Iter 893 | Energy = 718.978564
# Iter 894 | Energy = 718.899206
# Iter 895 | Energy = 718.820115
# Iter 896 | Energy = 718.741290
# Iter 897 | Energy = 718.662731
# Iter 898 | Energy = 718.584436
# Iter 899 | Energy = 718.506406
# Iter 900 | Energy = 718.428638
# Iter 901 | Energy = 718.351132
# Iter 902 | Energy = 718.273887
# Iter 903 | Energy = 718.196902
# Iter 904 | Energy = 718.120176
# Iter 905 | Energy = 718.043708
# Iter 906 | Energy = 717.967498
# Iter 907 | Energy = 717.891545
# Iter 908 | Energy = 717.815847
# Iter 909 | Energy = 717.740404
# Iter 910 | Energy = 717.665215
# Iter 911 | Energy = 717.590279
# Iter 912 | Energy = 717.515595
# Iter 913 | Energy = 717.441162
# Iter 914 | Energy = 717.366980
# Iter 915 | Energy = 717.293047
# Iter 916 | Energy = 717.219364
# Iter 917 | Energy = 717.145927
# Iter 918 | Energy = 717.072739
# Iter 919 | Energy = 716.999796
# Iter 920 | Energy = 716.927098
# Iter 921 | Energy = 716.854645
# Iter 922 | Energy = 716.782436
# Iter 923 | Energy = 716.710469
# Iter 924 | Energy = 716.638745
# Iter 925 | Energy = 716.567261
# Iter 926 | Energy = 716.496018
# Iter 927 | Energy = 716.425015
# Iter 928 | Energy = 716.354250
# Iter 929 | Energy = 716.283723
# Iter 930 | Energy = 716.213433
# Iter 931 | Energy = 716.143380
# Iter 932 | Energy = 716.073561
# Iter 933 | Energy = 716.003978
# Iter 934 | Energy = 715.934628
# Iter 935 | Energy = 715.865511
# Iter 936 | Energy = 715.796627
# Iter 937 | Energy = 715.727973
# Iter 938 | Energy = 715.659551
# Iter 939 | Energy = 715.591358
# Iter 940 | Energy = 715.523395
# Iter 941 | Energy = 715.455660
# Iter 942 | Energy = 715.388152
# Iter 943 | Energy = 715.320871
# Iter 944 | Energy = 715.253816
# Iter 945 | Energy = 715.186986
# Iter 946 | Energy = 715.120380
# Iter 947 | Energy = 715.053999
# Iter 948 | Energy = 714.987840
# Iter 949 | Energy = 714.921903
# Iter 950 | Energy = 714.856187
# Iter 951 | Energy = 714.790692
# Iter 952 | Energy = 714.725417
# Iter 953 | Energy = 714.660361
# Iter 954 | Energy = 714.595524
# Iter 955 | Energy = 714.530904
# Iter 956 | Energy = 714.466501
# Iter 957 | Energy = 714.402314
# Iter 958 | Energy = 714.338342
# Iter 959 | Energy = 714.274585
# Iter 960 | Energy = 714.211042
# Iter 961 | Energy = 714.147712
# Iter 962 | Energy = 714.084595
# Iter 963 | Energy = 714.021689
# Iter 964 | Energy = 713.958994
# Iter 965 | Energy = 713.896510
# Iter 966 | Energy = 713.834235
# Iter 967 | Energy = 713.772169
# Iter 968 | Energy = 713.710311
# Iter 969 | Energy = 713.648661
# Iter 970 | Energy = 713.587217
# Iter 971 | Energy = 713.525980
# Iter 972 | Energy = 713.464947
# Iter 973 | Energy = 713.404120
# Iter 974 | Energy = 713.343496
# Iter 975 | Energy = 713.283076
# Iter 976 | Energy = 713.222858
# Iter 977 | Energy = 713.162841
# Iter 978 | Energy = 713.103026
# Iter 979 | Energy = 713.043412
# Iter 980 | Energy = 712.983997
# Iter 981 | Energy = 712.924782
# Iter 982 | Energy = 712.865765
# Iter 983 | Energy = 712.806945
# Iter 984 | Energy = 712.748323
# Iter 985 | Energy = 712.689897
# Iter 986 | Energy = 712.631667
# Iter 987 | Energy = 712.573632
# Iter 988 | Energy = 712.515791
# Iter 989 | Energy = 712.458144
# Iter 990 | Energy = 712.400691
# Iter 991 | Energy = 712.343429
# Iter 992 | Energy = 712.286360
# Iter 993 | Energy = 712.229481
# Iter 994 | Energy = 712.172793
# Iter 995 | Energy = 712.116295
# Iter 996 | Energy = 712.059986
# Iter 997 | Energy = 712.003866
# Iter 998 | Energy = 711.947934
# Iter 999 | Energy = 711.892189
# Iter 1000 | Energy = 711.836630

# %%
# -----------------------
# K-Means 聚合
# -----------------------
def fuse_to_super_knn(prev_nodes, prev_edges, k, layer_idx, max_iters=20, tol=1e-6, seed=0):
    positions = np.array([[n["position"]["x"], n["position"]["y"]] for n in prev_nodes], dtype=float)
    n = positions.shape[0]
    if k <= 0: k = 1
    k = min(k, n)
    rng = np.random.default_rng(seed)

    # k-means++ init
    centers = np.empty((k, 2), dtype=float)
    first = rng.integers(0, n)
    centers[0] = positions[first]
    closest_d2 = np.sum((positions - centers[0])**2, axis=1)
    for i in range(1, k):
        denom = float(closest_d2.sum()) + 1e-12
        probs = closest_d2 / denom
        idx = rng.choice(n, p=probs)
        centers[i] = positions[idx]
        d2_new = np.sum((positions - centers[i])**2, axis=1)
        closest_d2 = np.minimum(closest_d2, d2_new)

    # Lloyd iterations
    for _ in range(max_iters):
        d2 = ((positions[:, None, :] - centers[None, :, :]) ** 2).sum(axis=2)
        assign = np.argmin(d2, axis=1)
        moved = 0.0
        for ci in range(k):
            idxs = np.where(assign == ci)[0]
            if idxs.size == 0:
                far_idx = int(np.argmax(np.min(d2, axis=1)))
                new_c = positions[far_idx]
            else:
                new_c = positions[idxs].mean(axis=0)
            moved = max(moved, float(np.linalg.norm(new_c - centers[ci])))
            centers[ci] = new_c
        if moved < tol:
            break

    # final assign
    d2 = ((positions[:, None, :] - centers[None, :, :]) ** 2).sum(axis=2)
    assign = np.argmin(d2, axis=1)

    super_nodes, node_map = [], {}
    for ci in range(k):
        idxs = np.where(assign == ci)[0]
        if idxs.size == 0:
            continue
        pts = positions[idxs]
        mean_x, mean_y = pts.mean(axis=0)
        child_dims = [prev_nodes[i]["data"]["dim"] for i in idxs]
        dim_val = int(max(1, sum(child_dims)))
        nid = f"{ci}"
        super_nodes.append({
            "data": {"id": nid, "layer": layer_idx, "dim": dim_val},
            "position": {"x": float(mean_x), "y": float(mean_y)}
        })
        for i in idxs:
            node_map[prev_nodes[i]["data"]["id"]] = nid
    super_edges, seen = [], set()
    for e in prev_edges:
        u, v = e["data"]["source"], e["data"]["target"]
        if v != "prior":
            su, sv = node_map[u], node_map[v]
            if su != sv:
                eid = tuple(sorted((su, sv)))
                if eid not in seen:
                    super_edges.append({"data": {"source": su, "target": sv}})
                    seen.add(eid)
            elif su == sv:
                eid = tuple(sorted((su, su)))
                if eid not in seen:
                    super_edges.append({"data": {"source": su, "target": "prior"}})
                    seen.add(eid)

        elif v == "prior":
            eid = tuple(sorted((su, su)))
            if eid not in seen:
                super_edges.append({"data": {"source": su, "target": "prior"}})
                seen.add(eid)

    return super_nodes, super_edges, node_map

# %%
def build_super_graph(layers):
    """
    基于 layers[-2] 的 base graph, 和 layers[-1] 的 super 分组，构造 super graph。
    要求: layers[-2]["graph"] 已经是构建好的基图（含 unary/binary 因子）。
    layers[-1]["node_map"]: { base_node_id(str, 如 'b12') -> super_node_id(str) }
    """
    # ---------- 取出 base & super ----------
    base_graph = layers[-2]["graph"]
    super_nodes = layers[-1]["nodes"]
    super_edges = layers[-1]["edges"]
    node_map    = layers[-1]["node_map"]   # 'bN' -> 'sX_...'

    # base: id(int)->VariableNode，方便查 dofs 和 mu
    id2var = {vn.variableID: vn for vn in base_graph.var_nodes}

    # ---------- super_id -> [base_id(int)] ----------
    super_groups = {}
    for b_str, s_id in node_map.items():
        b_int = int(b_str)
        super_groups.setdefault(s_id, []).append(b_int)


    # ---------- 为每个 super 组建立 (start, dofs) 表 ----------
    # local_idx[sid][bid] = (start, dofs), total_dofs[sid] = sum(dofs)
    local_idx   = {}
    total_dofs  = {}
    for sid, group in super_groups.items():
        off = 0
        local_idx[sid] = {}
        for bid in group:
            d = id2var[bid].dofs
            local_idx[sid][bid] = (off, d)
            off += d
        total_dofs[sid] = off


    # ---------- 创建 super VariableNodes ----------
    fg = FactorGraph(nonlinear_factors=False, eta_damping=0)

    super_var_nodes = {}
    for i, sn in enumerate(super_nodes):
        sid = sn["data"]["id"]
        dofs = total_dofs.get(sid, 0)

        v = VariableNode(i, dofs=dofs)

        # === 叠加 base GT ===
        gt_vec = np.zeros(dofs)
        for bid, (st, d) in local_idx[sid].items():
            gt_base = getattr(id2var[bid], "GT", None)
            if gt_base is None or len(gt_base) != d:
                gt_base = np.zeros(d)
            gt_vec[st:st+d] = gt_base
        v.GT = gt_vec

        super_var_nodes[sid] = v
        fg.var_nodes.append(v)
    fg.n_var_nodes = len(fg.var_nodes)

    # ---------- 工具：拼接某组的 linpoint（用 base belief 均值） ----------
    def make_linpoint_for_group(sid):
        x = np.zeros(total_dofs[sid])
        for bid, (st, d) in local_idx[sid].items():
            mu = getattr(id2var[bid], "mu", None)
            if mu is None or len(mu) != d:
                mu = np.zeros(d)
            x[st:st+d] = mu
        return x

    # ---------- 3) super prior（组内 unary + 组内 binary） ----------
    def make_super_prior_factor(sid, base_factors):
        group = super_groups[sid]
        idx_map = local_idx[sid]
        ncols = total_dofs[sid]

        # 选出：所有变量都在组内的因子（unary 或 binary）
        in_group = []
        for f in base_factors:
            vids = [v.variableID for v in f.adj_var_nodes]
            if all(vid in group for vid in vids):
                in_group.append(f)

        def meas_fn_super_prior(x_super, *args):
            meas_fn = []
            for f in in_group:
                vids = [v.variableID for v in f.adj_var_nodes]
                # 拼本因子的局部 x
                x_loc_list = []
                for vid in vids:
                    st, d = idx_map[vid]
                    x_loc_list.append(x_super[st:st+d])
                x_loc = np.concatenate(x_loc_list) if x_loc_list else np.zeros(0)
                meas_fn.append(f.meas_fn(x_loc))
            return np.concatenate(meas_fn) if meas_fn else np.zeros(0)

        def jac_fn_super_prior(x_super, *args):
            Jrows = []
            for f in in_group:
                vids = [v.variableID for v in f.adj_var_nodes]
                # 构造本因子的局部 x，用于（潜在）非线性雅可比
                x_loc_list = []
                dims = []
                for vid in vids:
                    st, d = idx_map[vid]
                    dims.append(d)
                    x_loc_list.append(x_super[st:st+d])
                x_loc = np.concatenate(x_loc_list) if x_loc_list else np.zeros(0)

                Jloc = f.jac_fn(x_loc)
                # 将 Jloc 列块映射回 super 变量的列
                row = np.zeros((Jloc.shape[0], ncols))
                c0 = 0
                for vid, d in zip(vids, dims):
                    st, _ = idx_map[vid]
                    row[:, st:st+d] = Jloc[:, c0:c0+d]
                    c0 += d

                row *= f.gauss_noise_std
                
                Jrows.append(row)
            return np.vstack(Jrows) if Jrows else np.zeros((0, ncols))

        # z_super：拼各 base 因子的 z
        z_list = [f.measurement for f in in_group]
        z_super = np.concatenate(z_list) if z_list else np.zeros(0)

        return meas_fn_super_prior, jac_fn_super_prior, z_super

    # 为每个 super node 加 prior 因子
    for sid in super_groups.keys():
        meas_fn, jac_fn, z = make_super_prior_factor(sid, base_graph.factors)
        f = Factor(len(fg.factors), [super_var_nodes[sid]], z, 1, meas_fn, jac_fn)
        f.type = "super_prior"
        lin0 = make_linpoint_for_group(sid)
        f.compute_factor(linpoint=lin0, update_self=True)
        fg.factors.append(f)
        super_var_nodes[sid].adj_factors.append(f)

    # ---------- 4) super between（只取跨组 binary） ----------
    def make_super_between_factor(sidA, sidB, base_factors):
        groupA, groupB = super_groups[sidA], super_groups[sidB]
        idxA, idxB = local_idx[sidA], local_idx[sidB]
        nA, nB = total_dofs[sidA], total_dofs[sidB]

        cross = []
        for f in base_factors:
            vids = [v.variableID for v in f.adj_var_nodes]
            if len(vids) != 2:
                continue
            i, j = vids
            # 恰有一端在 A，一端在 B
            if (i in groupA and j in groupB) or (i in groupB and j in groupA):
                cross.append(f)

        def meas_fn_super_between(xAB, *args):
            xA, xB = xAB[:nA], xAB[nA:]
            meas_fn = []
            for f in cross:
                i, j = [v.variableID for v in f.adj_var_nodes]
                if i in groupA:
                    si, di = idxA[i]
                    sj, dj = idxB[j]
                    xi = xA[si:si+di]
                    xj = xB[sj:sj+dj]
                else:
                    si, di = idxB[i]
                    sj, dj = idxA[j]
                    xi = xB[si:si+di]
                    xj = xA[sj:sj+dj]
                x_loc = np.concatenate([xi, xj])
                meas_fn.append(f.meas_fn(x_loc))
            return np.concatenate(meas_fn) if meas_fn else np.zeros(0)

        def jac_fn_super_between(xAB, *args):
            xA, xB = xAB[:nA], xAB[nA:]
            Jrows = []
            for f in cross:
                i, j = [v.variableID for v in f.adj_var_nodes]
                if i in groupA:
                    si, di = idxA[i]
                    sj, dj = idxB[j]
                    xi = xA[si:si+di]
                    xj = xB[sj:sj+dj]
                    left_start, right_start = si, nA + sj
                else:
                    si, di = idxB[i]
                    sj, dj = idxA[j]
                    xi = xB[si:si+di]
                    xj = xA[sj:sj+dj]
                    left_start, right_start = nA + si, sj
                x_loc = np.concatenate([xi, xj])
                Jloc = f.jac_fn(x_loc)

                row = np.zeros((Jloc.shape[0], nA + nB))
                row[:, left_start:left_start+di]   = Jloc[:, :di]
                row[:, right_start:right_start+dj] = Jloc[:, di:di+dj]

                row *= f.gauss_noise_std
                Jrows.append(row)
            return np.vstack(Jrows) if Jrows else np.zeros((0, nA + nB))

        z_super = np.concatenate([f.measurement for f in cross]) if cross else np.zeros(0)
        return meas_fn_super_between, jac_fn_super_between, z_super

    for e in super_edges:
        u, v = e["data"]["source"], e["data"]["target"]
        if v == "prior":
            continue
        if (u not in super_groups) or (v not in super_groups):
            continue
        meas_fn, jac_fn, z = make_super_between_factor(u, v, base_graph.factors)
        f = Factor(len(fg.factors), [super_var_nodes[u], super_var_nodes[v]], z, 1, meas_fn, jac_fn)
        f.type = "super_between"
        lin0 = np.concatenate([make_linpoint_for_group(u), make_linpoint_for_group(v)])
        f.compute_factor(linpoint=lin0, update_self=True)
        fg.factors.append(f)
        super_var_nodes[u].adj_factors.append(f)
        super_var_nodes[v].adj_factors.append(f)

    fg.n_factor_nodes = len(fg.factors)
    return fg

# %%
N=50 
step=25
prob=0.1
radius=50 
prior_prop=0
prior_sigma=1.0
odom_sigma=1.0
layers = []


# -----------------------
# 初始化 & 边界
# -----------------------
def init_layers(N=100, step_size=25, loop_prob=0.05, loop_radius=50, prior_prop=0.0):
    base_nodes, base_edges = make_slam_like_graph(N, step_size, loop_prob, loop_radius, prior_prop)
    return [{"name": "base", "nodes": base_nodes, "edges": base_edges}]

layers = init_layers(N=N, step_size=step, loop_prob=prob, loop_radius=radius, prior_prop=prior_prop)
pair_idx = 0



# 构建 GBP 图
gbp_graph = build_noisy_pose_graph(layers[0]["nodes"], layers[0]["edges"],
                                    prior_sigma=prior_sigma,
                                    odom_sigma=odom_sigma
                                    )
layers[0]["graph"] = gbp_graph
opts=[{"label":"base","value":"base"}]


last = layers[-1]
super_layer_idx = 1

super_nodes, super_edges, node_map = fuse_to_super_knn(last["nodes"], last["edges"], 100, super_layer_idx)
layers.append({"name":f"super{1}", "nodes":super_nodes, "edges":super_edges, "node_map":node_map})
layers[-1]["graph"] = build_super_graph(layers)

# %%
basegraph = layers[-2]["graph"]
for it in range(1000):
    basegraph.synchronous_iteration()
    energy = basegraph.energy_map(include_priors=True, include_factors=True)
    print(f"Iter {it+1:03d} | Energy = {energy:.6f}")
# Out:
# Iter 001 | Energy = 778574.627234
# Iter 002 | Energy = 772996.443973
# Iter 003 | Energy = 759558.827819
# Iter 004 | Energy = 742400.003158
# Iter 005 | Energy = 726266.509014
# Iter 006 | Energy = 706131.684716
# Iter 007 | Energy = 679144.405732
# Iter 008 | Energy = 635315.722710
# Iter 009 | Energy = 573214.713720
# Iter 010 | Energy = 494852.180056
# Iter 011 | Energy = 360850.499019
# Iter 012 | Energy = 208086.267749
# Iter 013 | Energy = 113549.972748
# Iter 014 | Energy = 75650.829708
# Iter 015 | Energy = 38168.248163
# Iter 016 | Energy = 550.437136
# Iter 017 | Energy = 539.648360
# Iter 018 | Energy = 530.050867
# Iter 019 | Energy = 524.780532
# Iter 020 | Energy = 524.119224
# Iter 021 | Energy = 523.046554
# Iter 022 | Energy = 520.725485
# Iter 023 | Energy = 519.699446
# Iter 024 | Energy = 519.251487
# Iter 025 | Energy = 518.582409
# Iter 026 | Energy = 518.636456
# Iter 027 | Energy = 518.886443
# Iter 028 | Energy = 518.679822
# Iter 029 | Energy = 517.902858
# Iter 030 | Energy = 517.324672
# Iter 031 | Energy = 516.939179
# Iter 032 | Energy = 516.379433
# Iter 033 | Energy = 515.982438
# Iter 034 | Energy = 515.626793
# Iter 035 | Energy = 515.162575
# Iter 036 | Energy = 514.719183
# Iter 037 | Energy = 514.295158
# Iter 038 | Energy = 513.831854
# Iter 039 | Energy = 513.388059
# Iter 040 | Energy = 512.982970
# Iter 041 | Energy = 512.575566
# Iter 042 | Energy = 512.169337
# Iter 043 | Energy = 511.776649
# Iter 044 | Energy = 511.378794
# Iter 045 | Energy = 510.970537
# Iter 046 | Energy = 510.570035
# Iter 047 | Energy = 510.177622
# Iter 048 | Energy = 509.788298
# Iter 049 | Energy = 509.404497
# Iter 050 | Energy = 509.024201
# Iter 051 | Energy = 508.644594
# Iter 052 | Energy = 508.267161
# Iter 053 | Energy = 507.892466
# Iter 054 | Energy = 507.520143
# Iter 055 | Energy = 507.151335
# Iter 056 | Energy = 506.786180
# Iter 057 | Energy = 506.423494
# Iter 058 | Energy = 506.063095
# Iter 059 | Energy = 505.705389
# Iter 060 | Energy = 505.350116
# Iter 061 | Energy = 504.997261
# Iter 062 | Energy = 504.647106
# Iter 063 | Energy = 504.299575
# Iter 064 | Energy = 503.954537
# Iter 065 | Energy = 503.611988
# Iter 066 | Energy = 503.271851
# Iter 067 | Energy = 502.934067
# Iter 068 | Energy = 502.598683
# Iter 069 | Energy = 502.265687
# Iter 070 | Energy = 501.935036
# Iter 071 | Energy = 501.606732
# Iter 072 | Energy = 501.280760
# Iter 073 | Energy = 500.957072
# Iter 074 | Energy = 500.635651
# Iter 075 | Energy = 500.316489
# Iter 076 | Energy = 499.999562
# Iter 077 | Energy = 499.684856
# Iter 078 | Energy = 499.372359
# Iter 079 | Energy = 499.062050
# Iter 080 | Energy = 498.753912
# Iter 081 | Energy = 498.447928
# Iter 082 | Energy = 498.144080
# Iter 083 | Energy = 497.842352
# Iter 084 | Energy = 497.542729
# Iter 085 | Energy = 497.245197
# Iter 086 | Energy = 496.949738
# Iter 087 | Energy = 496.656339
# Iter 088 | Energy = 496.364982
# Iter 089 | Energy = 496.075654
# Iter 090 | Energy = 495.788338
# Iter 091 | Energy = 495.503020
# Iter 092 | Energy = 495.219686
# Iter 093 | Energy = 494.938321
# Iter 094 | Energy = 494.658911
# Iter 095 | Energy = 494.381441
# Iter 096 | Energy = 494.105897
# Iter 097 | Energy = 493.832266
# Iter 098 | Energy = 493.560532
# Iter 099 | Energy = 493.290683
# Iter 100 | Energy = 493.022704
# Iter 101 | Energy = 492.756582
# Iter 102 | Energy = 492.492304
# Iter 103 | Energy = 492.229856
# Iter 104 | Energy = 491.969225
# Iter 105 | Energy = 491.710398
# Iter 106 | Energy = 491.453362
# Iter 107 | Energy = 491.198103
# Iter 108 | Energy = 490.944609
# Iter 109 | Energy = 490.692868
# Iter 110 | Energy = 490.442867
# Iter 111 | Energy = 490.194592
# Iter 112 | Energy = 489.948032
# Iter 113 | Energy = 489.703175
# Iter 114 | Energy = 489.460007
# Iter 115 | Energy = 489.218518
# Iter 116 | Energy = 488.978694
# Iter 117 | Energy = 488.740524
# Iter 118 | Energy = 488.503996
# Iter 119 | Energy = 488.269099
# Iter 120 | Energy = 488.035820
# Iter 121 | Energy = 487.804148
# Iter 122 | Energy = 487.574072
# Iter 123 | Energy = 487.345580
# Iter 124 | Energy = 487.118660
# Iter 125 | Energy = 486.893302
# Iter 126 | Energy = 486.669494
# Iter 127 | Energy = 486.447226
# Iter 128 | Energy = 486.226486
# Iter 129 | Energy = 486.007263
# Iter 130 | Energy = 485.789546
# Iter 131 | Energy = 485.573326
# Iter 132 | Energy = 485.358591
# Iter 133 | Energy = 485.145330
# Iter 134 | Energy = 484.933533
# Iter 135 | Energy = 484.723190
# Iter 136 | Energy = 484.514290
# Iter 137 | Energy = 484.306823
# Iter 138 | Energy = 484.100779
# Iter 139 | Energy = 483.896148
# Iter 140 | Energy = 483.692920
# Iter 141 | Energy = 483.491084
# Iter 142 | Energy = 483.290631
# Iter 143 | Energy = 483.091552
# Iter 144 | Energy = 482.893835
# Iter 145 | Energy = 482.697472
# Iter 146 | Energy = 482.502454
# Iter 147 | Energy = 482.308770
# Iter 148 | Energy = 482.116411
# Iter 149 | Energy = 481.925368
# Iter 150 | Energy = 481.735631
# Iter 151 | Energy = 481.547192
# Iter 152 | Energy = 481.360041
# Iter 153 | Energy = 481.174168
# Iter 154 | Energy = 480.989566
# Iter 155 | Energy = 480.806224
# Iter 156 | Energy = 480.624135
# Iter 157 | Energy = 480.443289
# Iter 158 | Energy = 480.263677
# Iter 159 | Energy = 480.085292
# Iter 160 | Energy = 479.908123
# Iter 161 | Energy = 479.732163
# Iter 162 | Energy = 479.557403
# Iter 163 | Energy = 479.383835
# Iter 164 | Energy = 479.211450
# Iter 165 | Energy = 479.040240
# Iter 166 | Energy = 478.870197
# Iter 167 | Energy = 478.701312
# Iter 168 | Energy = 478.533578
# Iter 169 | Energy = 478.366986
# Iter 170 | Energy = 478.201528
# Iter 171 | Energy = 478.037197
# Iter 172 | Energy = 477.873984
# Iter 173 | Energy = 477.711882
# Iter 174 | Energy = 477.550883
# Iter 175 | Energy = 477.390978
# Iter 176 | Energy = 477.232162
# Iter 177 | Energy = 477.074425
# Iter 178 | Energy = 476.917760
# Iter 179 | Energy = 476.762160
# Iter 180 | Energy = 476.607618
# Iter 181 | Energy = 476.454125
# Iter 182 | Energy = 476.301675
# Iter 183 | Energy = 476.150261
# Iter 184 | Energy = 475.999874
# Iter 185 | Energy = 475.850509
# Iter 186 | Energy = 475.702157
# Iter 187 | Energy = 475.554812
# Iter 188 | Energy = 475.408467
# Iter 189 | Energy = 475.263115
# Iter 190 | Energy = 475.118749
# Iter 191 | Energy = 474.975361
# Iter 192 | Energy = 474.832946
# Iter 193 | Energy = 474.691496
# Iter 194 | Energy = 474.551005
# Iter 195 | Energy = 474.411466
# Iter 196 | Energy = 474.272872
# Iter 197 | Energy = 474.135218
# Iter 198 | Energy = 473.998495
# Iter 199 | Energy = 473.862699
# Iter 200 | Energy = 473.727822
# Iter 201 | Energy = 473.593858
# Iter 202 | Energy = 473.460800
# Iter 203 | Energy = 473.328644
# Iter 204 | Energy = 473.197381
# Iter 205 | Energy = 473.067006
# Iter 206 | Energy = 472.937513
# Iter 207 | Energy = 472.808896
# Iter 208 | Energy = 472.681149
# Iter 209 | Energy = 472.554265
# Iter 210 | Energy = 472.428239
# Iter 211 | Energy = 472.303064
# Iter 212 | Energy = 472.178736
# Iter 213 | Energy = 472.055247
# Iter 214 | Energy = 471.932593
# Iter 215 | Energy = 471.810767
# Iter 216 | Energy = 471.689764
# Iter 217 | Energy = 471.569577
# Iter 218 | Energy = 471.450203
# Iter 219 | Energy = 471.331633
# Iter 220 | Energy = 471.213865
# Iter 221 | Energy = 471.096890
# Iter 222 | Energy = 470.980705
# Iter 223 | Energy = 470.865304
# Iter 224 | Energy = 470.750681
# Iter 225 | Energy = 470.636832
# Iter 226 | Energy = 470.523749
# Iter 227 | Energy = 470.411430
# Iter 228 | Energy = 470.299867
# Iter 229 | Energy = 470.189056
# Iter 230 | Energy = 470.078992
# Iter 231 | Energy = 469.969670
# Iter 232 | Energy = 469.861084
# Iter 233 | Energy = 469.753230
# Iter 234 | Energy = 469.646102
# Iter 235 | Energy = 469.539696
# Iter 236 | Energy = 469.434006
# Iter 237 | Energy = 469.329027
# Iter 238 | Energy = 469.224755
# Iter 239 | Energy = 469.121185
# Iter 240 | Energy = 469.018312
# Iter 241 | Energy = 468.916132
# Iter 242 | Energy = 468.814638
# Iter 243 | Energy = 468.713828
# Iter 244 | Energy = 468.613695
# Iter 245 | Energy = 468.514236
# Iter 246 | Energy = 468.415446
# Iter 247 | Energy = 468.317320
# Iter 248 | Energy = 468.219854
# Iter 249 | Energy = 468.123043
# Iter 250 | Energy = 468.026882
# Iter 251 | Energy = 467.931368
# Iter 252 | Energy = 467.836495
# Iter 253 | Energy = 467.742260
# Iter 254 | Energy = 467.648658
# Iter 255 | Energy = 467.555685
# Iter 256 | Energy = 467.463336
# Iter 257 | Energy = 467.371607
# Iter 258 | Energy = 467.280494
# Iter 259 | Energy = 467.189993
# Iter 260 | Energy = 467.100099
# Iter 261 | Energy = 467.010809
# Iter 262 | Energy = 466.922118
# Iter 263 | Energy = 466.834022
# Iter 264 | Energy = 466.746517
# Iter 265 | Energy = 466.659600
# Iter 266 | Energy = 466.573265
# Iter 267 | Energy = 466.487509
# Iter 268 | Energy = 466.402329
# Iter 269 | Energy = 466.317720
# Iter 270 | Energy = 466.233678
# Iter 271 | Energy = 466.150199
# Iter 272 | Energy = 466.067280
# Iter 273 | Energy = 465.984917
# Iter 274 | Energy = 465.903106
# Iter 275 | Energy = 465.821843
# Iter 276 | Energy = 465.741125
# Iter 277 | Energy = 465.660948
# Iter 278 | Energy = 465.581307
# Iter 279 | Energy = 465.502200
# Iter 280 | Energy = 465.423623
# Iter 281 | Energy = 465.345573
# Iter 282 | Energy = 465.268045
# Iter 283 | Energy = 465.191036
# Iter 284 | Energy = 465.114542
# Iter 285 | Energy = 465.038561
# Iter 286 | Energy = 464.963088
# Iter 287 | Energy = 464.888121
# Iter 288 | Energy = 464.813655
# Iter 289 | Energy = 464.739687
# Iter 290 | Energy = 464.666215
# Iter 291 | Energy = 464.593234
# Iter 292 | Energy = 464.520741
# Iter 293 | Energy = 464.448733
# Iter 294 | Energy = 464.377207
# Iter 295 | Energy = 464.306159
# Iter 296 | Energy = 464.235586
# Iter 297 | Energy = 464.165486
# Iter 298 | Energy = 464.095853
# Iter 299 | Energy = 464.026687
# Iter 300 | Energy = 463.957983
# Iter 301 | Energy = 463.889738
# Iter 302 | Energy = 463.821949
# Iter 303 | Energy = 463.754613
# Iter 304 | Energy = 463.687727
# Iter 305 | Energy = 463.621288
# Iter 306 | Energy = 463.555293
# Iter 307 | Energy = 463.489739
# Iter 308 | Energy = 463.424622
# Iter 309 | Energy = 463.359941
# Iter 310 | Energy = 463.295692
# Iter 311 | Energy = 463.231871
# Iter 312 | Energy = 463.168477
# Iter 313 | Energy = 463.105507
# Iter 314 | Energy = 463.042956
# Iter 315 | Energy = 462.980823
# Iter 316 | Energy = 462.919105
# Iter 317 | Energy = 462.857799
# Iter 318 | Energy = 462.796903
# Iter 319 | Energy = 462.736412
# Iter 320 | Energy = 462.676325
# Iter 321 | Energy = 462.616639
# Iter 322 | Energy = 462.557352
# Iter 323 | Energy = 462.498460
# Iter 324 | Energy = 462.439961
# Iter 325 | Energy = 462.381852
# Iter 326 | Energy = 462.324130
# Iter 327 | Energy = 462.266794
# Iter 328 | Energy = 462.209840
# Iter 329 | Energy = 462.153266
# Iter 330 | Energy = 462.097069
# Iter 331 | Energy = 462.041247
# Iter 332 | Energy = 461.985797
# Iter 333 | Energy = 461.930716
# Iter 334 | Energy = 461.876003
# Iter 335 | Energy = 461.821654
# Iter 336 | Energy = 461.767668
# Iter 337 | Energy = 461.714042
# Iter 338 | Energy = 461.660772
# Iter 339 | Energy = 461.607858
# Iter 340 | Energy = 461.555297
# Iter 341 | Energy = 461.503085
# Iter 342 | Energy = 461.451222
# Iter 343 | Energy = 461.399704
# Iter 344 | Energy = 461.348529
# Iter 345 | Energy = 461.297695
# Iter 346 | Energy = 461.247199
# Iter 347 | Energy = 461.197040
# Iter 348 | Energy = 461.147215
# Iter 349 | Energy = 461.097722
# Iter 350 | Energy = 461.048558
# Iter 351 | Energy = 460.999722
# Iter 352 | Energy = 460.951210
# Iter 353 | Energy = 460.903022
# Iter 354 | Energy = 460.855155
# Iter 355 | Energy = 460.807606
# Iter 356 | Energy = 460.760373
# Iter 357 | Energy = 460.713455
# Iter 358 | Energy = 460.666849
# Iter 359 | Energy = 460.620554
# Iter 360 | Energy = 460.574566
# Iter 361 | Energy = 460.528884
# Iter 362 | Energy = 460.483507
# Iter 363 | Energy = 460.438431
# Iter 364 | Energy = 460.393655
# Iter 365 | Energy = 460.349177
# Iter 366 | Energy = 460.304995
# Iter 367 | Energy = 460.261107
# Iter 368 | Energy = 460.217510
# Iter 369 | Energy = 460.174204
# Iter 370 | Energy = 460.131185
# Iter 371 | Energy = 460.088453
# Iter 372 | Energy = 460.046005
# Iter 373 | Energy = 460.003838
# Iter 374 | Energy = 459.961953
# Iter 375 | Energy = 459.920346
# Iter 376 | Energy = 459.879015
# Iter 377 | Energy = 459.837959
# Iter 378 | Energy = 459.797176
# Iter 379 | Energy = 459.756664
# Iter 380 | Energy = 459.716422
# Iter 381 | Energy = 459.676447
# Iter 382 | Energy = 459.636737
# Iter 383 | Energy = 459.597292
# Iter 384 | Energy = 459.558108
# Iter 385 | Energy = 459.519185
# Iter 386 | Energy = 459.480520
# Iter 387 | Energy = 459.442113
# Iter 388 | Energy = 459.403960
# Iter 389 | Energy = 459.366061
# Iter 390 | Energy = 459.328414
# Iter 391 | Energy = 459.291017
# Iter 392 | Energy = 459.253868
# Iter 393 | Energy = 459.216966
# Iter 394 | Energy = 459.180309
# Iter 395 | Energy = 459.143896
# Iter 396 | Energy = 459.107724
# Iter 397 | Energy = 459.071793
# Iter 398 | Energy = 459.036100
# Iter 399 | Energy = 459.000644
# Iter 400 | Energy = 458.965423
# Iter 401 | Energy = 458.930437
# Iter 402 | Energy = 458.895682
# Iter 403 | Energy = 458.861159
# Iter 404 | Energy = 458.826864
# Iter 405 | Energy = 458.792798
# Iter 406 | Energy = 458.758957
# Iter 407 | Energy = 458.725341
# Iter 408 | Energy = 458.691948
# Iter 409 | Energy = 458.658776
# Iter 410 | Energy = 458.625825
# Iter 411 | Energy = 458.593093
# Iter 412 | Energy = 458.560577
# Iter 413 | Energy = 458.528278
# Iter 414 | Energy = 458.496193
# Iter 415 | Energy = 458.464320
# Iter 416 | Energy = 458.432659
# Iter 417 | Energy = 458.401209
# Iter 418 | Energy = 458.369966
# Iter 419 | Energy = 458.338931
# Iter 420 | Energy = 458.308102
# Iter 421 | Energy = 458.277478
# Iter 422 | Energy = 458.247056
# Iter 423 | Energy = 458.216837
# Iter 424 | Energy = 458.186817
# Iter 425 | Energy = 458.156997
# Iter 426 | Energy = 458.127375
# Iter 427 | Energy = 458.097949
# Iter 428 | Energy = 458.068718
# Iter 429 | Energy = 458.039681
# Iter 430 | Energy = 458.010837
# Iter 431 | Energy = 457.982184
# Iter 432 | Energy = 457.953721
# Iter 433 | Energy = 457.925446
# Iter 434 | Energy = 457.897359
# Iter 435 | Energy = 457.869458
# Iter 436 | Energy = 457.841742
# Iter 437 | Energy = 457.814210
# Iter 438 | Energy = 457.786861
# Iter 439 | Energy = 457.759692
# Iter 440 | Energy = 457.732704
# Iter 441 | Energy = 457.705895
# Iter 442 | Energy = 457.679263
# Iter 443 | Energy = 457.652808
# Iter 444 | Energy = 457.626528
# Iter 445 | Energy = 457.600422
# Iter 446 | Energy = 457.574490
# Iter 447 | Energy = 457.548729
# Iter 448 | Energy = 457.523139
# Iter 449 | Energy = 457.497718
# Iter 450 | Energy = 457.472466
# Iter 451 | Energy = 457.447381
# Iter 452 | Energy = 457.422462
# Iter 453 | Energy = 457.397709
# Iter 454 | Energy = 457.373119
# Iter 455 | Energy = 457.348693
# Iter 456 | Energy = 457.324428
# Iter 457 | Energy = 457.300324
# Iter 458 | Energy = 457.276379
# Iter 459 | Energy = 457.252593
# Iter 460 | Energy = 457.228965
# Iter 461 | Energy = 457.205493
# Iter 462 | Energy = 457.182177
# Iter 463 | Energy = 457.159015
# Iter 464 | Energy = 457.136006
# Iter 465 | Energy = 457.113150
# Iter 466 | Energy = 457.090446
# Iter 467 | Energy = 457.067891
# Iter 468 | Energy = 457.045486
# Iter 469 | Energy = 457.023229
# Iter 470 | Energy = 457.001120
# Iter 471 | Energy = 456.979157
# Iter 472 | Energy = 456.957340
# Iter 473 | Energy = 456.935666
# Iter 474 | Energy = 456.914137
# Iter 475 | Energy = 456.892750
# Iter 476 | Energy = 456.871504
# Iter 477 | Energy = 456.850400
# Iter 478 | Energy = 456.829435
# Iter 479 | Energy = 456.808608
# Iter 480 | Energy = 456.787920
# Iter 481 | Energy = 456.767368
# Iter 482 | Energy = 456.746953
# Iter 483 | Energy = 456.726672
# Iter 484 | Energy = 456.706526
# Iter 485 | Energy = 456.686514
# Iter 486 | Energy = 456.666633
# Iter 487 | Energy = 456.646885
# Iter 488 | Energy = 456.627266
# Iter 489 | Energy = 456.607778
# Iter 490 | Energy = 456.588419
# Iter 491 | Energy = 456.569188
# Iter 492 | Energy = 456.550084
# Iter 493 | Energy = 456.531107
# Iter 494 | Energy = 456.512255
# Iter 495 | Energy = 456.493528
# Iter 496 | Energy = 456.474924
# Iter 497 | Energy = 456.456444
# Iter 498 | Energy = 456.438086
# Iter 499 | Energy = 456.419850
# Iter 500 | Energy = 456.401734
# Iter 501 | Energy = 456.383738
# Iter 502 | Energy = 456.365861
# Iter 503 | Energy = 456.348103
# Iter 504 | Energy = 456.330462
# Iter 505 | Energy = 456.312937
# Iter 506 | Energy = 456.295529
# Iter 507 | Energy = 456.278235
# Iter 508 | Energy = 456.261056
# Iter 509 | Energy = 456.243991
# Iter 510 | Energy = 456.227039
# Iter 511 | Energy = 456.210198
# Iter 512 | Energy = 456.193469
# Iter 513 | Energy = 456.176851
# Iter 514 | Energy = 456.160343
# Iter 515 | Energy = 456.143943
# Iter 516 | Energy = 456.127653
# Iter 517 | Energy = 456.111470
# Iter 518 | Energy = 456.095394
# Iter 519 | Energy = 456.079424
# Iter 520 | Energy = 456.063560
# Iter 521 | Energy = 456.047801
# Iter 522 | Energy = 456.032146
# Iter 523 | Energy = 456.016594
# Iter 524 | Energy = 456.001146
# Iter 525 | Energy = 455.985799
# Iter 526 | Energy = 455.970554
# Iter 527 | Energy = 455.955410
# Iter 528 | Energy = 455.940366
# Iter 529 | Energy = 455.925421
# Iter 530 | Energy = 455.910576
# Iter 531 | Energy = 455.895828
# Iter 532 | Energy = 455.881178
# Iter 533 | Energy = 455.866625
# Iter 534 | Energy = 455.852167
# Iter 535 | Energy = 455.837806
# Iter 536 | Energy = 455.823539
# Iter 537 | Energy = 455.809367
# Iter 538 | Energy = 455.795289
# Iter 539 | Energy = 455.781303
# Iter 540 | Energy = 455.767410
# Iter 541 | Energy = 455.753609
# Iter 542 | Energy = 455.739899
# Iter 543 | Energy = 455.726279
# Iter 544 | Energy = 455.712750
# Iter 545 | Energy = 455.699310
# Iter 546 | Energy = 455.685959
# Iter 547 | Energy = 455.672696
# Iter 548 | Energy = 455.659521
# Iter 549 | Energy = 455.646433
# Iter 550 | Energy = 455.633431
# Iter 551 | Energy = 455.620515
# Iter 552 | Energy = 455.607685
# Iter 553 | Energy = 455.594939
# Iter 554 | Energy = 455.582278
# Iter 555 | Energy = 455.569700
# Iter 556 | Energy = 455.557206
# Iter 557 | Energy = 455.544794
# Iter 558 | Energy = 455.532464
# Iter 559 | Energy = 455.520215
# Iter 560 | Energy = 455.508048
# Iter 561 | Energy = 455.495960
# Iter 562 | Energy = 455.483953
# Iter 563 | Energy = 455.472025
# Iter 564 | Energy = 455.460176
# Iter 565 | Energy = 455.448405
# Iter 566 | Energy = 455.436712
# Iter 567 | Energy = 455.425096
# Iter 568 | Energy = 455.413557
# Iter 569 | Energy = 455.402094
# Iter 570 | Energy = 455.390707
# Iter 571 | Energy = 455.379395
# Iter 572 | Energy = 455.368158
# Iter 573 | Energy = 455.356995
# Iter 574 | Energy = 455.345906
# Iter 575 | Energy = 455.334890
# Iter 576 | Energy = 455.323947
# Iter 577 | Energy = 455.313076
# Iter 578 | Energy = 455.302277
# Iter 579 | Energy = 455.291549
# Iter 580 | Energy = 455.280892
# Iter 581 | Energy = 455.270305
# Iter 582 | Energy = 455.259789
# Iter 583 | Energy = 455.249342
# Iter 584 | Energy = 455.238964
# Iter 585 | Energy = 455.228654
# Iter 586 | Energy = 455.218413
# Iter 587 | Energy = 455.208239
# Iter 588 | Energy = 455.198132
# Iter 589 | Energy = 455.188093
# Iter 590 | Energy = 455.178119
# Iter 591 | Energy = 455.168211
# Iter 592 | Energy = 455.158369
# Iter 593 | Energy = 455.148592
# Iter 594 | Energy = 455.138879
# Iter 595 | Energy = 455.129231
# Iter 596 | Energy = 455.119646
# Iter 597 | Energy = 455.110124
# Iter 598 | Energy = 455.100666
# Iter 599 | Energy = 455.091270
# Iter 600 | Energy = 455.081935
# Iter 601 | Energy = 455.072663
# Iter 602 | Energy = 455.063452
# Iter 603 | Energy = 455.054301
# Iter 604 | Energy = 455.045211
# Iter 605 | Energy = 455.036181
# Iter 606 | Energy = 455.027211
# Iter 607 | Energy = 455.018300
# Iter 608 | Energy = 455.009448
# Iter 609 | Energy = 455.000654
# Iter 610 | Energy = 454.991918
# Iter 611 | Energy = 454.983240
# Iter 612 | Energy = 454.974619
# Iter 613 | Energy = 454.966055
# Iter 614 | Energy = 454.957548
# Iter 615 | Energy = 454.949097
# Iter 616 | Energy = 454.940702
# Iter 617 | Energy = 454.932362
# Iter 618 | Energy = 454.924077
# Iter 619 | Energy = 454.915847
# Iter 620 | Energy = 454.907671
# Iter 621 | Energy = 454.899549
# Iter 622 | Energy = 454.891481
# Iter 623 | Energy = 454.883466
# Iter 624 | Energy = 454.875504
# Iter 625 | Energy = 454.867594
# Iter 626 | Energy = 454.859737
# Iter 627 | Energy = 454.851932
# Iter 628 | Energy = 454.844178
# Iter 629 | Energy = 454.836475
# Iter 630 | Energy = 454.828823
# Iter 631 | Energy = 454.821222
# Iter 632 | Energy = 454.813671
# Iter 633 | Energy = 454.806170
# Iter 634 | Energy = 454.798718
# Iter 635 | Energy = 454.791315
# Iter 636 | Energy = 454.783962
# Iter 637 | Energy = 454.776656
# Iter 638 | Energy = 454.769399
# Iter 639 | Energy = 454.762190
# Iter 640 | Energy = 454.755029
# Iter 641 | Energy = 454.747915
# Iter 642 | Energy = 454.740848
# Iter 643 | Energy = 454.733827
# Iter 644 | Energy = 454.726853
# Iter 645 | Energy = 454.719924
# Iter 646 | Energy = 454.713042
# Iter 647 | Energy = 454.706205
# Iter 648 | Energy = 454.699413
# Iter 649 | Energy = 454.692666
# Iter 650 | Energy = 454.685963
# Iter 651 | Energy = 454.679305
# Iter 652 | Energy = 454.672690
# Iter 653 | Energy = 454.666120
# Iter 654 | Energy = 454.659592
# Iter 655 | Energy = 454.653108
# Iter 656 | Energy = 454.646667
# Iter 657 | Energy = 454.640268
# Iter 658 | Energy = 454.633911
# Iter 659 | Energy = 454.627596
# Iter 660 | Energy = 454.621323
# Iter 661 | Energy = 454.615091
# Iter 662 | Energy = 454.608900
# Iter 663 | Energy = 454.602751
# Iter 664 | Energy = 454.596642
# Iter 665 | Energy = 454.590573
# Iter 666 | Energy = 454.584544
# Iter 667 | Energy = 454.578555
# Iter 668 | Energy = 454.572605
# Iter 669 | Energy = 454.566695
# Iter 670 | Energy = 454.560824
# Iter 671 | Energy = 454.554991
# Iter 672 | Energy = 454.549197
# Iter 673 | Energy = 454.543441
# Iter 674 | Energy = 454.537724
# Iter 675 | Energy = 454.532044
# Iter 676 | Energy = 454.526401
# Iter 677 | Energy = 454.520796
# Iter 678 | Energy = 454.515227
# Iter 679 | Energy = 454.509696
# Iter 680 | Energy = 454.504201
# Iter 681 | Energy = 454.498742
# Iter 682 | Energy = 454.493319
# Iter 683 | Energy = 454.487932
# Iter 684 | Energy = 454.482580
# Iter 685 | Energy = 454.477264
# Iter 686 | Energy = 454.471983
# Iter 687 | Energy = 454.466737
# Iter 688 | Energy = 454.461525
# Iter 689 | Energy = 454.456348
# Iter 690 | Energy = 454.451204
# Iter 691 | Energy = 454.446095
# Iter 692 | Energy = 454.441020
# Iter 693 | Energy = 454.435978
# Iter 694 | Energy = 454.430969
# Iter 695 | Energy = 454.425993
# Iter 696 | Energy = 454.421050
# Iter 697 | Energy = 454.416140
# Iter 698 | Energy = 454.411262
# Iter 699 | Energy = 454.406417
# Iter 700 | Energy = 454.401603
# Iter 701 | Energy = 454.396821
# Iter 702 | Energy = 454.392071
# Iter 703 | Energy = 454.387351
# Iter 704 | Energy = 454.382664
# Iter 705 | Energy = 454.378007
# Iter 706 | Energy = 454.373380
# Iter 707 | Energy = 454.368784
# Iter 708 | Energy = 454.364219
# Iter 709 | Energy = 454.359684
# Iter 710 | Energy = 454.355178
# Iter 711 | Energy = 454.350703
# Iter 712 | Energy = 454.346256
# Iter 713 | Energy = 454.341840
# Iter 714 | Energy = 454.337452
# Iter 715 | Energy = 454.333093
# Iter 716 | Energy = 454.328763
# Iter 717 | Energy = 454.324462
# Iter 718 | Energy = 454.320189
# Iter 719 | Energy = 454.315944
# Iter 720 | Energy = 454.311727
# Iter 721 | Energy = 454.307538
# Iter 722 | Energy = 454.303376
# Iter 723 | Energy = 454.299243
# Iter 724 | Energy = 454.295136
# Iter 725 | Energy = 454.291056
# Iter 726 | Energy = 454.287004
# Iter 727 | Energy = 454.282978
# Iter 728 | Energy = 454.278978
# Iter 729 | Energy = 454.275005
# Iter 730 | Energy = 454.271058
# Iter 731 | Energy = 454.267138
# Iter 732 | Energy = 454.263243
# Iter 733 | Energy = 454.259373
# Iter 734 | Energy = 454.255530
# Iter 735 | Energy = 454.251711
# Iter 736 | Energy = 454.247918
# Iter 737 | Energy = 454.244150
# Iter 738 | Energy = 454.240407
# Iter 739 | Energy = 454.236688
# Iter 740 | Energy = 454.232994
# Iter 741 | Energy = 454.229324
# Iter 742 | Energy = 454.225679
# Iter 743 | Energy = 454.222057
# Iter 744 | Energy = 454.218460
# Iter 745 | Energy = 454.214886
# Iter 746 | Energy = 454.211336
# Iter 747 | Energy = 454.207809
# Iter 748 | Energy = 454.204305
# Iter 749 | Energy = 454.200825
# Iter 750 | Energy = 454.197367
# Iter 751 | Energy = 454.193932
# Iter 752 | Energy = 454.190520
# Iter 753 | Energy = 454.187131
# Iter 754 | Energy = 454.183763
# Iter 755 | Energy = 454.180418
# Iter 756 | Energy = 454.177095
# Iter 757 | Energy = 454.173794
# Iter 758 | Energy = 454.170515
# Iter 759 | Energy = 454.167257
# Iter 760 | Energy = 454.164021
# Iter 761 | Energy = 454.160807
# Iter 762 | Energy = 454.157613
# Iter 763 | Energy = 454.154440
# Iter 764 | Energy = 454.151289
# Iter 765 | Energy = 454.148158
# Iter 766 | Energy = 454.145048
# Iter 767 | Energy = 454.141958
# Iter 768 | Energy = 454.138889
# Iter 769 | Energy = 454.135840
# Iter 770 | Energy = 454.132811
# Iter 771 | Energy = 454.129802
# Iter 772 | Energy = 454.126813
# Iter 773 | Energy = 454.123843
# Iter 774 | Energy = 454.120893
# Iter 775 | Energy = 454.117963
# Iter 776 | Energy = 454.115052
# Iter 777 | Energy = 454.112160
# Iter 778 | Energy = 454.109287
# Iter 779 | Energy = 454.106433
# Iter 780 | Energy = 454.103598
# Iter 781 | Energy = 454.100782
# Iter 782 | Energy = 454.097984
# Iter 783 | Energy = 454.095205
# Iter 784 | Energy = 454.092444
# Iter 785 | Energy = 454.089701
# Iter 786 | Energy = 454.086977
# Iter 787 | Energy = 454.084270
# Iter 788 | Energy = 454.081581
# Iter 789 | Energy = 454.078910
# Iter 790 | Energy = 454.076256
# Iter 791 | Energy = 454.073620
# Iter 792 | Energy = 454.071002
# Iter 793 | Energy = 454.068400
# Iter 794 | Energy = 454.065816
# Iter 795 | Energy = 454.063249
# Iter 796 | Energy = 454.060699
# Iter 797 | Energy = 454.058165
# Iter 798 | Energy = 454.055648
# Iter 799 | Energy = 454.053148
# Iter 800 | Energy = 454.050665
# Iter 801 | Energy = 454.048197
# Iter 802 | Energy = 454.045746
# Iter 803 | Energy = 454.043312
# Iter 804 | Energy = 454.040893
# Iter 805 | Energy = 454.038490
# Iter 806 | Energy = 454.036103
# Iter 807 | Energy = 454.033732
# Iter 808 | Energy = 454.031376
# Iter 809 | Energy = 454.029036
# Iter 810 | Energy = 454.026711
# Iter 811 | Energy = 454.024402
# Iter 812 | Energy = 454.022108
# Iter 813 | Energy = 454.019829
# Iter 814 | Energy = 454.017565
# Iter 815 | Energy = 454.015316
# Iter 816 | Energy = 454.013082
# Iter 817 | Energy = 454.010862
# Iter 818 | Energy = 454.008658
# Iter 819 | Energy = 454.006467
# Iter 820 | Energy = 454.004291
# Iter 821 | Energy = 454.002130
# Iter 822 | Energy = 453.999983
# Iter 823 | Energy = 453.997850
# Iter 824 | Energy = 453.995731
# Iter 825 | Energy = 453.993626
# Iter 826 | Energy = 453.991534
# Iter 827 | Energy = 453.989457
# Iter 828 | Energy = 453.987393
# Iter 829 | Energy = 453.985343
# Iter 830 | Energy = 453.983307
# Iter 831 | Energy = 453.981284
# Iter 832 | Energy = 453.979274
# Iter 833 | Energy = 453.977277
# Iter 834 | Energy = 453.975294
# Iter 835 | Energy = 453.973324
# Iter 836 | Energy = 453.971366
# Iter 837 | Energy = 453.969422
# Iter 838 | Energy = 453.967490
# Iter 839 | Energy = 453.965572
# Iter 840 | Energy = 453.963665
# Iter 841 | Energy = 453.961772
# Iter 842 | Energy = 453.959891
# Iter 843 | Energy = 453.958022
# Iter 844 | Energy = 453.956165
# Iter 845 | Energy = 453.954321
# Iter 846 | Energy = 453.952489
# Iter 847 | Energy = 453.950669
# Iter 848 | Energy = 453.948861
# Iter 849 | Energy = 453.947065
# Iter 850 | Energy = 453.945281
# Iter 851 | Energy = 453.943509
# Iter 852 | Energy = 453.941748
# Iter 853 | Energy = 453.939999
# Iter 854 | Energy = 453.938261
# Iter 855 | Energy = 453.936535
# Iter 856 | Energy = 453.934820
# Iter 857 | Energy = 453.933117
# Iter 858 | Energy = 453.931425
# Iter 859 | Energy = 453.929744
# Iter 860 | Energy = 453.928074
# Iter 861 | Energy = 453.926415
# Iter 862 | Energy = 453.924767
# Iter 863 | Energy = 453.923130
# Iter 864 | Energy = 453.921503
# Iter 865 | Energy = 453.919888
# Iter 866 | Energy = 453.918283
# Iter 867 | Energy = 453.916688
# Iter 868 | Energy = 453.915104
# Iter 869 | Energy = 453.913531
# Iter 870 | Energy = 453.911968
# Iter 871 | Energy = 453.910415
# Iter 872 | Energy = 453.908872
# Iter 873 | Energy = 453.907340
# Iter 874 | Energy = 453.905818
# Iter 875 | Energy = 453.904306
# Iter 876 | Energy = 453.902803
# Iter 877 | Energy = 453.901311
# Iter 878 | Energy = 453.899828
# Iter 879 | Energy = 453.898356
# Iter 880 | Energy = 453.896893
# Iter 881 | Energy = 453.895439
# Iter 882 | Energy = 453.893995
# Iter 883 | Energy = 453.892561
# Iter 884 | Energy = 453.891136
# Iter 885 | Energy = 453.889721
# Iter 886 | Energy = 453.888315
# Iter 887 | Energy = 453.886918
# Iter 888 | Energy = 453.885530
# Iter 889 | Energy = 453.884152
# Iter 890 | Energy = 453.882782
# Iter 891 | Energy = 453.881422
# Iter 892 | Energy = 453.880071
# Iter 893 | Energy = 453.878728
# Iter 894 | Energy = 453.877394
# Iter 895 | Energy = 453.876070
# Iter 896 | Energy = 453.874753
# Iter 897 | Energy = 453.873446
# Iter 898 | Energy = 453.872147
# Iter 899 | Energy = 453.870857
# Iter 900 | Energy = 453.869575
# Iter 901 | Energy = 453.868302
# Iter 902 | Energy = 453.867037
# Iter 903 | Energy = 453.865780
# Iter 904 | Energy = 453.864532
# Iter 905 | Energy = 453.863292
# Iter 906 | Energy = 453.862060
# Iter 907 | Energy = 453.860836
# Iter 908 | Energy = 453.859621
# Iter 909 | Energy = 453.858413
# Iter 910 | Energy = 453.857213
# Iter 911 | Energy = 453.856022
# Iter 912 | Energy = 453.854838
# Iter 913 | Energy = 453.853661
# Iter 914 | Energy = 453.852493
# Iter 915 | Energy = 453.851332
# Iter 916 | Energy = 453.850179
# Iter 917 | Energy = 453.849034
# Iter 918 | Energy = 453.847896
# Iter 919 | Energy = 453.846766
# Iter 920 | Energy = 453.845643
# Iter 921 | Energy = 453.844527
# Iter 922 | Energy = 453.843419
# Iter 923 | Energy = 453.842318
# Iter 924 | Energy = 453.841224
# Iter 925 | Energy = 453.840138
# Iter 926 | Energy = 453.839059
# Iter 927 | Energy = 453.837987
# Iter 928 | Energy = 453.836922
# Iter 929 | Energy = 453.835864
# Iter 930 | Energy = 453.834813
# Iter 931 | Energy = 453.833768
# Iter 932 | Energy = 453.832731
# Iter 933 | Energy = 453.831701
# Iter 934 | Energy = 453.830677
# Iter 935 | Energy = 453.829660
# Iter 936 | Energy = 453.828650
# Iter 937 | Energy = 453.827647
# Iter 938 | Energy = 453.826650
# Iter 939 | Energy = 453.825659
# Iter 940 | Energy = 453.824676
# Iter 941 | Energy = 453.823698
# Iter 942 | Energy = 453.822727
# Iter 943 | Energy = 453.821763
# Iter 944 | Energy = 453.820805
# Iter 945 | Energy = 453.819853
# Iter 946 | Energy = 453.818907
# Iter 947 | Energy = 453.817968
# Iter 948 | Energy = 453.817035
# Iter 949 | Energy = 453.816108
# Iter 950 | Energy = 453.815187
# Iter 951 | Energy = 453.814272
# Iter 952 | Energy = 453.813364
# Iter 953 | Energy = 453.812461
# Iter 954 | Energy = 453.811564
# Iter 955 | Energy = 453.810673
# Iter 956 | Energy = 453.809788
# Iter 957 | Energy = 453.808909
# Iter 958 | Energy = 453.808036
# Iter 959 | Energy = 453.807168
# Iter 960 | Energy = 453.806306
# Iter 961 | Energy = 453.805450
# Iter 962 | Energy = 453.804599
# Iter 963 | Energy = 453.803754
# Iter 964 | Energy = 453.802915
# Iter 965 | Energy = 453.802081
# Iter 966 | Energy = 453.801253
# Iter 967 | Energy = 453.800430
# Iter 968 | Energy = 453.799612
# Iter 969 | Energy = 453.798800
# Iter 970 | Energy = 453.797994
# Iter 971 | Energy = 453.797192
# Iter 972 | Energy = 453.796396
# Iter 973 | Energy = 453.795605
# Iter 974 | Energy = 453.794819
# Iter 975 | Energy = 453.794039
# Iter 976 | Energy = 453.793263
# Iter 977 | Energy = 453.792493
# Iter 978 | Energy = 453.791728
# Iter 979 | Energy = 453.790968
# Iter 980 | Energy = 453.790213
# Iter 981 | Energy = 453.789463
# Iter 982 | Energy = 453.788717
# Iter 983 | Energy = 453.787977
# Iter 984 | Energy = 453.787242
# Iter 985 | Energy = 453.786511
# Iter 986 | Energy = 453.785785
# Iter 987 | Energy = 453.785065
# Iter 988 | Energy = 453.784348
# Iter 989 | Energy = 453.783637
# Iter 990 | Energy = 453.782930
# Iter 991 | Energy = 453.782228
# Iter 992 | Energy = 453.781530
# Iter 993 | Energy = 453.780837
# Iter 994 | Energy = 453.780149
# Iter 995 | Energy = 453.779465
# Iter 996 | Energy = 453.778786
# Iter 997 | Energy = 453.778111
# Iter 998 | Energy = 453.777441
# Iter 999 | Energy = 453.776775
# Iter 1000 | Energy = 453.776113

# %%
supergraph = layers[-1]["graph"]
for it in range(1000):
    supergraph.synchronous_iteration()
    energy = supergraph.energy_map(include_priors=True, include_factors=True)
    print(f"Iter {it+1:03d} | Energy = {energy:.6f}")
# Out:
# Iter 001 | Energy = nan
# Iter 002 | Energy = nan
# Iter 003 | Energy = nan
# Iter 004 | Energy = nan
# Iter 005 | Energy = nan
# Iter 006 | Energy = nan
# Iter 007 | Energy = nan
# Iter 008 | Energy = nan
# Iter 009 | Energy = nan
# Iter 010 | Energy = nan
# Iter 011 | Energy = nan
# Iter 012 | Energy = nan
# Iter 013 | Energy = nan
# Iter 014 | Energy = nan
# Iter 015 | Energy = nan
# Iter 016 | Energy = 550.441208
# Iter 017 | Energy = 539.654051
# Iter 018 | Energy = 530.056178
# Iter 019 | Energy = 524.786365
# Iter 020 | Energy = 524.125733
# Iter 021 | Energy = 523.053179
# Iter 022 | Energy = 520.731847
# Iter 023 | Energy = 519.705554
# Iter 024 | Energy = 519.257536
# Iter 025 | Energy = 518.588418
# Iter 026 | Energy = 518.642361
# Iter 027 | Energy = 518.892212
# Iter 028 | Energy = 518.685474
# Iter 029 | Energy = 517.908418
# Iter 030 | Energy = 517.330123
# Iter 031 | Energy = 516.944545
# Iter 032 | Energy = 516.384745
# Iter 033 | Energy = 515.987702
# Iter 034 | Energy = 515.632004
# Iter 035 | Energy = 515.167727
# Iter 036 | Energy = 514.724276
# Iter 037 | Energy = 514.300199
# Iter 038 | Energy = 513.836851
# Iter 039 | Energy = 513.393017
# Iter 040 | Energy = 512.987892
# Iter 041 | Energy = 512.580453
# Iter 042 | Energy = 512.174188
# Iter 043 | Energy = 511.781464
# Iter 044 | Energy = 511.383575
# Iter 045 | Energy = 510.975285
# Iter 046 | Energy = 510.574751
# Iter 047 | Energy = 510.182308
# Iter 048 | Energy = 509.792955
# Iter 049 | Energy = 509.409125
# Iter 050 | Energy = 509.028800
# Iter 051 | Energy = 508.649165
# Iter 052 | Energy = 508.271705
# Iter 053 | Energy = 507.896983
# Iter 054 | Energy = 507.524633
# Iter 055 | Energy = 507.155799
# Iter 056 | Energy = 506.790618
# Iter 057 | Energy = 506.427907
# Iter 058 | Energy = 506.067483
# Iter 059 | Energy = 505.709751
# Iter 060 | Energy = 505.354454
# Iter 061 | Energy = 505.001574
# Iter 062 | Energy = 504.651395
# Iter 063 | Energy = 504.303840
# Iter 064 | Energy = 503.958778
# Iter 065 | Energy = 503.616206
# Iter 066 | Energy = 503.276045
# Iter 067 | Energy = 502.938238
# Iter 068 | Energy = 502.602830
# Iter 069 | Energy = 502.269811
# Iter 070 | Energy = 501.939137
# Iter 071 | Energy = 501.610810
# Iter 072 | Energy = 501.284815
# Iter 073 | Energy = 500.961105
# Iter 074 | Energy = 500.639662
# Iter 075 | Energy = 500.320477
# Iter 076 | Energy = 500.003528
# Iter 077 | Energy = 499.688800
# Iter 078 | Energy = 499.376281
# Iter 079 | Energy = 499.065951
# Iter 080 | Energy = 498.757790
# Iter 081 | Energy = 498.451784
# Iter 082 | Energy = 498.147915
# Iter 083 | Energy = 497.846166
# Iter 084 | Energy = 497.546522
# Iter 085 | Energy = 497.248968
# Iter 086 | Energy = 496.953489
# Iter 087 | Energy = 496.660068
# Iter 088 | Energy = 496.368691
# Iter 089 | Energy = 496.079341
# Iter 090 | Energy = 495.792005
# Iter 091 | Energy = 495.506667
# Iter 092 | Energy = 495.223312
# Iter 093 | Energy = 494.941927
# Iter 094 | Energy = 494.662496
# Iter 095 | Energy = 494.385006
# Iter 096 | Energy = 494.109442
# Iter 097 | Energy = 493.835791
# Iter 098 | Energy = 493.564037
# Iter 099 | Energy = 493.294168
# Iter 100 | Energy = 493.026169
# Iter 101 | Energy = 492.760028
# Iter 102 | Energy = 492.495731
# Iter 103 | Energy = 492.233263
# Iter 104 | Energy = 491.972613
# Iter 105 | Energy = 491.713767
# Iter 106 | Energy = 491.456711
# Iter 107 | Energy = 491.201434
# Iter 108 | Energy = 490.947921
# Iter 109 | Energy = 490.696161
# Iter 110 | Energy = 490.446141
# Iter 111 | Energy = 490.197848
# Iter 112 | Energy = 489.951269
# Iter 113 | Energy = 489.706393
# Iter 114 | Energy = 489.463208
# Iter 115 | Energy = 489.221700
# Iter 116 | Energy = 488.981858
# Iter 117 | Energy = 488.743670
# Iter 118 | Energy = 488.507125
# Iter 119 | Energy = 488.272209
# Iter 120 | Energy = 488.038913
# Iter 121 | Energy = 487.807223
# Iter 122 | Energy = 487.577129
# Iter 123 | Energy = 487.348620
# Iter 124 | Energy = 487.121683
# Iter 125 | Energy = 486.896307
# Iter 126 | Energy = 486.672482
# Iter 127 | Energy = 486.450197
# Iter 128 | Energy = 486.229440
# Iter 129 | Energy = 486.010200
# Iter 130 | Energy = 485.792467
# Iter 131 | Energy = 485.576229
# Iter 132 | Energy = 485.361477
# Iter 133 | Energy = 485.148200
# Iter 134 | Energy = 484.936387
# Iter 135 | Energy = 484.726027
# Iter 136 | Energy = 484.517111
# Iter 137 | Energy = 484.309628
# Iter 138 | Energy = 484.103568
# Iter 139 | Energy = 483.898921
# Iter 140 | Energy = 483.695677
# Iter 141 | Energy = 483.493825
# Iter 142 | Energy = 483.293356
# Iter 143 | Energy = 483.094261
# Iter 144 | Energy = 482.896529
# Iter 145 | Energy = 482.700151
# Iter 146 | Energy = 482.505117
# Iter 147 | Energy = 482.311417
# Iter 148 | Energy = 482.119043
# Iter 149 | Energy = 481.927985
# Iter 150 | Energy = 481.738233
# Iter 151 | Energy = 481.549779
# Iter 152 | Energy = 481.362613
# Iter 153 | Energy = 481.176725
# Iter 154 | Energy = 480.992108
# Iter 155 | Energy = 480.808752
# Iter 156 | Energy = 480.626648
# Iter 157 | Energy = 480.445788
# Iter 158 | Energy = 480.266162
# Iter 159 | Energy = 480.087762
# Iter 160 | Energy = 479.910579
# Iter 161 | Energy = 479.734605
# Iter 162 | Energy = 479.559831
# Iter 163 | Energy = 479.386248
# Iter 164 | Energy = 479.213850
# Iter 165 | Energy = 479.042626
# Iter 166 | Energy = 478.872569
# Iter 167 | Energy = 478.703670
# Iter 168 | Energy = 478.535922
# Iter 169 | Energy = 478.369317
# Iter 170 | Energy = 478.203846
# Iter 171 | Energy = 478.039501
# Iter 172 | Energy = 477.876275
# Iter 173 | Energy = 477.714159
# Iter 174 | Energy = 477.553147
# Iter 175 | Energy = 477.393229
# Iter 176 | Energy = 477.234400
# Iter 177 | Energy = 477.076650
# Iter 178 | Energy = 476.919972
# Iter 179 | Energy = 476.764359
# Iter 180 | Energy = 476.609804
# Iter 181 | Energy = 476.456299
# Iter 182 | Energy = 476.303836
# Iter 183 | Energy = 476.152409
# Iter 184 | Energy = 476.002011
# Iter 185 | Energy = 475.852633
# Iter 186 | Energy = 475.704269
# Iter 187 | Energy = 475.556912
# Iter 188 | Energy = 475.410555
# Iter 189 | Energy = 475.265190
# Iter 190 | Energy = 475.120812
# Iter 191 | Energy = 474.977412
# Iter 192 | Energy = 474.834985
# Iter 193 | Energy = 474.693524
# Iter 194 | Energy = 474.553021
# Iter 195 | Energy = 474.413470
# Iter 196 | Energy = 474.274865
# Iter 197 | Energy = 474.137199
# Iter 198 | Energy = 474.000465
# Iter 199 | Energy = 473.864657
# Iter 200 | Energy = 473.729769
# Iter 201 | Energy = 473.595793
# Iter 202 | Energy = 473.462725
# Iter 203 | Energy = 473.330557
# Iter 204 | Energy = 473.199283
# Iter 205 | Energy = 473.068897
# Iter 206 | Energy = 472.939393
# Iter 207 | Energy = 472.810765
# Iter 208 | Energy = 472.683007
# Iter 209 | Energy = 472.556113
# Iter 210 | Energy = 472.430076
# Iter 211 | Energy = 472.304891
# Iter 212 | Energy = 472.180552
# Iter 213 | Energy = 472.057053
# Iter 214 | Energy = 471.934388
# Iter 215 | Energy = 471.812551
# Iter 216 | Energy = 471.691538
# Iter 217 | Energy = 471.571341
# Iter 218 | Energy = 471.451956
# Iter 219 | Energy = 471.333377
# Iter 220 | Energy = 471.215598
# Iter 221 | Energy = 471.098614
# Iter 222 | Energy = 470.982419
# Iter 223 | Energy = 470.867008
# Iter 224 | Energy = 470.752375
# Iter 225 | Energy = 470.638516
# Iter 226 | Energy = 470.525424
# Iter 227 | Energy = 470.413094
# Iter 228 | Energy = 470.301522
# Iter 229 | Energy = 470.190702
# Iter 230 | Energy = 470.080629
# Iter 231 | Energy = 469.971297
# Iter 232 | Energy = 469.862702
# Iter 233 | Energy = 469.754838
# Iter 234 | Energy = 469.647701
# Iter 235 | Energy = 469.541285
# Iter 236 | Energy = 469.435586
# Iter 237 | Energy = 469.330598
# Iter 238 | Energy = 469.226318
# Iter 239 | Energy = 469.122739
# Iter 240 | Energy = 469.019857
# Iter 241 | Energy = 468.917667
# Iter 242 | Energy = 468.816165
# Iter 243 | Energy = 468.715346
# Iter 244 | Energy = 468.615205
# Iter 245 | Energy = 468.515737
# Iter 246 | Energy = 468.416938
# Iter 247 | Energy = 468.318804
# Iter 248 | Energy = 468.221329
# Iter 249 | Energy = 468.124509
# Iter 250 | Energy = 468.028340
# Iter 251 | Energy = 467.932817
# Iter 252 | Energy = 467.837937
# Iter 253 | Energy = 467.743693
# Iter 254 | Energy = 467.650083
# Iter 255 | Energy = 467.557102
# Iter 256 | Energy = 467.464745
# Iter 257 | Energy = 467.373008
# Iter 258 | Energy = 467.281887
# Iter 259 | Energy = 467.191378
# Iter 260 | Energy = 467.101476
# Iter 261 | Energy = 467.012178
# Iter 262 | Energy = 466.923479
# Iter 263 | Energy = 466.835375
# Iter 264 | Energy = 466.747863
# Iter 265 | Energy = 466.660937
# Iter 266 | Energy = 466.574595
# Iter 267 | Energy = 466.488832
# Iter 268 | Energy = 466.403644
# Iter 269 | Energy = 466.319027
# Iter 270 | Energy = 466.234978
# Iter 271 | Energy = 466.151492
# Iter 272 | Energy = 466.068566
# Iter 273 | Energy = 465.986195
# Iter 274 | Energy = 465.904377
# Iter 275 | Energy = 465.823107
# Iter 276 | Energy = 465.742382
# Iter 277 | Energy = 465.662197
# Iter 278 | Energy = 465.582550
# Iter 279 | Energy = 465.503436
# Iter 280 | Energy = 465.424852
# Iter 281 | Energy = 465.346794
# Iter 282 | Energy = 465.269259
# Iter 283 | Energy = 465.192243
# Iter 284 | Energy = 465.115743
# Iter 285 | Energy = 465.039755
# Iter 286 | Energy = 464.964276
# Iter 287 | Energy = 464.889301
# Iter 288 | Energy = 464.814829
# Iter 289 | Energy = 464.740855
# Iter 290 | Energy = 464.667376
# Iter 291 | Energy = 464.594388
# Iter 292 | Energy = 464.521889
# Iter 293 | Energy = 464.449875
# Iter 294 | Energy = 464.378342
# Iter 295 | Energy = 464.307288
# Iter 296 | Energy = 464.236709
# Iter 297 | Energy = 464.166602
# Iter 298 | Energy = 464.096963
# Iter 299 | Energy = 464.027790
# Iter 300 | Energy = 463.959080
# Iter 301 | Energy = 463.890829
# Iter 302 | Energy = 463.823034
# Iter 303 | Energy = 463.755692
# Iter 304 | Energy = 463.688800
# Iter 305 | Energy = 463.622355
# Iter 306 | Energy = 463.556354
# Iter 307 | Energy = 463.490794
# Iter 308 | Energy = 463.425672
# Iter 309 | Energy = 463.360985
# Iter 310 | Energy = 463.296730
# Iter 311 | Energy = 463.232904
# Iter 312 | Energy = 463.169504
# Iter 313 | Energy = 463.106527
# Iter 314 | Energy = 463.043971
# Iter 315 | Energy = 462.981833
# Iter 316 | Energy = 462.920109
# Iter 317 | Energy = 462.858798
# Iter 318 | Energy = 462.797895
# Iter 319 | Energy = 462.737399
# Iter 320 | Energy = 462.677307
# Iter 321 | Energy = 462.617616
# Iter 322 | Energy = 462.558323
# Iter 323 | Energy = 462.499426
# Iter 324 | Energy = 462.440921
# Iter 325 | Energy = 462.382807
# Iter 326 | Energy = 462.325080
# Iter 327 | Energy = 462.267739
# Iter 328 | Energy = 462.210780
# Iter 329 | Energy = 462.154200
# Iter 330 | Energy = 462.097998
# Iter 331 | Energy = 462.042171
# Iter 332 | Energy = 461.986716
# Iter 333 | Energy = 461.931630
# Iter 334 | Energy = 461.876912
# Iter 335 | Energy = 461.822559
# Iter 336 | Energy = 461.768567
# Iter 337 | Energy = 461.714936
# Iter 338 | Energy = 461.661662
# Iter 339 | Energy = 461.608743
# Iter 340 | Energy = 461.556177
# Iter 341 | Energy = 461.503960
# Iter 342 | Energy = 461.452092
# Iter 343 | Energy = 461.400569
# Iter 344 | Energy = 461.349390
# Iter 345 | Energy = 461.298551
# Iter 346 | Energy = 461.248051
# Iter 347 | Energy = 461.197887
# Iter 348 | Energy = 461.148058
# Iter 349 | Energy = 461.098560
# Iter 350 | Energy = 461.049392
# Iter 351 | Energy = 461.000551
# Iter 352 | Energy = 460.952035
# Iter 353 | Energy = 460.903842
# Iter 354 | Energy = 460.855970
# Iter 355 | Energy = 460.808417
# Iter 356 | Energy = 460.761180
# Iter 357 | Energy = 460.714258
# Iter 358 | Energy = 460.667648
# Iter 359 | Energy = 460.621348
# Iter 360 | Energy = 460.575356
# Iter 361 | Energy = 460.529670
# Iter 362 | Energy = 460.484289
# Iter 363 | Energy = 460.439209
# Iter 364 | Energy = 460.394429
# Iter 365 | Energy = 460.349946
# Iter 366 | Energy = 460.305760
# Iter 367 | Energy = 460.261868
# Iter 368 | Energy = 460.218267
# Iter 369 | Energy = 460.174957
# Iter 370 | Energy = 460.131935
# Iter 371 | Energy = 460.089198
# Iter 372 | Energy = 460.046746
# Iter 373 | Energy = 460.004576
# Iter 374 | Energy = 459.962687
# Iter 375 | Energy = 459.921076
# Iter 376 | Energy = 459.879741
# Iter 377 | Energy = 459.838682
# Iter 378 | Energy = 459.797895
# Iter 379 | Energy = 459.757379
# Iter 380 | Energy = 459.717133
# Iter 381 | Energy = 459.677154
# Iter 382 | Energy = 459.637441
# Iter 383 | Energy = 459.597992
# Iter 384 | Energy = 459.558805
# Iter 385 | Energy = 459.519878
# Iter 386 | Energy = 459.481210
# Iter 387 | Energy = 459.442799
# Iter 388 | Energy = 459.404643
# Iter 389 | Energy = 459.366740
# Iter 390 | Energy = 459.329089
# Iter 391 | Energy = 459.291689
# Iter 392 | Energy = 459.254537
# Iter 393 | Energy = 459.217631
# Iter 394 | Energy = 459.180971
# Iter 395 | Energy = 459.144554
# Iter 396 | Energy = 459.108379
# Iter 397 | Energy = 459.072444
# Iter 398 | Energy = 459.036748
# Iter 399 | Energy = 459.001289
# Iter 400 | Energy = 458.966065
# Iter 401 | Energy = 458.931075
# Iter 402 | Energy = 458.896317
# Iter 403 | Energy = 458.861791
# Iter 404 | Energy = 458.827493
# Iter 405 | Energy = 458.793423
# Iter 406 | Energy = 458.759579
# Iter 407 | Energy = 458.725960
# Iter 408 | Energy = 458.692564
# Iter 409 | Energy = 458.659390
# Iter 410 | Energy = 458.626435
# Iter 411 | Energy = 458.593700
# Iter 412 | Energy = 458.561181
# Iter 413 | Energy = 458.528879
# Iter 414 | Energy = 458.496791
# Iter 415 | Energy = 458.464915
# Iter 416 | Energy = 458.433251
# Iter 417 | Energy = 458.401798
# Iter 418 | Energy = 458.370553
# Iter 419 | Energy = 458.339515
# Iter 420 | Energy = 458.308683
# Iter 421 | Energy = 458.278055
# Iter 422 | Energy = 458.247631
# Iter 423 | Energy = 458.217409
# Iter 424 | Energy = 458.187387
# Iter 425 | Energy = 458.157564
# Iter 426 | Energy = 458.127939
# Iter 427 | Energy = 458.098510
# Iter 428 | Energy = 458.069276
# Iter 429 | Energy = 458.040237
# Iter 430 | Energy = 458.011390
# Iter 431 | Energy = 457.982734
# Iter 432 | Energy = 457.954268
# Iter 433 | Energy = 457.925991
# Iter 434 | Energy = 457.897901
# Iter 435 | Energy = 457.869998
# Iter 436 | Energy = 457.842279
# Iter 437 | Energy = 457.814745
# Iter 438 | Energy = 457.787392
# Iter 439 | Energy = 457.760222
# Iter 440 | Energy = 457.733231
# Iter 441 | Energy = 457.706419
# Iter 442 | Energy = 457.679785
# Iter 443 | Energy = 457.653327
# Iter 444 | Energy = 457.627045
# Iter 445 | Energy = 457.600937
# Iter 446 | Energy = 457.575001
# Iter 447 | Energy = 457.549238
# Iter 448 | Energy = 457.523646
# Iter 449 | Energy = 457.498223
# Iter 450 | Energy = 457.472968
# Iter 451 | Energy = 457.447881
# Iter 452 | Energy = 457.422960
# Iter 453 | Energy = 457.398204
# Iter 454 | Energy = 457.373612
# Iter 455 | Energy = 457.349183
# Iter 456 | Energy = 457.324916
# Iter 457 | Energy = 457.300810
# Iter 458 | Energy = 457.276863
# Iter 459 | Energy = 457.253075
# Iter 460 | Energy = 457.229444
# Iter 461 | Energy = 457.205970
# Iter 462 | Energy = 457.182652
# Iter 463 | Energy = 457.159488
# Iter 464 | Energy = 457.136477
# Iter 465 | Energy = 457.113619
# Iter 466 | Energy = 457.090912
# Iter 467 | Energy = 457.068355
# Iter 468 | Energy = 457.045948
# Iter 469 | Energy = 457.023689
# Iter 470 | Energy = 457.001578
# Iter 471 | Energy = 456.979613
# Iter 472 | Energy = 456.957793
# Iter 473 | Energy = 456.936118
# Iter 474 | Energy = 456.914587
# Iter 475 | Energy = 456.893198
# Iter 476 | Energy = 456.871950
# Iter 477 | Energy = 456.850843
# Iter 478 | Energy = 456.829876
# Iter 479 | Energy = 456.809048
# Iter 480 | Energy = 456.788358
# Iter 481 | Energy = 456.767804
# Iter 482 | Energy = 456.747387
# Iter 483 | Energy = 456.727105
# Iter 484 | Energy = 456.706957
# Iter 485 | Energy = 456.686942
# Iter 486 | Energy = 456.667060
# Iter 487 | Energy = 456.647309
# Iter 488 | Energy = 456.627689
# Iter 489 | Energy = 456.608199
# Iter 490 | Energy = 456.588838
# Iter 491 | Energy = 456.569605
# Iter 492 | Energy = 456.550500
# Iter 493 | Energy = 456.531520
# Iter 494 | Energy = 456.512667
# Iter 495 | Energy = 456.493938
# Iter 496 | Energy = 456.475333
# Iter 497 | Energy = 456.456851
# Iter 498 | Energy = 456.438491
# Iter 499 | Energy = 456.420253
# Iter 500 | Energy = 456.402136
# Iter 501 | Energy = 456.384138
# Iter 502 | Energy = 456.366259
# Iter 503 | Energy = 456.348499
# Iter 504 | Energy = 456.330856
# Iter 505 | Energy = 456.313330
# Iter 506 | Energy = 456.295920
# Iter 507 | Energy = 456.278625
# Iter 508 | Energy = 456.261445
# Iter 509 | Energy = 456.244378
# Iter 510 | Energy = 456.227424
# Iter 511 | Energy = 456.210582
# Iter 512 | Energy = 456.193851
# Iter 513 | Energy = 456.177231
# Iter 514 | Energy = 456.160721
# Iter 515 | Energy = 456.144321
# Iter 516 | Energy = 456.128028
# Iter 517 | Energy = 456.111844
# Iter 518 | Energy = 456.095766
# Iter 519 | Energy = 456.079795
# Iter 520 | Energy = 456.063930
# Iter 521 | Energy = 456.048169
# Iter 522 | Energy = 456.032512
# Iter 523 | Energy = 456.016960
# Iter 524 | Energy = 456.001509
# Iter 525 | Energy = 455.986162
# Iter 526 | Energy = 455.970915
# Iter 527 | Energy = 455.955769
# Iter 528 | Energy = 455.940724
# Iter 529 | Energy = 455.925778
# Iter 530 | Energy = 455.910931
# Iter 531 | Energy = 455.896182
# Iter 532 | Energy = 455.881530
# Iter 533 | Energy = 455.866976
# Iter 534 | Energy = 455.852517
# Iter 535 | Energy = 455.838154
# Iter 536 | Energy = 455.823886
# Iter 537 | Energy = 455.809713
# Iter 538 | Energy = 455.795633
# Iter 539 | Energy = 455.781646
# Iter 540 | Energy = 455.767752
# Iter 541 | Energy = 455.753949
# Iter 542 | Energy = 455.740238
# Iter 543 | Energy = 455.726617
# Iter 544 | Energy = 455.713086
# Iter 545 | Energy = 455.699645
# Iter 546 | Energy = 455.686293
# Iter 547 | Energy = 455.673029
# Iter 548 | Energy = 455.659852
# Iter 549 | Energy = 455.646763
# Iter 550 | Energy = 455.633760
# Iter 551 | Energy = 455.620843
# Iter 552 | Energy = 455.608011
# Iter 553 | Energy = 455.595264
# Iter 554 | Energy = 455.582602
# Iter 555 | Energy = 455.570023
# Iter 556 | Energy = 455.557527
# Iter 557 | Energy = 455.545114
# Iter 558 | Energy = 455.532783
# Iter 559 | Energy = 455.520533
# Iter 560 | Energy = 455.508364
# Iter 561 | Energy = 455.496276
# Iter 562 | Energy = 455.484268
# Iter 563 | Energy = 455.472339
# Iter 564 | Energy = 455.460488
# Iter 565 | Energy = 455.448716
# Iter 566 | Energy = 455.437022
# Iter 567 | Energy = 455.425405
# Iter 568 | Energy = 455.413865
# Iter 569 | Energy = 455.402401
# Iter 570 | Energy = 455.391013
# Iter 571 | Energy = 455.379700
# Iter 572 | Energy = 455.368461
# Iter 573 | Energy = 455.357297
# Iter 574 | Energy = 455.346207
# Iter 575 | Energy = 455.335190
# Iter 576 | Energy = 455.324246
# Iter 577 | Energy = 455.313374
# Iter 578 | Energy = 455.302574
# Iter 579 | Energy = 455.291845
# Iter 580 | Energy = 455.281187
# Iter 581 | Energy = 455.270600
# Iter 582 | Energy = 455.260082
# Iter 583 | Energy = 455.249634
# Iter 584 | Energy = 455.239255
# Iter 585 | Energy = 455.228945
# Iter 586 | Energy = 455.218702
# Iter 587 | Energy = 455.208527
# Iter 588 | Energy = 455.198420
# Iter 589 | Energy = 455.188379
# Iter 590 | Energy = 455.178405
# Iter 591 | Energy = 455.168496
# Iter 592 | Energy = 455.158653
# Iter 593 | Energy = 455.148875
# Iter 594 | Energy = 455.139161
# Iter 595 | Energy = 455.129512
# Iter 596 | Energy = 455.119926
# Iter 597 | Energy = 455.110403
# Iter 598 | Energy = 455.100944
# Iter 599 | Energy = 455.091547
# Iter 600 | Energy = 455.082212
# Iter 601 | Energy = 455.072939
# Iter 602 | Energy = 455.063726
# Iter 603 | Energy = 455.054575
# Iter 604 | Energy = 455.045484
# Iter 605 | Energy = 455.036453
# Iter 606 | Energy = 455.027482
# Iter 607 | Energy = 455.018570
# Iter 608 | Energy = 455.009717
# Iter 609 | Energy = 455.000923
# Iter 610 | Energy = 454.992186
# Iter 611 | Energy = 454.983507
# Iter 612 | Energy = 454.974885
# Iter 613 | Energy = 454.966321
# Iter 614 | Energy = 454.957813
# Iter 615 | Energy = 454.949361
# Iter 616 | Energy = 454.940965
# Iter 617 | Energy = 454.932624
# Iter 618 | Energy = 454.924338
# Iter 619 | Energy = 454.916107
# Iter 620 | Energy = 454.907931
# Iter 621 | Energy = 454.899808
# Iter 622 | Energy = 454.891739
# Iter 623 | Energy = 454.883723
# Iter 624 | Energy = 454.875761
# Iter 625 | Energy = 454.867850
# Iter 626 | Energy = 454.859992
# Iter 627 | Energy = 454.852186
# Iter 628 | Energy = 454.844432
# Iter 629 | Energy = 454.836728
# Iter 630 | Energy = 454.829076
# Iter 631 | Energy = 454.821474
# Iter 632 | Energy = 454.813922
# Iter 633 | Energy = 454.806420
# Iter 634 | Energy = 454.798967
# Iter 635 | Energy = 454.791564
# Iter 636 | Energy = 454.784210
# Iter 637 | Energy = 454.776904
# Iter 638 | Energy = 454.769646
# Iter 639 | Energy = 454.762436
# Iter 640 | Energy = 454.755274
# Iter 641 | Energy = 454.748159
# Iter 642 | Energy = 454.741091
# Iter 643 | Energy = 454.734070
# Iter 644 | Energy = 454.727095
# Iter 645 | Energy = 454.720166
# Iter 646 | Energy = 454.713283
# Iter 647 | Energy = 454.706445
# Iter 648 | Energy = 454.699653
# Iter 649 | Energy = 454.692905
# Iter 650 | Energy = 454.686202
# Iter 651 | Energy = 454.679543
# Iter 652 | Energy = 454.672928
# Iter 653 | Energy = 454.666356
# Iter 654 | Energy = 454.659828
# Iter 655 | Energy = 454.653344
# Iter 656 | Energy = 454.646901
# Iter 657 | Energy = 454.640502
# Iter 658 | Energy = 454.634144
# Iter 659 | Energy = 454.627829
# Iter 660 | Energy = 454.621555
# Iter 661 | Energy = 454.615323
# Iter 662 | Energy = 454.609132
# Iter 663 | Energy = 454.602981
# Iter 664 | Energy = 454.596872
# Iter 665 | Energy = 454.590802
# Iter 666 | Energy = 454.584773
# Iter 667 | Energy = 454.578783
# Iter 668 | Energy = 454.572833
# Iter 669 | Energy = 454.566922
# Iter 670 | Energy = 454.561050
# Iter 671 | Energy = 454.555217
# Iter 672 | Energy = 454.549423
# Iter 673 | Energy = 454.543667
# Iter 674 | Energy = 454.537948
# Iter 675 | Energy = 454.532268
# Iter 676 | Energy = 454.526624
# Iter 677 | Energy = 454.521019
# Iter 678 | Energy = 454.515450
# Iter 679 | Energy = 454.509917
# Iter 680 | Energy = 454.504422
# Iter 681 | Energy = 454.498962
# Iter 682 | Energy = 454.493539
# Iter 683 | Energy = 454.488151
# Iter 684 | Energy = 454.482799
# Iter 685 | Energy = 454.477483
# Iter 686 | Energy = 454.472201
# Iter 687 | Energy = 454.466954
# Iter 688 | Energy = 454.461742
# Iter 689 | Energy = 454.456564
# Iter 690 | Energy = 454.451421
# Iter 691 | Energy = 454.446311
# Iter 692 | Energy = 454.441235
# Iter 693 | Energy = 454.436192
# Iter 694 | Energy = 454.431183
# Iter 695 | Energy = 454.426207
# Iter 696 | Energy = 454.421264
# Iter 697 | Energy = 454.416353
# Iter 698 | Energy = 454.411475
# Iter 699 | Energy = 454.406629
# Iter 700 | Energy = 454.401814
# Iter 701 | Energy = 454.397032
# Iter 702 | Energy = 454.392281
# Iter 703 | Energy = 454.387562
# Iter 704 | Energy = 454.382873
# Iter 705 | Energy = 454.378216
# Iter 706 | Energy = 454.373589
# Iter 707 | Energy = 454.368993
# Iter 708 | Energy = 454.364427
# Iter 709 | Energy = 454.359891
# Iter 710 | Energy = 454.355385
# Iter 711 | Energy = 454.350909
# Iter 712 | Energy = 454.346463
# Iter 713 | Energy = 454.342045
# Iter 714 | Energy = 454.337657
# Iter 715 | Energy = 454.333298
# Iter 716 | Energy = 454.328968
# Iter 717 | Energy = 454.324666
# Iter 718 | Energy = 454.320392
# Iter 719 | Energy = 454.316147
# Iter 720 | Energy = 454.311930
# Iter 721 | Energy = 454.307740
# Iter 722 | Energy = 454.303579
# Iter 723 | Energy = 454.299444
# Iter 724 | Energy = 454.295337
# Iter 725 | Energy = 454.291257
# Iter 726 | Energy = 454.287204
# Iter 727 | Energy = 454.283178
# Iter 728 | Energy = 454.279178
# Iter 729 | Energy = 454.275204
# Iter 730 | Energy = 454.271257
# Iter 731 | Energy = 454.267336
# Iter 732 | Energy = 454.263441
# Iter 733 | Energy = 454.259571
# Iter 734 | Energy = 454.255727
# Iter 735 | Energy = 454.251908
# Iter 736 | Energy = 454.248115
# Iter 737 | Energy = 454.244346
# Iter 738 | Energy = 454.240603
# Iter 739 | Energy = 454.236884
# Iter 740 | Energy = 454.233189
# Iter 741 | Energy = 454.229519
# Iter 742 | Energy = 454.225873
# Iter 743 | Energy = 454.222252
# Iter 744 | Energy = 454.218654
# Iter 745 | Energy = 454.215079
# Iter 746 | Energy = 454.211529
# Iter 747 | Energy = 454.208002
# Iter 748 | Energy = 454.204498
# Iter 749 | Energy = 454.201017
# Iter 750 | Energy = 454.197559
# Iter 751 | Energy = 454.194124
# Iter 752 | Energy = 454.190711
# Iter 753 | Energy = 454.187322
# Iter 754 | Energy = 454.183954
# Iter 755 | Energy = 454.180609
# Iter 756 | Energy = 454.177285
# Iter 757 | Energy = 454.173984
# Iter 758 | Energy = 454.170704
# Iter 759 | Energy = 454.167447
# Iter 760 | Energy = 454.164210
# Iter 761 | Energy = 454.160995
# Iter 762 | Energy = 454.157801
# Iter 763 | Energy = 454.154628
# Iter 764 | Energy = 454.151476
# Iter 765 | Energy = 454.148345
# Iter 766 | Energy = 454.145235
# Iter 767 | Energy = 454.142145
# Iter 768 | Energy = 454.139075
# Iter 769 | Energy = 454.136026
# Iter 770 | Energy = 454.132996
# Iter 771 | Energy = 454.129987
# Iter 772 | Energy = 454.126998
# Iter 773 | Energy = 454.124028
# Iter 774 | Energy = 454.121078
# Iter 775 | Energy = 454.118147
# Iter 776 | Energy = 454.115236
# Iter 777 | Energy = 454.112344
# Iter 778 | Energy = 454.109471
# Iter 779 | Energy = 454.106617
# Iter 780 | Energy = 454.103781
# Iter 781 | Energy = 454.100965
# Iter 782 | Energy = 454.098167
# Iter 783 | Energy = 454.095387
# Iter 784 | Energy = 454.092626
# Iter 785 | Energy = 454.089883
# Iter 786 | Energy = 454.087158
# Iter 787 | Energy = 454.084451
# Iter 788 | Energy = 454.081762
# Iter 789 | Energy = 454.079090
# Iter 790 | Energy = 454.076437
# Iter 791 | Energy = 454.073800
# Iter 792 | Energy = 454.071181
# Iter 793 | Energy = 454.068580
# Iter 794 | Energy = 454.065995
# Iter 795 | Energy = 454.063428
# Iter 796 | Energy = 454.060877
# Iter 797 | Energy = 454.058344
# Iter 798 | Energy = 454.055827
# Iter 799 | Energy = 454.053326
# Iter 800 | Energy = 454.050842
# Iter 801 | Energy = 454.048375
# Iter 802 | Energy = 454.045924
# Iter 803 | Energy = 454.043489
# Iter 804 | Energy = 454.041070
# Iter 805 | Energy = 454.038667
# Iter 806 | Energy = 454.036279
# Iter 807 | Energy = 454.033908
# Iter 808 | Energy = 454.031552
# Iter 809 | Energy = 454.029212
# Iter 810 | Energy = 454.026887
# Iter 811 | Energy = 454.024577
# Iter 812 | Energy = 454.022283
# Iter 813 | Energy = 454.020004
# Iter 814 | Energy = 454.017740
# Iter 815 | Energy = 454.015490
# Iter 816 | Energy = 454.013256
# Iter 817 | Energy = 454.011036
# Iter 818 | Energy = 454.008831
# Iter 819 | Energy = 454.006641
# Iter 820 | Energy = 454.004465
# Iter 821 | Energy = 454.002303
# Iter 822 | Energy = 454.000156
# Iter 823 | Energy = 453.998022
# Iter 824 | Energy = 453.995903
# Iter 825 | Energy = 453.993798
# Iter 826 | Energy = 453.991707
# Iter 827 | Energy = 453.989629
# Iter 828 | Energy = 453.987565
# Iter 829 | Energy = 453.985515
# Iter 830 | Energy = 453.983478
# Iter 831 | Energy = 453.981455
# Iter 832 | Energy = 453.979445
# Iter 833 | Energy = 453.977448
# Iter 834 | Energy = 453.975465
# Iter 835 | Energy = 453.973494
# Iter 836 | Energy = 453.971537
# Iter 837 | Energy = 453.969592
# Iter 838 | Energy = 453.967660
# Iter 839 | Energy = 453.965741
# Iter 840 | Energy = 453.963835
# Iter 841 | Energy = 453.961941
# Iter 842 | Energy = 453.960060
# Iter 843 | Energy = 453.958191
# Iter 844 | Energy = 453.956334
# Iter 845 | Energy = 453.954490
# Iter 846 | Energy = 453.952658
# Iter 847 | Energy = 453.950838
# Iter 848 | Energy = 453.949029
# Iter 849 | Energy = 453.947233
# Iter 850 | Energy = 453.945449
# Iter 851 | Energy = 453.943676
# Iter 852 | Energy = 453.941915
# Iter 853 | Energy = 453.940166
# Iter 854 | Energy = 453.938428
# Iter 855 | Energy = 453.936702
# Iter 856 | Energy = 453.934987
# Iter 857 | Energy = 453.933284
# Iter 858 | Energy = 453.931591
# Iter 859 | Energy = 453.929910
# Iter 860 | Energy = 453.928240
# Iter 861 | Energy = 453.926581
# Iter 862 | Energy = 453.924932
# Iter 863 | Energy = 453.923295
# Iter 864 | Energy = 453.921669
# Iter 865 | Energy = 453.920053
# Iter 866 | Energy = 453.918448
# Iter 867 | Energy = 453.916853
# Iter 868 | Energy = 453.915269
# Iter 869 | Energy = 453.913695
# Iter 870 | Energy = 453.912132
# Iter 871 | Energy = 453.910579
# Iter 872 | Energy = 453.909037
# Iter 873 | Energy = 453.907504
# Iter 874 | Energy = 453.905982
# Iter 875 | Energy = 453.904469
# Iter 876 | Energy = 453.902967
# Iter 877 | Energy = 453.901474
# Iter 878 | Energy = 453.899992
# Iter 879 | Energy = 453.898519
# Iter 880 | Energy = 453.897056
# Iter 881 | Energy = 453.895602
# Iter 882 | Energy = 453.894158
# Iter 883 | Energy = 453.892724
# Iter 884 | Energy = 453.891299
# Iter 885 | Energy = 453.889883
# Iter 886 | Energy = 453.888477
# Iter 887 | Energy = 453.887080
# Iter 888 | Energy = 453.885692
# Iter 889 | Energy = 453.884314
# Iter 890 | Energy = 453.882944
# Iter 891 | Energy = 453.881584
# Iter 892 | Energy = 453.880232
# Iter 893 | Energy = 453.878889
# Iter 894 | Energy = 453.877556
# Iter 895 | Energy = 453.876231
# Iter 896 | Energy = 453.874914
# Iter 897 | Energy = 453.873607
# Iter 898 | Energy = 453.872308
# Iter 899 | Energy = 453.871018
# Iter 900 | Energy = 453.869736
# Iter 901 | Energy = 453.868462
# Iter 902 | Energy = 453.867197
# Iter 903 | Energy = 453.865941
# Iter 904 | Energy = 453.864692
# Iter 905 | Energy = 453.863452
# Iter 906 | Energy = 453.862220
# Iter 907 | Energy = 453.860996
# Iter 908 | Energy = 453.859780
# Iter 909 | Energy = 453.858572
# Iter 910 | Energy = 453.857373
# Iter 911 | Energy = 453.856181
# Iter 912 | Energy = 453.854997
# Iter 913 | Energy = 453.853820
# Iter 914 | Energy = 453.852652
# Iter 915 | Energy = 453.851491
# Iter 916 | Energy = 453.850338
# Iter 917 | Energy = 453.849192
# Iter 918 | Energy = 453.848054
# Iter 919 | Energy = 453.846924
# Iter 920 | Energy = 453.845801
# Iter 921 | Energy = 453.844685
# Iter 922 | Energy = 453.843577
# Iter 923 | Energy = 453.842476
# Iter 924 | Energy = 453.841382
# Iter 925 | Energy = 453.840296
# Iter 926 | Energy = 453.839216
# Iter 927 | Energy = 453.838144
# Iter 928 | Energy = 453.837079
# Iter 929 | Energy = 453.836021
# Iter 930 | Energy = 453.834970
# Iter 931 | Energy = 453.833925
# Iter 932 | Energy = 453.832888
# Iter 933 | Energy = 453.831858
# Iter 934 | Energy = 453.830834
# Iter 935 | Energy = 453.829817
# Iter 936 | Energy = 453.828807
# Iter 937 | Energy = 453.827803
# Iter 938 | Energy = 453.826806
# Iter 939 | Energy = 453.825816
# Iter 940 | Energy = 453.824832
# Iter 941 | Energy = 453.823854
# Iter 942 | Energy = 453.822883
# Iter 943 | Energy = 453.821919
# Iter 944 | Energy = 453.820961
# Iter 945 | Energy = 453.820009
# Iter 946 | Energy = 453.819063
# Iter 947 | Energy = 453.818124
# Iter 948 | Energy = 453.817190
# Iter 949 | Energy = 453.816263
# Iter 950 | Energy = 453.815342
# Iter 951 | Energy = 453.814428
# Iter 952 | Energy = 453.813519
# Iter 953 | Energy = 453.812616
# Iter 954 | Energy = 453.811719
# Iter 955 | Energy = 453.810828
# Iter 956 | Energy = 453.809943
# Iter 957 | Energy = 453.809064
# Iter 958 | Energy = 453.808190
# Iter 959 | Energy = 453.807323
# Iter 960 | Energy = 453.806461
# Iter 961 | Energy = 453.805604
# Iter 962 | Energy = 453.804754
# Iter 963 | Energy = 453.803909
# Iter 964 | Energy = 453.803069
# Iter 965 | Energy = 453.802235
# Iter 966 | Energy = 453.801407
# Iter 967 | Energy = 453.800584
# Iter 968 | Energy = 453.799766
# Iter 969 | Energy = 453.798954
# Iter 970 | Energy = 453.798147
# Iter 971 | Energy = 453.797346
# Iter 972 | Energy = 453.796549
# Iter 973 | Energy = 453.795758
# Iter 974 | Energy = 453.794973
# Iter 975 | Energy = 453.794192
# Iter 976 | Energy = 453.793417
# Iter 977 | Energy = 453.792646
# Iter 978 | Energy = 453.791881
# Iter 979 | Energy = 453.791121
# Iter 980 | Energy = 453.790366
# Iter 981 | Energy = 453.789615
# Iter 982 | Energy = 453.788870
# Iter 983 | Energy = 453.788130
# Iter 984 | Energy = 453.787394
# Iter 985 | Energy = 453.786664
# Iter 986 | Energy = 453.785938
# Iter 987 | Energy = 453.785217
# Iter 988 | Energy = 453.784501
# Iter 989 | Energy = 453.783789
# Iter 990 | Energy = 453.783082
# Iter 991 | Energy = 453.782380
# Iter 992 | Energy = 453.781682
# Iter 993 | Energy = 453.780989
# Iter 994 | Energy = 453.780301
# Iter 995 | Energy = 453.779617
# Iter 996 | Energy = 453.778938
# Iter 997 | Energy = 453.778263
# Iter 998 | Energy = 453.777592
# Iter 999 | Energy = 453.776926
# Iter 1000 | Energy = 453.776265

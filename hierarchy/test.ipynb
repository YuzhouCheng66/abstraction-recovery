# %%
import numpy as np
from gbp.gbp import FactorGraph, VariableNode, Factor

# -----------------------
# SLAM-like base graph
# -----------------------
def make_slam_like_graph(N=100, step_size=25, loop_prob=0.2, loop_radius=50, rng=None):
    if rng is None:
        rng = np.random.default_rng()

    nodes, edges = [], []
    positions = []
    x, y = 0.0, 0.0
    positions.append((x, y))

    # 随机游走生成轨迹
    for _ in range(1, int(N)):
        dx, dy = rng.normal(size=2)
        norm = np.sqrt(dx**2 + dy**2) + 1e-6
        dx, dy = dx / norm * float(step_size), dy / norm * float(step_size)
        x, y = x + dx, y + dy
        positions.append((x, y))

    # 节点
    for i, (px, py) in enumerate(positions):
        nodes.append({
            "data": {"id": f"b{i}", "layer": 0, "dim": 2},
            "position": {"x": float(px), "y": float(py)}
        })

    # 顺序边
    for i in range(int(N) - 1):
        edges.append({"data": {"source": f"b{i}", "target": f"b{i+1}"}})

    # 随机回环
    for i in range(int(N)):
        for j in range(i + 5, int(N)):
            if rng.random() < float(loop_prob):
                xi, yi = positions[i]; xj, yj = positions[j]
                if np.hypot(xi-xj, yi-yj) < float(loop_radius):
                    edges.append({"data": {"source": f"b{i}", "target": f"b{j}"}})
    return nodes, edges


# -----------------------
# GBP Graph 构建
# -----------------------
def build_noisy_pose_graph(
    nodes,
    edges,
    prior_sigma: float = 10,
    odom_sigma: float = 10,
    prior_prop: float = 0.0,
    tiny_prior: float = 1e-6,
    rng=None,
):
    """
    构造二维 pose-only 因子图（线性，高斯），并注入噪声。
    参数:
      prior_sigma : 强先验的标准差（小=强）
      odom_sigma  : 里程计测量噪声标准差
      prior_prop  : 0.0=仅 anchor；(0,1)=按比例随机选；>=1.0=全体
      tiny_prior  : 所有节点默认加的极小先验，防止奇异
    """
    if rng is None:
        rng = np.random.default_rng()

    fg = FactorGraph(nonlinear_factors=False, eta_damping=0)

    # ---- 变量节点 + 先验 ----
    var_nodes = []
    I2 = np.eye(2, dtype=float)
    N = len(nodes)

    # 确定强先验的节点集合
    if prior_prop <= 0.0:
        strong_ids = {0}
    elif prior_prop >= 1.0:
        strong_ids = set(range(N))
    else:
        k = max(1, int(np.floor(prior_prop * N)))
        strong_ids = set(rng.choice(N, size=k, replace=False).tolist())

    for i, n in enumerate(nodes):
        v = VariableNode(i, dofs=2)
        # 保存 GT（只用于生成测量 & 初始线性化点）
        v.GT = np.array([n["position"]["x"], n["position"]["y"]], dtype=float)

        # 极小先验（所有节点都有，避免奇异）
        v.prior.lam = tiny_prior * I2
        v.prior.eta = np.zeros(2, dtype=float)

        # 强先验（根据 prior_prop 选择）
        if i in strong_ids:
            lam_strong = I2 / (prior_sigma ** 2)
            eta_strong = lam_strong @ (v.GT + rng.normal(0.0, prior_sigma, size=2))
            v.prior.lam = v.prior.lam + lam_strong
            v.prior.eta = v.prior.eta + eta_strong

        var_nodes.append(v)

    fg.var_nodes = var_nodes
    fg.n_var_nodes = len(var_nodes)

    # ---- 测量模型（线性的）----
    def meas_fn(xy, *args):
        # measurement = p_j - p_i
        xy = np.asarray(xy, dtype=float)
        return xy[2:] - xy[:2]

    def jac_fn(xy, *args):
        # d(pj - pi)/d[pi,pj] = [-I, I]
        return np.array([[-1, 0, 1, 0],
                         [ 0,-1, 0, 1]], dtype=float)

    # ---- 里程计/回环 因子 ----
    factors = []
    fid = 0
    for e in edges:
        src = e["data"]["source"]; dst = e["data"]["target"]
        # 只连 base 层的节点
        if not (src.startswith("b") and dst.startswith("b")):
            continue
        i = int(src[1:]); j = int(dst[1:])
        vi, vj = var_nodes[i], var_nodes[j]

        # 测量 = GT 差值 + 高斯噪声
        meas = (vj.GT - vi.GT) + rng.normal(0.0, odom_sigma, size=2)

        f = Factor(fid, [vi, vj], meas, odom_sigma, meas_fn, jac_fn)
        f.type = "base"

        # 用 GT 作为初始线性化点
        linpoint = np.r_[vi.GT, vj.GT]
        f.compute_factor(linpoint=linpoint, update_self=True)

        factors.append(f)
        vi.adj_factors.append(f)
        vj.adj_factors.append(f)
        fid += 1

    fg.factors = factors
    fg.n_factor_nodes = len(factors)
    return fg


# -----------------------
# 主程序：跑 100 次迭代
# -----------------------
if __name__ == "__main__":
    rng = np.random.default_rng(42)  # 固定随机种子

    # 1. 造一个图
    nodes, edges = make_slam_like_graph(N=50, step_size=25, loop_prob=0.1, loop_radius=50, rng=rng)

    # 2. 构建 GBP 图
    fg = build_noisy_pose_graph(nodes, edges, prior_sigma=10.0, odom_sigma=10.0, prior_prop=0, rng=rng)

    # 3. 跑迭代
    for it in range(1000):
        fg.synchronous_iteration()
        energy = fg.energy_map(include_priors=True, include_factors=True)
        print(f"Iter {it+1:03d} | Energy = {energy:.6f}")
# Out:
# Iter 001 | Energy = 251.687168
# Iter 002 | Energy = 177.024744
# Iter 003 | Energy = 250.069207
# Iter 004 | Energy = 353.602824
# Iter 005 | Energy = 259.619680
# Iter 006 | Energy = 283.434695
# Iter 007 | Energy = 119.811879
# Iter 008 | Energy = 182.714717
# Iter 009 | Energy = 288.556415
# Iter 010 | Energy = 312.656287
# Iter 011 | Energy = 205.160532
# Iter 012 | Energy = 122.110361
# Iter 013 | Energy = 80.473774
# Iter 014 | Energy = 22.979506
# Iter 015 | Energy = 19.219965
# Iter 016 | Energy = 17.402127
# Iter 017 | Energy = 16.878754
# Iter 018 | Energy = 16.700481
# Iter 019 | Energy = 16.514586
# Iter 020 | Energy = 16.362264
# Iter 021 | Energy = 16.320413
# Iter 022 | Energy = 16.284298
# Iter 023 | Energy = 16.245519
# Iter 024 | Energy = 16.225189
# Iter 025 | Energy = 16.213172
# Iter 026 | Energy = 16.201660
# Iter 027 | Energy = 16.191625
# Iter 028 | Energy = 16.184999
# Iter 029 | Energy = 16.179464
# Iter 030 | Energy = 16.174265
# Iter 031 | Energy = 16.169919
# Iter 032 | Energy = 16.166454
# Iter 033 | Energy = 16.163505
# Iter 034 | Energy = 16.160943
# Iter 035 | Energy = 16.158697
# Iter 036 | Energy = 16.156693
# Iter 037 | Energy = 16.154885
# Iter 038 | Energy = 16.153253
# Iter 039 | Energy = 16.151767
# Iter 040 | Energy = 16.150398
# Iter 041 | Energy = 16.149126
# Iter 042 | Energy = 16.147937
# Iter 043 | Energy = 16.146812
# Iter 044 | Energy = 16.145742
# Iter 045 | Energy = 16.144723
# Iter 046 | Energy = 16.143749
# Iter 047 | Energy = 16.142816
# Iter 048 | Energy = 16.141919
# Iter 049 | Energy = 16.141055
# Iter 050 | Energy = 16.140222
# Iter 051 | Energy = 16.139415
# Iter 052 | Energy = 16.138635
# Iter 053 | Energy = 16.137880
# Iter 054 | Energy = 16.137147
# Iter 055 | Energy = 16.136437
# Iter 056 | Energy = 16.135747
# Iter 057 | Energy = 16.135077
# Iter 058 | Energy = 16.134427
# Iter 059 | Energy = 16.133795
# Iter 060 | Energy = 16.133180
# Iter 061 | Energy = 16.132583
# Iter 062 | Energy = 16.132002
# Iter 063 | Energy = 16.131437
# Iter 064 | Energy = 16.130888
# Iter 065 | Energy = 16.130353
# Iter 066 | Energy = 16.129834
# Iter 067 | Energy = 16.129328
# Iter 068 | Energy = 16.128836
# Iter 069 | Energy = 16.128358
# Iter 070 | Energy = 16.127892
# Iter 071 | Energy = 16.127439
# Iter 072 | Energy = 16.126999
# Iter 073 | Energy = 16.126570
# Iter 074 | Energy = 16.126153
# Iter 075 | Energy = 16.125747
# Iter 076 | Energy = 16.125352
# Iter 077 | Energy = 16.124968
# Iter 078 | Energy = 16.124594
# Iter 079 | Energy = 16.124230
# Iter 080 | Energy = 16.123876
# Iter 081 | Energy = 16.123531
# Iter 082 | Energy = 16.123196
# Iter 083 | Energy = 16.122870
# Iter 084 | Energy = 16.122552
# Iter 085 | Energy = 16.122244
# Iter 086 | Energy = 16.121943
# Iter 087 | Energy = 16.121651
# Iter 088 | Energy = 16.121366
# Iter 089 | Energy = 16.121089
# Iter 090 | Energy = 16.120820
# Iter 091 | Energy = 16.120558
# Iter 092 | Energy = 16.120302
# Iter 093 | Energy = 16.120054
# Iter 094 | Energy = 16.119813
# Iter 095 | Energy = 16.119577
# Iter 096 | Energy = 16.119349
# Iter 097 | Energy = 16.119126
# Iter 098 | Energy = 16.118909
# Iter 099 | Energy = 16.118699
# Iter 100 | Energy = 16.118494
# Iter 101 | Energy = 16.118294
# Iter 102 | Energy = 16.118100
# Iter 103 | Energy = 16.117911
# Iter 104 | Energy = 16.117727
# Iter 105 | Energy = 16.117548
# Iter 106 | Energy = 16.117374
# Iter 107 | Energy = 16.117204
# Iter 108 | Energy = 16.117039
# Iter 109 | Energy = 16.116879
# Iter 110 | Energy = 16.116723
# Iter 111 | Energy = 16.116571
# Iter 112 | Energy = 16.116423
# Iter 113 | Energy = 16.116279
# Iter 114 | Energy = 16.116139
# Iter 115 | Energy = 16.116003
# Iter 116 | Energy = 16.115871
# Iter 117 | Energy = 16.115742
# Iter 118 | Energy = 16.115616
# Iter 119 | Energy = 16.115494
# Iter 120 | Energy = 16.115375
# Iter 121 | Energy = 16.115259
# Iter 122 | Energy = 16.115147
# Iter 123 | Energy = 16.115037
# Iter 124 | Energy = 16.114931
# Iter 125 | Energy = 16.114827
# Iter 126 | Energy = 16.114726
# Iter 127 | Energy = 16.114628
# Iter 128 | Energy = 16.114532
# Iter 129 | Energy = 16.114439
# Iter 130 | Energy = 16.114349
# Iter 131 | Energy = 16.114261
# Iter 132 | Energy = 16.114175
# Iter 133 | Energy = 16.114092
# Iter 134 | Energy = 16.114011
# Iter 135 | Energy = 16.113932
# Iter 136 | Energy = 16.113855
# Iter 137 | Energy = 16.113780
# Iter 138 | Energy = 16.113708
# Iter 139 | Energy = 16.113637
# Iter 140 | Energy = 16.113568
# Iter 141 | Energy = 16.113501
# Iter 142 | Energy = 16.113436
# Iter 143 | Energy = 16.113372
# Iter 144 | Energy = 16.113310
# Iter 145 | Energy = 16.113250
# Iter 146 | Energy = 16.113192
# Iter 147 | Energy = 16.113135
# Iter 148 | Energy = 16.113080
# Iter 149 | Energy = 16.113026
# Iter 150 | Energy = 16.112973
# Iter 151 | Energy = 16.112922
# Iter 152 | Energy = 16.112873
# Iter 153 | Energy = 16.112824
# Iter 154 | Energy = 16.112777
# Iter 155 | Energy = 16.112732
# Iter 156 | Energy = 16.112687
# Iter 157 | Energy = 16.112644
# Iter 158 | Energy = 16.112602
# Iter 159 | Energy = 16.112561
# Iter 160 | Energy = 16.112521
# Iter 161 | Energy = 16.112482
# Iter 162 | Energy = 16.112444
# Iter 163 | Energy = 16.112407
# Iter 164 | Energy = 16.112372
# Iter 165 | Energy = 16.112337
# Iter 166 | Energy = 16.112303
# Iter 167 | Energy = 16.112270
# Iter 168 | Energy = 16.112238
# Iter 169 | Energy = 16.112207
# Iter 170 | Energy = 16.112176
# Iter 171 | Energy = 16.112147
# Iter 172 | Energy = 16.112118
# Iter 173 | Energy = 16.112090
# Iter 174 | Energy = 16.112063
# Iter 175 | Energy = 16.112036
# Iter 176 | Energy = 16.112010
# Iter 177 | Energy = 16.111985
# Iter 178 | Energy = 16.111961
# Iter 179 | Energy = 16.111937
# Iter 180 | Energy = 16.111914
# Iter 181 | Energy = 16.111891
# Iter 182 | Energy = 16.111870
# Iter 183 | Energy = 16.111848
# Iter 184 | Energy = 16.111827
# Iter 185 | Energy = 16.111807
# Iter 186 | Energy = 16.111788
# Iter 187 | Energy = 16.111769
# Iter 188 | Energy = 16.111750
# Iter 189 | Energy = 16.111732
# Iter 190 | Energy = 16.111714
# Iter 191 | Energy = 16.111697
# Iter 192 | Energy = 16.111680
# Iter 193 | Energy = 16.111664
# Iter 194 | Energy = 16.111648
# Iter 195 | Energy = 16.111633
# Iter 196 | Energy = 16.111618
# Iter 197 | Energy = 16.111604
# Iter 198 | Energy = 16.111589
# Iter 199 | Energy = 16.111576
# Iter 200 | Energy = 16.111562
# Iter 201 | Energy = 16.111549
# Iter 202 | Energy = 16.111537
# Iter 203 | Energy = 16.111524
# Iter 204 | Energy = 16.111512
# Iter 205 | Energy = 16.111500
# Iter 206 | Energy = 16.111489
# Iter 207 | Energy = 16.111478
# Iter 208 | Energy = 16.111467
# Iter 209 | Energy = 16.111457
# Iter 210 | Energy = 16.111447
# Iter 211 | Energy = 16.111437
# Iter 212 | Energy = 16.111427
# Iter 213 | Energy = 16.111418
# Iter 214 | Energy = 16.111408
# Iter 215 | Energy = 16.111400
# Iter 216 | Energy = 16.111391
# Iter 217 | Energy = 16.111382
# Iter 218 | Energy = 16.111374
# Iter 219 | Energy = 16.111366
# Iter 220 | Energy = 16.111358
# Iter 221 | Energy = 16.111351
# Iter 222 | Energy = 16.111344
# Iter 223 | Energy = 16.111336
# Iter 224 | Energy = 16.111329
# Iter 225 | Energy = 16.111323
# Iter 226 | Energy = 16.111316
# Iter 227 | Energy = 16.111310
# Iter 228 | Energy = 16.111303
# Iter 229 | Energy = 16.111297
# Iter 230 | Energy = 16.111291
# Iter 231 | Energy = 16.111286
# Iter 232 | Energy = 16.111280
# Iter 233 | Energy = 16.111275
# Iter 234 | Energy = 16.111269
# Iter 235 | Energy = 16.111264
# Iter 236 | Energy = 16.111259
# Iter 237 | Energy = 16.111254
# Iter 238 | Energy = 16.111250
# Iter 239 | Energy = 16.111245
# Iter 240 | Energy = 16.111240
# Iter 241 | Energy = 16.111236
# Iter 242 | Energy = 16.111232
# Iter 243 | Energy = 16.111228
# Iter 244 | Energy = 16.111224
# Iter 245 | Energy = 16.111220
# Iter 246 | Energy = 16.111216
# Iter 247 | Energy = 16.111212
# Iter 248 | Energy = 16.111209
# Iter 249 | Energy = 16.111205
# Iter 250 | Energy = 16.111202
# Iter 251 | Energy = 16.111198
# Iter 252 | Energy = 16.111195
# Iter 253 | Energy = 16.111192
# Iter 254 | Energy = 16.111189
# Iter 255 | Energy = 16.111186
# Iter 256 | Energy = 16.111183
# Iter 257 | Energy = 16.111180
# Iter 258 | Energy = 16.111177
# Iter 259 | Energy = 16.111175
# Iter 260 | Energy = 16.111172
# Iter 261 | Energy = 16.111169
# Iter 262 | Energy = 16.111167
# Iter 263 | Energy = 16.111165
# Iter 264 | Energy = 16.111162
# Iter 265 | Energy = 16.111160
# Iter 266 | Energy = 16.111158
# Iter 267 | Energy = 16.111156
# Iter 268 | Energy = 16.111154
# Iter 269 | Energy = 16.111151
# Iter 270 | Energy = 16.111149
# Iter 271 | Energy = 16.111148
# Iter 272 | Energy = 16.111146
# Iter 273 | Energy = 16.111144
# Iter 274 | Energy = 16.111142
# Iter 275 | Energy = 16.111140
# Iter 276 | Energy = 16.111139
# Iter 277 | Energy = 16.111137
# Iter 278 | Energy = 16.111135
# Iter 279 | Energy = 16.111134
# Iter 280 | Energy = 16.111132
# Iter 281 | Energy = 16.111131
# Iter 282 | Energy = 16.111129
# Iter 283 | Energy = 16.111128
# Iter 284 | Energy = 16.111127
# Iter 285 | Energy = 16.111125
# Iter 286 | Energy = 16.111124
# Iter 287 | Energy = 16.111123
# Iter 288 | Energy = 16.111122
# Iter 289 | Energy = 16.111120
# Iter 290 | Energy = 16.111119
# Iter 291 | Energy = 16.111118
# Iter 292 | Energy = 16.111117
# Iter 293 | Energy = 16.111116
# Iter 294 | Energy = 16.111115
# Iter 295 | Energy = 16.111114
# Iter 296 | Energy = 16.111113
# Iter 297 | Energy = 16.111112
# Iter 298 | Energy = 16.111111
# Iter 299 | Energy = 16.111110
# Iter 300 | Energy = 16.111109
# Iter 301 | Energy = 16.111109
# Iter 302 | Energy = 16.111108
# Iter 303 | Energy = 16.111107
# Iter 304 | Energy = 16.111106
# Iter 305 | Energy = 16.111105
# Iter 306 | Energy = 16.111105
# Iter 307 | Energy = 16.111104
# Iter 308 | Energy = 16.111103
# Iter 309 | Energy = 16.111102
# Iter 310 | Energy = 16.111102
# Iter 311 | Energy = 16.111101
# Iter 312 | Energy = 16.111101
# Iter 313 | Energy = 16.111100
# Iter 314 | Energy = 16.111099
# Iter 315 | Energy = 16.111099
# Iter 316 | Energy = 16.111098
# Iter 317 | Energy = 16.111098
# Iter 318 | Energy = 16.111097
# Iter 319 | Energy = 16.111097
# Iter 320 | Energy = 16.111096
# Iter 321 | Energy = 16.111096
# Iter 322 | Energy = 16.111095
# Iter 323 | Energy = 16.111095
# Iter 324 | Energy = 16.111094
# Iter 325 | Energy = 16.111094
# Iter 326 | Energy = 16.111093
# Iter 327 | Energy = 16.111093
# Iter 328 | Energy = 16.111092
# Iter 329 | Energy = 16.111092
# Iter 330 | Energy = 16.111092
# Iter 331 | Energy = 16.111091
# Iter 332 | Energy = 16.111091
# Iter 333 | Energy = 16.111091
# Iter 334 | Energy = 16.111090
# Iter 335 | Energy = 16.111090
# Iter 336 | Energy = 16.111090
# Iter 337 | Energy = 16.111089
# Iter 338 | Energy = 16.111089
# Iter 339 | Energy = 16.111089
# Iter 340 | Energy = 16.111088
# Iter 341 | Energy = 16.111088
# Iter 342 | Energy = 16.111088
# Iter 343 | Energy = 16.111087
# Iter 344 | Energy = 16.111087
# Iter 345 | Energy = 16.111087
# Iter 346 | Energy = 16.111087
# Iter 347 | Energy = 16.111086
# Iter 348 | Energy = 16.111086
# Iter 349 | Energy = 16.111086
# Iter 350 | Energy = 16.111086
# Iter 351 | Energy = 16.111086
# Iter 352 | Energy = 16.111085
# Iter 353 | Energy = 16.111085
# Iter 354 | Energy = 16.111085
# Iter 355 | Energy = 16.111085
# Iter 356 | Energy = 16.111085
# Iter 357 | Energy = 16.111084
# Iter 358 | Energy = 16.111084
# Iter 359 | Energy = 16.111084
# Iter 360 | Energy = 16.111084
# Iter 361 | Energy = 16.111084
# Iter 362 | Energy = 16.111084
# Iter 363 | Energy = 16.111083
# Iter 364 | Energy = 16.111083
# Iter 365 | Energy = 16.111083
# Iter 366 | Energy = 16.111083
# Iter 367 | Energy = 16.111083
# Iter 368 | Energy = 16.111083
# Iter 369 | Energy = 16.111083
# Iter 370 | Energy = 16.111082
# Iter 371 | Energy = 16.111082
# Iter 372 | Energy = 16.111082
# Iter 373 | Energy = 16.111082
# Iter 374 | Energy = 16.111082
# Iter 375 | Energy = 16.111082
# Iter 376 | Energy = 16.111082
# Iter 377 | Energy = 16.111082
# Iter 378 | Energy = 16.111081
# Iter 379 | Energy = 16.111081
# Iter 380 | Energy = 16.111081
# Iter 381 | Energy = 16.111081
# Iter 382 | Energy = 16.111081
# Iter 383 | Energy = 16.111081
# Iter 384 | Energy = 16.111081
# Iter 385 | Energy = 16.111081
# Iter 386 | Energy = 16.111081
# Iter 387 | Energy = 16.111081
# Iter 388 | Energy = 16.111081
# Iter 389 | Energy = 16.111080
# Iter 390 | Energy = 16.111080
# Iter 391 | Energy = 16.111080
# Iter 392 | Energy = 16.111080
# Iter 393 | Energy = 16.111080
# Iter 394 | Energy = 16.111080
# Iter 395 | Energy = 16.111080
# Iter 396 | Energy = 16.111080
# Iter 397 | Energy = 16.111080
# Iter 398 | Energy = 16.111080
# Iter 399 | Energy = 16.111080
# Iter 400 | Energy = 16.111080
# Iter 401 | Energy = 16.111080
# Iter 402 | Energy = 16.111080
# Iter 403 | Energy = 16.111080
# Iter 404 | Energy = 16.111080
# Iter 405 | Energy = 16.111080
# Iter 406 | Energy = 16.111079
# Iter 407 | Energy = 16.111079
# Iter 408 | Energy = 16.111079
# Iter 409 | Energy = 16.111079
# Iter 410 | Energy = 16.111079
# Iter 411 | Energy = 16.111079
# Iter 412 | Energy = 16.111079
# Iter 413 | Energy = 16.111079
# Iter 414 | Energy = 16.111079
# Iter 415 | Energy = 16.111079
# Iter 416 | Energy = 16.111079
# Iter 417 | Energy = 16.111079
# Iter 418 | Energy = 16.111079
# Iter 419 | Energy = 16.111079
# Iter 420 | Energy = 16.111079
# Iter 421 | Energy = 16.111079
# Iter 422 | Energy = 16.111079
# Iter 423 | Energy = 16.111079
# Iter 424 | Energy = 16.111079
# Iter 425 | Energy = 16.111079
# Iter 426 | Energy = 16.111079
# Iter 427 | Energy = 16.111079
# Iter 428 | Energy = 16.111079
# Iter 429 | Energy = 16.111079
# Iter 430 | Energy = 16.111079
# Iter 431 | Energy = 16.111079
# Iter 432 | Energy = 16.111079
# Iter 433 | Energy = 16.111079
# Iter 434 | Energy = 16.111079
# Iter 435 | Energy = 16.111078
# Iter 436 | Energy = 16.111078
# Iter 437 | Energy = 16.111078
# Iter 438 | Energy = 16.111078
# Iter 439 | Energy = 16.111078
# Iter 440 | Energy = 16.111078
# Iter 441 | Energy = 16.111078
# Iter 442 | Energy = 16.111078
# Iter 443 | Energy = 16.111078
# Iter 444 | Energy = 16.111078
# Iter 445 | Energy = 16.111078
# Iter 446 | Energy = 16.111078
# Iter 447 | Energy = 16.111078
# Iter 448 | Energy = 16.111078
# Iter 449 | Energy = 16.111078
# Iter 450 | Energy = 16.111078
# Iter 451 | Energy = 16.111078
# Iter 452 | Energy = 16.111078
# Iter 453 | Energy = 16.111078
# Iter 454 | Energy = 16.111078
# Iter 455 | Energy = 16.111078
# Iter 456 | Energy = 16.111078
# Iter 457 | Energy = 16.111078
# Iter 458 | Energy = 16.111078
# Iter 459 | Energy = 16.111078
# Iter 460 | Energy = 16.111078
# Iter 461 | Energy = 16.111078
# Iter 462 | Energy = 16.111078
# Iter 463 | Energy = 16.111078
# Iter 464 | Energy = 16.111078
# Iter 465 | Energy = 16.111078
# Iter 466 | Energy = 16.111078
# Iter 467 | Energy = 16.111078
# Iter 468 | Energy = 16.111078
# Iter 469 | Energy = 16.111078
# Iter 470 | Energy = 16.111078
# Iter 471 | Energy = 16.111078
# Iter 472 | Energy = 16.111078
# Iter 473 | Energy = 16.111078
# Iter 474 | Energy = 16.111078
# Iter 475 | Energy = 16.111078
# Iter 476 | Energy = 16.111078
# Iter 477 | Energy = 16.111078
# Iter 478 | Energy = 16.111078
# Iter 479 | Energy = 16.111078
# Iter 480 | Energy = 16.111078
# Iter 481 | Energy = 16.111078
# Iter 482 | Energy = 16.111078
# Iter 483 | Energy = 16.111078
# Iter 484 | Energy = 16.111078
# Iter 485 | Energy = 16.111078
# Iter 486 | Energy = 16.111078
# Iter 487 | Energy = 16.111078
# Iter 488 | Energy = 16.111078
# Iter 489 | Energy = 16.111078
# Iter 490 | Energy = 16.111078
# Iter 491 | Energy = 16.111078
# Iter 492 | Energy = 16.111078
# Iter 493 | Energy = 16.111078
# Iter 494 | Energy = 16.111078
# Iter 495 | Energy = 16.111078
# Iter 496 | Energy = 16.111078
# Iter 497 | Energy = 16.111078
# Iter 498 | Energy = 16.111078
# Iter 499 | Energy = 16.111078
# Iter 500 | Energy = 16.111078
# Iter 501 | Energy = 16.111078
# Iter 502 | Energy = 16.111078
# Iter 503 | Energy = 16.111078
# Iter 504 | Energy = 16.111078
# Iter 505 | Energy = 16.111078
# Iter 506 | Energy = 16.111078
# Iter 507 | Energy = 16.111078
# Iter 508 | Energy = 16.111078
# Iter 509 | Energy = 16.111078
# Iter 510 | Energy = 16.111078
# Iter 511 | Energy = 16.111078
# Iter 512 | Energy = 16.111078
# Iter 513 | Energy = 16.111078
# Iter 514 | Energy = 16.111078
# Iter 515 | Energy = 16.111078
# Iter 516 | Energy = 16.111078
# Iter 517 | Energy = 16.111078
# Iter 518 | Energy = 16.111078
# Iter 519 | Energy = 16.111078
# Iter 520 | Energy = 16.111078
# Iter 521 | Energy = 16.111078
# Iter 522 | Energy = 16.111078
# Iter 523 | Energy = 16.111078
# Iter 524 | Energy = 16.111078
# Iter 525 | Energy = 16.111078
# Iter 526 | Energy = 16.111078
# Iter 527 | Energy = 16.111078
# Iter 528 | Energy = 16.111078
# Iter 529 | Energy = 16.111078
# Iter 530 | Energy = 16.111078
# Iter 531 | Energy = 16.111078
# Iter 532 | Energy = 16.111078
# Iter 533 | Energy = 16.111078
# Iter 534 | Energy = 16.111078
# Iter 535 | Energy = 16.111078
# Iter 536 | Energy = 16.111078
# Iter 537 | Energy = 16.111078
# Iter 538 | Energy = 16.111078
# Iter 539 | Energy = 16.111078
# Iter 540 | Energy = 16.111078
# Iter 541 | Energy = 16.111078
# Iter 542 | Energy = 16.111078
# Iter 543 | Energy = 16.111078
# Iter 544 | Energy = 16.111078
# Iter 545 | Energy = 16.111078
# Iter 546 | Energy = 16.111078
# Iter 547 | Energy = 16.111078
# Iter 548 | Energy = 16.111078
# Iter 549 | Energy = 16.111078
# Iter 550 | Energy = 16.111078
# Iter 551 | Energy = 16.111078
# Iter 552 | Energy = 16.111078
# Iter 553 | Energy = 16.111078
# Iter 554 | Energy = 16.111078
# Iter 555 | Energy = 16.111078
# Iter 556 | Energy = 16.111078
# Iter 557 | Energy = 16.111078
# Iter 558 | Energy = 16.111078
# Iter 559 | Energy = 16.111078
# Iter 560 | Energy = 16.111078
# Iter 561 | Energy = 16.111078
# Iter 562 | Energy = 16.111078
# Iter 563 | Energy = 16.111078
# Iter 564 | Energy = 16.111078
# Iter 565 | Energy = 16.111078
# Iter 566 | Energy = 16.111078
# Iter 567 | Energy = 16.111078
# Iter 568 | Energy = 16.111078
# Iter 569 | Energy = 16.111078
# Iter 570 | Energy = 16.111078
# Iter 571 | Energy = 16.111078
# Iter 572 | Energy = 16.111078
# Iter 573 | Energy = 16.111078
# Iter 574 | Energy = 16.111078
# Iter 575 | Energy = 16.111078
# Iter 576 | Energy = 16.111078
# Iter 577 | Energy = 16.111078
# Iter 578 | Energy = 16.111078
# Iter 579 | Energy = 16.111078
# Iter 580 | Energy = 16.111078
# Iter 581 | Energy = 16.111078
# Iter 582 | Energy = 16.111078
# Iter 583 | Energy = 16.111078
# Iter 584 | Energy = 16.111078
# Iter 585 | Energy = 16.111078
# Iter 586 | Energy = 16.111078
# Iter 587 | Energy = 16.111078
# Iter 588 | Energy = 16.111078
# Iter 589 | Energy = 16.111078
# Iter 590 | Energy = 16.111078
# Iter 591 | Energy = 16.111078
# Iter 592 | Energy = 16.111078
# Iter 593 | Energy = 16.111078
# Iter 594 | Energy = 16.111078
# Iter 595 | Energy = 16.111078
# Iter 596 | Energy = 16.111078
# Iter 597 | Energy = 16.111078
# Iter 598 | Energy = 16.111078
# Iter 599 | Energy = 16.111078
# Iter 600 | Energy = 16.111078
# Iter 601 | Energy = 16.111078
# Iter 602 | Energy = 16.111078
# Iter 603 | Energy = 16.111078
# Iter 604 | Energy = 16.111078
# Iter 605 | Energy = 16.111078
# Iter 606 | Energy = 16.111078
# Iter 607 | Energy = 16.111078
# Iter 608 | Energy = 16.111078
# Iter 609 | Energy = 16.111078
# Iter 610 | Energy = 16.111078
# Iter 611 | Energy = 16.111078
# Iter 612 | Energy = 16.111078
# Iter 613 | Energy = 16.111078
# Iter 614 | Energy = 16.111078
# Iter 615 | Energy = 16.111078
# Iter 616 | Energy = 16.111078
# Iter 617 | Energy = 16.111078
# Iter 618 | Energy = 16.111078
# Iter 619 | Energy = 16.111078
# Iter 620 | Energy = 16.111078
# Iter 621 | Energy = 16.111078
# Iter 622 | Energy = 16.111078
# Iter 623 | Energy = 16.111078
# Iter 624 | Energy = 16.111078
# Iter 625 | Energy = 16.111078
# Iter 626 | Energy = 16.111078
# Iter 627 | Energy = 16.111078
# Iter 628 | Energy = 16.111078
# Iter 629 | Energy = 16.111078
# Iter 630 | Energy = 16.111078
# Iter 631 | Energy = 16.111078
# Iter 632 | Energy = 16.111078
# Iter 633 | Energy = 16.111078
# Iter 634 | Energy = 16.111078
# Iter 635 | Energy = 16.111078
# Iter 636 | Energy = 16.111078
# Iter 637 | Energy = 16.111078
# Iter 638 | Energy = 16.111078
# Iter 639 | Energy = 16.111078
# Iter 640 | Energy = 16.111078
# Iter 641 | Energy = 16.111078
# Iter 642 | Energy = 16.111078
# Iter 643 | Energy = 16.111078
# Iter 644 | Energy = 16.111078
# Iter 645 | Energy = 16.111078
# Iter 646 | Energy = 16.111078
# Iter 647 | Energy = 16.111078
# Iter 648 | Energy = 16.111078
# Iter 649 | Energy = 16.111078
# Iter 650 | Energy = 16.111078
# Iter 651 | Energy = 16.111078
# Iter 652 | Energy = 16.111078
# Iter 653 | Energy = 16.111078
# Iter 654 | Energy = 16.111078
# Iter 655 | Energy = 16.111078
# Iter 656 | Energy = 16.111078
# Iter 657 | Energy = 16.111078
# Iter 658 | Energy = 16.111078
# Iter 659 | Energy = 16.111078
# Iter 660 | Energy = 16.111078
# Iter 661 | Energy = 16.111078
# Iter 662 | Energy = 16.111078
# Iter 663 | Energy = 16.111078
# Iter 664 | Energy = 16.111078
# Iter 665 | Energy = 16.111078
# Iter 666 | Energy = 16.111078
# Iter 667 | Energy = 16.111078
# Iter 668 | Energy = 16.111078
# Iter 669 | Energy = 16.111078
# Iter 670 | Energy = 16.111078
# Iter 671 | Energy = 16.111078
# Iter 672 | Energy = 16.111078
# Iter 673 | Energy = 16.111078
# Iter 674 | Energy = 16.111078
# Iter 675 | Energy = 16.111078
# Iter 676 | Energy = 16.111078
# Iter 677 | Energy = 16.111078
# Iter 678 | Energy = 16.111078
# Iter 679 | Energy = 16.111078
# Iter 680 | Energy = 16.111078
# Iter 681 | Energy = 16.111078
# Iter 682 | Energy = 16.111078
# Iter 683 | Energy = 16.111078
# Iter 684 | Energy = 16.111078
# Iter 685 | Energy = 16.111078
# Iter 686 | Energy = 16.111078
# Iter 687 | Energy = 16.111078
# Iter 688 | Energy = 16.111078
# Iter 689 | Energy = 16.111078
# Iter 690 | Energy = 16.111078
# Iter 691 | Energy = 16.111078
# Iter 692 | Energy = 16.111078
# Iter 693 | Energy = 16.111078
# Iter 694 | Energy = 16.111078
# Iter 695 | Energy = 16.111078
# Iter 696 | Energy = 16.111078
# Iter 697 | Energy = 16.111078
# Iter 698 | Energy = 16.111078
# Iter 699 | Energy = 16.111078
# Iter 700 | Energy = 16.111078
# Iter 701 | Energy = 16.111078
# Iter 702 | Energy = 16.111078
# Iter 703 | Energy = 16.111078
# Iter 704 | Energy = 16.111078
# Iter 705 | Energy = 16.111078
# Iter 706 | Energy = 16.111078
# Iter 707 | Energy = 16.111078
# Iter 708 | Energy = 16.111078
# Iter 709 | Energy = 16.111078
# Iter 710 | Energy = 16.111078
# Iter 711 | Energy = 16.111078
# Iter 712 | Energy = 16.111078
# Iter 713 | Energy = 16.111078
# Iter 714 | Energy = 16.111078
# Iter 715 | Energy = 16.111078
# Iter 716 | Energy = 16.111078
# Iter 717 | Energy = 16.111078
# Iter 718 | Energy = 16.111078
# Iter 719 | Energy = 16.111078
# Iter 720 | Energy = 16.111078
# Iter 721 | Energy = 16.111078
# Iter 722 | Energy = 16.111078
# Iter 723 | Energy = 16.111078
# Iter 724 | Energy = 16.111078
# Iter 725 | Energy = 16.111078
# Iter 726 | Energy = 16.111078
# Iter 727 | Energy = 16.111078
# Iter 728 | Energy = 16.111078
# Iter 729 | Energy = 16.111078
# Iter 730 | Energy = 16.111078
# Iter 731 | Energy = 16.111078
# Iter 732 | Energy = 16.111078
# Iter 733 | Energy = 16.111078
# Iter 734 | Energy = 16.111078
# Iter 735 | Energy = 16.111078
# Iter 736 | Energy = 16.111078
# Iter 737 | Energy = 16.111078
# Iter 738 | Energy = 16.111078
# Iter 739 | Energy = 16.111078
# Iter 740 | Energy = 16.111078
# Iter 741 | Energy = 16.111078
# Iter 742 | Energy = 16.111078
# Iter 743 | Energy = 16.111078
# Iter 744 | Energy = 16.111078
# Iter 745 | Energy = 16.111078
# Iter 746 | Energy = 16.111078
# Iter 747 | Energy = 16.111078
# Iter 748 | Energy = 16.111078
# Iter 749 | Energy = 16.111078
# Iter 750 | Energy = 16.111078
# Iter 751 | Energy = 16.111078
# Iter 752 | Energy = 16.111078
# Iter 753 | Energy = 16.111078
# Iter 754 | Energy = 16.111078
# Iter 755 | Energy = 16.111078
# Iter 756 | Energy = 16.111078
# Iter 757 | Energy = 16.111078
# Iter 758 | Energy = 16.111078
# Iter 759 | Energy = 16.111078
# Iter 760 | Energy = 16.111078
# Iter 761 | Energy = 16.111078
# Iter 762 | Energy = 16.111078
# Iter 763 | Energy = 16.111078
# Iter 764 | Energy = 16.111078
# Iter 765 | Energy = 16.111078
# Iter 766 | Energy = 16.111078
# Iter 767 | Energy = 16.111078
# Iter 768 | Energy = 16.111078
# Iter 769 | Energy = 16.111078
# Iter 770 | Energy = 16.111078
# Iter 771 | Energy = 16.111078
# Iter 772 | Energy = 16.111078
# Iter 773 | Energy = 16.111078
# Iter 774 | Energy = 16.111078
# Iter 775 | Energy = 16.111078
# Iter 776 | Energy = 16.111078
# Iter 777 | Energy = 16.111078
# Iter 778 | Energy = 16.111078
# Iter 779 | Energy = 16.111078
# Iter 780 | Energy = 16.111078
# Iter 781 | Energy = 16.111078
# Iter 782 | Energy = 16.111078
# Iter 783 | Energy = 16.111078
# Iter 784 | Energy = 16.111078
# Iter 785 | Energy = 16.111078
# Iter 786 | Energy = 16.111078
# Iter 787 | Energy = 16.111078
# Iter 788 | Energy = 16.111078
# Iter 789 | Energy = 16.111078
# Iter 790 | Energy = 16.111078
# Iter 791 | Energy = 16.111078
# Iter 792 | Energy = 16.111078
# Iter 793 | Energy = 16.111078
# Iter 794 | Energy = 16.111078
# Iter 795 | Energy = 16.111078
# Iter 796 | Energy = 16.111078
# Iter 797 | Energy = 16.111078
# Iter 798 | Energy = 16.111078
# Iter 799 | Energy = 16.111078
# Iter 800 | Energy = 16.111078
# Iter 801 | Energy = 16.111078
# Iter 802 | Energy = 16.111078
# Iter 803 | Energy = 16.111078
# Iter 804 | Energy = 16.111078
# Iter 805 | Energy = 16.111078
# Iter 806 | Energy = 16.111078
# Iter 807 | Energy = 16.111078
# Iter 808 | Energy = 16.111078
# Iter 809 | Energy = 16.111078
# Iter 810 | Energy = 16.111078
# Iter 811 | Energy = 16.111078
# Iter 812 | Energy = 16.111078
# Iter 813 | Energy = 16.111078
# Iter 814 | Energy = 16.111078
# Iter 815 | Energy = 16.111078
# Iter 816 | Energy = 16.111078
# Iter 817 | Energy = 16.111078
# Iter 818 | Energy = 16.111078
# Iter 819 | Energy = 16.111078
# Iter 820 | Energy = 16.111078
# Iter 821 | Energy = 16.111078
# Iter 822 | Energy = 16.111078
# Iter 823 | Energy = 16.111078
# Iter 824 | Energy = 16.111078
# Iter 825 | Energy = 16.111078
# Iter 826 | Energy = 16.111078
# Iter 827 | Energy = 16.111078
# Iter 828 | Energy = 16.111078
# Iter 829 | Energy = 16.111078
# Iter 830 | Energy = 16.111078
# Iter 831 | Energy = 16.111078
# Iter 832 | Energy = 16.111078
# Iter 833 | Energy = 16.111078
# Iter 834 | Energy = 16.111078
# Iter 835 | Energy = 16.111078
# Iter 836 | Energy = 16.111078
# Iter 837 | Energy = 16.111078
# Iter 838 | Energy = 16.111078
# Iter 839 | Energy = 16.111078
# Iter 840 | Energy = 16.111078
# Iter 841 | Energy = 16.111078
# Iter 842 | Energy = 16.111078
# Iter 843 | Energy = 16.111078
# Iter 844 | Energy = 16.111078
# Iter 845 | Energy = 16.111078
# Iter 846 | Energy = 16.111078
# Iter 847 | Energy = 16.111078
# Iter 848 | Energy = 16.111078
# Iter 849 | Energy = 16.111078
# Iter 850 | Energy = 16.111078
# Iter 851 | Energy = 16.111078
# Iter 852 | Energy = 16.111078
# Iter 853 | Energy = 16.111078
# Iter 854 | Energy = 16.111078
# Iter 855 | Energy = 16.111078
# Iter 856 | Energy = 16.111078
# Iter 857 | Energy = 16.111078
# Iter 858 | Energy = 16.111078
# Iter 859 | Energy = 16.111078
# Iter 860 | Energy = 16.111078
# Iter 861 | Energy = 16.111078
# Iter 862 | Energy = 16.111078
# Iter 863 | Energy = 16.111078
# Iter 864 | Energy = 16.111078
# Iter 865 | Energy = 16.111078
# Iter 866 | Energy = 16.111078
# Iter 867 | Energy = 16.111078
# Iter 868 | Energy = 16.111078
# Iter 869 | Energy = 16.111078
# Iter 870 | Energy = 16.111078
# Iter 871 | Energy = 16.111078
# Iter 872 | Energy = 16.111078
# Iter 873 | Energy = 16.111078
# Iter 874 | Energy = 16.111078
# Iter 875 | Energy = 16.111078
# Iter 876 | Energy = 16.111078
# Iter 877 | Energy = 16.111078
# Iter 878 | Energy = 16.111078
# Iter 879 | Energy = 16.111078
# Iter 880 | Energy = 16.111078
# Iter 881 | Energy = 16.111078
# Iter 882 | Energy = 16.111078
# Iter 883 | Energy = 16.111078
# Iter 884 | Energy = 16.111078
# Iter 885 | Energy = 16.111078
# Iter 886 | Energy = 16.111078
# Iter 887 | Energy = 16.111078
# Iter 888 | Energy = 16.111078
# Iter 889 | Energy = 16.111078
# Iter 890 | Energy = 16.111078
# Iter 891 | Energy = 16.111078
# Iter 892 | Energy = 16.111078
# Iter 893 | Energy = 16.111078
# Iter 894 | Energy = 16.111078
# Iter 895 | Energy = 16.111078
# Iter 896 | Energy = 16.111078
# Iter 897 | Energy = 16.111078
# Iter 898 | Energy = 16.111078
# Iter 899 | Energy = 16.111078
# Iter 900 | Energy = 16.111078
# Iter 901 | Energy = 16.111078
# Iter 902 | Energy = 16.111078
# Iter 903 | Energy = 16.111078
# Iter 904 | Energy = 16.111078
# Iter 905 | Energy = 16.111078
# Iter 906 | Energy = 16.111078
# Iter 907 | Energy = 16.111078
# Iter 908 | Energy = 16.111078
# Iter 909 | Energy = 16.111078
# Iter 910 | Energy = 16.111078
# Iter 911 | Energy = 16.111078
# Iter 912 | Energy = 16.111078
# Iter 913 | Energy = 16.111078
# Iter 914 | Energy = 16.111078
# Iter 915 | Energy = 16.111078
# Iter 916 | Energy = 16.111078
# Iter 917 | Energy = 16.111078
# Iter 918 | Energy = 16.111078
# Iter 919 | Energy = 16.111078
# Iter 920 | Energy = 16.111078
# Iter 921 | Energy = 16.111078
# Iter 922 | Energy = 16.111078
# Iter 923 | Energy = 16.111078
# Iter 924 | Energy = 16.111078
# Iter 925 | Energy = 16.111078
# Iter 926 | Energy = 16.111078
# Iter 927 | Energy = 16.111078
# Iter 928 | Energy = 16.111078
# Iter 929 | Energy = 16.111078
# Iter 930 | Energy = 16.111078
# Iter 931 | Energy = 16.111078
# Iter 932 | Energy = 16.111078
# Iter 933 | Energy = 16.111078
# Iter 934 | Energy = 16.111078
# Iter 935 | Energy = 16.111078
# Iter 936 | Energy = 16.111078
# Iter 937 | Energy = 16.111078
# Iter 938 | Energy = 16.111078
# Iter 939 | Energy = 16.111078
# Iter 940 | Energy = 16.111078
# Iter 941 | Energy = 16.111078
# Iter 942 | Energy = 16.111078
# Iter 943 | Energy = 16.111078
# Iter 944 | Energy = 16.111078
# Iter 945 | Energy = 16.111078
# Iter 946 | Energy = 16.111078
# Iter 947 | Energy = 16.111078
# Iter 948 | Energy = 16.111078
# Iter 949 | Energy = 16.111078
# Iter 950 | Energy = 16.111078
# Iter 951 | Energy = 16.111078
# Iter 952 | Energy = 16.111078
# Iter 953 | Energy = 16.111078
# Iter 954 | Energy = 16.111078
# Iter 955 | Energy = 16.111078
# Iter 956 | Energy = 16.111078
# Iter 957 | Energy = 16.111078
# Iter 958 | Energy = 16.111078
# Iter 959 | Energy = 16.111078
# Iter 960 | Energy = 16.111078
# Iter 961 | Energy = 16.111078
# Iter 962 | Energy = 16.111078
# Iter 963 | Energy = 16.111078
# Iter 964 | Energy = 16.111078
# Iter 965 | Energy = 16.111078
# Iter 966 | Energy = 16.111078
# Iter 967 | Energy = 16.111078
# Iter 968 | Energy = 16.111078
# Iter 969 | Energy = 16.111078
# Iter 970 | Energy = 16.111078
# Iter 971 | Energy = 16.111078
# Iter 972 | Energy = 16.111078
# Iter 973 | Energy = 16.111078
# Iter 974 | Energy = 16.111078
# Iter 975 | Energy = 16.111078
# Iter 976 | Energy = 16.111078
# Iter 977 | Energy = 16.111078
# Iter 978 | Energy = 16.111078
# Iter 979 | Energy = 16.111078
# Iter 980 | Energy = 16.111078
# Iter 981 | Energy = 16.111078
# Iter 982 | Energy = 16.111078
# Iter 983 | Energy = 16.111078
# Iter 984 | Energy = 16.111078
# Iter 985 | Energy = 16.111078
# Iter 986 | Energy = 16.111078
# Iter 987 | Energy = 16.111078
# Iter 988 | Energy = 16.111078
# Iter 989 | Energy = 16.111078
# Iter 990 | Energy = 16.111078
# Iter 991 | Energy = 16.111078
# Iter 992 | Energy = 16.111078
# Iter 993 | Energy = 16.111078
# Iter 994 | Energy = 16.111078
# Iter 995 | Energy = 16.111078
# Iter 996 | Energy = 16.111078
# Iter 997 | Energy = 16.111078
# Iter 998 | Energy = 16.111078
# Iter 999 | Energy = 16.111078
# Iter 1000 | Energy = 16.111078

# %%
import numpy as np
from gbp.gbp_corrected import FactorGraph, VariableNode, Factor

# -----------------------
# SLAM-like base graph
# -----------------------
def make_slam_like_graph(N=100, step_size=25, loop_prob=0.2, loop_radius=50, rng=None):
    if rng is None:
        rng = np.random.default_rng()

    nodes, edges = [], []
    positions = []
    x, y = 0.0, 0.0
    positions.append((x, y))

    # 随机游走生成轨迹
    for _ in range(1, int(N)):
        dx, dy = rng.normal(size=2)
        norm = np.sqrt(dx**2 + dy**2) + 1e-6
        dx, dy = dx / norm * float(step_size), dy / norm * float(step_size)
        x, y = x + dx, y + dy
        positions.append((x, y))

    # 节点
    for i, (px, py) in enumerate(positions):
        nodes.append({
            "data": {"id": f"b{i}", "layer": 0, "dim": 2},
            "position": {"x": float(px), "y": float(py)}
        })

    # 顺序边
    for i in range(int(N) - 1):
        edges.append({"data": {"source": f"b{i}", "target": f"b{i+1}"}})

    # 随机回环
    for i in range(int(N)):
        for j in range(i + 5, int(N)):
            if rng.random() < float(loop_prob):
                xi, yi = positions[i]; xj, yj = positions[j]
                if np.hypot(xi-xj, yi-yj) < float(loop_radius):
                    edges.append({"data": {"source": f"b{i}", "target": f"b{j}"}})
    return nodes, edges


# -----------------------
# GBP Graph 构建
# -----------------------
def build_noisy_pose_graph(
    nodes,
    edges,
    prior_sigma: float = 10,
    odom_sigma: float = 10,
    prior_prop: float = 0.0,
    tiny_prior: float = 1e-6,
    rng=None,
):
    """
    构造二维 pose-only 因子图（线性，高斯），并注入噪声。
    参数:
      prior_sigma : 强先验的标准差（小=强）
      odom_sigma  : 里程计测量噪声标准差
      prior_prop  : 0.0=仅 anchor；(0,1)=按比例随机选；>=1.0=全体
      tiny_prior  : 所有节点默认加的极小先验，防止奇异
    """
    if rng is None:
        rng = np.random.default_rng()

    fg = FactorGraph(nonlinear_factors=False, eta_damping=0)

    # ---- 变量节点 + 先验 ----
    var_nodes = []
    I2 = np.eye(2, dtype=float)
    N = len(nodes)

    # 确定强先验的节点集合
    if prior_prop <= 0.0:
        strong_ids = {0}
    elif prior_prop >= 1.0:
        strong_ids = set(range(N))
    else:
        k = max(1, int(np.floor(prior_prop * N)))
        strong_ids = set(rng.choice(N, size=k, replace=False).tolist())

    for i, n in enumerate(nodes):
        v = VariableNode(i, dofs=2)
        # 保存 GT（只用于生成测量 & 初始线性化点）
        v.GT = np.array([n["position"]["x"], n["position"]["y"]], dtype=float)

        # 极小先验（所有节点都有，避免奇异）
        v.prior.lam = tiny_prior * I2
        v.prior.eta = np.zeros(2, dtype=float)

        # 强先验（根据 prior_prop 选择）
        if i in strong_ids:
            lam_strong = I2 / (prior_sigma ** 2)
            eta_strong = lam_strong @ (v.GT + rng.normal(0.0, prior_sigma, size=2))
            v.prior.lam = v.prior.lam + lam_strong
            v.prior.eta = v.prior.eta + eta_strong

        var_nodes.append(v)

    fg.var_nodes = var_nodes
    fg.n_var_nodes = len(var_nodes)

    # ---- 测量模型（线性的）----
    def meas_fn(xy, *args):
        # measurement = p_j - p_i
        xy = np.asarray(xy, dtype=float)
        return xy[2:] - xy[:2]

    def jac_fn(xy, *args):
        # d(pj - pi)/d[pi,pj] = [-I, I]
        return np.array([[-1, 0, 1, 0],
                         [ 0,-1, 0, 1]], dtype=float)

    # ---- 里程计/回环 因子 ----
    factors = []
    fid = 0
    for e in edges:
        src = e["data"]["source"]; dst = e["data"]["target"]
        # 只连 base 层的节点
        if not (src.startswith("b") and dst.startswith("b")):
            continue
        i = int(src[1:]); j = int(dst[1:])
        vi, vj = var_nodes[i], var_nodes[j]

        # 测量 = GT 差值 + 高斯噪声
        meas = (vj.GT - vi.GT) + rng.normal(0.0, odom_sigma, size=2)

        f = Factor(fid, [vi, vj], meas, odom_sigma, meas_fn, jac_fn)
        f.type = "base"

        # 用 GT 作为初始线性化点
        linpoint = np.r_[vi.GT, vj.GT]
        f.compute_factor(linpoint=linpoint, update_self=True)

        factors.append(f)
        vi.adj_factors.append(f)
        vj.adj_factors.append(f)
        fid += 1

    fg.factors = factors
    fg.n_factor_nodes = len(factors)
    return fg


# -----------------------
# 主程序：跑 100 次迭代
# -----------------------
if __name__ == "__main__":
    rng = np.random.default_rng(42)  # 固定随机种子

    # 1. 造一个图
    nodes, edges = make_slam_like_graph(N=50, step_size=25, loop_prob=0.1, loop_radius=50, rng=rng)

    # 2. 构建 GBP 图
    fg = build_noisy_pose_graph(nodes, edges, prior_sigma=10.0, odom_sigma=10.0, prior_prop=0, rng=rng)

    # 3. 跑迭代
    for it in range(1000):
        fg.synchronous_iteration()
        energy = fg.energy_map(include_priors=True, include_factors=True)
        print(f"Iter {it+1:03d} | Energy = {energy:.6f}")
# Out:
# Iter 001 | Energy = 251.687168
# Iter 002 | Energy = 177.024744
# Iter 003 | Energy = 250.069207
# Iter 004 | Energy = 353.602824
# Iter 005 | Energy = 259.619680
# Iter 006 | Energy = 283.434695
# Iter 007 | Energy = 119.811879
# Iter 008 | Energy = 182.714717
# Iter 009 | Energy = 288.556415
# Iter 010 | Energy = 312.656287
# Iter 011 | Energy = 205.160532
# Iter 012 | Energy = 122.110361
# Iter 013 | Energy = 80.473774
# Iter 014 | Energy = 22.979506
# Iter 015 | Energy = 19.219965
# Iter 016 | Energy = 17.402127
# Iter 017 | Energy = 16.878754
# Iter 018 | Energy = 16.700481
# Iter 019 | Energy = 16.514586
# Iter 020 | Energy = 16.362264
# Iter 021 | Energy = 16.320413
# Iter 022 | Energy = 16.284298
# Iter 023 | Energy = 16.245519
# Iter 024 | Energy = 16.225189
# Iter 025 | Energy = 16.213172
# Iter 026 | Energy = 16.201660
# Iter 027 | Energy = 16.191625
# Iter 028 | Energy = 16.184999
# Iter 029 | Energy = 16.179464
# Iter 030 | Energy = 16.174265
# Iter 031 | Energy = 16.169919
# Iter 032 | Energy = 16.166454
# Iter 033 | Energy = 16.163505
# Iter 034 | Energy = 16.160943
# Iter 035 | Energy = 16.158697
# Iter 036 | Energy = 16.156693
# Iter 037 | Energy = 16.154885
# Iter 038 | Energy = 16.153253
# Iter 039 | Energy = 16.151767
# Iter 040 | Energy = 16.150398
# Iter 041 | Energy = 16.149126
# Iter 042 | Energy = 16.147937
# Iter 043 | Energy = 16.146812
# Iter 044 | Energy = 16.145742
# Iter 045 | Energy = 16.144723
# Iter 046 | Energy = 16.143749
# Iter 047 | Energy = 16.142816
# Iter 048 | Energy = 16.141919
# Iter 049 | Energy = 16.141055
# Iter 050 | Energy = 16.140222
# Iter 051 | Energy = 16.139415
# Iter 052 | Energy = 16.138635
# Iter 053 | Energy = 16.137880
# Iter 054 | Energy = 16.137147
# Iter 055 | Energy = 16.136437
# Iter 056 | Energy = 16.135747
# Iter 057 | Energy = 16.135077
# Iter 058 | Energy = 16.134427
# Iter 059 | Energy = 16.133795
# Iter 060 | Energy = 16.133180
# Iter 061 | Energy = 16.132583
# Iter 062 | Energy = 16.132002
# Iter 063 | Energy = 16.131437
# Iter 064 | Energy = 16.130888
# Iter 065 | Energy = 16.130353
# Iter 066 | Energy = 16.129834
# Iter 067 | Energy = 16.129328
# Iter 068 | Energy = 16.128836
# Iter 069 | Energy = 16.128358
# Iter 070 | Energy = 16.127892
# Iter 071 | Energy = 16.127439
# Iter 072 | Energy = 16.126999
# Iter 073 | Energy = 16.126570
# Iter 074 | Energy = 16.126153
# Iter 075 | Energy = 16.125747
# Iter 076 | Energy = 16.125352
# Iter 077 | Energy = 16.124968
# Iter 078 | Energy = 16.124594
# Iter 079 | Energy = 16.124230
# Iter 080 | Energy = 16.123876
# Iter 081 | Energy = 16.123531
# Iter 082 | Energy = 16.123196
# Iter 083 | Energy = 16.122870
# Iter 084 | Energy = 16.122552
# Iter 085 | Energy = 16.122244
# Iter 086 | Energy = 16.121943
# Iter 087 | Energy = 16.121651
# Iter 088 | Energy = 16.121366
# Iter 089 | Energy = 16.121089
# Iter 090 | Energy = 16.120820
# Iter 091 | Energy = 16.120558
# Iter 092 | Energy = 16.120302
# Iter 093 | Energy = 16.120054
# Iter 094 | Energy = 16.119813
# Iter 095 | Energy = 16.119577
# Iter 096 | Energy = 16.119349
# Iter 097 | Energy = 16.119126
# Iter 098 | Energy = 16.118909
# Iter 099 | Energy = 16.118699
# Iter 100 | Energy = 16.118494
# Iter 101 | Energy = 16.118294
# Iter 102 | Energy = 16.118100
# Iter 103 | Energy = 16.117911
# Iter 104 | Energy = 16.117727
# Iter 105 | Energy = 16.117548
# Iter 106 | Energy = 16.117374
# Iter 107 | Energy = 16.117204
# Iter 108 | Energy = 16.117039
# Iter 109 | Energy = 16.116879
# Iter 110 | Energy = 16.116723
# Iter 111 | Energy = 16.116571
# Iter 112 | Energy = 16.116423
# Iter 113 | Energy = 16.116279
# Iter 114 | Energy = 16.116139
# Iter 115 | Energy = 16.116003
# Iter 116 | Energy = 16.115871
# Iter 117 | Energy = 16.115742
# Iter 118 | Energy = 16.115616
# Iter 119 | Energy = 16.115494
# Iter 120 | Energy = 16.115375
# Iter 121 | Energy = 16.115259
# Iter 122 | Energy = 16.115147
# Iter 123 | Energy = 16.115037
# Iter 124 | Energy = 16.114931
# Iter 125 | Energy = 16.114827
# Iter 126 | Energy = 16.114726
# Iter 127 | Energy = 16.114628
# Iter 128 | Energy = 16.114532
# Iter 129 | Energy = 16.114439
# Iter 130 | Energy = 16.114349
# Iter 131 | Energy = 16.114261
# Iter 132 | Energy = 16.114175
# Iter 133 | Energy = 16.114092
# Iter 134 | Energy = 16.114011
# Iter 135 | Energy = 16.113932
# Iter 136 | Energy = 16.113855
# Iter 137 | Energy = 16.113780
# Iter 138 | Energy = 16.113708
# Iter 139 | Energy = 16.113637
# Iter 140 | Energy = 16.113568
# Iter 141 | Energy = 16.113501
# Iter 142 | Energy = 16.113436
# Iter 143 | Energy = 16.113372
# Iter 144 | Energy = 16.113310
# Iter 145 | Energy = 16.113250
# Iter 146 | Energy = 16.113192
# Iter 147 | Energy = 16.113135
# Iter 148 | Energy = 16.113080
# Iter 149 | Energy = 16.113026
# Iter 150 | Energy = 16.112973
# Iter 151 | Energy = 16.112922
# Iter 152 | Energy = 16.112873
# Iter 153 | Energy = 16.112824
# Iter 154 | Energy = 16.112777
# Iter 155 | Energy = 16.112732
# Iter 156 | Energy = 16.112687
# Iter 157 | Energy = 16.112644
# Iter 158 | Energy = 16.112602
# Iter 159 | Energy = 16.112561
# Iter 160 | Energy = 16.112521
# Iter 161 | Energy = 16.112482
# Iter 162 | Energy = 16.112444
# Iter 163 | Energy = 16.112407
# Iter 164 | Energy = 16.112372
# Iter 165 | Energy = 16.112337
# Iter 166 | Energy = 16.112303
# Iter 167 | Energy = 16.112270
# Iter 168 | Energy = 16.112238
# Iter 169 | Energy = 16.112207
# Iter 170 | Energy = 16.112176
# Iter 171 | Energy = 16.112147
# Iter 172 | Energy = 16.112118
# Iter 173 | Energy = 16.112090
# Iter 174 | Energy = 16.112063
# Iter 175 | Energy = 16.112036
# Iter 176 | Energy = 16.112010
# Iter 177 | Energy = 16.111985
# Iter 178 | Energy = 16.111961
# Iter 179 | Energy = 16.111937
# Iter 180 | Energy = 16.111914
# Iter 181 | Energy = 16.111891
# Iter 182 | Energy = 16.111870
# Iter 183 | Energy = 16.111848
# Iter 184 | Energy = 16.111827
# Iter 185 | Energy = 16.111807
# Iter 186 | Energy = 16.111788
# Iter 187 | Energy = 16.111769
# Iter 188 | Energy = 16.111750
# Iter 189 | Energy = 16.111732
# Iter 190 | Energy = 16.111714
# Iter 191 | Energy = 16.111697
# Iter 192 | Energy = 16.111680
# Iter 193 | Energy = 16.111664
# Iter 194 | Energy = 16.111648
# Iter 195 | Energy = 16.111633
# Iter 196 | Energy = 16.111618
# Iter 197 | Energy = 16.111604
# Iter 198 | Energy = 16.111589
# Iter 199 | Energy = 16.111576
# Iter 200 | Energy = 16.111562
# Iter 201 | Energy = 16.111549
# Iter 202 | Energy = 16.111537
# Iter 203 | Energy = 16.111524
# Iter 204 | Energy = 16.111512
# Iter 205 | Energy = 16.111500
# Iter 206 | Energy = 16.111489
# Iter 207 | Energy = 16.111478
# Iter 208 | Energy = 16.111467
# Iter 209 | Energy = 16.111457
# Iter 210 | Energy = 16.111447
# Iter 211 | Energy = 16.111437
# Iter 212 | Energy = 16.111427
# Iter 213 | Energy = 16.111418
# Iter 214 | Energy = 16.111408
# Iter 215 | Energy = 16.111400
# Iter 216 | Energy = 16.111391
# Iter 217 | Energy = 16.111382
# Iter 218 | Energy = 16.111374
# Iter 219 | Energy = 16.111366
# Iter 220 | Energy = 16.111358
# Iter 221 | Energy = 16.111351
# Iter 222 | Energy = 16.111344
# Iter 223 | Energy = 16.111336
# Iter 224 | Energy = 16.111329
# Iter 225 | Energy = 16.111323
# Iter 226 | Energy = 16.111316
# Iter 227 | Energy = 16.111310
# Iter 228 | Energy = 16.111303
# Iter 229 | Energy = 16.111297
# Iter 230 | Energy = 16.111291
# Iter 231 | Energy = 16.111286
# Iter 232 | Energy = 16.111280
# Iter 233 | Energy = 16.111275
# Iter 234 | Energy = 16.111269
# Iter 235 | Energy = 16.111264
# Iter 236 | Energy = 16.111259
# Iter 237 | Energy = 16.111254
# Iter 238 | Energy = 16.111250
# Iter 239 | Energy = 16.111245
# Iter 240 | Energy = 16.111240
# Iter 241 | Energy = 16.111236
# Iter 242 | Energy = 16.111232
# Iter 243 | Energy = 16.111228
# Iter 244 | Energy = 16.111224
# Iter 245 | Energy = 16.111220
# Iter 246 | Energy = 16.111216
# Iter 247 | Energy = 16.111212
# Iter 248 | Energy = 16.111209
# Iter 249 | Energy = 16.111205
# Iter 250 | Energy = 16.111202
# Iter 251 | Energy = 16.111198
# Iter 252 | Energy = 16.111195
# Iter 253 | Energy = 16.111192
# Iter 254 | Energy = 16.111189
# Iter 255 | Energy = 16.111186
# Iter 256 | Energy = 16.111183
# Iter 257 | Energy = 16.111180
# Iter 258 | Energy = 16.111177
# Iter 259 | Energy = 16.111175
# Iter 260 | Energy = 16.111172
# Iter 261 | Energy = 16.111169
# Iter 262 | Energy = 16.111167
# Iter 263 | Energy = 16.111165
# Iter 264 | Energy = 16.111162
# Iter 265 | Energy = 16.111160
# Iter 266 | Energy = 16.111158
# Iter 267 | Energy = 16.111156
# Iter 268 | Energy = 16.111154
# Iter 269 | Energy = 16.111151
# Iter 270 | Energy = 16.111149
# Iter 271 | Energy = 16.111148
# Iter 272 | Energy = 16.111146
# Iter 273 | Energy = 16.111144
# Iter 274 | Energy = 16.111142
# Iter 275 | Energy = 16.111140
# Iter 276 | Energy = 16.111139
# Iter 277 | Energy = 16.111137
# Iter 278 | Energy = 16.111135
# Iter 279 | Energy = 16.111134
# Iter 280 | Energy = 16.111132
# Iter 281 | Energy = 16.111131
# Iter 282 | Energy = 16.111129
# Iter 283 | Energy = 16.111128
# Iter 284 | Energy = 16.111127
# Iter 285 | Energy = 16.111125
# Iter 286 | Energy = 16.111124
# Iter 287 | Energy = 16.111123
# Iter 288 | Energy = 16.111122
# Iter 289 | Energy = 16.111120
# Iter 290 | Energy = 16.111119
# Iter 291 | Energy = 16.111118
# Iter 292 | Energy = 16.111117
# Iter 293 | Energy = 16.111116
# Iter 294 | Energy = 16.111115
# Iter 295 | Energy = 16.111114
# Iter 296 | Energy = 16.111113
# Iter 297 | Energy = 16.111112
# Iter 298 | Energy = 16.111111
# Iter 299 | Energy = 16.111110
# Iter 300 | Energy = 16.111109
# Iter 301 | Energy = 16.111109
# Iter 302 | Energy = 16.111108
# Iter 303 | Energy = 16.111107
# Iter 304 | Energy = 16.111106
# Iter 305 | Energy = 16.111105
# Iter 306 | Energy = 16.111105
# Iter 307 | Energy = 16.111104
# Iter 308 | Energy = 16.111103
# Iter 309 | Energy = 16.111102
# Iter 310 | Energy = 16.111102
# Iter 311 | Energy = 16.111101
# Iter 312 | Energy = 16.111101
# Iter 313 | Energy = 16.111100
# Iter 314 | Energy = 16.111099
# Iter 315 | Energy = 16.111099
# Iter 316 | Energy = 16.111098
# Iter 317 | Energy = 16.111098
# Iter 318 | Energy = 16.111097
# Iter 319 | Energy = 16.111097
# Iter 320 | Energy = 16.111096
# Iter 321 | Energy = 16.111096
# Iter 322 | Energy = 16.111095
# Iter 323 | Energy = 16.111095
# Iter 324 | Energy = 16.111094
# Iter 325 | Energy = 16.111094
# Iter 326 | Energy = 16.111093
# Iter 327 | Energy = 16.111093
# Iter 328 | Energy = 16.111092
# Iter 329 | Energy = 16.111092
# Iter 330 | Energy = 16.111092
# Iter 331 | Energy = 16.111091
# Iter 332 | Energy = 16.111091
# Iter 333 | Energy = 16.111091
# Iter 334 | Energy = 16.111090
# Iter 335 | Energy = 16.111090
# Iter 336 | Energy = 16.111090
# Iter 337 | Energy = 16.111089
# Iter 338 | Energy = 16.111089
# Iter 339 | Energy = 16.111089
# Iter 340 | Energy = 16.111088
# Iter 341 | Energy = 16.111088
# Iter 342 | Energy = 16.111088
# Iter 343 | Energy = 16.111087
# Iter 344 | Energy = 16.111087
# Iter 345 | Energy = 16.111087
# Iter 346 | Energy = 16.111087
# Iter 347 | Energy = 16.111086
# Iter 348 | Energy = 16.111086
# Iter 349 | Energy = 16.111086
# Iter 350 | Energy = 16.111086
# Iter 351 | Energy = 16.111086
# Iter 352 | Energy = 16.111085
# Iter 353 | Energy = 16.111085
# Iter 354 | Energy = 16.111085
# Iter 355 | Energy = 16.111085
# Iter 356 | Energy = 16.111085
# Iter 357 | Energy = 16.111084
# Iter 358 | Energy = 16.111084
# Iter 359 | Energy = 16.111084
# Iter 360 | Energy = 16.111084
# Iter 361 | Energy = 16.111084
# Iter 362 | Energy = 16.111084
# Iter 363 | Energy = 16.111083
# Iter 364 | Energy = 16.111083
# Iter 365 | Energy = 16.111083
# Iter 366 | Energy = 16.111083
# Iter 367 | Energy = 16.111083
# Iter 368 | Energy = 16.111083
# Iter 369 | Energy = 16.111083
# Iter 370 | Energy = 16.111082
# Iter 371 | Energy = 16.111082
# Iter 372 | Energy = 16.111082
# Iter 373 | Energy = 16.111082
# Iter 374 | Energy = 16.111082
# Iter 375 | Energy = 16.111082
# Iter 376 | Energy = 16.111082
# Iter 377 | Energy = 16.111082
# Iter 378 | Energy = 16.111081
# Iter 379 | Energy = 16.111081
# Iter 380 | Energy = 16.111081
# Iter 381 | Energy = 16.111081
# Iter 382 | Energy = 16.111081
# Iter 383 | Energy = 16.111081
# Iter 384 | Energy = 16.111081
# Iter 385 | Energy = 16.111081
# Iter 386 | Energy = 16.111081
# Iter 387 | Energy = 16.111081
# Iter 388 | Energy = 16.111081
# Iter 389 | Energy = 16.111080
# Iter 390 | Energy = 16.111080
# Iter 391 | Energy = 16.111080
# Iter 392 | Energy = 16.111080
# Iter 393 | Energy = 16.111080
# Iter 394 | Energy = 16.111080
# Iter 395 | Energy = 16.111080
# Iter 396 | Energy = 16.111080
# Iter 397 | Energy = 16.111080
# Iter 398 | Energy = 16.111080
# Iter 399 | Energy = 16.111080
# Iter 400 | Energy = 16.111080
# Iter 401 | Energy = 16.111080
# Iter 402 | Energy = 16.111080
# Iter 403 | Energy = 16.111080
# Iter 404 | Energy = 16.111080
# Iter 405 | Energy = 16.111080
# Iter 406 | Energy = 16.111079
# Iter 407 | Energy = 16.111079
# Iter 408 | Energy = 16.111079
# Iter 409 | Energy = 16.111079
# Iter 410 | Energy = 16.111079
# Iter 411 | Energy = 16.111079
# Iter 412 | Energy = 16.111079
# Iter 413 | Energy = 16.111079
# Iter 414 | Energy = 16.111079
# Iter 415 | Energy = 16.111079
# Iter 416 | Energy = 16.111079
# Iter 417 | Energy = 16.111079
# Iter 418 | Energy = 16.111079
# Iter 419 | Energy = 16.111079
# Iter 420 | Energy = 16.111079
# Iter 421 | Energy = 16.111079
# Iter 422 | Energy = 16.111079
# Iter 423 | Energy = 16.111079
# Iter 424 | Energy = 16.111079
# Iter 425 | Energy = 16.111079
# Iter 426 | Energy = 16.111079
# Iter 427 | Energy = 16.111079
# Iter 428 | Energy = 16.111079
# Iter 429 | Energy = 16.111079
# Iter 430 | Energy = 16.111079
# Iter 431 | Energy = 16.111079
# Iter 432 | Energy = 16.111079
# Iter 433 | Energy = 16.111079
# Iter 434 | Energy = 16.111079
# Iter 435 | Energy = 16.111078
# Iter 436 | Energy = 16.111078
# Iter 437 | Energy = 16.111078
# Iter 438 | Energy = 16.111078
# Iter 439 | Energy = 16.111078
# Iter 440 | Energy = 16.111078
# Iter 441 | Energy = 16.111078
# Iter 442 | Energy = 16.111078
# Iter 443 | Energy = 16.111078
# Iter 444 | Energy = 16.111078
# Iter 445 | Energy = 16.111078
# Iter 446 | Energy = 16.111078
# Iter 447 | Energy = 16.111078
# Iter 448 | Energy = 16.111078
# Iter 449 | Energy = 16.111078
# Iter 450 | Energy = 16.111078
# Iter 451 | Energy = 16.111078
# Iter 452 | Energy = 16.111078
# Iter 453 | Energy = 16.111078
# Iter 454 | Energy = 16.111078
# Iter 455 | Energy = 16.111078
# Iter 456 | Energy = 16.111078
# Iter 457 | Energy = 16.111078
# Iter 458 | Energy = 16.111078
# Iter 459 | Energy = 16.111078
# Iter 460 | Energy = 16.111078
# Iter 461 | Energy = 16.111078
# Iter 462 | Energy = 16.111078
# Iter 463 | Energy = 16.111078
# Iter 464 | Energy = 16.111078
# Iter 465 | Energy = 16.111078
# Iter 466 | Energy = 16.111078
# Iter 467 | Energy = 16.111078
# Iter 468 | Energy = 16.111078
# Iter 469 | Energy = 16.111078
# Iter 470 | Energy = 16.111078
# Iter 471 | Energy = 16.111078
# Iter 472 | Energy = 16.111078
# Iter 473 | Energy = 16.111078
# Iter 474 | Energy = 16.111078
# Iter 475 | Energy = 16.111078
# Iter 476 | Energy = 16.111078
# Iter 477 | Energy = 16.111078
# Iter 478 | Energy = 16.111078
# Iter 479 | Energy = 16.111078
# Iter 480 | Energy = 16.111078
# Iter 481 | Energy = 16.111078
# Iter 482 | Energy = 16.111078
# Iter 483 | Energy = 16.111078
# Iter 484 | Energy = 16.111078
# Iter 485 | Energy = 16.111078
# Iter 486 | Energy = 16.111078
# Iter 487 | Energy = 16.111078
# Iter 488 | Energy = 16.111078
# Iter 489 | Energy = 16.111078
# Iter 490 | Energy = 16.111078
# Iter 491 | Energy = 16.111078
# Iter 492 | Energy = 16.111078
# Iter 493 | Energy = 16.111078
# Iter 494 | Energy = 16.111078
# Iter 495 | Energy = 16.111078
# Iter 496 | Energy = 16.111078
# Iter 497 | Energy = 16.111078
# Iter 498 | Energy = 16.111078
# Iter 499 | Energy = 16.111078
# Iter 500 | Energy = 16.111078
# Iter 501 | Energy = 16.111078
# Iter 502 | Energy = 16.111078
# Iter 503 | Energy = 16.111078
# Iter 504 | Energy = 16.111078
# Iter 505 | Energy = 16.111078
# Iter 506 | Energy = 16.111078
# Iter 507 | Energy = 16.111078
# Iter 508 | Energy = 16.111078
# Iter 509 | Energy = 16.111078
# Iter 510 | Energy = 16.111078
# Iter 511 | Energy = 16.111078
# Iter 512 | Energy = 16.111078
# Iter 513 | Energy = 16.111078
# Iter 514 | Energy = 16.111078
# Iter 515 | Energy = 16.111078
# Iter 516 | Energy = 16.111078
# Iter 517 | Energy = 16.111078
# Iter 518 | Energy = 16.111078
# Iter 519 | Energy = 16.111078
# Iter 520 | Energy = 16.111078
# Iter 521 | Energy = 16.111078
# Iter 522 | Energy = 16.111078
# Iter 523 | Energy = 16.111078
# Iter 524 | Energy = 16.111078
# Iter 525 | Energy = 16.111078
# Iter 526 | Energy = 16.111078
# Iter 527 | Energy = 16.111078
# Iter 528 | Energy = 16.111078
# Iter 529 | Energy = 16.111078
# Iter 530 | Energy = 16.111078
# Iter 531 | Energy = 16.111078
# Iter 532 | Energy = 16.111078
# Iter 533 | Energy = 16.111078
# Iter 534 | Energy = 16.111078
# Iter 535 | Energy = 16.111078
# Iter 536 | Energy = 16.111078
# Iter 537 | Energy = 16.111078
# Iter 538 | Energy = 16.111078
# Iter 539 | Energy = 16.111078
# Iter 540 | Energy = 16.111078
# Iter 541 | Energy = 16.111078
# Iter 542 | Energy = 16.111078
# Iter 543 | Energy = 16.111078
# Iter 544 | Energy = 16.111078
# Iter 545 | Energy = 16.111078
# Iter 546 | Energy = 16.111078
# Iter 547 | Energy = 16.111078
# Iter 548 | Energy = 16.111078
# Iter 549 | Energy = 16.111078
# Iter 550 | Energy = 16.111078
# Iter 551 | Energy = 16.111078
# Iter 552 | Energy = 16.111078
# Iter 553 | Energy = 16.111078
# Iter 554 | Energy = 16.111078
# Iter 555 | Energy = 16.111078
# Iter 556 | Energy = 16.111078
# Iter 557 | Energy = 16.111078
# Iter 558 | Energy = 16.111078
# Iter 559 | Energy = 16.111078
# Iter 560 | Energy = 16.111078
# Iter 561 | Energy = 16.111078
# Iter 562 | Energy = 16.111078
# Iter 563 | Energy = 16.111078
# Iter 564 | Energy = 16.111078
# Iter 565 | Energy = 16.111078
# Iter 566 | Energy = 16.111078
# Iter 567 | Energy = 16.111078
# Iter 568 | Energy = 16.111078
# Iter 569 | Energy = 16.111078
# Iter 570 | Energy = 16.111078
# Iter 571 | Energy = 16.111078
# Iter 572 | Energy = 16.111078
# Iter 573 | Energy = 16.111078
# Iter 574 | Energy = 16.111078
# Iter 575 | Energy = 16.111078
# Iter 576 | Energy = 16.111078
# Iter 577 | Energy = 16.111078
# Iter 578 | Energy = 16.111078
# Iter 579 | Energy = 16.111078
# Iter 580 | Energy = 16.111078
# Iter 581 | Energy = 16.111078
# Iter 582 | Energy = 16.111078
# Iter 583 | Energy = 16.111078
# Iter 584 | Energy = 16.111078
# Iter 585 | Energy = 16.111078
# Iter 586 | Energy = 16.111078
# Iter 587 | Energy = 16.111078
# Iter 588 | Energy = 16.111078
# Iter 589 | Energy = 16.111078
# Iter 590 | Energy = 16.111078
# Iter 591 | Energy = 16.111078
# Iter 592 | Energy = 16.111078
# Iter 593 | Energy = 16.111078
# Iter 594 | Energy = 16.111078
# Iter 595 | Energy = 16.111078
# Iter 596 | Energy = 16.111078
# Iter 597 | Energy = 16.111078
# Iter 598 | Energy = 16.111078
# Iter 599 | Energy = 16.111078
# Iter 600 | Energy = 16.111078
# Iter 601 | Energy = 16.111078
# Iter 602 | Energy = 16.111078
# Iter 603 | Energy = 16.111078
# Iter 604 | Energy = 16.111078
# Iter 605 | Energy = 16.111078
# Iter 606 | Energy = 16.111078
# Iter 607 | Energy = 16.111078
# Iter 608 | Energy = 16.111078
# Iter 609 | Energy = 16.111078
# Iter 610 | Energy = 16.111078
# Iter 611 | Energy = 16.111078
# Iter 612 | Energy = 16.111078
# Iter 613 | Energy = 16.111078
# Iter 614 | Energy = 16.111078
# Iter 615 | Energy = 16.111078
# Iter 616 | Energy = 16.111078
# Iter 617 | Energy = 16.111078
# Iter 618 | Energy = 16.111078
# Iter 619 | Energy = 16.111078
# Iter 620 | Energy = 16.111078
# Iter 621 | Energy = 16.111078
# Iter 622 | Energy = 16.111078
# Iter 623 | Energy = 16.111078
# Iter 624 | Energy = 16.111078
# Iter 625 | Energy = 16.111078
# Iter 626 | Energy = 16.111078
# Iter 627 | Energy = 16.111078
# Iter 628 | Energy = 16.111078
# Iter 629 | Energy = 16.111078
# Iter 630 | Energy = 16.111078
# Iter 631 | Energy = 16.111078
# Iter 632 | Energy = 16.111078
# Iter 633 | Energy = 16.111078
# Iter 634 | Energy = 16.111078
# Iter 635 | Energy = 16.111078
# Iter 636 | Energy = 16.111078
# Iter 637 | Energy = 16.111078
# Iter 638 | Energy = 16.111078
# Iter 639 | Energy = 16.111078
# Iter 640 | Energy = 16.111078
# Iter 641 | Energy = 16.111078
# Iter 642 | Energy = 16.111078
# Iter 643 | Energy = 16.111078
# Iter 644 | Energy = 16.111078
# Iter 645 | Energy = 16.111078
# Iter 646 | Energy = 16.111078
# Iter 647 | Energy = 16.111078
# Iter 648 | Energy = 16.111078
# Iter 649 | Energy = 16.111078
# Iter 650 | Energy = 16.111078
# Iter 651 | Energy = 16.111078
# Iter 652 | Energy = 16.111078
# Iter 653 | Energy = 16.111078
# Iter 654 | Energy = 16.111078
# Iter 655 | Energy = 16.111078
# Iter 656 | Energy = 16.111078
# Iter 657 | Energy = 16.111078
# Iter 658 | Energy = 16.111078
# Iter 659 | Energy = 16.111078
# Iter 660 | Energy = 16.111078
# Iter 661 | Energy = 16.111078
# Iter 662 | Energy = 16.111078
# Iter 663 | Energy = 16.111078
# Iter 664 | Energy = 16.111078
# Iter 665 | Energy = 16.111078
# Iter 666 | Energy = 16.111078
# Iter 667 | Energy = 16.111078
# Iter 668 | Energy = 16.111078
# Iter 669 | Energy = 16.111078
# Iter 670 | Energy = 16.111078
# Iter 671 | Energy = 16.111078
# Iter 672 | Energy = 16.111078
# Iter 673 | Energy = 16.111078
# Iter 674 | Energy = 16.111078
# Iter 675 | Energy = 16.111078
# Iter 676 | Energy = 16.111078
# Iter 677 | Energy = 16.111078
# Iter 678 | Energy = 16.111078
# Iter 679 | Energy = 16.111078
# Iter 680 | Energy = 16.111078
# Iter 681 | Energy = 16.111078
# Iter 682 | Energy = 16.111078
# Iter 683 | Energy = 16.111078
# Iter 684 | Energy = 16.111078
# Iter 685 | Energy = 16.111078
# Iter 686 | Energy = 16.111078
# Iter 687 | Energy = 16.111078
# Iter 688 | Energy = 16.111078
# Iter 689 | Energy = 16.111078
# Iter 690 | Energy = 16.111078
# Iter 691 | Energy = 16.111078
# Iter 692 | Energy = 16.111078
# Iter 693 | Energy = 16.111078
# Iter 694 | Energy = 16.111078
# Iter 695 | Energy = 16.111078
# Iter 696 | Energy = 16.111078
# Iter 697 | Energy = 16.111078
# Iter 698 | Energy = 16.111078
# Iter 699 | Energy = 16.111078
# Iter 700 | Energy = 16.111078
# Iter 701 | Energy = 16.111078
# Iter 702 | Energy = 16.111078
# Iter 703 | Energy = 16.111078
# Iter 704 | Energy = 16.111078
# Iter 705 | Energy = 16.111078
# Iter 706 | Energy = 16.111078
# Iter 707 | Energy = 16.111078
# Iter 708 | Energy = 16.111078
# Iter 709 | Energy = 16.111078
# Iter 710 | Energy = 16.111078
# Iter 711 | Energy = 16.111078
# Iter 712 | Energy = 16.111078
# Iter 713 | Energy = 16.111078
# Iter 714 | Energy = 16.111078
# Iter 715 | Energy = 16.111078
# Iter 716 | Energy = 16.111078
# Iter 717 | Energy = 16.111078
# Iter 718 | Energy = 16.111078
# Iter 719 | Energy = 16.111078
# Iter 720 | Energy = 16.111078
# Iter 721 | Energy = 16.111078
# Iter 722 | Energy = 16.111078
# Iter 723 | Energy = 16.111078
# Iter 724 | Energy = 16.111078
# Iter 725 | Energy = 16.111078
# Iter 726 | Energy = 16.111078
# Iter 727 | Energy = 16.111078
# Iter 728 | Energy = 16.111078
# Iter 729 | Energy = 16.111078
# Iter 730 | Energy = 16.111078
# Iter 731 | Energy = 16.111078
# Iter 732 | Energy = 16.111078
# Iter 733 | Energy = 16.111078
# Iter 734 | Energy = 16.111078
# Iter 735 | Energy = 16.111078
# Iter 736 | Energy = 16.111078
# Iter 737 | Energy = 16.111078
# Iter 738 | Energy = 16.111078
# Iter 739 | Energy = 16.111078
# Iter 740 | Energy = 16.111078
# Iter 741 | Energy = 16.111078
# Iter 742 | Energy = 16.111078
# Iter 743 | Energy = 16.111078
# Iter 744 | Energy = 16.111078
# Iter 745 | Energy = 16.111078
# Iter 746 | Energy = 16.111078
# Iter 747 | Energy = 16.111078
# Iter 748 | Energy = 16.111078
# Iter 749 | Energy = 16.111078
# Iter 750 | Energy = 16.111078
# Iter 751 | Energy = 16.111078
# Iter 752 | Energy = 16.111078
# Iter 753 | Energy = 16.111078
# Iter 754 | Energy = 16.111078
# Iter 755 | Energy = 16.111078
# Iter 756 | Energy = 16.111078
# Iter 757 | Energy = 16.111078
# Iter 758 | Energy = 16.111078
# Iter 759 | Energy = 16.111078
# Iter 760 | Energy = 16.111078
# Iter 761 | Energy = 16.111078
# Iter 762 | Energy = 16.111078
# Iter 763 | Energy = 16.111078
# Iter 764 | Energy = 16.111078
# Iter 765 | Energy = 16.111078
# Iter 766 | Energy = 16.111078
# Iter 767 | Energy = 16.111078
# Iter 768 | Energy = 16.111078
# Iter 769 | Energy = 16.111078
# Iter 770 | Energy = 16.111078
# Iter 771 | Energy = 16.111078
# Iter 772 | Energy = 16.111078
# Iter 773 | Energy = 16.111078
# Iter 774 | Energy = 16.111078
# Iter 775 | Energy = 16.111078
# Iter 776 | Energy = 16.111078
# Iter 777 | Energy = 16.111078
# Iter 778 | Energy = 16.111078
# Iter 779 | Energy = 16.111078
# Iter 780 | Energy = 16.111078
# Iter 781 | Energy = 16.111078
# Iter 782 | Energy = 16.111078
# Iter 783 | Energy = 16.111078
# Iter 784 | Energy = 16.111078
# Iter 785 | Energy = 16.111078
# Iter 786 | Energy = 16.111078
# Iter 787 | Energy = 16.111078
# Iter 788 | Energy = 16.111078
# Iter 789 | Energy = 16.111078
# Iter 790 | Energy = 16.111078
# Iter 791 | Energy = 16.111078
# Iter 792 | Energy = 16.111078
# Iter 793 | Energy = 16.111078
# Iter 794 | Energy = 16.111078
# Iter 795 | Energy = 16.111078
# Iter 796 | Energy = 16.111078
# Iter 797 | Energy = 16.111078
# Iter 798 | Energy = 16.111078
# Iter 799 | Energy = 16.111078
# Iter 800 | Energy = 16.111078
# Iter 801 | Energy = 16.111078
# Iter 802 | Energy = 16.111078
# Iter 803 | Energy = 16.111078
# Iter 804 | Energy = 16.111078
# Iter 805 | Energy = 16.111078
# Iter 806 | Energy = 16.111078
# Iter 807 | Energy = 16.111078
# Iter 808 | Energy = 16.111078
# Iter 809 | Energy = 16.111078
# Iter 810 | Energy = 16.111078
# Iter 811 | Energy = 16.111078
# Iter 812 | Energy = 16.111078
# Iter 813 | Energy = 16.111078
# Iter 814 | Energy = 16.111078
# Iter 815 | Energy = 16.111078
# Iter 816 | Energy = 16.111078
# Iter 817 | Energy = 16.111078
# Iter 818 | Energy = 16.111078
# Iter 819 | Energy = 16.111078
# Iter 820 | Energy = 16.111078
# Iter 821 | Energy = 16.111078
# Iter 822 | Energy = 16.111078
# Iter 823 | Energy = 16.111078
# Iter 824 | Energy = 16.111078
# Iter 825 | Energy = 16.111078
# Iter 826 | Energy = 16.111078
# Iter 827 | Energy = 16.111078
# Iter 828 | Energy = 16.111078
# Iter 829 | Energy = 16.111078
# Iter 830 | Energy = 16.111078
# Iter 831 | Energy = 16.111078
# Iter 832 | Energy = 16.111078
# Iter 833 | Energy = 16.111078
# Iter 834 | Energy = 16.111078
# Iter 835 | Energy = 16.111078
# Iter 836 | Energy = 16.111078
# Iter 837 | Energy = 16.111078
# Iter 838 | Energy = 16.111078
# Iter 839 | Energy = 16.111078
# Iter 840 | Energy = 16.111078
# Iter 841 | Energy = 16.111078
# Iter 842 | Energy = 16.111078
# Iter 843 | Energy = 16.111078
# Iter 844 | Energy = 16.111078
# Iter 845 | Energy = 16.111078
# Iter 846 | Energy = 16.111078
# Iter 847 | Energy = 16.111078
# Iter 848 | Energy = 16.111078
# Iter 849 | Energy = 16.111078
# Iter 850 | Energy = 16.111078
# Iter 851 | Energy = 16.111078
# Iter 852 | Energy = 16.111078
# Iter 853 | Energy = 16.111078
# Iter 854 | Energy = 16.111078
# Iter 855 | Energy = 16.111078
# Iter 856 | Energy = 16.111078
# Iter 857 | Energy = 16.111078
# Iter 858 | Energy = 16.111078
# Iter 859 | Energy = 16.111078
# Iter 860 | Energy = 16.111078
# Iter 861 | Energy = 16.111078
# Iter 862 | Energy = 16.111078
# Iter 863 | Energy = 16.111078
# Iter 864 | Energy = 16.111078
# Iter 865 | Energy = 16.111078
# Iter 866 | Energy = 16.111078
# Iter 867 | Energy = 16.111078
# Iter 868 | Energy = 16.111078
# Iter 869 | Energy = 16.111078
# Iter 870 | Energy = 16.111078
# Iter 871 | Energy = 16.111078
# Iter 872 | Energy = 16.111078
# Iter 873 | Energy = 16.111078
# Iter 874 | Energy = 16.111078
# Iter 875 | Energy = 16.111078
# Iter 876 | Energy = 16.111078
# Iter 877 | Energy = 16.111078
# Iter 878 | Energy = 16.111078
# Iter 879 | Energy = 16.111078
# Iter 880 | Energy = 16.111078
# Iter 881 | Energy = 16.111078
# Iter 882 | Energy = 16.111078
# Iter 883 | Energy = 16.111078
# Iter 884 | Energy = 16.111078
# Iter 885 | Energy = 16.111078
# Iter 886 | Energy = 16.111078
# Iter 887 | Energy = 16.111078
# Iter 888 | Energy = 16.111078
# Iter 889 | Energy = 16.111078
# Iter 890 | Energy = 16.111078
# Iter 891 | Energy = 16.111078
# Iter 892 | Energy = 16.111078
# Iter 893 | Energy = 16.111078
# Iter 894 | Energy = 16.111078
# Iter 895 | Energy = 16.111078
# Iter 896 | Energy = 16.111078
# Iter 897 | Energy = 16.111078
# Iter 898 | Energy = 16.111078
# Iter 899 | Energy = 16.111078
# Iter 900 | Energy = 16.111078
# Iter 901 | Energy = 16.111078
# Iter 902 | Energy = 16.111078
# Iter 903 | Energy = 16.111078
# Iter 904 | Energy = 16.111078
# Iter 905 | Energy = 16.111078
# Iter 906 | Energy = 16.111078
# Iter 907 | Energy = 16.111078
# Iter 908 | Energy = 16.111078
# Iter 909 | Energy = 16.111078
# Iter 910 | Energy = 16.111078
# Iter 911 | Energy = 16.111078
# Iter 912 | Energy = 16.111078
# Iter 913 | Energy = 16.111078
# Iter 914 | Energy = 16.111078
# Iter 915 | Energy = 16.111078
# Iter 916 | Energy = 16.111078
# Iter 917 | Energy = 16.111078
# Iter 918 | Energy = 16.111078
# Iter 919 | Energy = 16.111078
# Iter 920 | Energy = 16.111078
# Iter 921 | Energy = 16.111078
# Iter 922 | Energy = 16.111078
# Iter 923 | Energy = 16.111078
# Iter 924 | Energy = 16.111078
# Iter 925 | Energy = 16.111078
# Iter 926 | Energy = 16.111078
# Iter 927 | Energy = 16.111078
# Iter 928 | Energy = 16.111078
# Iter 929 | Energy = 16.111078
# Iter 930 | Energy = 16.111078
# Iter 931 | Energy = 16.111078
# Iter 932 | Energy = 16.111078
# Iter 933 | Energy = 16.111078
# Iter 934 | Energy = 16.111078
# Iter 935 | Energy = 16.111078
# Iter 936 | Energy = 16.111078
# Iter 937 | Energy = 16.111078
# Iter 938 | Energy = 16.111078
# Iter 939 | Energy = 16.111078
# Iter 940 | Energy = 16.111078
# Iter 941 | Energy = 16.111078
# Iter 942 | Energy = 16.111078
# Iter 943 | Energy = 16.111078
# Iter 944 | Energy = 16.111078
# Iter 945 | Energy = 16.111078
# Iter 946 | Energy = 16.111078
# Iter 947 | Energy = 16.111078
# Iter 948 | Energy = 16.111078
# Iter 949 | Energy = 16.111078
# Iter 950 | Energy = 16.111078
# Iter 951 | Energy = 16.111078
# Iter 952 | Energy = 16.111078
# Iter 953 | Energy = 16.111078
# Iter 954 | Energy = 16.111078
# Iter 955 | Energy = 16.111078
# Iter 956 | Energy = 16.111078
# Iter 957 | Energy = 16.111078
# Iter 958 | Energy = 16.111078
# Iter 959 | Energy = 16.111078
# Iter 960 | Energy = 16.111078
# Iter 961 | Energy = 16.111078
# Iter 962 | Energy = 16.111078
# Iter 963 | Energy = 16.111078
# Iter 964 | Energy = 16.111078
# Iter 965 | Energy = 16.111078
# Iter 966 | Energy = 16.111078
# Iter 967 | Energy = 16.111078
# Iter 968 | Energy = 16.111078
# Iter 969 | Energy = 16.111078
# Iter 970 | Energy = 16.111078
# Iter 971 | Energy = 16.111078
# Iter 972 | Energy = 16.111078
# Iter 973 | Energy = 16.111078
# Iter 974 | Energy = 16.111078
# Iter 975 | Energy = 16.111078
# Iter 976 | Energy = 16.111078
# Iter 977 | Energy = 16.111078
# Iter 978 | Energy = 16.111078
# Iter 979 | Energy = 16.111078
# Iter 980 | Energy = 16.111078
# Iter 981 | Energy = 16.111078
# Iter 982 | Energy = 16.111078
# Iter 983 | Energy = 16.111078
# Iter 984 | Energy = 16.111078
# Iter 985 | Energy = 16.111078
# Iter 986 | Energy = 16.111078
# Iter 987 | Energy = 16.111078
# Iter 988 | Energy = 16.111078
# Iter 989 | Energy = 16.111078
# Iter 990 | Energy = 16.111078
# Iter 991 | Energy = 16.111078
# Iter 992 | Energy = 16.111078
# Iter 993 | Energy = 16.111078
# Iter 994 | Energy = 16.111078
# Iter 995 | Energy = 16.111078
# Iter 996 | Energy = 16.111078
# Iter 997 | Energy = 16.111078
# Iter 998 | Energy = 16.111078
# Iter 999 | Energy = 16.111078
# Iter 1000 | Energy = 16.111078

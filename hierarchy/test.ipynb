# %%
import numpy as np
from gbp.gbp import FactorGraph, VariableNode, Factor

# -----------------------
# SLAM-like base graph
# -----------------------
def make_slam_like_graph(N=100, step_size=25, loop_prob=0.05, loop_radius=50, prior_prop=0.0, rng=None,):
    nodes, edges = [], []
    positions = []
    x, y = 0.0, 0.0
    positions.append((x, y))
    for _ in range(1, int(N)):
        dx, dy = np.random.randn(2)
        norm = np.sqrt(dx**2 + dy**2) + 1e-6
        dx, dy = dx / norm * float(step_size), dy / norm * float(step_size)
        x, y = x + dx, y + dy
        positions.append((x, y))
    for i, (px, py) in enumerate(positions):
        nodes.append({
            "data": {"id": f"{i}", "layer": 0, "dim": 2},
            "position": {"x": float(px), "y": float(py)}
        })
    for i in range(int(N) - 1):
        edges.append({"data": {"source": f"{i}", "target": f"{i+1}"}})
    for i in range(int(N)):
        for j in range(i + 5, int(N)):
            if np.random.rand() < float(loop_prob):
                xi, yi = positions[i]; xj, yj = positions[j]
                if np.hypot(xi-xj, yi-yj) < float(loop_radius):
                    edges.append({"data": {"source": f"{i}", "target": f"{j}"}})

    # 确定强先验的节点集合
    if rng is None:
        rng = np.random.default_rng()

    if prior_prop <= 0.0:
        strong_ids = {0}
    elif prior_prop >= 1.0:
        strong_ids = set(range(N))
    else:
        k = max(1, int(np.floor(prior_prop * N)))
        strong_ids = set(rng.choice(N, size=k, replace=False).tolist())

    # 给 strong prior 节点加 edge
    for i in strong_ids:
        edges.append({
            "data": {"source": f"{i}", "target": "prior"}
        })


    return nodes, edges

# -----------------------
# GBP Graph 构建
# -----------------------
def build_noisy_pose_graph(
    nodes,
    edges,
    prior_sigma: float = 10,
    odom_sigma: float = 10,
    tiny_prior: float = 1e-10,
    rng=None,
):
    
    """
    构造二维 pose-only 因子图（线性，高斯），并注入噪声。
    参数:
      prior_sigma : 强先验的标准差（小=强）
      odom_sigma  : 里程计测量噪声标准差
      prior_prop  : 0.0=仅 anchor；(0,1)=按比例随机选；>=1.0=全体
      tiny_prior  : 所有节点默认加的极小先验，防止奇异
      seed        : 随机种子（可复现）
    """

    fg = FactorGraph(nonlinear_factors=False, eta_damping=0)

    var_nodes = []
    I2 = np.eye(2, dtype=float)
    N = len(nodes)

    # ---- 预生成噪声 ----
    prior_noises = {}
    odom_noises = {}

    if rng is None:
        rng = np.random.default_rng()

    # 为所有边生成噪声
    for e in edges:
        src = e["data"]["source"]; dst = e["data"]["target"]
        # 二元边
        if dst != "prior":
            odom_noises[(int(src[:]), int(dst[:]))] = rng.normal(0.0, odom_sigma, size=2)
        # 一元边（强先验）
        elif dst == "prior":
            prior_noises[int(src[:])] = rng.normal(0.0, prior_sigma, size=2)


    # ---- variable nodes ----
    for i, n in enumerate(nodes):
        v = VariableNode(i, dofs=2)
        v.GT = np.array([n["position"]["x"], n["position"]["y"]], dtype=float)

        # 极小先验
        v.prior.lam = tiny_prior * I2
        v.prior.eta = np.zeros(2, dtype=float)

        var_nodes.append(v)

    fg.var_nodes = var_nodes
    fg.n_var_nodes = len(var_nodes)


    # ---- prior factors ----
    def meas_fn_unary(x, *args):
        return x
    def jac_fn_unary(x, *args):
        return np.eye(2)
    # ---- odometry factors ----
    def meas_fn(xy, *args):
        return xy[2:] - xy[:2]
    def jac_fn(xy, *args):
        return np.array([[-1, 0, 1, 0],
                         [ 0,-1, 0, 1]], dtype=float)
    
    factors = []
    fid = 0

    for e in edges:
        src = e["data"]["source"]; dst = e["data"]["target"]
        if dst != "prior":
            i, j = int(src[:]), int(dst[:])
            vi, vj = var_nodes[i], var_nodes[j]

            meas = (vj.GT - vi.GT) + odom_noises[(i, j)]

            f = Factor(fid, [vi, vj], meas, odom_sigma, meas_fn, jac_fn)
            f.type = "base"
            linpoint = np.r_[vi.GT, vj.GT]
            f.compute_factor(linpoint=linpoint, update_self=True)

            factors.append(f)
            vi.adj_factors.append(f)
            vj.adj_factors.append(f)
            fid += 1

        else:
            i = int(src[:])
            vi = var_nodes[i]
            z = vi.GT + prior_noises[i]

            f = Factor(fid, [vi], z, prior_sigma, meas_fn_unary, jac_fn_unary)
            f.type = "prior"
            f.compute_factor(linpoint=z, update_self=True)

            factors.append(f)
            vi.adj_factors.append(f)
            fid += 1

    fg.factors = factors
    fg.n_factor_nodes = len(factors)
    return fg


# -----------------------
# 主程序：跑 100 次迭代
# -----------------------
if __name__ == "__main__":
    rng = np.random.default_rng(42)  # 固定随机种子

    # 1. 造一个图
    nodes, edges = make_slam_like_graph(N=50, step_size=25, loop_prob=0.1, loop_radius=50, prior_prop=0.1, rng=rng)

    # 2. 构建 GBP 图
    fg = build_noisy_pose_graph(nodes, edges, prior_sigma=10.0, odom_sigma=10.0, rng=rng)

    # 3. 跑迭代
    for it in range(1000):
        fg.synchronous_iteration()
        energy = fg.energy_map(include_priors=True, include_factors=True)
        print(f"Iter {it+1:03d} | Energy = {energy:.6f}")
# Out:
# Iter 001 | Energy = 1236.002631
# Iter 002 | Energy = 1143.218944
# Iter 003 | Energy = 1040.783914
# Iter 004 | Energy = 603.590442
# Iter 005 | Energy = 397.718820
# Iter 006 | Energy = 31.461087
# Iter 007 | Energy = 27.198158
# Iter 008 | Energy = 23.963469
# Iter 009 | Energy = 23.158922
# Iter 010 | Energy = 22.759066
# Iter 011 | Energy = 22.494367
# Iter 012 | Energy = 22.335384
# Iter 013 | Energy = 22.249079
# Iter 014 | Energy = 22.202953
# Iter 015 | Energy = 22.190539
# Iter 016 | Energy = 22.183803
# Iter 017 | Energy = 22.177812
# Iter 018 | Energy = 22.173379
# Iter 019 | Energy = 22.169922
# Iter 020 | Energy = 22.167210
# Iter 021 | Energy = 22.165054
# Iter 022 | Energy = 22.163294
# Iter 023 | Energy = 22.161812
# Iter 024 | Energy = 22.160541
# Iter 025 | Energy = 22.159395
# Iter 026 | Energy = 22.158357
# Iter 027 | Energy = 22.157416
# Iter 028 | Energy = 22.156563
# Iter 029 | Energy = 22.155792
# Iter 030 | Energy = 22.155091
# Iter 031 | Energy = 22.154452
# Iter 032 | Energy = 22.153871
# Iter 033 | Energy = 22.153343
# Iter 034 | Energy = 22.152861
# Iter 035 | Energy = 22.152423
# Iter 036 | Energy = 22.152024
# Iter 037 | Energy = 22.151661
# Iter 038 | Energy = 22.151331
# Iter 039 | Energy = 22.151030
# Iter 040 | Energy = 22.150757
# Iter 041 | Energy = 22.150508
# Iter 042 | Energy = 22.150281
# Iter 043 | Energy = 22.150075
# Iter 044 | Energy = 22.149887
# Iter 045 | Energy = 22.149716
# Iter 046 | Energy = 22.149560
# Iter 047 | Energy = 22.149419
# Iter 048 | Energy = 22.149290
# Iter 049 | Energy = 22.149173
# Iter 050 | Energy = 22.149066
# Iter 051 | Energy = 22.148969
# Iter 052 | Energy = 22.148880
# Iter 053 | Energy = 22.148800
# Iter 054 | Energy = 22.148727
# Iter 055 | Energy = 22.148660
# Iter 056 | Energy = 22.148599
# Iter 057 | Energy = 22.148544
# Iter 058 | Energy = 22.148494
# Iter 059 | Energy = 22.148448
# Iter 060 | Energy = 22.148406
# Iter 061 | Energy = 22.148368
# Iter 062 | Energy = 22.148334
# Iter 063 | Energy = 22.148303
# Iter 064 | Energy = 22.148274
# Iter 065 | Energy = 22.148248
# Iter 066 | Energy = 22.148224
# Iter 067 | Energy = 22.148203
# Iter 068 | Energy = 22.148183
# Iter 069 | Energy = 22.148165
# Iter 070 | Energy = 22.148149
# Iter 071 | Energy = 22.148134
# Iter 072 | Energy = 22.148121
# Iter 073 | Energy = 22.148109
# Iter 074 | Energy = 22.148097
# Iter 075 | Energy = 22.148087
# Iter 076 | Energy = 22.148078
# Iter 077 | Energy = 22.148070
# Iter 078 | Energy = 22.148062
# Iter 079 | Energy = 22.148055
# Iter 080 | Energy = 22.148049
# Iter 081 | Energy = 22.148043
# Iter 082 | Energy = 22.148038
# Iter 083 | Energy = 22.148033
# Iter 084 | Energy = 22.148029
# Iter 085 | Energy = 22.148025
# Iter 086 | Energy = 22.148021
# Iter 087 | Energy = 22.148018
# Iter 088 | Energy = 22.148015
# Iter 089 | Energy = 22.148012
# Iter 090 | Energy = 22.148010
# Iter 091 | Energy = 22.148007
# Iter 092 | Energy = 22.148005
# Iter 093 | Energy = 22.148003
# Iter 094 | Energy = 22.148002
# Iter 095 | Energy = 22.148000
# Iter 096 | Energy = 22.147999
# Iter 097 | Energy = 22.147997
# Iter 098 | Energy = 22.147996
# Iter 099 | Energy = 22.147995
# Iter 100 | Energy = 22.147994
# Iter 101 | Energy = 22.147993
# Iter 102 | Energy = 22.147993
# Iter 103 | Energy = 22.147992
# Iter 104 | Energy = 22.147991
# Iter 105 | Energy = 22.147991
# Iter 106 | Energy = 22.147990
# Iter 107 | Energy = 22.147990
# Iter 108 | Energy = 22.147989
# Iter 109 | Energy = 22.147989
# Iter 110 | Energy = 22.147988
# Iter 111 | Energy = 22.147988
# Iter 112 | Energy = 22.147988
# Iter 113 | Energy = 22.147987
# Iter 114 | Energy = 22.147987
# Iter 115 | Energy = 22.147987
# Iter 116 | Energy = 22.147987
# Iter 117 | Energy = 22.147987
# Iter 118 | Energy = 22.147986
# Iter 119 | Energy = 22.147986
# Iter 120 | Energy = 22.147986
# Iter 121 | Energy = 22.147986
# Iter 122 | Energy = 22.147986
# Iter 123 | Energy = 22.147986
# Iter 124 | Energy = 22.147986
# Iter 125 | Energy = 22.147985
# Iter 126 | Energy = 22.147985
# Iter 127 | Energy = 22.147985
# Iter 128 | Energy = 22.147985
# Iter 129 | Energy = 22.147985
# Iter 130 | Energy = 22.147985
# Iter 131 | Energy = 22.147985
# Iter 132 | Energy = 22.147985
# Iter 133 | Energy = 22.147985
# Iter 134 | Energy = 22.147985
# Iter 135 | Energy = 22.147985
# Iter 136 | Energy = 22.147985
# Iter 137 | Energy = 22.147985
# Iter 138 | Energy = 22.147985
# Iter 139 | Energy = 22.147985
# Iter 140 | Energy = 22.147985
# Iter 141 | Energy = 22.147985
# Iter 142 | Energy = 22.147985
# Iter 143 | Energy = 22.147985
# Iter 144 | Energy = 22.147985
# Iter 145 | Energy = 22.147985
# Iter 146 | Energy = 22.147985
# Iter 147 | Energy = 22.147985
# Iter 148 | Energy = 22.147985
# Iter 149 | Energy = 22.147985
# Iter 150 | Energy = 22.147985
# Iter 151 | Energy = 22.147985
# Iter 152 | Energy = 22.147985
# Iter 153 | Energy = 22.147985
# Iter 154 | Energy = 22.147985
# Iter 155 | Energy = 22.147985
# Iter 156 | Energy = 22.147985
# Iter 157 | Energy = 22.147985
# Iter 158 | Energy = 22.147985
# Iter 159 | Energy = 22.147985
# Iter 160 | Energy = 22.147985
# Iter 161 | Energy = 22.147985
# Iter 162 | Energy = 22.147985
# Iter 163 | Energy = 22.147985
# Iter 164 | Energy = 22.147985
# Iter 165 | Energy = 22.147985
# Iter 166 | Energy = 22.147985
# Iter 167 | Energy = 22.147985
# Iter 168 | Energy = 22.147985
# Iter 169 | Energy = 22.147985
# Iter 170 | Energy = 22.147985
# Iter 171 | Energy = 22.147985
# Iter 172 | Energy = 22.147985
# Iter 173 | Energy = 22.147985
# Iter 174 | Energy = 22.147985
# Iter 175 | Energy = 22.147985
# Iter 176 | Energy = 22.147985
# Iter 177 | Energy = 22.147985
# Iter 178 | Energy = 22.147985
# Iter 179 | Energy = 22.147985
# Iter 180 | Energy = 22.147985
# Iter 181 | Energy = 22.147985
# Iter 182 | Energy = 22.147985
# Iter 183 | Energy = 22.147985
# Iter 184 | Energy = 22.147985
# Iter 185 | Energy = 22.147985
# Iter 186 | Energy = 22.147985
# Iter 187 | Energy = 22.147985
# Iter 188 | Energy = 22.147985
# Iter 189 | Energy = 22.147985
# Iter 190 | Energy = 22.147985
# Iter 191 | Energy = 22.147985
# Iter 192 | Energy = 22.147985
# Iter 193 | Energy = 22.147985
# Iter 194 | Energy = 22.147985
# Iter 195 | Energy = 22.147985
# Iter 196 | Energy = 22.147985
# Iter 197 | Energy = 22.147985
# Iter 198 | Energy = 22.147985
# Iter 199 | Energy = 22.147985
# Iter 200 | Energy = 22.147985
# Iter 201 | Energy = 22.147985
# Iter 202 | Energy = 22.147985
# Iter 203 | Energy = 22.147985
# Iter 204 | Energy = 22.147985
# Iter 205 | Energy = 22.147985
# Iter 206 | Energy = 22.147985
# Iter 207 | Energy = 22.147985
# Iter 208 | Energy = 22.147985
# Iter 209 | Energy = 22.147985
# Iter 210 | Energy = 22.147985
# Iter 211 | Energy = 22.147985
# Iter 212 | Energy = 22.147985
# Iter 213 | Energy = 22.147985
# Iter 214 | Energy = 22.147985
# Iter 215 | Energy = 22.147985
# Iter 216 | Energy = 22.147985
# Iter 217 | Energy = 22.147985
# Iter 218 | Energy = 22.147985
# Iter 219 | Energy = 22.147985
# Iter 220 | Energy = 22.147985
# Iter 221 | Energy = 22.147985
# Iter 222 | Energy = 22.147985
# Iter 223 | Energy = 22.147985
# Iter 224 | Energy = 22.147985
# Iter 225 | Energy = 22.147985
# Iter 226 | Energy = 22.147985
# Iter 227 | Energy = 22.147985
# Iter 228 | Energy = 22.147985
# Iter 229 | Energy = 22.147985
# Iter 230 | Energy = 22.147985
# Iter 231 | Energy = 22.147985
# Iter 232 | Energy = 22.147985
# Iter 233 | Energy = 22.147985
# Iter 234 | Energy = 22.147985
# Iter 235 | Energy = 22.147985
# Iter 236 | Energy = 22.147985
# Iter 237 | Energy = 22.147985
# Iter 238 | Energy = 22.147985
# Iter 239 | Energy = 22.147985
# Iter 240 | Energy = 22.147985
# Iter 241 | Energy = 22.147985
# Iter 242 | Energy = 22.147985
# Iter 243 | Energy = 22.147985
# Iter 244 | Energy = 22.147985
# Iter 245 | Energy = 22.147985
# Iter 246 | Energy = 22.147985
# Iter 247 | Energy = 22.147985
# Iter 248 | Energy = 22.147985
# Iter 249 | Energy = 22.147985
# Iter 250 | Energy = 22.147985
# Iter 251 | Energy = 22.147985
# Iter 252 | Energy = 22.147985
# Iter 253 | Energy = 22.147985
# Iter 254 | Energy = 22.147985
# Iter 255 | Energy = 22.147985
# Iter 256 | Energy = 22.147985
# Iter 257 | Energy = 22.147985
# Iter 258 | Energy = 22.147985
# Iter 259 | Energy = 22.147985
# Iter 260 | Energy = 22.147985
# Iter 261 | Energy = 22.147985
# Iter 262 | Energy = 22.147985
# Iter 263 | Energy = 22.147985
# Iter 264 | Energy = 22.147985
# Iter 265 | Energy = 22.147985
# Iter 266 | Energy = 22.147985
# Iter 267 | Energy = 22.147985
# Iter 268 | Energy = 22.147985
# Iter 269 | Energy = 22.147985
# Iter 270 | Energy = 22.147985
# Iter 271 | Energy = 22.147985
# Iter 272 | Energy = 22.147985
# Iter 273 | Energy = 22.147985
# Iter 274 | Energy = 22.147985
# Iter 275 | Energy = 22.147985
# Iter 276 | Energy = 22.147985
# Iter 277 | Energy = 22.147985
# Iter 278 | Energy = 22.147985
# Iter 279 | Energy = 22.147985
# Iter 280 | Energy = 22.147985
# Iter 281 | Energy = 22.147985
# Iter 282 | Energy = 22.147985
# Iter 283 | Energy = 22.147985
# Iter 284 | Energy = 22.147985
# Iter 285 | Energy = 22.147985
# Iter 286 | Energy = 22.147985
# Iter 287 | Energy = 22.147985
# Iter 288 | Energy = 22.147985
# Iter 289 | Energy = 22.147985
# Iter 290 | Energy = 22.147985
# Iter 291 | Energy = 22.147985
# Iter 292 | Energy = 22.147985
# Iter 293 | Energy = 22.147985
# Iter 294 | Energy = 22.147985
# Iter 295 | Energy = 22.147985
# Iter 296 | Energy = 22.147985
# Iter 297 | Energy = 22.147985
# Iter 298 | Energy = 22.147985
# Iter 299 | Energy = 22.147985
# Iter 300 | Energy = 22.147985
# Iter 301 | Energy = 22.147985
# Iter 302 | Energy = 22.147985
# Iter 303 | Energy = 22.147985
# Iter 304 | Energy = 22.147985
# Iter 305 | Energy = 22.147985
# Iter 306 | Energy = 22.147985
# Iter 307 | Energy = 22.147985
# Iter 308 | Energy = 22.147985
# Iter 309 | Energy = 22.147985
# Iter 310 | Energy = 22.147985
# Iter 311 | Energy = 22.147985
# Iter 312 | Energy = 22.147985
# Iter 313 | Energy = 22.147985
# Iter 314 | Energy = 22.147985
# Iter 315 | Energy = 22.147985
# Iter 316 | Energy = 22.147985
# Iter 317 | Energy = 22.147985
# Iter 318 | Energy = 22.147985
# Iter 319 | Energy = 22.147985
# Iter 320 | Energy = 22.147985
# Iter 321 | Energy = 22.147985
# Iter 322 | Energy = 22.147985
# Iter 323 | Energy = 22.147985
# Iter 324 | Energy = 22.147985
# Iter 325 | Energy = 22.147985
# Iter 326 | Energy = 22.147985
# Iter 327 | Energy = 22.147985
# Iter 328 | Energy = 22.147985
# Iter 329 | Energy = 22.147985
# Iter 330 | Energy = 22.147985
# Iter 331 | Energy = 22.147985
# Iter 332 | Energy = 22.147985
# Iter 333 | Energy = 22.147985
# Iter 334 | Energy = 22.147985
# Iter 335 | Energy = 22.147985
# Iter 336 | Energy = 22.147985
# Iter 337 | Energy = 22.147985
# Iter 338 | Energy = 22.147985
# Iter 339 | Energy = 22.147985
# Iter 340 | Energy = 22.147985
# Iter 341 | Energy = 22.147985
# Iter 342 | Energy = 22.147985
# Iter 343 | Energy = 22.147985
# Iter 344 | Energy = 22.147985
# Iter 345 | Energy = 22.147985
# Iter 346 | Energy = 22.147985
# Iter 347 | Energy = 22.147985
# Iter 348 | Energy = 22.147985
# Iter 349 | Energy = 22.147985
# Iter 350 | Energy = 22.147985
# Iter 351 | Energy = 22.147985
# Iter 352 | Energy = 22.147985
# Iter 353 | Energy = 22.147985
# Iter 354 | Energy = 22.147985
# Iter 355 | Energy = 22.147985
# Iter 356 | Energy = 22.147985
# Iter 357 | Energy = 22.147985
# Iter 358 | Energy = 22.147985
# Iter 359 | Energy = 22.147985
# Iter 360 | Energy = 22.147985
# Iter 361 | Energy = 22.147985
# Iter 362 | Energy = 22.147985
# Iter 363 | Energy = 22.147985
# Iter 364 | Energy = 22.147985
# Iter 365 | Energy = 22.147985
# Iter 366 | Energy = 22.147985
# Iter 367 | Energy = 22.147985
# Iter 368 | Energy = 22.147985
# Iter 369 | Energy = 22.147985
# Iter 370 | Energy = 22.147985
# Iter 371 | Energy = 22.147985
# Iter 372 | Energy = 22.147985
# Iter 373 | Energy = 22.147985
# Iter 374 | Energy = 22.147985
# Iter 375 | Energy = 22.147985
# Iter 376 | Energy = 22.147985
# Iter 377 | Energy = 22.147985
# Iter 378 | Energy = 22.147985
# Iter 379 | Energy = 22.147985
# Iter 380 | Energy = 22.147985
# Iter 381 | Energy = 22.147985
# Iter 382 | Energy = 22.147985
# Iter 383 | Energy = 22.147985
# Iter 384 | Energy = 22.147985
# Iter 385 | Energy = 22.147985
# Iter 386 | Energy = 22.147985
# Iter 387 | Energy = 22.147985
# Iter 388 | Energy = 22.147985
# Iter 389 | Energy = 22.147985
# Iter 390 | Energy = 22.147985
# Iter 391 | Energy = 22.147985
# Iter 392 | Energy = 22.147985
# Iter 393 | Energy = 22.147985
# Iter 394 | Energy = 22.147985
# Iter 395 | Energy = 22.147985
# Iter 396 | Energy = 22.147985
# Iter 397 | Energy = 22.147985
# Iter 398 | Energy = 22.147985
# Iter 399 | Energy = 22.147985
# Iter 400 | Energy = 22.147985
# Iter 401 | Energy = 22.147985
# Iter 402 | Energy = 22.147985
# Iter 403 | Energy = 22.147985
# Iter 404 | Energy = 22.147985
# Iter 405 | Energy = 22.147985
# Iter 406 | Energy = 22.147985
# Iter 407 | Energy = 22.147985
# Iter 408 | Energy = 22.147985
# Iter 409 | Energy = 22.147985
# Iter 410 | Energy = 22.147985
# Iter 411 | Energy = 22.147985
# Iter 412 | Energy = 22.147985
# Iter 413 | Energy = 22.147985
# Iter 414 | Energy = 22.147985
# Iter 415 | Energy = 22.147985
# Iter 416 | Energy = 22.147985
# Iter 417 | Energy = 22.147985
# Iter 418 | Energy = 22.147985
# Iter 419 | Energy = 22.147985
# Iter 420 | Energy = 22.147985
# Iter 421 | Energy = 22.147985
# Iter 422 | Energy = 22.147985
# Iter 423 | Energy = 22.147985
# Iter 424 | Energy = 22.147985
# Iter 425 | Energy = 22.147985
# Iter 426 | Energy = 22.147985
# Iter 427 | Energy = 22.147985
# Iter 428 | Energy = 22.147985
# Iter 429 | Energy = 22.147985
# Iter 430 | Energy = 22.147985
# Iter 431 | Energy = 22.147985
# Iter 432 | Energy = 22.147985
# Iter 433 | Energy = 22.147985
# Iter 434 | Energy = 22.147985
# Iter 435 | Energy = 22.147985
# Iter 436 | Energy = 22.147985
# Iter 437 | Energy = 22.147985
# Iter 438 | Energy = 22.147985
# Iter 439 | Energy = 22.147985
# Iter 440 | Energy = 22.147985
# Iter 441 | Energy = 22.147985
# Iter 442 | Energy = 22.147985
# Iter 443 | Energy = 22.147985
# Iter 444 | Energy = 22.147985
# Iter 445 | Energy = 22.147985
# Iter 446 | Energy = 22.147985
# Iter 447 | Energy = 22.147985
# Iter 448 | Energy = 22.147985
# Iter 449 | Energy = 22.147985
# Iter 450 | Energy = 22.147985
# Iter 451 | Energy = 22.147985
# Iter 452 | Energy = 22.147985
# Iter 453 | Energy = 22.147985
# Iter 454 | Energy = 22.147985
# Iter 455 | Energy = 22.147985
# Iter 456 | Energy = 22.147985
# Iter 457 | Energy = 22.147985
# Iter 458 | Energy = 22.147985
# Iter 459 | Energy = 22.147985
# Iter 460 | Energy = 22.147985
# Iter 461 | Energy = 22.147985
# Iter 462 | Energy = 22.147985
# Iter 463 | Energy = 22.147985
# Iter 464 | Energy = 22.147985
# Iter 465 | Energy = 22.147985
# Iter 466 | Energy = 22.147985
# Iter 467 | Energy = 22.147985
# Iter 468 | Energy = 22.147985
# Iter 469 | Energy = 22.147985
# Iter 470 | Energy = 22.147985
# Iter 471 | Energy = 22.147985
# Iter 472 | Energy = 22.147985
# Iter 473 | Energy = 22.147985
# Iter 474 | Energy = 22.147985
# Iter 475 | Energy = 22.147985
# Iter 476 | Energy = 22.147985
# Iter 477 | Energy = 22.147985
# Iter 478 | Energy = 22.147985
# Iter 479 | Energy = 22.147985
# Iter 480 | Energy = 22.147985
# Iter 481 | Energy = 22.147985
# Iter 482 | Energy = 22.147985
# Iter 483 | Energy = 22.147985
# Iter 484 | Energy = 22.147985
# Iter 485 | Energy = 22.147985
# Iter 486 | Energy = 22.147985
# Iter 487 | Energy = 22.147985
# Iter 488 | Energy = 22.147985
# Iter 489 | Energy = 22.147985
# Iter 490 | Energy = 22.147985
# Iter 491 | Energy = 22.147985
# Iter 492 | Energy = 22.147985
# Iter 493 | Energy = 22.147985
# Iter 494 | Energy = 22.147985
# Iter 495 | Energy = 22.147985
# Iter 496 | Energy = 22.147985
# Iter 497 | Energy = 22.147985
# Iter 498 | Energy = 22.147985
# Iter 499 | Energy = 22.147985
# Iter 500 | Energy = 22.147985
# Iter 501 | Energy = 22.147985
# Iter 502 | Energy = 22.147985
# Iter 503 | Energy = 22.147985
# Iter 504 | Energy = 22.147985
# Iter 505 | Energy = 22.147985
# Iter 506 | Energy = 22.147985
# Iter 507 | Energy = 22.147985
# Iter 508 | Energy = 22.147985
# Iter 509 | Energy = 22.147985
# Iter 510 | Energy = 22.147985
# Iter 511 | Energy = 22.147985
# Iter 512 | Energy = 22.147985
# Iter 513 | Energy = 22.147985
# Iter 514 | Energy = 22.147985
# Iter 515 | Energy = 22.147985
# Iter 516 | Energy = 22.147985
# Iter 517 | Energy = 22.147985
# Iter 518 | Energy = 22.147985
# Iter 519 | Energy = 22.147985
# Iter 520 | Energy = 22.147985
# Iter 521 | Energy = 22.147985
# Iter 522 | Energy = 22.147985
# Iter 523 | Energy = 22.147985
# Iter 524 | Energy = 22.147985
# Iter 525 | Energy = 22.147985
# Iter 526 | Energy = 22.147985
# Iter 527 | Energy = 22.147985
# Iter 528 | Energy = 22.147985
# Iter 529 | Energy = 22.147985
# Iter 530 | Energy = 22.147985
# Iter 531 | Energy = 22.147985
# Iter 532 | Energy = 22.147985
# Iter 533 | Energy = 22.147985
# Iter 534 | Energy = 22.147985
# Iter 535 | Energy = 22.147985
# Iter 536 | Energy = 22.147985
# Iter 537 | Energy = 22.147985
# Iter 538 | Energy = 22.147985
# Iter 539 | Energy = 22.147985
# Iter 540 | Energy = 22.147985
# Iter 541 | Energy = 22.147985
# Iter 542 | Energy = 22.147985
# Iter 543 | Energy = 22.147985
# Iter 544 | Energy = 22.147985
# Iter 545 | Energy = 22.147985
# Iter 546 | Energy = 22.147985
# Iter 547 | Energy = 22.147985
# Iter 548 | Energy = 22.147985
# Iter 549 | Energy = 22.147985
# Iter 550 | Energy = 22.147985
# Iter 551 | Energy = 22.147985
# Iter 552 | Energy = 22.147985
# Iter 553 | Energy = 22.147985
# Iter 554 | Energy = 22.147985
# Iter 555 | Energy = 22.147985
# Iter 556 | Energy = 22.147985
# Iter 557 | Energy = 22.147985
# Iter 558 | Energy = 22.147985
# Iter 559 | Energy = 22.147985
# Iter 560 | Energy = 22.147985
# Iter 561 | Energy = 22.147985
# Iter 562 | Energy = 22.147985
# Iter 563 | Energy = 22.147985
# Iter 564 | Energy = 22.147985
# Iter 565 | Energy = 22.147985
# Iter 566 | Energy = 22.147985
# Iter 567 | Energy = 22.147985
# Iter 568 | Energy = 22.147985
# Iter 569 | Energy = 22.147985
# Iter 570 | Energy = 22.147985
# Iter 571 | Energy = 22.147985
# Iter 572 | Energy = 22.147985
# Iter 573 | Energy = 22.147985
# Iter 574 | Energy = 22.147985
# Iter 575 | Energy = 22.147985
# Iter 576 | Energy = 22.147985
# Iter 577 | Energy = 22.147985
# Iter 578 | Energy = 22.147985
# Iter 579 | Energy = 22.147985
# Iter 580 | Energy = 22.147985
# Iter 581 | Energy = 22.147985
# Iter 582 | Energy = 22.147985
# Iter 583 | Energy = 22.147985
# Iter 584 | Energy = 22.147985
# Iter 585 | Energy = 22.147985
# Iter 586 | Energy = 22.147985
# Iter 587 | Energy = 22.147985
# Iter 588 | Energy = 22.147985
# Iter 589 | Energy = 22.147985
# Iter 590 | Energy = 22.147985
# Iter 591 | Energy = 22.147985
# Iter 592 | Energy = 22.147985
# Iter 593 | Energy = 22.147985
# Iter 594 | Energy = 22.147985
# Iter 595 | Energy = 22.147985
# Iter 596 | Energy = 22.147985
# Iter 597 | Energy = 22.147985
# Iter 598 | Energy = 22.147985
# Iter 599 | Energy = 22.147985
# Iter 600 | Energy = 22.147985
# Iter 601 | Energy = 22.147985
# Iter 602 | Energy = 22.147985
# Iter 603 | Energy = 22.147985
# Iter 604 | Energy = 22.147985
# Iter 605 | Energy = 22.147985
# Iter 606 | Energy = 22.147985
# Iter 607 | Energy = 22.147985
# Iter 608 | Energy = 22.147985
# Iter 609 | Energy = 22.147985
# Iter 610 | Energy = 22.147985
# Iter 611 | Energy = 22.147985
# Iter 612 | Energy = 22.147985
# Iter 613 | Energy = 22.147985
# Iter 614 | Energy = 22.147985
# Iter 615 | Energy = 22.147985
# Iter 616 | Energy = 22.147985
# Iter 617 | Energy = 22.147985
# Iter 618 | Energy = 22.147985
# Iter 619 | Energy = 22.147985
# Iter 620 | Energy = 22.147985
# Iter 621 | Energy = 22.147985
# Iter 622 | Energy = 22.147985
# Iter 623 | Energy = 22.147985
# Iter 624 | Energy = 22.147985
# Iter 625 | Energy = 22.147985
# Iter 626 | Energy = 22.147985
# Iter 627 | Energy = 22.147985
# Iter 628 | Energy = 22.147985
# Iter 629 | Energy = 22.147985
# Iter 630 | Energy = 22.147985
# Iter 631 | Energy = 22.147985
# Iter 632 | Energy = 22.147985
# Iter 633 | Energy = 22.147985
# Iter 634 | Energy = 22.147985
# Iter 635 | Energy = 22.147985
# Iter 636 | Energy = 22.147985
# Iter 637 | Energy = 22.147985
# Iter 638 | Energy = 22.147985
# Iter 639 | Energy = 22.147985
# Iter 640 | Energy = 22.147985
# Iter 641 | Energy = 22.147985
# Iter 642 | Energy = 22.147985
# Iter 643 | Energy = 22.147985
# Iter 644 | Energy = 22.147985
# Iter 645 | Energy = 22.147985
# Iter 646 | Energy = 22.147985
# Iter 647 | Energy = 22.147985
# Iter 648 | Energy = 22.147985
# Iter 649 | Energy = 22.147985
# Iter 650 | Energy = 22.147985
# Iter 651 | Energy = 22.147985
# Iter 652 | Energy = 22.147985
# Iter 653 | Energy = 22.147985
# Iter 654 | Energy = 22.147985
# Iter 655 | Energy = 22.147985
# Iter 656 | Energy = 22.147985
# Iter 657 | Energy = 22.147985
# Iter 658 | Energy = 22.147985
# Iter 659 | Energy = 22.147985
# Iter 660 | Energy = 22.147985
# Iter 661 | Energy = 22.147985
# Iter 662 | Energy = 22.147985
# Iter 663 | Energy = 22.147985
# Iter 664 | Energy = 22.147985
# Iter 665 | Energy = 22.147985
# Iter 666 | Energy = 22.147985
# Iter 667 | Energy = 22.147985
# Iter 668 | Energy = 22.147985
# Iter 669 | Energy = 22.147985
# Iter 670 | Energy = 22.147985
# Iter 671 | Energy = 22.147985
# Iter 672 | Energy = 22.147985
# Iter 673 | Energy = 22.147985
# Iter 674 | Energy = 22.147985
# Iter 675 | Energy = 22.147985
# Iter 676 | Energy = 22.147985
# Iter 677 | Energy = 22.147985
# Iter 678 | Energy = 22.147985
# Iter 679 | Energy = 22.147985
# Iter 680 | Energy = 22.147985
# Iter 681 | Energy = 22.147985
# Iter 682 | Energy = 22.147985
# Iter 683 | Energy = 22.147985
# Iter 684 | Energy = 22.147985
# Iter 685 | Energy = 22.147985
# Iter 686 | Energy = 22.147985
# Iter 687 | Energy = 22.147985
# Iter 688 | Energy = 22.147985
# Iter 689 | Energy = 22.147985
# Iter 690 | Energy = 22.147985
# Iter 691 | Energy = 22.147985
# Iter 692 | Energy = 22.147985
# Iter 693 | Energy = 22.147985
# Iter 694 | Energy = 22.147985
# Iter 695 | Energy = 22.147985
# Iter 696 | Energy = 22.147985
# Iter 697 | Energy = 22.147985
# Iter 698 | Energy = 22.147985
# Iter 699 | Energy = 22.147985
# Iter 700 | Energy = 22.147985
# Iter 701 | Energy = 22.147985
# Iter 702 | Energy = 22.147985
# Iter 703 | Energy = 22.147985
# Iter 704 | Energy = 22.147985
# Iter 705 | Energy = 22.147985
# Iter 706 | Energy = 22.147985
# Iter 707 | Energy = 22.147985
# Iter 708 | Energy = 22.147985
# Iter 709 | Energy = 22.147985
# Iter 710 | Energy = 22.147985
# Iter 711 | Energy = 22.147985
# Iter 712 | Energy = 22.147985
# Iter 713 | Energy = 22.147985
# Iter 714 | Energy = 22.147985
# Iter 715 | Energy = 22.147985
# Iter 716 | Energy = 22.147985
# Iter 717 | Energy = 22.147985
# Iter 718 | Energy = 22.147985
# Iter 719 | Energy = 22.147985
# Iter 720 | Energy = 22.147985
# Iter 721 | Energy = 22.147985
# Iter 722 | Energy = 22.147985
# Iter 723 | Energy = 22.147985
# Iter 724 | Energy = 22.147985
# Iter 725 | Energy = 22.147985
# Iter 726 | Energy = 22.147985
# Iter 727 | Energy = 22.147985
# Iter 728 | Energy = 22.147985
# Iter 729 | Energy = 22.147985
# Iter 730 | Energy = 22.147985
# Iter 731 | Energy = 22.147985
# Iter 732 | Energy = 22.147985
# Iter 733 | Energy = 22.147985
# Iter 734 | Energy = 22.147985
# Iter 735 | Energy = 22.147985
# Iter 736 | Energy = 22.147985
# Iter 737 | Energy = 22.147985
# Iter 738 | Energy = 22.147985
# Iter 739 | Energy = 22.147985
# Iter 740 | Energy = 22.147985
# Iter 741 | Energy = 22.147985
# Iter 742 | Energy = 22.147985
# Iter 743 | Energy = 22.147985
# Iter 744 | Energy = 22.147985
# Iter 745 | Energy = 22.147985
# Iter 746 | Energy = 22.147985
# Iter 747 | Energy = 22.147985
# Iter 748 | Energy = 22.147985
# Iter 749 | Energy = 22.147985
# Iter 750 | Energy = 22.147985
# Iter 751 | Energy = 22.147985
# Iter 752 | Energy = 22.147985
# Iter 753 | Energy = 22.147985
# Iter 754 | Energy = 22.147985
# Iter 755 | Energy = 22.147985
# Iter 756 | Energy = 22.147985
# Iter 757 | Energy = 22.147985
# Iter 758 | Energy = 22.147985
# Iter 759 | Energy = 22.147985
# Iter 760 | Energy = 22.147985
# Iter 761 | Energy = 22.147985
# Iter 762 | Energy = 22.147985
# Iter 763 | Energy = 22.147985
# Iter 764 | Energy = 22.147985
# Iter 765 | Energy = 22.147985
# Iter 766 | Energy = 22.147985
# Iter 767 | Energy = 22.147985
# Iter 768 | Energy = 22.147985
# Iter 769 | Energy = 22.147985
# Iter 770 | Energy = 22.147985
# Iter 771 | Energy = 22.147985
# Iter 772 | Energy = 22.147985
# Iter 773 | Energy = 22.147985
# Iter 774 | Energy = 22.147985
# Iter 775 | Energy = 22.147985
# Iter 776 | Energy = 22.147985
# Iter 777 | Energy = 22.147985
# Iter 778 | Energy = 22.147985
# Iter 779 | Energy = 22.147985
# Iter 780 | Energy = 22.147985
# Iter 781 | Energy = 22.147985
# Iter 782 | Energy = 22.147985
# Iter 783 | Energy = 22.147985
# Iter 784 | Energy = 22.147985
# Iter 785 | Energy = 22.147985
# Iter 786 | Energy = 22.147985
# Iter 787 | Energy = 22.147985
# Iter 788 | Energy = 22.147985
# Iter 789 | Energy = 22.147985
# Iter 790 | Energy = 22.147985
# Iter 791 | Energy = 22.147985
# Iter 792 | Energy = 22.147985
# Iter 793 | Energy = 22.147985
# Iter 794 | Energy = 22.147985
# Iter 795 | Energy = 22.147985
# Iter 796 | Energy = 22.147985
# Iter 797 | Energy = 22.147985
# Iter 798 | Energy = 22.147985
# Iter 799 | Energy = 22.147985
# Iter 800 | Energy = 22.147985
# Iter 801 | Energy = 22.147985
# Iter 802 | Energy = 22.147985
# Iter 803 | Energy = 22.147985
# Iter 804 | Energy = 22.147985
# Iter 805 | Energy = 22.147985
# Iter 806 | Energy = 22.147985
# Iter 807 | Energy = 22.147985
# Iter 808 | Energy = 22.147985
# Iter 809 | Energy = 22.147985
# Iter 810 | Energy = 22.147985
# Iter 811 | Energy = 22.147985
# Iter 812 | Energy = 22.147985
# Iter 813 | Energy = 22.147985
# Iter 814 | Energy = 22.147985
# Iter 815 | Energy = 22.147985
# Iter 816 | Energy = 22.147985
# Iter 817 | Energy = 22.147985
# Iter 818 | Energy = 22.147985
# Iter 819 | Energy = 22.147985
# Iter 820 | Energy = 22.147985
# Iter 821 | Energy = 22.147985
# Iter 822 | Energy = 22.147985
# Iter 823 | Energy = 22.147985
# Iter 824 | Energy = 22.147985
# Iter 825 | Energy = 22.147985
# Iter 826 | Energy = 22.147985
# Iter 827 | Energy = 22.147985
# Iter 828 | Energy = 22.147985
# Iter 829 | Energy = 22.147985
# Iter 830 | Energy = 22.147985
# Iter 831 | Energy = 22.147985
# Iter 832 | Energy = 22.147985
# Iter 833 | Energy = 22.147985
# Iter 834 | Energy = 22.147985
# Iter 835 | Energy = 22.147985
# Iter 836 | Energy = 22.147985
# Iter 837 | Energy = 22.147985
# Iter 838 | Energy = 22.147985
# Iter 839 | Energy = 22.147985
# Iter 840 | Energy = 22.147985
# Iter 841 | Energy = 22.147985
# Iter 842 | Energy = 22.147985
# Iter 843 | Energy = 22.147985
# Iter 844 | Energy = 22.147985
# Iter 845 | Energy = 22.147985
# Iter 846 | Energy = 22.147985
# Iter 847 | Energy = 22.147985
# Iter 848 | Energy = 22.147985
# Iter 849 | Energy = 22.147985
# Iter 850 | Energy = 22.147985
# Iter 851 | Energy = 22.147985
# Iter 852 | Energy = 22.147985
# Iter 853 | Energy = 22.147985
# Iter 854 | Energy = 22.147985
# Iter 855 | Energy = 22.147985
# Iter 856 | Energy = 22.147985
# Iter 857 | Energy = 22.147985
# Iter 858 | Energy = 22.147985
# Iter 859 | Energy = 22.147985
# Iter 860 | Energy = 22.147985
# Iter 861 | Energy = 22.147985
# Iter 862 | Energy = 22.147985
# Iter 863 | Energy = 22.147985
# Iter 864 | Energy = 22.147985
# Iter 865 | Energy = 22.147985
# Iter 866 | Energy = 22.147985
# Iter 867 | Energy = 22.147985
# Iter 868 | Energy = 22.147985
# Iter 869 | Energy = 22.147985
# Iter 870 | Energy = 22.147985
# Iter 871 | Energy = 22.147985
# Iter 872 | Energy = 22.147985
# Iter 873 | Energy = 22.147985
# Iter 874 | Energy = 22.147985
# Iter 875 | Energy = 22.147985
# Iter 876 | Energy = 22.147985
# Iter 877 | Energy = 22.147985
# Iter 878 | Energy = 22.147985
# Iter 879 | Energy = 22.147985
# Iter 880 | Energy = 22.147985
# Iter 881 | Energy = 22.147985
# Iter 882 | Energy = 22.147985
# Iter 883 | Energy = 22.147985
# Iter 884 | Energy = 22.147985
# Iter 885 | Energy = 22.147985
# Iter 886 | Energy = 22.147985
# Iter 887 | Energy = 22.147985
# Iter 888 | Energy = 22.147985
# Iter 889 | Energy = 22.147985
# Iter 890 | Energy = 22.147985
# Iter 891 | Energy = 22.147985
# Iter 892 | Energy = 22.147985
# Iter 893 | Energy = 22.147985
# Iter 894 | Energy = 22.147985
# Iter 895 | Energy = 22.147985
# Iter 896 | Energy = 22.147985
# Iter 897 | Energy = 22.147985
# Iter 898 | Energy = 22.147985
# Iter 899 | Energy = 22.147985
# Iter 900 | Energy = 22.147985
# Iter 901 | Energy = 22.147985
# Iter 902 | Energy = 22.147985
# Iter 903 | Energy = 22.147985
# Iter 904 | Energy = 22.147985
# Iter 905 | Energy = 22.147985
# Iter 906 | Energy = 22.147985
# Iter 907 | Energy = 22.147985
# Iter 908 | Energy = 22.147985
# Iter 909 | Energy = 22.147985
# Iter 910 | Energy = 22.147985
# Iter 911 | Energy = 22.147985
# Iter 912 | Energy = 22.147985
# Iter 913 | Energy = 22.147985
# Iter 914 | Energy = 22.147985
# Iter 915 | Energy = 22.147985
# Iter 916 | Energy = 22.147985
# Iter 917 | Energy = 22.147985
# Iter 918 | Energy = 22.147985
# Iter 919 | Energy = 22.147985
# Iter 920 | Energy = 22.147985
# Iter 921 | Energy = 22.147985
# Iter 922 | Energy = 22.147985
# Iter 923 | Energy = 22.147985
# Iter 924 | Energy = 22.147985
# Iter 925 | Energy = 22.147985
# Iter 926 | Energy = 22.147985
# Iter 927 | Energy = 22.147985
# Iter 928 | Energy = 22.147985
# Iter 929 | Energy = 22.147985
# Iter 930 | Energy = 22.147985
# Iter 931 | Energy = 22.147985
# Iter 932 | Energy = 22.147985
# Iter 933 | Energy = 22.147985
# Iter 934 | Energy = 22.147985
# Iter 935 | Energy = 22.147985
# Iter 936 | Energy = 22.147985
# Iter 937 | Energy = 22.147985
# Iter 938 | Energy = 22.147985
# Iter 939 | Energy = 22.147985
# Iter 940 | Energy = 22.147985
# Iter 941 | Energy = 22.147985
# Iter 942 | Energy = 22.147985
# Iter 943 | Energy = 22.147985
# Iter 944 | Energy = 22.147985
# Iter 945 | Energy = 22.147985
# Iter 946 | Energy = 22.147985
# Iter 947 | Energy = 22.147985
# Iter 948 | Energy = 22.147985
# Iter 949 | Energy = 22.147985
# Iter 950 | Energy = 22.147985
# Iter 951 | Energy = 22.147985
# Iter 952 | Energy = 22.147985
# Iter 953 | Energy = 22.147985
# Iter 954 | Energy = 22.147985
# Iter 955 | Energy = 22.147985
# Iter 956 | Energy = 22.147985
# Iter 957 | Energy = 22.147985
# Iter 958 | Energy = 22.147985
# Iter 959 | Energy = 22.147985
# Iter 960 | Energy = 22.147985
# Iter 961 | Energy = 22.147985
# Iter 962 | Energy = 22.147985
# Iter 963 | Energy = 22.147985
# Iter 964 | Energy = 22.147985
# Iter 965 | Energy = 22.147985
# Iter 966 | Energy = 22.147985
# Iter 967 | Energy = 22.147985
# Iter 968 | Energy = 22.147985
# Iter 969 | Energy = 22.147985
# Iter 970 | Energy = 22.147985
# Iter 971 | Energy = 22.147985
# Iter 972 | Energy = 22.147985
# Iter 973 | Energy = 22.147985
# Iter 974 | Energy = 22.147985
# Iter 975 | Energy = 22.147985
# Iter 976 | Energy = 22.147985
# Iter 977 | Energy = 22.147985
# Iter 978 | Energy = 22.147985
# Iter 979 | Energy = 22.147985
# Iter 980 | Energy = 22.147985
# Iter 981 | Energy = 22.147985
# Iter 982 | Energy = 22.147985
# Iter 983 | Energy = 22.147985
# Iter 984 | Energy = 22.147985
# Iter 985 | Energy = 22.147985
# Iter 986 | Energy = 22.147985
# Iter 987 | Energy = 22.147985
# Iter 988 | Energy = 22.147985
# Iter 989 | Energy = 22.147985
# Iter 990 | Energy = 22.147985
# Iter 991 | Energy = 22.147985
# Iter 992 | Energy = 22.147985
# Iter 993 | Energy = 22.147985
# Iter 994 | Energy = 22.147985
# Iter 995 | Energy = 22.147985
# Iter 996 | Energy = 22.147985
# Iter 997 | Energy = 22.147985
# Iter 998 | Energy = 22.147985
# Iter 999 | Energy = 22.147985
# Iter 1000 | Energy = 22.147985

# %%
# -----------------------
# K-Means 聚合
# -----------------------
def fuse_to_super_knn(prev_nodes, prev_edges, k, layer_idx, max_iters=20, tol=1e-6, seed=0):
    positions = np.array([[n["position"]["x"], n["position"]["y"]] for n in prev_nodes], dtype=float)
    n = positions.shape[0]
    if k <= 0: k = 1
    k = min(k, n)
    rng = np.random.default_rng(seed)

    # k-means++ init
    centers = np.empty((k, 2), dtype=float)
    first = rng.integers(0, n)
    centers[0] = positions[first]
    closest_d2 = np.sum((positions - centers[0])**2, axis=1)
    for i in range(1, k):
        denom = float(closest_d2.sum()) + 1e-12
        probs = closest_d2 / denom
        idx = rng.choice(n, p=probs)
        centers[i] = positions[idx]
        d2_new = np.sum((positions - centers[i])**2, axis=1)
        closest_d2 = np.minimum(closest_d2, d2_new)

    # Lloyd iterations
    for _ in range(max_iters):
        d2 = ((positions[:, None, :] - centers[None, :, :]) ** 2).sum(axis=2)
        assign = np.argmin(d2, axis=1)
        moved = 0.0
        for ci in range(k):
            idxs = np.where(assign == ci)[0]
            if idxs.size == 0:
                far_idx = int(np.argmax(np.min(d2, axis=1)))
                new_c = positions[far_idx]
            else:
                new_c = positions[idxs].mean(axis=0)
            moved = max(moved, float(np.linalg.norm(new_c - centers[ci])))
            centers[ci] = new_c
        if moved < tol:
            break

    # final assign
    d2 = ((positions[:, None, :] - centers[None, :, :]) ** 2).sum(axis=2)
    assign = np.argmin(d2, axis=1)

    super_nodes, node_map = [], {}
    for ci in range(k):
        idxs = np.where(assign == ci)[0]
        if idxs.size == 0:
            continue
        pts = positions[idxs]
        mean_x, mean_y = pts.mean(axis=0)
        child_dims = [prev_nodes[i]["data"]["dim"] for i in idxs]
        dim_val = int(max(1, sum(child_dims)))
        nid = f"{ci}"
        super_nodes.append({
            "data": {"id": nid, "layer": layer_idx, "dim": dim_val},
            "position": {"x": float(mean_x), "y": float(mean_y)}
        })
        for i in idxs:
            node_map[prev_nodes[i]["data"]["id"]] = nid
    super_edges, seen = [], set()
    for e in prev_edges:
        u, v = e["data"]["source"], e["data"]["target"]
        if v != "prior":
            su, sv = node_map[u], node_map[v]
            if su != sv:
                eid = tuple(sorted((su, sv)))
                if eid not in seen:
                    super_edges.append({"data": {"source": su, "target": sv}})
                    seen.add(eid)
            elif su == sv:
                eid = tuple(sorted((su, su)))
                if eid not in seen:
                    super_edges.append({"data": {"source": su, "target": "prior"}})
                    seen.add(eid)

        elif v == "prior":
            eid = tuple(sorted((su, su)))
            if eid not in seen:
                super_edges.append({"data": {"source": su, "target": "prior"}})
                seen.add(eid)

    return super_nodes, super_edges, node_map

# %%
def build_super_graph(layers, prior_sigma=1.0, odom_sigma=1.0):
    """
    基于 layers[-2] 的 base graph, 和 layers[-1] 的 super 分组，构造 super graph。
    要求: layers[-2]["graph"] 已经是构建好的基图（含 unary/binary 因子）。
    layers[-1]["node_map"]: { base_node_id(str, 如 'b12') -> super_node_id(str) }
    """
    # ---------- 取出 base & super ----------
    base_graph = layers[-2]["graph"]
    super_nodes = layers[-1]["nodes"]
    super_edges = layers[-1]["edges"]
    node_map    = layers[-1]["node_map"]   # 'bN' -> 'sX_...'

    # base: id(int)->VariableNode，方便查 dofs 和 mu
    id2var = {vn.variableID: vn for vn in base_graph.var_nodes}

    # ---------- super_id -> [base_id(int)] ----------
    super_groups = {}
    for b_str, s_id in node_map.items():
        b_int = int(b_str)
        super_groups.setdefault(s_id, []).append(b_int)


    # ---------- 为每个 super 组建立 (start, dofs) 表 ----------
    # local_idx[sid][bid] = (start, dofs), total_dofs[sid] = sum(dofs)
    local_idx   = {}
    total_dofs  = {}
    for sid, group in super_groups.items():
        off = 0
        local_idx[sid] = {}
        for bid in group:
            d = id2var[bid].dofs
            local_idx[sid][bid] = (off, d)
            off += d
        total_dofs[sid] = off

    # ---------- 创建 super VariableNodes ----------
    fg = FactorGraph(nonlinear_factors=False, eta_damping=0)

    super_var_nodes = {}
    for i, sn in enumerate(super_nodes):
        sid = sn["data"]["id"]
        dofs = total_dofs.get(sid, 0)
        v = VariableNode(i, dofs=dofs)
        super_var_nodes[sid] = v
        fg.var_nodes.append(v)
    fg.n_var_nodes = len(fg.var_nodes)

    # ---------- 工具：拼接某组的 linpoint（用 base belief 均值） ----------
    def make_linpoint_for_group(sid):
        x = np.zeros(total_dofs[sid])
        for bid, (st, d) in local_idx[sid].items():
            mu = getattr(id2var[bid], "mu", None)
            if mu is None or len(mu) != d:
                mu = np.zeros(d)
            x[st:st+d] = mu
        return x

    # ---------- 3) super prior（组内 unary + 组内 binary） ----------
    def make_super_prior_factor(sid, base_factors):
        group = super_groups[sid]
        idx_map = local_idx[sid]
        ncols = total_dofs[sid]

        # 选出：所有变量都在组内的因子（unary 或 binary）
        in_group = []
        for f in base_factors:
            vids = [v.variableID for v in f.adj_var_nodes]
            if all(vid in group for vid in vids):
                in_group.append(f)

        def meas_fn_super_prior(x_super, *args):
            meas_fn = []
            for f in in_group:
                vids = [v.variableID for v in f.adj_var_nodes]
                # 拼本因子的局部 x
                x_loc_list = []
                for vid in vids:
                    st, d = idx_map[vid]
                    x_loc_list.append(x_super[st:st+d])
                x_loc = np.concatenate(x_loc_list) if x_loc_list else np.zeros(0)
                meas_fn.append(f.meas_fn(x_loc) - f.z)
            return np.concatenate(meas_fn) if meas_fn else np.zeros(0)

        def jac_fn_super_prior(x_super, *args):
            Jrows = []
            for f in in_group:
                vids = [v.variableID for v in f.adj_var_nodes]
                # 构造本因子的局部 x，用于（潜在）非线性雅可比
                x_loc_list = []
                dims = []
                for vid in vids:
                    st, d = idx_map[vid]
                    dims.append(d)
                    x_loc_list.append(x_super[st:st+d])
                x_loc = np.concatenate(x_loc_list) if x_loc_list else np.zeros(0)

                Jloc = f.jac_fn(x_loc)
                # 将 Jloc 列块映射回 super 变量的列
                row = np.zeros((Jloc.shape[0], ncols))
                c0 = 0
                for vid, d in zip(vids, dims):
                    st, _ = idx_map[vid]
                    row[:, st:st+d] = Jloc[:, c0:c0+d]
                    c0 += d
                Jrows.append(row)
            return np.vstack(Jrows) if Jrows else np.zeros((0, ncols))

        # z_super：拼各 base 因子的 z
        z_list = [f.measurement for f in in_group]
        z_super = np.concatenate(z_list) if z_list else np.zeros(0)

        return meas_fn_super_prior, jac_fn_super_prior, z_super

    # 为每个 super node 加 prior 因子
    for sid in super_groups.keys():
        meas_fn, jac_fn, z = make_super_prior_factor(sid, base_graph.factors)
        f = Factor(len(fg.factors), [super_var_nodes[sid]], z, prior_sigma, meas_fn, jac_fn)
        f.type = "super_prior"
        lin0 = make_linpoint_for_group(sid)
        f.compute_factor(linpoint=lin0, update_self=True)
        fg.factors.append(f)
        super_var_nodes[sid].adj_factors.append(f)

    # ---------- 4) super between（只取跨组 binary） ----------
    def make_super_between_factor(sidA, sidB, base_factors):
        groupA, groupB = super_groups[sidA], super_groups[sidB]
        idxA, idxB = local_idx[sidA], local_idx[sidB]
        nA, nB = total_dofs[sidA], total_dofs[sidB]

        cross = []
        for f in base_factors:
            vids = [v.variableID for v in f.adj_var_nodes]
            if len(vids) != 2:
                continue
            i, j = vids
            # 恰有一端在 A，一端在 B
            if (i in groupA and j in groupB) or (i in groupB and j in groupA):
                cross.append(f)

        def meas_fn_super_between(xAB, *args):
            xA, xB = xAB[:nA], xAB[nA:]
            meas_fn = []
            for f in cross:
                i, j = [v.variableID for v in f.adj_var_nodes]
                if i in groupA:
                    si, di = idxA[i]
                    sj, dj = idxB[j]
                    xi = xA[si:si+di]
                    xj = xB[sj:sj+dj]
                else:
                    si, di = idxB[i]
                    sj, dj = idxA[j]
                    xi = xB[si:si+di]
                    xj = xA[sj:sj+dj]
                x_loc = np.concatenate([xi, xj])
                meas_fn.append(f.meas_fn(x_loc) - f.z)
            return np.concatenate(meas_fn) if meas_fn else np.zeros(0)

        def jac_fn_super_between(xAB, *args):
            xA, xB = xAB[:nA], xAB[nA:]
            Jrows = []
            for f in cross:
                i, j = [v.variableID for v in f.adj_var_nodes]
                if i in groupA:
                    si, di = idxA[i]
                    sj, dj = idxB[j]
                    xi = xA[si:si+di]
                    xj = xB[sj:sj+dj]
                    left_start, right_start = si, nA + sj
                else:
                    si, di = idxB[i]
                    sj, dj = idxA[j]
                    xi = xB[si:si+di]
                    xj = xA[sj:sj+dj]
                    left_start, right_start = nA + si, sj
                x_loc = np.concatenate([xi, xj])
                Jloc = f.jac_fn(x_loc)

                row = np.zeros((Jloc.shape[0], nA + nB))
                row[:, left_start:left_start+di]   = Jloc[:, :di]
                row[:, right_start:right_start+dj] = Jloc[:, di:di+dj]
                Jrows.append(row)
            return np.vstack(Jrows) if Jrows else np.zeros((0, nA + nB))

        z_super = np.concatenate([f.z for f in cross]) if cross else np.zeros(0)
        return meas_fn_super_between, jac_fn_super_between, z_super

    for e in super_edges:
        u, v = e["data"]["source"], e["data"]["target"]
        if u == "prior" or v == "prior":
            continue
        if (u not in super_groups) or (v not in super_groups):
            continue
        meas_fn, jac_fn, z = make_super_between_factor(u, v, base_graph.factors)
        f = Factor(len(fg.factors), [super_var_nodes[u], super_var_nodes[v]], z, odom_sigma, meas_fn, jac_fn)
        f.type = "super_between"
        lin0 = np.concatenate([make_linpoint_for_group(u), make_linpoint_for_group(v)])
        f.compute_factor(linpoint=lin0, update_self=True)
        fg.factors.append(f)
        super_var_nodes[u].adj_factors.append(f)
        super_var_nodes[v].adj_factors.append(f)

    fg.n_factor_nodes = len(fg.factors)
    return fg

# %%
N=500 
step=25
prob=0.1
radius=50 
prior_prop=0.1
prior_sigma=10.0
odom_sigma=10.0
layers = []


# -----------------------
# 初始化 & 边界
# -----------------------
def init_layers(N=100, step_size=25, loop_prob=0.05, loop_radius=50, prior_prop=0.0):
    base_nodes, base_edges = make_slam_like_graph(N, step_size, loop_prob, loop_radius, prior_prop)
    return [{"name": "base", "nodes": base_nodes, "edges": base_edges}]

layers = init_layers(N=N, step_size=step, loop_prob=prob, loop_radius=radius, prior_prop=prior_prop)
pair_idx = 0



# 构建 GBP 图
gbp_graph = build_noisy_pose_graph(layers[0]["nodes"], layers[0]["edges"],
                                    prior_sigma=prior_sigma,
                                    odom_sigma=odom_sigma
                                    )
layers[0]["graph"] = gbp_graph
opts=[{"label":"base","value":"base"}]


last = layers[-1]
super_layer_idx = 1

super_nodes, super_edges, node_map = fuse_to_super_knn(last["nodes"], last["edges"], 100, super_layer_idx)
layers.append({"name":f"super{1}", "nodes":super_nodes, "edges":super_edges, "node_map":node_map})
layers[-1]["graph"] = build_super_graph(layers)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[79], line 37
#      35 super_nodes, super_edges, node_map = fuse_to_super_knn(last["nodes"], last["edges"], 100, super_layer_idx)
#      36 layers.append({"name":f"super{1}", "nodes":super_nodes, "edges":super_edges, "node_map":node_map})
# ---> 37 layers[-1]["graph"] = build_super_graph(layers)
#
# Cell In[78], line 120, in build_super_graph(layers, prior_sigma, odom_sigma)
#     118 f.type = "super_prior"
#     119 lin0 = make_linpoint_for_group(sid)
# --> 120 f.compute_factor(linpoint=lin0, update_self=True)
#     121 fg.factors.append(f)
#     122 super_var_nodes[sid].adj_factors.append(f)
#
# File ~/Desktop/abstraction-recovery/hierarchy/gbp/gbp.py:823, in Factor.compute_factor(self, linpoint, update_self)
#     821 else:
#     822     J = self.jac_fn(self.linpoint, *self.args)
# --> 823     pred_measurement = self.meas_fn(self.linpoint, *self.args)
#     825 if isinstance(self.measurement, float):
#     826     meas_model_lambda = 1 / self.adaptive_gauss_noise_var
#
# Cell In[78], line 81, in build_super_graph.<locals>.make_super_prior_factor.<locals>.meas_fn_super_prior(x_super, *args)
#      79         x_loc_list.append(x_super[st:st+d])
#      80     x_loc = np.concatenate(x_loc_list) if x_loc_list else np.zeros(0)
# ---> 81     meas_fn.append(f.meas_fn(x_loc) - f.z)
#      82 return np.concatenate(meas_fn) if meas_fn else np.zeros(0)
#
# AttributeError: 'Factor' object has no attribute 'z'

# %%
layers[-2]["graph"].n_var_nodes
# Out:
# 500

# %%
layers[-1]["graph"].n_var_nodes
# Out:
# 100

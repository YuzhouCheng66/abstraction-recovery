# %%
import numpy as np
from gbp.gbp import FactorGraph, VariableNode, Factor

# -----------------------
# SLAM-like base graph
# -----------------------
def make_slam_like_graph(N=100, step_size=25, loop_prob=0.05, loop_radius=50, prior_prop=0.0, rng=None,):
    nodes, edges = [], []
    positions = []
    x, y = 0.0, 0.0
    positions.append((x, y))
    for _ in range(1, int(N)):
        dx, dy = np.random.randn(2)
        norm = np.sqrt(dx**2 + dy**2) + 1e-6
        dx, dy = dx / norm * float(step_size), dy / norm * float(step_size)
        x, y = x + dx, y + dy
        positions.append((x, y))
    for i, (px, py) in enumerate(positions):
        nodes.append({
            "data": {"id": f"{i}", "layer": 0, "dim": 2},
            "position": {"x": float(px), "y": float(py)}
        })
    for i in range(int(N) - 1):
        edges.append({"data": {"source": f"{i}", "target": f"{i+1}"}})
    for i in range(int(N)):
        for j in range(i + 5, int(N)):
            if np.random.rand() < float(loop_prob):
                xi, yi = positions[i]; xj, yj = positions[j]
                if np.hypot(xi-xj, yi-yj) < float(loop_radius):
                    edges.append({"data": {"source": f"{i}", "target": f"{j}"}})

    # 确定强先验的节点集合
    if rng is None:
        rng = np.random.default_rng()

    if prior_prop <= 0.0:
        strong_ids = {0}
    elif prior_prop >= 1.0:
        strong_ids = set(range(N))
    else:
        k = max(1, int(np.floor(prior_prop * N)))
        strong_ids = set(rng.choice(N, size=k, replace=False).tolist())

    # 给 strong prior 节点加 edge
    for i in strong_ids:
        edges.append({
            "data": {"source": f"{i}", "target": "prior"}
        })


    return nodes, edges

# -----------------------
# GBP Graph 构建
# -----------------------
def build_noisy_pose_graph(
    nodes,
    edges,
    prior_sigma: float = 10,
    odom_sigma: float = 10,
    tiny_prior: float = 1e-10,
    rng=None,
):
    
    """
    构造二维 pose-only 因子图（线性，高斯），并注入噪声。
    参数:
      prior_sigma : 强先验的标准差（小=强）
      odom_sigma  : 里程计测量噪声标准差
      prior_prop  : 0.0=仅 anchor；(0,1)=按比例随机选；>=1.0=全体
      tiny_prior  : 所有节点默认加的极小先验，防止奇异
      seed        : 随机种子（可复现）
    """

    fg = FactorGraph(nonlinear_factors=False, eta_damping=0)

    var_nodes = []
    I2 = np.eye(2, dtype=float)
    N = len(nodes)

    # ---- 预生成噪声 ----
    prior_noises = {}
    odom_noises = {}

    if rng is None:
        rng = np.random.default_rng()

    # 为所有边生成噪声
    for e in edges:
        src = e["data"]["source"]; dst = e["data"]["target"]
        # 二元边
        if dst != "prior":
            odom_noises[(int(src[:]), int(dst[:]))] = rng.normal(0.0, odom_sigma, size=2)
        # 一元边（强先验）
        elif dst == "prior":
            prior_noises[int(src[:])] = rng.normal(0.0, prior_sigma, size=2)


    # ---- variable nodes ----
    for i, n in enumerate(nodes):
        v = VariableNode(i, dofs=2)
        v.GT = np.array([n["position"]["x"], n["position"]["y"]], dtype=float)

        # 极小先验
        v.prior.lam = tiny_prior * I2
        v.prior.eta = np.zeros(2, dtype=float)

        var_nodes.append(v)

    fg.var_nodes = var_nodes
    fg.n_var_nodes = len(var_nodes)


    # ---- prior factors ----
    def meas_fn_unary(x, *args):
        return x
    def jac_fn_unary(x, *args):
        return np.eye(2)
    # ---- odometry factors ----
    def meas_fn(xy, *args):
        return xy[2:] - xy[:2]
    def jac_fn(xy, *args):
        return np.array([[-1, 0, 1, 0],
                         [ 0,-1, 0, 1]], dtype=float)
    
    factors = []
    fid = 0

    for e in edges:
        src = e["data"]["source"]; dst = e["data"]["target"]
        if dst != "prior":
            i, j = int(src[:]), int(dst[:])
            vi, vj = var_nodes[i], var_nodes[j]

            meas = (vj.GT - vi.GT) + odom_noises[(i, j)]

            f = Factor(fid, [vi, vj], meas, odom_sigma, meas_fn, jac_fn)
            f.type = "base"
            linpoint = np.r_[vi.GT, vj.GT]
            f.compute_factor(linpoint=linpoint, update_self=True)

            factors.append(f)
            vi.adj_factors.append(f)
            vj.adj_factors.append(f)
            fid += 1

        else:
            i = int(src[:])
            vi = var_nodes[i]
            z = vi.GT + prior_noises[i]

            f = Factor(fid, [vi], z, prior_sigma, meas_fn_unary, jac_fn_unary)
            f.type = "prior"
            f.compute_factor(linpoint=z, update_self=True)

            factors.append(f)
            vi.adj_factors.append(f)
            fid += 1

    fg.factors = factors
    fg.n_factor_nodes = len(factors)
    return fg


# -----------------------
# 主程序：跑 100 次迭代
# -----------------------
if __name__ == "__main__":
    rng = np.random.default_rng(42)  # 固定随机种子

    # 1. 造一个图
    nodes, edges = make_slam_like_graph(N=50, step_size=25, loop_prob=0.1, loop_radius=50, prior_prop=0.01, rng=rng)

    # 2. 构建 GBP 图
    fg = build_noisy_pose_graph(nodes, edges, prior_sigma=1, odom_sigma=1, rng=rng)

    # 3. 跑迭代
    for it in range(1000):
        fg.synchronous_iteration()
        energy = fg.energy_map(include_priors=True, include_factors=True)
        print(f"Iter {it+1:03d} | Energy = {energy:.6f}")
# Out:
# Iter 001 | Energy = 207353.374138
# Iter 002 | Energy = 198535.788687
# Iter 003 | Energy = 185779.995025
# Iter 004 | Energy = 167580.424527
# Iter 005 | Energy = 143522.219696
# Iter 006 | Energy = 111419.652417
# Iter 007 | Energy = 72718.831080
# Iter 008 | Energy = 41214.456705
# Iter 009 | Energy = 22392.885297
# Iter 010 | Energy = 11988.313611
# Iter 011 | Energy = 3574.689193
# Iter 012 | Energy = 120.255969
# Iter 013 | Energy = 111.231590
# Iter 014 | Energy = 105.276889
# Iter 015 | Energy = 100.014994
# Iter 016 | Energy = 96.867191
# Iter 017 | Energy = 95.894364
# Iter 018 | Energy = 95.328113
# Iter 019 | Energy = 94.931407
# Iter 020 | Energy = 95.297694
# Iter 021 | Energy = 95.749853
# Iter 022 | Energy = 95.816876
# Iter 023 | Energy = 95.712516
# Iter 024 | Energy = 95.640319
# Iter 025 | Energy = 95.634775
# Iter 026 | Energy = 95.591934
# Iter 027 | Energy = 95.578952
# Iter 028 | Energy = 95.583812
# Iter 029 | Energy = 95.548308
# Iter 030 | Energy = 95.453429
# Iter 031 | Energy = 95.370123
# Iter 032 | Energy = 95.311691
# Iter 033 | Energy = 95.270233
# Iter 034 | Energy = 95.231968
# Iter 035 | Energy = 95.198907
# Iter 036 | Energy = 95.154162
# Iter 037 | Energy = 95.102657
# Iter 038 | Energy = 95.044446
# Iter 039 | Energy = 94.993630
# Iter 040 | Energy = 94.947883
# Iter 041 | Energy = 94.906850
# Iter 042 | Energy = 94.866016
# Iter 043 | Energy = 94.825872
# Iter 044 | Energy = 94.782888
# Iter 045 | Energy = 94.740541
# Iter 046 | Energy = 94.698539
# Iter 047 | Energy = 94.659418
# Iter 048 | Energy = 94.621509
# Iter 049 | Energy = 94.585166
# Iter 050 | Energy = 94.548853
# Iter 051 | Energy = 94.513232
# Iter 052 | Energy = 94.477600
# Iter 053 | Energy = 94.443074
# Iter 054 | Energy = 94.409289
# Iter 055 | Energy = 94.376765
# Iter 056 | Energy = 94.344875
# Iter 057 | Energy = 94.313836
# Iter 058 | Energy = 94.283204
# Iter 059 | Energy = 94.253294
# Iter 060 | Energy = 94.223897
# Iter 061 | Energy = 94.195315
# Iter 062 | Energy = 94.167347
# Iter 063 | Energy = 94.140127
# Iter 064 | Energy = 94.113445
# Iter 065 | Energy = 94.087397
# Iter 066 | Energy = 94.061852
# Iter 067 | Energy = 94.036917
# Iter 068 | Energy = 94.012507
# Iter 069 | Energy = 93.988698
# Iter 070 | Energy = 93.965404
# Iter 071 | Energy = 93.942664
# Iter 072 | Energy = 93.920405
# Iter 073 | Energy = 93.898661
# Iter 074 | Energy = 93.877383
# Iter 075 | Energy = 93.856601
# Iter 076 | Energy = 93.836276
# Iter 077 | Energy = 93.816423
# Iter 078 | Energy = 93.797008
# Iter 079 | Energy = 93.778037
# Iter 080 | Energy = 93.759484
# Iter 081 | Energy = 93.741355
# Iter 082 | Energy = 93.723627
# Iter 083 | Energy = 93.706304
# Iter 084 | Energy = 93.689367
# Iter 085 | Energy = 93.672816
# Iter 086 | Energy = 93.656634
# Iter 087 | Energy = 93.640820
# Iter 088 | Energy = 93.625358
# Iter 089 | Energy = 93.610247
# Iter 090 | Energy = 93.595474
# Iter 091 | Energy = 93.581036
# Iter 092 | Energy = 93.566921
# Iter 093 | Energy = 93.553126
# Iter 094 | Energy = 93.539641
# Iter 095 | Energy = 93.526461
# Iter 096 | Energy = 93.513576
# Iter 097 | Energy = 93.500983
# Iter 098 | Energy = 93.488673
# Iter 099 | Energy = 93.476641
# Iter 100 | Energy = 93.464879
# Iter 101 | Energy = 93.453384
# Iter 102 | Energy = 93.442147
# Iter 103 | Energy = 93.431164
# Iter 104 | Energy = 93.420428
# Iter 105 | Energy = 93.409935
# Iter 106 | Energy = 93.399678
# Iter 107 | Energy = 93.389653
# Iter 108 | Energy = 93.379853
# Iter 109 | Energy = 93.370275
# Iter 110 | Energy = 93.360913
# Iter 111 | Energy = 93.351763
# Iter 112 | Energy = 93.342819
# Iter 113 | Energy = 93.334077
# Iter 114 | Energy = 93.325532
# Iter 115 | Energy = 93.317180
# Iter 116 | Energy = 93.309016
# Iter 117 | Energy = 93.301038
# Iter 118 | Energy = 93.293239
# Iter 119 | Energy = 93.285616
# Iter 120 | Energy = 93.278166
# Iter 121 | Energy = 93.270884
# Iter 122 | Energy = 93.263766
# Iter 123 | Energy = 93.256810
# Iter 124 | Energy = 93.250010
# Iter 125 | Energy = 93.243365
# Iter 126 | Energy = 93.236869
# Iter 127 | Energy = 93.230521
# Iter 128 | Energy = 93.224316
# Iter 129 | Energy = 93.218251
# Iter 130 | Energy = 93.212323
# Iter 131 | Energy = 93.206530
# Iter 132 | Energy = 93.200868
# Iter 133 | Energy = 93.195334
# Iter 134 | Energy = 93.189925
# Iter 135 | Energy = 93.184638
# Iter 136 | Energy = 93.179471
# Iter 137 | Energy = 93.174422
# Iter 138 | Energy = 93.169486
# Iter 139 | Energy = 93.164663
# Iter 140 | Energy = 93.159948
# Iter 141 | Energy = 93.155341
# Iter 142 | Energy = 93.150837
# Iter 143 | Energy = 93.146436
# Iter 144 | Energy = 93.142135
# Iter 145 | Energy = 93.137931
# Iter 146 | Energy = 93.133822
# Iter 147 | Energy = 93.129807
# Iter 148 | Energy = 93.125883
# Iter 149 | Energy = 93.122048
# Iter 150 | Energy = 93.118299
# Iter 151 | Energy = 93.114636
# Iter 152 | Energy = 93.111056
# Iter 153 | Energy = 93.107557
# Iter 154 | Energy = 93.104138
# Iter 155 | Energy = 93.100796
# Iter 156 | Energy = 93.097530
# Iter 157 | Energy = 93.094339
# Iter 158 | Energy = 93.091220
# Iter 159 | Energy = 93.088172
# Iter 160 | Energy = 93.085193
# Iter 161 | Energy = 93.082281
# Iter 162 | Energy = 93.079436
# Iter 163 | Energy = 93.076656
# Iter 164 | Energy = 93.073939
# Iter 165 | Energy = 93.071284
# Iter 166 | Energy = 93.068689
# Iter 167 | Energy = 93.066153
# Iter 168 | Energy = 93.063675
# Iter 169 | Energy = 93.061254
# Iter 170 | Energy = 93.058887
# Iter 171 | Energy = 93.056575
# Iter 172 | Energy = 93.054315
# Iter 173 | Energy = 93.052106
# Iter 174 | Energy = 93.049948
# Iter 175 | Energy = 93.047840
# Iter 176 | Energy = 93.045779
# Iter 177 | Energy = 93.043765
# Iter 178 | Energy = 93.041798
# Iter 179 | Energy = 93.039875
# Iter 180 | Energy = 93.037996
# Iter 181 | Energy = 93.036160
# Iter 182 | Energy = 93.034366
# Iter 183 | Energy = 93.032613
# Iter 184 | Energy = 93.030899
# Iter 185 | Energy = 93.029226
# Iter 186 | Energy = 93.027590
# Iter 187 | Energy = 93.025992
# Iter 188 | Energy = 93.024430
# Iter 189 | Energy = 93.022904
# Iter 190 | Energy = 93.021413
# Iter 191 | Energy = 93.019956
# Iter 192 | Energy = 93.018533
# Iter 193 | Energy = 93.017142
# Iter 194 | Energy = 93.015783
# Iter 195 | Energy = 93.014455
# Iter 196 | Energy = 93.013157
# Iter 197 | Energy = 93.011890
# Iter 198 | Energy = 93.010651
# Iter 199 | Energy = 93.009441
# Iter 200 | Energy = 93.008259
# Iter 201 | Energy = 93.007103
# Iter 202 | Energy = 93.005975
# Iter 203 | Energy = 93.004872
# Iter 204 | Energy = 93.003794
# Iter 205 | Energy = 93.002742
# Iter 206 | Energy = 93.001713
# Iter 207 | Energy = 93.000708
# Iter 208 | Energy = 92.999727
# Iter 209 | Energy = 92.998768
# Iter 210 | Energy = 92.997831
# Iter 211 | Energy = 92.996915
# Iter 212 | Energy = 92.996021
# Iter 213 | Energy = 92.995147
# Iter 214 | Energy = 92.994294
# Iter 215 | Energy = 92.993460
# Iter 216 | Energy = 92.992645
# Iter 217 | Energy = 92.991849
# Iter 218 | Energy = 92.991072
# Iter 219 | Energy = 92.990312
# Iter 220 | Energy = 92.989571
# Iter 221 | Energy = 92.988846
# Iter 222 | Energy = 92.988138
# Iter 223 | Energy = 92.987446
# Iter 224 | Energy = 92.986771
# Iter 225 | Energy = 92.986111
# Iter 226 | Energy = 92.985466
# Iter 227 | Energy = 92.984836
# Iter 228 | Energy = 92.984221
# Iter 229 | Energy = 92.983620
# Iter 230 | Energy = 92.983034
# Iter 231 | Energy = 92.982460
# Iter 232 | Energy = 92.981900
# Iter 233 | Energy = 92.981353
# Iter 234 | Energy = 92.980819
# Iter 235 | Energy = 92.980297
# Iter 236 | Energy = 92.979788
# Iter 237 | Energy = 92.979290
# Iter 238 | Energy = 92.978804
# Iter 239 | Energy = 92.978329
# Iter 240 | Energy = 92.977865
# Iter 241 | Energy = 92.977412
# Iter 242 | Energy = 92.976970
# Iter 243 | Energy = 92.976538
# Iter 244 | Energy = 92.976116
# Iter 245 | Energy = 92.975704
# Iter 246 | Energy = 92.975302
# Iter 247 | Energy = 92.974909
# Iter 248 | Energy = 92.974525
# Iter 249 | Energy = 92.974150
# Iter 250 | Energy = 92.973784
# Iter 251 | Energy = 92.973427
# Iter 252 | Energy = 92.973078
# Iter 253 | Energy = 92.972737
# Iter 254 | Energy = 92.972404
# Iter 255 | Energy = 92.972079
# Iter 256 | Energy = 92.971762
# Iter 257 | Energy = 92.971452
# Iter 258 | Energy = 92.971149
# Iter 259 | Energy = 92.970854
# Iter 260 | Energy = 92.970566
# Iter 261 | Energy = 92.970284
# Iter 262 | Energy = 92.970009
# Iter 263 | Energy = 92.969740
# Iter 264 | Energy = 92.969478
# Iter 265 | Energy = 92.969222
# Iter 266 | Energy = 92.968972
# Iter 267 | Energy = 92.968729
# Iter 268 | Energy = 92.968490
# Iter 269 | Energy = 92.968258
# Iter 270 | Energy = 92.968031
# Iter 271 | Energy = 92.967809
# Iter 272 | Energy = 92.967593
# Iter 273 | Energy = 92.967382
# Iter 274 | Energy = 92.967176
# Iter 275 | Energy = 92.966975
# Iter 276 | Energy = 92.966778
# Iter 277 | Energy = 92.966587
# Iter 278 | Energy = 92.966399
# Iter 279 | Energy = 92.966217
# Iter 280 | Energy = 92.966039
# Iter 281 | Energy = 92.965865
# Iter 282 | Energy = 92.965695
# Iter 283 | Energy = 92.965529
# Iter 284 | Energy = 92.965367
# Iter 285 | Energy = 92.965209
# Iter 286 | Energy = 92.965055
# Iter 287 | Energy = 92.964905
# Iter 288 | Energy = 92.964758
# Iter 289 | Energy = 92.964615
# Iter 290 | Energy = 92.964475
# Iter 291 | Energy = 92.964339
# Iter 292 | Energy = 92.964206
# Iter 293 | Energy = 92.964076
# Iter 294 | Energy = 92.963950
# Iter 295 | Energy = 92.963826
# Iter 296 | Energy = 92.963706
# Iter 297 | Energy = 92.963588
# Iter 298 | Energy = 92.963473
# Iter 299 | Energy = 92.963361
# Iter 300 | Energy = 92.963252
# Iter 301 | Energy = 92.963145
# Iter 302 | Energy = 92.963041
# Iter 303 | Energy = 92.962940
# Iter 304 | Energy = 92.962841
# Iter 305 | Energy = 92.962745
# Iter 306 | Energy = 92.962651
# Iter 307 | Energy = 92.962559
# Iter 308 | Energy = 92.962469
# Iter 309 | Energy = 92.962382
# Iter 310 | Energy = 92.962297
# Iter 311 | Energy = 92.962214
# Iter 312 | Energy = 92.962133
# Iter 313 | Energy = 92.962054
# Iter 314 | Energy = 92.961977
# Iter 315 | Energy = 92.961902
# Iter 316 | Energy = 92.961829
# Iter 317 | Energy = 92.961757
# Iter 318 | Energy = 92.961688
# Iter 319 | Energy = 92.961620
# Iter 320 | Energy = 92.961554
# Iter 321 | Energy = 92.961489
# Iter 322 | Energy = 92.961426
# Iter 323 | Energy = 92.961365
# Iter 324 | Energy = 92.961305
# Iter 325 | Energy = 92.961247
# Iter 326 | Energy = 92.961190
# Iter 327 | Energy = 92.961135
# Iter 328 | Energy = 92.961081
# Iter 329 | Energy = 92.961029
# Iter 330 | Energy = 92.960978
# Iter 331 | Energy = 92.960928
# Iter 332 | Energy = 92.960879
# Iter 333 | Energy = 92.960832
# Iter 334 | Energy = 92.960786
# Iter 335 | Energy = 92.960741
# Iter 336 | Energy = 92.960697
# Iter 337 | Energy = 92.960654
# Iter 338 | Energy = 92.960613
# Iter 339 | Energy = 92.960572
# Iter 340 | Energy = 92.960533
# Iter 341 | Energy = 92.960494
# Iter 342 | Energy = 92.960457
# Iter 343 | Energy = 92.960421
# Iter 344 | Energy = 92.960385
# Iter 345 | Energy = 92.960351
# Iter 346 | Energy = 92.960317
# Iter 347 | Energy = 92.960284
# Iter 348 | Energy = 92.960252
# Iter 349 | Energy = 92.960221
# Iter 350 | Energy = 92.960191
# Iter 351 | Energy = 92.960162
# Iter 352 | Energy = 92.960133
# Iter 353 | Energy = 92.960105
# Iter 354 | Energy = 92.960078
# Iter 355 | Energy = 92.960052
# Iter 356 | Energy = 92.960026
# Iter 357 | Energy = 92.960002
# Iter 358 | Energy = 92.959977
# Iter 359 | Energy = 92.959954
# Iter 360 | Energy = 92.959931
# Iter 361 | Energy = 92.959908
# Iter 362 | Energy = 92.959887
# Iter 363 | Energy = 92.959866
# Iter 364 | Energy = 92.959845
# Iter 365 | Energy = 92.959825
# Iter 366 | Energy = 92.959806
# Iter 367 | Energy = 92.959787
# Iter 368 | Energy = 92.959769
# Iter 369 | Energy = 92.959751
# Iter 370 | Energy = 92.959733
# Iter 371 | Energy = 92.959717
# Iter 372 | Energy = 92.959700
# Iter 373 | Energy = 92.959684
# Iter 374 | Energy = 92.959669
# Iter 375 | Energy = 92.959654
# Iter 376 | Energy = 92.959640
# Iter 377 | Energy = 92.959625
# Iter 378 | Energy = 92.959612
# Iter 379 | Energy = 92.959598
# Iter 380 | Energy = 92.959586
# Iter 381 | Energy = 92.959573
# Iter 382 | Energy = 92.959561
# Iter 383 | Energy = 92.959549
# Iter 384 | Energy = 92.959538
# Iter 385 | Energy = 92.959527
# Iter 386 | Energy = 92.959516
# Iter 387 | Energy = 92.959505
# Iter 388 | Energy = 92.959495
# Iter 389 | Energy = 92.959485
# Iter 390 | Energy = 92.959476
# Iter 391 | Energy = 92.959467
# Iter 392 | Energy = 92.959458
# Iter 393 | Energy = 92.959449
# Iter 394 | Energy = 92.959441
# Iter 395 | Energy = 92.959433
# Iter 396 | Energy = 92.959425
# Iter 397 | Energy = 92.959417
# Iter 398 | Energy = 92.959410
# Iter 399 | Energy = 92.959403
# Iter 400 | Energy = 92.959396
# Iter 401 | Energy = 92.959389
# Iter 402 | Energy = 92.959383
# Iter 403 | Energy = 92.959377
# Iter 404 | Energy = 92.959371
# Iter 405 | Energy = 92.959365
# Iter 406 | Energy = 92.959360
# Iter 407 | Energy = 92.959354
# Iter 408 | Energy = 92.959349
# Iter 409 | Energy = 92.959344
# Iter 410 | Energy = 92.959339
# Iter 411 | Energy = 92.959334
# Iter 412 | Energy = 92.959330
# Iter 413 | Energy = 92.959326
# Iter 414 | Energy = 92.959322
# Iter 415 | Energy = 92.959318
# Iter 416 | Energy = 92.959314
# Iter 417 | Energy = 92.959310
# Iter 418 | Energy = 92.959306
# Iter 419 | Energy = 92.959303
# Iter 420 | Energy = 92.959300
# Iter 421 | Energy = 92.959297
# Iter 422 | Energy = 92.959294
# Iter 423 | Energy = 92.959291
# Iter 424 | Energy = 92.959288
# Iter 425 | Energy = 92.959285
# Iter 426 | Energy = 92.959283
# Iter 427 | Energy = 92.959280
# Iter 428 | Energy = 92.959278
# Iter 429 | Energy = 92.959276
# Iter 430 | Energy = 92.959274
# Iter 431 | Energy = 92.959272
# Iter 432 | Energy = 92.959270
# Iter 433 | Energy = 92.959268
# Iter 434 | Energy = 92.959266
# Iter 435 | Energy = 92.959264
# Iter 436 | Energy = 92.959263
# Iter 437 | Energy = 92.959261
# Iter 438 | Energy = 92.959260
# Iter 439 | Energy = 92.959259
# Iter 440 | Energy = 92.959258
# Iter 441 | Energy = 92.959256
# Iter 442 | Energy = 92.959255
# Iter 443 | Energy = 92.959254
# Iter 444 | Energy = 92.959253
# Iter 445 | Energy = 92.959252
# Iter 446 | Energy = 92.959252
# Iter 447 | Energy = 92.959251
# Iter 448 | Energy = 92.959250
# Iter 449 | Energy = 92.959250
# Iter 450 | Energy = 92.959249
# Iter 451 | Energy = 92.959249
# Iter 452 | Energy = 92.959248
# Iter 453 | Energy = 92.959248
# Iter 454 | Energy = 92.959247
# Iter 455 | Energy = 92.959247
# Iter 456 | Energy = 92.959247
# Iter 457 | Energy = 92.959246
# Iter 458 | Energy = 92.959246
# Iter 459 | Energy = 92.959246
# Iter 460 | Energy = 92.959246
# Iter 461 | Energy = 92.959246
# Iter 462 | Energy = 92.959246
# Iter 463 | Energy = 92.959246
# Iter 464 | Energy = 92.959246
# Iter 465 | Energy = 92.959246
# Iter 466 | Energy = 92.959246
# Iter 467 | Energy = 92.959246
# Iter 468 | Energy = 92.959247
# Iter 469 | Energy = 92.959247
# Iter 470 | Energy = 92.959247
# Iter 471 | Energy = 92.959247
# Iter 472 | Energy = 92.959248
# Iter 473 | Energy = 92.959248
# Iter 474 | Energy = 92.959248
# Iter 475 | Energy = 92.959249
# Iter 476 | Energy = 92.959249
# Iter 477 | Energy = 92.959250
# Iter 478 | Energy = 92.959250
# Iter 479 | Energy = 92.959250
# Iter 480 | Energy = 92.959251
# Iter 481 | Energy = 92.959251
# Iter 482 | Energy = 92.959252
# Iter 483 | Energy = 92.959253
# Iter 484 | Energy = 92.959253
# Iter 485 | Energy = 92.959254
# Iter 486 | Energy = 92.959254
# Iter 487 | Energy = 92.959255
# Iter 488 | Energy = 92.959256
# Iter 489 | Energy = 92.959256
# Iter 490 | Energy = 92.959257
# Iter 491 | Energy = 92.959257
# Iter 492 | Energy = 92.959258
# Iter 493 | Energy = 92.959259
# Iter 494 | Energy = 92.959259
# Iter 495 | Energy = 92.959260
# Iter 496 | Energy = 92.959261
# Iter 497 | Energy = 92.959262
# Iter 498 | Energy = 92.959262
# Iter 499 | Energy = 92.959263
# Iter 500 | Energy = 92.959264
# Iter 501 | Energy = 92.959265
# Iter 502 | Energy = 92.959265
# Iter 503 | Energy = 92.959266
# Iter 504 | Energy = 92.959267
# Iter 505 | Energy = 92.959268
# Iter 506 | Energy = 92.959268
# Iter 507 | Energy = 92.959269
# Iter 508 | Energy = 92.959270
# Iter 509 | Energy = 92.959271
# Iter 510 | Energy = 92.959272
# Iter 511 | Energy = 92.959272
# Iter 512 | Energy = 92.959273
# Iter 513 | Energy = 92.959274
# Iter 514 | Energy = 92.959275
# Iter 515 | Energy = 92.959276
# Iter 516 | Energy = 92.959277
# Iter 517 | Energy = 92.959277
# Iter 518 | Energy = 92.959278
# Iter 519 | Energy = 92.959279
# Iter 520 | Energy = 92.959280
# Iter 521 | Energy = 92.959281
# Iter 522 | Energy = 92.959281
# Iter 523 | Energy = 92.959282
# Iter 524 | Energy = 92.959283
# Iter 525 | Energy = 92.959284
# Iter 526 | Energy = 92.959285
# Iter 527 | Energy = 92.959286
# Iter 528 | Energy = 92.959286
# Iter 529 | Energy = 92.959287
# Iter 530 | Energy = 92.959288
# Iter 531 | Energy = 92.959289
# Iter 532 | Energy = 92.959290
# Iter 533 | Energy = 92.959291
# Iter 534 | Energy = 92.959291
# Iter 535 | Energy = 92.959292
# Iter 536 | Energy = 92.959293
# Iter 537 | Energy = 92.959294
# Iter 538 | Energy = 92.959295
# Iter 539 | Energy = 92.959295
# Iter 540 | Energy = 92.959296
# Iter 541 | Energy = 92.959297
# Iter 542 | Energy = 92.959298
# Iter 543 | Energy = 92.959299
# Iter 544 | Energy = 92.959299
# Iter 545 | Energy = 92.959300
# Iter 546 | Energy = 92.959301
# Iter 547 | Energy = 92.959302
# Iter 548 | Energy = 92.959302
# Iter 549 | Energy = 92.959303
# Iter 550 | Energy = 92.959304
# Iter 551 | Energy = 92.959305
# Iter 552 | Energy = 92.959306
# Iter 553 | Energy = 92.959306
# Iter 554 | Energy = 92.959307
# Iter 555 | Energy = 92.959308
# Iter 556 | Energy = 92.959309
# Iter 557 | Energy = 92.959309
# Iter 558 | Energy = 92.959310
# Iter 559 | Energy = 92.959311
# Iter 560 | Energy = 92.959312
# Iter 561 | Energy = 92.959312
# Iter 562 | Energy = 92.959313
# Iter 563 | Energy = 92.959314
# Iter 564 | Energy = 92.959314
# Iter 565 | Energy = 92.959315
# Iter 566 | Energy = 92.959316
# Iter 567 | Energy = 92.959317
# Iter 568 | Energy = 92.959317
# Iter 569 | Energy = 92.959318
# Iter 570 | Energy = 92.959319
# Iter 571 | Energy = 92.959319
# Iter 572 | Energy = 92.959320
# Iter 573 | Energy = 92.959321
# Iter 574 | Energy = 92.959321
# Iter 575 | Energy = 92.959322
# Iter 576 | Energy = 92.959323
# Iter 577 | Energy = 92.959323
# Iter 578 | Energy = 92.959324
# Iter 579 | Energy = 92.959325
# Iter 580 | Energy = 92.959325
# Iter 581 | Energy = 92.959326
# Iter 582 | Energy = 92.959327
# Iter 583 | Energy = 92.959327
# Iter 584 | Energy = 92.959328
# Iter 585 | Energy = 92.959328
# Iter 586 | Energy = 92.959329
# Iter 587 | Energy = 92.959330
# Iter 588 | Energy = 92.959330
# Iter 589 | Energy = 92.959331
# Iter 590 | Energy = 92.959331
# Iter 591 | Energy = 92.959332
# Iter 592 | Energy = 92.959333
# Iter 593 | Energy = 92.959333
# Iter 594 | Energy = 92.959334
# Iter 595 | Energy = 92.959334
# Iter 596 | Energy = 92.959335
# Iter 597 | Energy = 92.959335
# Iter 598 | Energy = 92.959336
# Iter 599 | Energy = 92.959337
# Iter 600 | Energy = 92.959337
# Iter 601 | Energy = 92.959338
# Iter 602 | Energy = 92.959338
# Iter 603 | Energy = 92.959339
# Iter 604 | Energy = 92.959339
# Iter 605 | Energy = 92.959340
# Iter 606 | Energy = 92.959340
# Iter 607 | Energy = 92.959341
# Iter 608 | Energy = 92.959341
# Iter 609 | Energy = 92.959342
# Iter 610 | Energy = 92.959342
# Iter 611 | Energy = 92.959343
# Iter 612 | Energy = 92.959343
# Iter 613 | Energy = 92.959344
# Iter 614 | Energy = 92.959344
# Iter 615 | Energy = 92.959345
# Iter 616 | Energy = 92.959345
# Iter 617 | Energy = 92.959346
# Iter 618 | Energy = 92.959346
# Iter 619 | Energy = 92.959347
# Iter 620 | Energy = 92.959347
# Iter 621 | Energy = 92.959348
# Iter 622 | Energy = 92.959348
# Iter 623 | Energy = 92.959349
# Iter 624 | Energy = 92.959349
# Iter 625 | Energy = 92.959349
# Iter 626 | Energy = 92.959350
# Iter 627 | Energy = 92.959350
# Iter 628 | Energy = 92.959351
# Iter 629 | Energy = 92.959351
# Iter 630 | Energy = 92.959352
# Iter 631 | Energy = 92.959352
# Iter 632 | Energy = 92.959352
# Iter 633 | Energy = 92.959353
# Iter 634 | Energy = 92.959353
# Iter 635 | Energy = 92.959354
# Iter 636 | Energy = 92.959354
# Iter 637 | Energy = 92.959354
# Iter 638 | Energy = 92.959355
# Iter 639 | Energy = 92.959355
# Iter 640 | Energy = 92.959356
# Iter 641 | Energy = 92.959356
# Iter 642 | Energy = 92.959356
# Iter 643 | Energy = 92.959357
# Iter 644 | Energy = 92.959357
# Iter 645 | Energy = 92.959357
# Iter 646 | Energy = 92.959358
# Iter 647 | Energy = 92.959358
# Iter 648 | Energy = 92.959359
# Iter 649 | Energy = 92.959359
# Iter 650 | Energy = 92.959359
# Iter 651 | Energy = 92.959360
# Iter 652 | Energy = 92.959360
# Iter 653 | Energy = 92.959360
# Iter 654 | Energy = 92.959361
# Iter 655 | Energy = 92.959361
# Iter 656 | Energy = 92.959361
# Iter 657 | Energy = 92.959362
# Iter 658 | Energy = 92.959362
# Iter 659 | Energy = 92.959362
# Iter 660 | Energy = 92.959363
# Iter 661 | Energy = 92.959363
# Iter 662 | Energy = 92.959363
# Iter 663 | Energy = 92.959363
# Iter 664 | Energy = 92.959364
# Iter 665 | Energy = 92.959364
# Iter 666 | Energy = 92.959364
# Iter 667 | Energy = 92.959365
# Iter 668 | Energy = 92.959365
# Iter 669 | Energy = 92.959365
# Iter 670 | Energy = 92.959366
# Iter 671 | Energy = 92.959366
# Iter 672 | Energy = 92.959366
# Iter 673 | Energy = 92.959366
# Iter 674 | Energy = 92.959367
# Iter 675 | Energy = 92.959367
# Iter 676 | Energy = 92.959367
# Iter 677 | Energy = 92.959367
# Iter 678 | Energy = 92.959368
# Iter 679 | Energy = 92.959368
# Iter 680 | Energy = 92.959368
# Iter 681 | Energy = 92.959368
# Iter 682 | Energy = 92.959369
# Iter 683 | Energy = 92.959369
# Iter 684 | Energy = 92.959369
# Iter 685 | Energy = 92.959369
# Iter 686 | Energy = 92.959370
# Iter 687 | Energy = 92.959370
# Iter 688 | Energy = 92.959370
# Iter 689 | Energy = 92.959370
# Iter 690 | Energy = 92.959371
# Iter 691 | Energy = 92.959371
# Iter 692 | Energy = 92.959371
# Iter 693 | Energy = 92.959371
# Iter 694 | Energy = 92.959372
# Iter 695 | Energy = 92.959372
# Iter 696 | Energy = 92.959372
# Iter 697 | Energy = 92.959372
# Iter 698 | Energy = 92.959372
# Iter 699 | Energy = 92.959373
# Iter 700 | Energy = 92.959373
# Iter 701 | Energy = 92.959373
# Iter 702 | Energy = 92.959373
# Iter 703 | Energy = 92.959373
# Iter 704 | Energy = 92.959374
# Iter 705 | Energy = 92.959374
# Iter 706 | Energy = 92.959374
# Iter 707 | Energy = 92.959374
# Iter 708 | Energy = 92.959374
# Iter 709 | Energy = 92.959375
# Iter 710 | Energy = 92.959375
# Iter 711 | Energy = 92.959375
# Iter 712 | Energy = 92.959375
# Iter 713 | Energy = 92.959375
# Iter 714 | Energy = 92.959376
# Iter 715 | Energy = 92.959376
# Iter 716 | Energy = 92.959376
# Iter 717 | Energy = 92.959376
# Iter 718 | Energy = 92.959376
# Iter 719 | Energy = 92.959376
# Iter 720 | Energy = 92.959377
# Iter 721 | Energy = 92.959377
# Iter 722 | Energy = 92.959377
# Iter 723 | Energy = 92.959377
# Iter 724 | Energy = 92.959377
# Iter 725 | Energy = 92.959377
# Iter 726 | Energy = 92.959378
# Iter 727 | Energy = 92.959378
# Iter 728 | Energy = 92.959378
# Iter 729 | Energy = 92.959378
# Iter 730 | Energy = 92.959378
# Iter 731 | Energy = 92.959378
# Iter 732 | Energy = 92.959379
# Iter 733 | Energy = 92.959379
# Iter 734 | Energy = 92.959379
# Iter 735 | Energy = 92.959379
# Iter 736 | Energy = 92.959379
# Iter 737 | Energy = 92.959379
# Iter 738 | Energy = 92.959379
# Iter 739 | Energy = 92.959380
# Iter 740 | Energy = 92.959380
# Iter 741 | Energy = 92.959380
# Iter 742 | Energy = 92.959380
# Iter 743 | Energy = 92.959380
# Iter 744 | Energy = 92.959380
# Iter 745 | Energy = 92.959380
# Iter 746 | Energy = 92.959380
# Iter 747 | Energy = 92.959381
# Iter 748 | Energy = 92.959381
# Iter 749 | Energy = 92.959381
# Iter 750 | Energy = 92.959381
# Iter 751 | Energy = 92.959381
# Iter 752 | Energy = 92.959381
# Iter 753 | Energy = 92.959381
# Iter 754 | Energy = 92.959381
# Iter 755 | Energy = 92.959382
# Iter 756 | Energy = 92.959382
# Iter 757 | Energy = 92.959382
# Iter 758 | Energy = 92.959382
# Iter 759 | Energy = 92.959382
# Iter 760 | Energy = 92.959382
# Iter 761 | Energy = 92.959382
# Iter 762 | Energy = 92.959382
# Iter 763 | Energy = 92.959382
# Iter 764 | Energy = 92.959383
# Iter 765 | Energy = 92.959383
# Iter 766 | Energy = 92.959383
# Iter 767 | Energy = 92.959383
# Iter 768 | Energy = 92.959383
# Iter 769 | Energy = 92.959383
# Iter 770 | Energy = 92.959383
# Iter 771 | Energy = 92.959383
# Iter 772 | Energy = 92.959383
# Iter 773 | Energy = 92.959383
# Iter 774 | Energy = 92.959384
# Iter 775 | Energy = 92.959384
# Iter 776 | Energy = 92.959384
# Iter 777 | Energy = 92.959384
# Iter 778 | Energy = 92.959384
# Iter 779 | Energy = 92.959384
# Iter 780 | Energy = 92.959384
# Iter 781 | Energy = 92.959384
# Iter 782 | Energy = 92.959384
# Iter 783 | Energy = 92.959384
# Iter 784 | Energy = 92.959384
# Iter 785 | Energy = 92.959385
# Iter 786 | Energy = 92.959385
# Iter 787 | Energy = 92.959385
# Iter 788 | Energy = 92.959385
# Iter 789 | Energy = 92.959385
# Iter 790 | Energy = 92.959385
# Iter 791 | Energy = 92.959385
# Iter 792 | Energy = 92.959385
# Iter 793 | Energy = 92.959385
# Iter 794 | Energy = 92.959385
# Iter 795 | Energy = 92.959385
# Iter 796 | Energy = 92.959385
# Iter 797 | Energy = 92.959385
# Iter 798 | Energy = 92.959386
# Iter 799 | Energy = 92.959386
# Iter 800 | Energy = 92.959386
# Iter 801 | Energy = 92.959386
# Iter 802 | Energy = 92.959386
# Iter 803 | Energy = 92.959386
# Iter 804 | Energy = 92.959386
# Iter 805 | Energy = 92.959386
# Iter 806 | Energy = 92.959386
# Iter 807 | Energy = 92.959386
# Iter 808 | Energy = 92.959386
# Iter 809 | Energy = 92.959386
# Iter 810 | Energy = 92.959386
# Iter 811 | Energy = 92.959386
# Iter 812 | Energy = 92.959386
# Iter 813 | Energy = 92.959387
# Iter 814 | Energy = 92.959387
# Iter 815 | Energy = 92.959387
# Iter 816 | Energy = 92.959387
# Iter 817 | Energy = 92.959387
# Iter 818 | Energy = 92.959387
# Iter 819 | Energy = 92.959387
# Iter 820 | Energy = 92.959387
# Iter 821 | Energy = 92.959387
# Iter 822 | Energy = 92.959387
# Iter 823 | Energy = 92.959387
# Iter 824 | Energy = 92.959387
# Iter 825 | Energy = 92.959387
# Iter 826 | Energy = 92.959387
# Iter 827 | Energy = 92.959387
# Iter 828 | Energy = 92.959387
# Iter 829 | Energy = 92.959387
# Iter 830 | Energy = 92.959387
# Iter 831 | Energy = 92.959388
# Iter 832 | Energy = 92.959388
# Iter 833 | Energy = 92.959388
# Iter 834 | Energy = 92.959388
# Iter 835 | Energy = 92.959388
# Iter 836 | Energy = 92.959388
# Iter 837 | Energy = 92.959388
# Iter 838 | Energy = 92.959388
# Iter 839 | Energy = 92.959388
# Iter 840 | Energy = 92.959388
# Iter 841 | Energy = 92.959388
# Iter 842 | Energy = 92.959388
# Iter 843 | Energy = 92.959388
# Iter 844 | Energy = 92.959388
# Iter 845 | Energy = 92.959388
# Iter 846 | Energy = 92.959388
# Iter 847 | Energy = 92.959388
# Iter 848 | Energy = 92.959388
# Iter 849 | Energy = 92.959388
# Iter 850 | Energy = 92.959388
# Iter 851 | Energy = 92.959388
# Iter 852 | Energy = 92.959388
# Iter 853 | Energy = 92.959388
# Iter 854 | Energy = 92.959389
# Iter 855 | Energy = 92.959389
# Iter 856 | Energy = 92.959389
# Iter 857 | Energy = 92.959389
# Iter 858 | Energy = 92.959389
# Iter 859 | Energy = 92.959389
# Iter 860 | Energy = 92.959389
# Iter 861 | Energy = 92.959389
# Iter 862 | Energy = 92.959389
# Iter 863 | Energy = 92.959389
# Iter 864 | Energy = 92.959389
# Iter 865 | Energy = 92.959389
# Iter 866 | Energy = 92.959389
# Iter 867 | Energy = 92.959389
# Iter 868 | Energy = 92.959389
# Iter 869 | Energy = 92.959389
# Iter 870 | Energy = 92.959389
# Iter 871 | Energy = 92.959389
# Iter 872 | Energy = 92.959389
# Iter 873 | Energy = 92.959389
# Iter 874 | Energy = 92.959389
# Iter 875 | Energy = 92.959389
# Iter 876 | Energy = 92.959389
# Iter 877 | Energy = 92.959389
# Iter 878 | Energy = 92.959389
# Iter 879 | Energy = 92.959389
# Iter 880 | Energy = 92.959389
# Iter 881 | Energy = 92.959389
# Iter 882 | Energy = 92.959389
# Iter 883 | Energy = 92.959389
# Iter 884 | Energy = 92.959390
# Iter 885 | Energy = 92.959390
# Iter 886 | Energy = 92.959390
# Iter 887 | Energy = 92.959390
# Iter 888 | Energy = 92.959390
# Iter 889 | Energy = 92.959390
# Iter 890 | Energy = 92.959390
# Iter 891 | Energy = 92.959390
# Iter 892 | Energy = 92.959390
# Iter 893 | Energy = 92.959390
# Iter 894 | Energy = 92.959390
# Iter 895 | Energy = 92.959390
# Iter 896 | Energy = 92.959390
# Iter 897 | Energy = 92.959390
# Iter 898 | Energy = 92.959390
# Iter 899 | Energy = 92.959390
# Iter 900 | Energy = 92.959390
# Iter 901 | Energy = 92.959390
# Iter 902 | Energy = 92.959390
# Iter 903 | Energy = 92.959390
# Iter 904 | Energy = 92.959390
# Iter 905 | Energy = 92.959390
# Iter 906 | Energy = 92.959390
# Iter 907 | Energy = 92.959390
# Iter 908 | Energy = 92.959390
# Iter 909 | Energy = 92.959390
# Iter 910 | Energy = 92.959390
# Iter 911 | Energy = 92.959390
# Iter 912 | Energy = 92.959390
# Iter 913 | Energy = 92.959390
# Iter 914 | Energy = 92.959390
# Iter 915 | Energy = 92.959390
# Iter 916 | Energy = 92.959390
# Iter 917 | Energy = 92.959390
# Iter 918 | Energy = 92.959390
# Iter 919 | Energy = 92.959390
# Iter 920 | Energy = 92.959390
# Iter 921 | Energy = 92.959390
# Iter 922 | Energy = 92.959390
# Iter 923 | Energy = 92.959390
# Iter 924 | Energy = 92.959390
# Iter 925 | Energy = 92.959390
# Iter 926 | Energy = 92.959390
# Iter 927 | Energy = 92.959390
# Iter 928 | Energy = 92.959390
# Iter 929 | Energy = 92.959390
# Iter 930 | Energy = 92.959391
# Iter 931 | Energy = 92.959391
# Iter 932 | Energy = 92.959391
# Iter 933 | Energy = 92.959391
# Iter 934 | Energy = 92.959391
# Iter 935 | Energy = 92.959391
# Iter 936 | Energy = 92.959391
# Iter 937 | Energy = 92.959391
# Iter 938 | Energy = 92.959391
# Iter 939 | Energy = 92.959391
# Iter 940 | Energy = 92.959391
# Iter 941 | Energy = 92.959391
# Iter 942 | Energy = 92.959391
# Iter 943 | Energy = 92.959391
# Iter 944 | Energy = 92.959391
# Iter 945 | Energy = 92.959391
# Iter 946 | Energy = 92.959391
# Iter 947 | Energy = 92.959391
# Iter 948 | Energy = 92.959391
# Iter 949 | Energy = 92.959391
# Iter 950 | Energy = 92.959391
# Iter 951 | Energy = 92.959391
# Iter 952 | Energy = 92.959391
# Iter 953 | Energy = 92.959391
# Iter 954 | Energy = 92.959391
# Iter 955 | Energy = 92.959391
# Iter 956 | Energy = 92.959391
# Iter 957 | Energy = 92.959391
# Iter 958 | Energy = 92.959391
# Iter 959 | Energy = 92.959391
# Iter 960 | Energy = 92.959391
# Iter 961 | Energy = 92.959391
# Iter 962 | Energy = 92.959391
# Iter 963 | Energy = 92.959391
# Iter 964 | Energy = 92.959391
# Iter 965 | Energy = 92.959391
# Iter 966 | Energy = 92.959391
# Iter 967 | Energy = 92.959391
# Iter 968 | Energy = 92.959391
# Iter 969 | Energy = 92.959391
# Iter 970 | Energy = 92.959391
# Iter 971 | Energy = 92.959391
# Iter 972 | Energy = 92.959391
# Iter 973 | Energy = 92.959391
# Iter 974 | Energy = 92.959391
# Iter 975 | Energy = 92.959391
# Iter 976 | Energy = 92.959391
# Iter 977 | Energy = 92.959391
# Iter 978 | Energy = 92.959391
# Iter 979 | Energy = 92.959391
# Iter 980 | Energy = 92.959391
# Iter 981 | Energy = 92.959391
# Iter 982 | Energy = 92.959391
# Iter 983 | Energy = 92.959391
# Iter 984 | Energy = 92.959391
# Iter 985 | Energy = 92.959391
# Iter 986 | Energy = 92.959391
# Iter 987 | Energy = 92.959391
# Iter 988 | Energy = 92.959391
# Iter 989 | Energy = 92.959391
# Iter 990 | Energy = 92.959391
# Iter 991 | Energy = 92.959391
# Iter 992 | Energy = 92.959391
# Iter 993 | Energy = 92.959391
# Iter 994 | Energy = 92.959391
# Iter 995 | Energy = 92.959391
# Iter 996 | Energy = 92.959391
# Iter 997 | Energy = 92.959391
# Iter 998 | Energy = 92.959391
# Iter 999 | Energy = 92.959391
# Iter 1000 | Energy = 92.959391

# %%
# -----------------------
# K-Means 聚合
# -----------------------
def fuse_to_super_knn(prev_nodes, prev_edges, k, layer_idx, max_iters=20, tol=1e-6, seed=0):
    positions = np.array([[n["position"]["x"], n["position"]["y"]] for n in prev_nodes], dtype=float)
    n = positions.shape[0]
    if k <= 0: k = 1
    k = min(k, n)
    rng = np.random.default_rng(seed)

    # k-means++ init
    centers = np.empty((k, 2), dtype=float)
    first = rng.integers(0, n)
    centers[0] = positions[first]
    closest_d2 = np.sum((positions - centers[0])**2, axis=1)
    for i in range(1, k):
        denom = float(closest_d2.sum()) + 1e-12
        probs = closest_d2 / denom
        idx = rng.choice(n, p=probs)
        centers[i] = positions[idx]
        d2_new = np.sum((positions - centers[i])**2, axis=1)
        closest_d2 = np.minimum(closest_d2, d2_new)

    # Lloyd iterations
    for _ in range(max_iters):
        d2 = ((positions[:, None, :] - centers[None, :, :]) ** 2).sum(axis=2)
        assign = np.argmin(d2, axis=1)
        moved = 0.0
        for ci in range(k):
            idxs = np.where(assign == ci)[0]
            if idxs.size == 0:
                far_idx = int(np.argmax(np.min(d2, axis=1)))
                new_c = positions[far_idx]
            else:
                new_c = positions[idxs].mean(axis=0)
            moved = max(moved, float(np.linalg.norm(new_c - centers[ci])))
            centers[ci] = new_c
        if moved < tol:
            break

    # final assign
    d2 = ((positions[:, None, :] - centers[None, :, :]) ** 2).sum(axis=2)
    assign = np.argmin(d2, axis=1)

    super_nodes, node_map = [], {}
    for ci in range(k):
        idxs = np.where(assign == ci)[0]
        if idxs.size == 0:
            continue
        pts = positions[idxs]
        mean_x, mean_y = pts.mean(axis=0)
        child_dims = [prev_nodes[i]["data"]["dim"] for i in idxs]
        dim_val = int(max(1, sum(child_dims)))
        nid = f"{ci}"
        super_nodes.append({
            "data": {"id": nid, "layer": layer_idx, "dim": dim_val},
            "position": {"x": float(mean_x), "y": float(mean_y)}
        })
        for i in idxs:
            node_map[prev_nodes[i]["data"]["id"]] = nid
    super_edges, seen = [], set()
    for e in prev_edges:
        u, v = e["data"]["source"], e["data"]["target"]
        if v != "prior":
            su, sv = node_map[u], node_map[v]
            if su != sv:
                eid = tuple(sorted((su, sv)))
                if eid not in seen:
                    super_edges.append({"data": {"source": su, "target": sv}})
                    seen.add(eid)
            elif su == sv:
                eid = tuple(sorted((su, su)))
                if eid not in seen:
                    super_edges.append({"data": {"source": su, "target": "prior"}})
                    seen.add(eid)

        elif v == "prior":
            eid = tuple(sorted((su, su)))
            if eid not in seen:
                super_edges.append({"data": {"source": su, "target": "prior"}})
                seen.add(eid)

    return super_nodes, super_edges, node_map

# %%
def build_super_graph(layers):
    """
    基于 layers[-2] 的 base graph, 和 layers[-1] 的 super 分组，构造 super graph。
    要求: layers[-2]["graph"] 已经是构建好的基图（含 unary/binary 因子）。
    layers[-1]["node_map"]: { base_node_id(str, 如 'b12') -> super_node_id(str) }
    """
    # ---------- 取出 base & super ----------
    base_graph = layers[-2]["graph"]
    super_nodes = layers[-1]["nodes"]
    super_edges = layers[-1]["edges"]
    node_map    = layers[-1]["node_map"]   # 'bN' -> 'sX_...'

    # base: id(int)->VariableNode，方便查 dofs 和 mu
    id2var = {vn.variableID: vn for vn in base_graph.var_nodes}

    # ---------- super_id -> [base_id(int)] ----------
    super_groups = {}
    for b_str, s_id in node_map.items():
        b_int = int(b_str)
        super_groups.setdefault(s_id, []).append(b_int)


    # ---------- 为每个 super 组建立 (start, dofs) 表 ----------
    # local_idx[sid][bid] = (start, dofs), total_dofs[sid] = sum(dofs)
    local_idx   = {}
    total_dofs  = {}
    for sid, group in super_groups.items():
        off = 0
        local_idx[sid] = {}
        for bid in group:
            d = id2var[bid].dofs
            local_idx[sid][bid] = (off, d)
            off += d
        total_dofs[sid] = off


    # ---------- 创建 super VariableNodes ----------
    fg = FactorGraph(nonlinear_factors=False, eta_damping=0)

    super_var_nodes = {}
    for i, sn in enumerate(super_nodes):
        sid = sn["data"]["id"]
        dofs = total_dofs.get(sid, 0)

        v = VariableNode(i, dofs=dofs)

        # === 叠加 base GT ===
        gt_vec = np.zeros(dofs)
        for bid, (st, d) in local_idx[sid].items():
            gt_base = getattr(id2var[bid], "GT", None)
            if gt_base is None or len(gt_base) != d:
                gt_base = np.zeros(d)
            gt_vec[st:st+d] = gt_base
        v.GT = gt_vec

        super_var_nodes[sid] = v
        fg.var_nodes.append(v)
    fg.n_var_nodes = len(fg.var_nodes)

    # ---------- 工具：拼接某组的 linpoint（用 base belief 均值） ----------
    def make_linpoint_for_group(sid):
        x = np.zeros(total_dofs[sid])
        for bid, (st, d) in local_idx[sid].items():
            mu = getattr(id2var[bid], "mu", None)
            if mu is None or len(mu) != d:
                mu = np.zeros(d)
            x[st:st+d] = mu
        return x

    # ---------- 3) super prior（组内 unary + 组内 binary） ----------
    def make_super_prior_factor(sid, base_factors):
        group = super_groups[sid]
        idx_map = local_idx[sid]
        ncols = total_dofs[sid]

        # 选出：所有变量都在组内的因子（unary 或 binary）
        in_group = []
        for f in base_factors:
            vids = [v.variableID for v in f.adj_var_nodes]
            if all(vid in group for vid in vids):
                in_group.append(f)

        def meas_fn_super_prior(x_super, *args):
            meas_fn = []
            for f in in_group:
                vids = [v.variableID for v in f.adj_var_nodes]
                # 拼本因子的局部 x
                x_loc_list = []
                for vid in vids:
                    st, d = idx_map[vid]
                    x_loc_list.append(x_super[st:st+d])
                x_loc = np.concatenate(x_loc_list) if x_loc_list else np.zeros(0)
                meas_fn.append(f.meas_fn(x_loc))
            return np.concatenate(meas_fn) if meas_fn else np.zeros(0)

        def jac_fn_super_prior(x_super, *args):
            Jrows = []
            for f in in_group:
                vids = [v.variableID for v in f.adj_var_nodes]
                # 构造本因子的局部 x，用于（潜在）非线性雅可比
                x_loc_list = []
                dims = []
                for vid in vids:
                    st, d = idx_map[vid]
                    dims.append(d)
                    x_loc_list.append(x_super[st:st+d])
                x_loc = np.concatenate(x_loc_list) if x_loc_list else np.zeros(0)

                Jloc = f.jac_fn(x_loc)
                # 将 Jloc 列块映射回 super 变量的列
                row = np.zeros((Jloc.shape[0], ncols))
                c0 = 0
                for vid, d in zip(vids, dims):
                    st, _ = idx_map[vid]
                    row[:, st:st+d] = Jloc[:, c0:c0+d]
                    c0 += d

                row *= f.gauss_noise_std
                
                Jrows.append(row)
            return np.vstack(Jrows) if Jrows else np.zeros((0, ncols))

        # z_super：拼各 base 因子的 z
        z_list = [f.measurement for f in in_group]
        z_super = np.concatenate(z_list) if z_list else np.zeros(0)

        return meas_fn_super_prior, jac_fn_super_prior, z_super

    # 为每个 super node 加 prior 因子
    for sid in super_groups.keys():
        meas_fn, jac_fn, z = make_super_prior_factor(sid, base_graph.factors)
        f = Factor(len(fg.factors), [super_var_nodes[sid]], z, 1, meas_fn, jac_fn)
        f.type = "super_prior"
        lin0 = make_linpoint_for_group(sid)
        f.compute_factor(linpoint=lin0, update_self=True)
        fg.factors.append(f)
        super_var_nodes[sid].adj_factors.append(f)

    # ---------- 4) super between（只取跨组 binary） ----------
    def make_super_between_factor(sidA, sidB, base_factors):
        groupA, groupB = super_groups[sidA], super_groups[sidB]
        idxA, idxB = local_idx[sidA], local_idx[sidB]
        nA, nB = total_dofs[sidA], total_dofs[sidB]

        cross = []
        for f in base_factors:
            vids = [v.variableID for v in f.adj_var_nodes]
            if len(vids) != 2:
                continue
            i, j = vids
            # 恰有一端在 A，一端在 B
            if (i in groupA and j in groupB) or (i in groupB and j in groupA):
                cross.append(f)

        def meas_fn_super_between(xAB, *args):
            xA, xB = xAB[:nA], xAB[nA:]
            meas_fn = []
            for f in cross:
                i, j = [v.variableID for v in f.adj_var_nodes]
                if i in groupA:
                    si, di = idxA[i]
                    sj, dj = idxB[j]
                    xi = xA[si:si+di]
                    xj = xB[sj:sj+dj]
                else:
                    si, di = idxB[i]
                    sj, dj = idxA[j]
                    xi = xB[si:si+di]
                    xj = xA[sj:sj+dj]
                x_loc = np.concatenate([xi, xj])
                meas_fn.append(f.meas_fn(x_loc))
            return np.concatenate(meas_fn) if meas_fn else np.zeros(0)

        def jac_fn_super_between(xAB, *args):
            xA, xB = xAB[:nA], xAB[nA:]
            Jrows = []
            for f in cross:
                i, j = [v.variableID for v in f.adj_var_nodes]
                if i in groupA:
                    si, di = idxA[i]
                    sj, dj = idxB[j]
                    xi = xA[si:si+di]
                    xj = xB[sj:sj+dj]
                    left_start, right_start = si, nA + sj
                else:
                    si, di = idxB[i]
                    sj, dj = idxA[j]
                    xi = xB[si:si+di]
                    xj = xA[sj:sj+dj]
                    left_start, right_start = nA + si, sj
                x_loc = np.concatenate([xi, xj])
                Jloc = f.jac_fn(x_loc)

                row = np.zeros((Jloc.shape[0], nA + nB))
                row[:, left_start:left_start+di]   = Jloc[:, :di]
                row[:, right_start:right_start+dj] = Jloc[:, di:di+dj]

                row *= f.gauss_noise_std
                Jrows.append(row)
            return np.vstack(Jrows) if Jrows else np.zeros((0, nA + nB))

        z_super = np.concatenate([f.measurement for f in cross]) if cross else np.zeros(0)
        return meas_fn_super_between, jac_fn_super_between, z_super

    for e in super_edges:
        u, v = e["data"]["source"], e["data"]["target"]
        if v == "prior":
            continue
        if (u not in super_groups) or (v not in super_groups):
            continue
        meas_fn, jac_fn, z = make_super_between_factor(u, v, base_graph.factors)
        f = Factor(len(fg.factors), [super_var_nodes[u], super_var_nodes[v]], z, 1, meas_fn, jac_fn)
        f.type = "super_between"
        lin0 = np.concatenate([make_linpoint_for_group(u), make_linpoint_for_group(v)])
        f.compute_factor(linpoint=lin0, update_self=True)
        fg.factors.append(f)
        super_var_nodes[u].adj_factors.append(f)
        super_var_nodes[v].adj_factors.append(f)

    fg.n_factor_nodes = len(fg.factors)
    return fg

# %%
N=50 
step=25
prob=0.1
radius=50 
prior_prop=0.1
prior_sigma=1.0
odom_sigma=1.0
layers = []


# -----------------------
# 初始化 & 边界
# -----------------------
def init_layers(N=100, step_size=25, loop_prob=0.05, loop_radius=50, prior_prop=0.0):
    base_nodes, base_edges = make_slam_like_graph(N, step_size, loop_prob, loop_radius, prior_prop)
    return [{"name": "base", "nodes": base_nodes, "edges": base_edges}]

layers = init_layers(N=N, step_size=step, loop_prob=prob, loop_radius=radius, prior_prop=prior_prop)
pair_idx = 0



# 构建 GBP 图
gbp_graph = build_noisy_pose_graph(layers[0]["nodes"], layers[0]["edges"],
                                    prior_sigma=prior_sigma,
                                    odom_sigma=odom_sigma
                                    )
layers[0]["graph"] = gbp_graph
opts=[{"label":"base","value":"base"}]


last = layers[-1]
super_layer_idx = 1

super_nodes, super_edges, node_map = fuse_to_super_knn(last["nodes"], last["edges"], 100, super_layer_idx)
layers.append({"name":f"super{1}", "nodes":super_nodes, "edges":super_edges, "node_map":node_map})
layers[-1]["graph"] = build_super_graph(layers)

# %%
basegraph = layers[-2]["graph"]
for it in range(1000):
    basegraph.synchronous_iteration()
    energy = basegraph.energy_map(include_priors=True, include_factors=True)
    print(f"Iter {it+1:03d} | Energy = {energy:.6f}")
# Out:
# Iter 001 | Energy = 163739.898888
# Iter 002 | Energy = 122366.424774
# Iter 003 | Energy = 68632.679324
# Iter 004 | Energy = 30268.782476
# Iter 005 | Energy = 4683.032578
# Iter 006 | Energy = 75.213648
# Iter 007 | Energy = 71.740489
# Iter 008 | Energy = 73.051697
# Iter 009 | Energy = 73.466360
# Iter 010 | Energy = 73.663792
# Iter 011 | Energy = 73.704659
# Iter 012 | Energy = 73.654451
# Iter 013 | Energy = 73.796440
# Iter 014 | Energy = 73.937365
# Iter 015 | Energy = 74.067799
# Iter 016 | Energy = 74.155944
# Iter 017 | Energy = 74.238390
# Iter 018 | Energy = 74.317149
# Iter 019 | Energy = 74.390269
# Iter 020 | Energy = 74.458260
# Iter 021 | Energy = 74.524035
# Iter 022 | Energy = 74.587093
# Iter 023 | Energy = 74.647505
# Iter 024 | Energy = 74.705375
# Iter 025 | Energy = 74.761465
# Iter 026 | Energy = 74.815631
# Iter 027 | Energy = 74.868047
# Iter 028 | Energy = 74.918671
# Iter 029 | Energy = 74.967615
# Iter 030 | Energy = 75.014962
# Iter 031 | Energy = 75.060747
# Iter 032 | Energy = 75.105041
# Iter 033 | Energy = 75.147882
# Iter 034 | Energy = 75.189321
# Iter 035 | Energy = 75.229401
# Iter 036 | Energy = 75.268167
# Iter 037 | Energy = 75.305662
# Iter 038 | Energy = 75.341925
# Iter 039 | Energy = 75.376995
# Iter 040 | Energy = 75.410912
# Iter 041 | Energy = 75.443711
# Iter 042 | Energy = 75.475429
# Iter 043 | Energy = 75.506100
# Iter 044 | Energy = 75.535758
# Iter 045 | Energy = 75.564436
# Iter 046 | Energy = 75.592165
# Iter 047 | Energy = 75.618975
# Iter 048 | Energy = 75.644898
# Iter 049 | Energy = 75.669960
# Iter 050 | Energy = 75.694191
# Iter 051 | Energy = 75.717617
# Iter 052 | Energy = 75.740265
# Iter 053 | Energy = 75.762159
# Iter 054 | Energy = 75.783325
# Iter 055 | Energy = 75.803787
# Iter 056 | Energy = 75.823566
# Iter 057 | Energy = 75.842687
# Iter 058 | Energy = 75.861169
# Iter 059 | Energy = 75.879035
# Iter 060 | Energy = 75.896305
# Iter 061 | Energy = 75.912997
# Iter 062 | Energy = 75.929132
# Iter 063 | Energy = 75.944728
# Iter 064 | Energy = 75.959801
# Iter 065 | Energy = 75.974371
# Iter 066 | Energy = 75.988452
# Iter 067 | Energy = 76.002063
# Iter 068 | Energy = 76.015217
# Iter 069 | Energy = 76.027930
# Iter 070 | Energy = 76.040217
# Iter 071 | Energy = 76.052092
# Iter 072 | Energy = 76.063569
# Iter 073 | Energy = 76.074661
# Iter 074 | Energy = 76.085380
# Iter 075 | Energy = 76.095739
# Iter 076 | Energy = 76.105751
# Iter 077 | Energy = 76.115426
# Iter 078 | Energy = 76.124776
# Iter 079 | Energy = 76.133811
# Iter 080 | Energy = 76.142543
# Iter 081 | Energy = 76.150981
# Iter 082 | Energy = 76.159136
# Iter 083 | Energy = 76.167016
# Iter 084 | Energy = 76.174631
# Iter 085 | Energy = 76.181989
# Iter 086 | Energy = 76.189100
# Iter 087 | Energy = 76.195971
# Iter 088 | Energy = 76.202611
# Iter 089 | Energy = 76.209027
# Iter 090 | Energy = 76.215227
# Iter 091 | Energy = 76.221218
# Iter 092 | Energy = 76.227008
# Iter 093 | Energy = 76.232602
# Iter 094 | Energy = 76.238007
# Iter 095 | Energy = 76.243231
# Iter 096 | Energy = 76.248278
# Iter 097 | Energy = 76.253154
# Iter 098 | Energy = 76.257867
# Iter 099 | Energy = 76.262420
# Iter 100 | Energy = 76.266820
# Iter 101 | Energy = 76.271071
# Iter 102 | Energy = 76.275179
# Iter 103 | Energy = 76.279148
# Iter 104 | Energy = 76.282983
# Iter 105 | Energy = 76.286689
# Iter 106 | Energy = 76.290270
# Iter 107 | Energy = 76.293729
# Iter 108 | Energy = 76.297072
# Iter 109 | Energy = 76.300302
# Iter 110 | Energy = 76.303423
# Iter 111 | Energy = 76.306439
# Iter 112 | Energy = 76.309352
# Iter 113 | Energy = 76.312167
# Iter 114 | Energy = 76.314888
# Iter 115 | Energy = 76.317516
# Iter 116 | Energy = 76.320055
# Iter 117 | Energy = 76.322509
# Iter 118 | Energy = 76.324879
# Iter 119 | Energy = 76.327170
# Iter 120 | Energy = 76.329383
# Iter 121 | Energy = 76.331521
# Iter 122 | Energy = 76.333587
# Iter 123 | Energy = 76.335583
# Iter 124 | Energy = 76.337512
# Iter 125 | Energy = 76.339375
# Iter 126 | Energy = 76.341176
# Iter 127 | Energy = 76.342916
# Iter 128 | Energy = 76.344596
# Iter 129 | Energy = 76.346220
# Iter 130 | Energy = 76.347789
# Iter 131 | Energy = 76.349305
# Iter 132 | Energy = 76.350770
# Iter 133 | Energy = 76.352185
# Iter 134 | Energy = 76.353552
# Iter 135 | Energy = 76.354873
# Iter 136 | Energy = 76.356150
# Iter 137 | Energy = 76.357383
# Iter 138 | Energy = 76.358575
# Iter 139 | Energy = 76.359726
# Iter 140 | Energy = 76.360838
# Iter 141 | Energy = 76.361913
# Iter 142 | Energy = 76.362951
# Iter 143 | Energy = 76.363954
# Iter 144 | Energy = 76.364923
# Iter 145 | Energy = 76.365860
# Iter 146 | Energy = 76.366764
# Iter 147 | Energy = 76.367638
# Iter 148 | Energy = 76.368483
# Iter 149 | Energy = 76.369299
# Iter 150 | Energy = 76.370087
# Iter 151 | Energy = 76.370849
# Iter 152 | Energy = 76.371585
# Iter 153 | Energy = 76.372296
# Iter 154 | Energy = 76.372983
# Iter 155 | Energy = 76.373646
# Iter 156 | Energy = 76.374288
# Iter 157 | Energy = 76.374907
# Iter 158 | Energy = 76.375506
# Iter 159 | Energy = 76.376084
# Iter 160 | Energy = 76.376643
# Iter 161 | Energy = 76.377183
# Iter 162 | Energy = 76.377704
# Iter 163 | Energy = 76.378208
# Iter 164 | Energy = 76.378695
# Iter 165 | Energy = 76.379165
# Iter 166 | Energy = 76.379620
# Iter 167 | Energy = 76.380059
# Iter 168 | Energy = 76.380483
# Iter 169 | Energy = 76.380893
# Iter 170 | Energy = 76.381289
# Iter 171 | Energy = 76.381671
# Iter 172 | Energy = 76.382041
# Iter 173 | Energy = 76.382398
# Iter 174 | Energy = 76.382743
# Iter 175 | Energy = 76.383076
# Iter 176 | Energy = 76.383399
# Iter 177 | Energy = 76.383710
# Iter 178 | Energy = 76.384010
# Iter 179 | Energy = 76.384301
# Iter 180 | Energy = 76.384581
# Iter 181 | Energy = 76.384853
# Iter 182 | Energy = 76.385114
# Iter 183 | Energy = 76.385368
# Iter 184 | Energy = 76.385612
# Iter 185 | Energy = 76.385848
# Iter 186 | Energy = 76.386077
# Iter 187 | Energy = 76.386297
# Iter 188 | Energy = 76.386510
# Iter 189 | Energy = 76.386716
# Iter 190 | Energy = 76.386915
# Iter 191 | Energy = 76.387107
# Iter 192 | Energy = 76.387293
# Iter 193 | Energy = 76.387472
# Iter 194 | Energy = 76.387645
# Iter 195 | Energy = 76.387813
# Iter 196 | Energy = 76.387974
# Iter 197 | Energy = 76.388131
# Iter 198 | Energy = 76.388282
# Iter 199 | Energy = 76.388427
# Iter 200 | Energy = 76.388568
# Iter 201 | Energy = 76.388704
# Iter 202 | Energy = 76.388836
# Iter 203 | Energy = 76.388963
# Iter 204 | Energy = 76.389086
# Iter 205 | Energy = 76.389205
# Iter 206 | Energy = 76.389319
# Iter 207 | Energy = 76.389430
# Iter 208 | Energy = 76.389537
# Iter 209 | Energy = 76.389640
# Iter 210 | Energy = 76.389740
# Iter 211 | Energy = 76.389837
# Iter 212 | Energy = 76.389930
# Iter 213 | Energy = 76.390020
# Iter 214 | Energy = 76.390107
# Iter 215 | Energy = 76.390191
# Iter 216 | Energy = 76.390272
# Iter 217 | Energy = 76.390351
# Iter 218 | Energy = 76.390426
# Iter 219 | Energy = 76.390500
# Iter 220 | Energy = 76.390570
# Iter 221 | Energy = 76.390639
# Iter 222 | Energy = 76.390705
# Iter 223 | Energy = 76.390769
# Iter 224 | Energy = 76.390830
# Iter 225 | Energy = 76.390890
# Iter 226 | Energy = 76.390947
# Iter 227 | Energy = 76.391003
# Iter 228 | Energy = 76.391057
# Iter 229 | Energy = 76.391109
# Iter 230 | Energy = 76.391159
# Iter 231 | Energy = 76.391207
# Iter 232 | Energy = 76.391254
# Iter 233 | Energy = 76.391299
# Iter 234 | Energy = 76.391343
# Iter 235 | Energy = 76.391385
# Iter 236 | Energy = 76.391426
# Iter 237 | Energy = 76.391465
# Iter 238 | Energy = 76.391504
# Iter 239 | Energy = 76.391540
# Iter 240 | Energy = 76.391576
# Iter 241 | Energy = 76.391610
# Iter 242 | Energy = 76.391643
# Iter 243 | Energy = 76.391675
# Iter 244 | Energy = 76.391706
# Iter 245 | Energy = 76.391736
# Iter 246 | Energy = 76.391765
# Iter 247 | Energy = 76.391793
# Iter 248 | Energy = 76.391820
# Iter 249 | Energy = 76.391846
# Iter 250 | Energy = 76.391871
# Iter 251 | Energy = 76.391896
# Iter 252 | Energy = 76.391919
# Iter 253 | Energy = 76.391942
# Iter 254 | Energy = 76.391964
# Iter 255 | Energy = 76.391985
# Iter 256 | Energy = 76.392005
# Iter 257 | Energy = 76.392025
# Iter 258 | Energy = 76.392044
# Iter 259 | Energy = 76.392063
# Iter 260 | Energy = 76.392081
# Iter 261 | Energy = 76.392098
# Iter 262 | Energy = 76.392115
# Iter 263 | Energy = 76.392131
# Iter 264 | Energy = 76.392146
# Iter 265 | Energy = 76.392161
# Iter 266 | Energy = 76.392176
# Iter 267 | Energy = 76.392190
# Iter 268 | Energy = 76.392203
# Iter 269 | Energy = 76.392216
# Iter 270 | Energy = 76.392229
# Iter 271 | Energy = 76.392241
# Iter 272 | Energy = 76.392253
# Iter 273 | Energy = 76.392264
# Iter 274 | Energy = 76.392275
# Iter 275 | Energy = 76.392286
# Iter 276 | Energy = 76.392296
# Iter 277 | Energy = 76.392306
# Iter 278 | Energy = 76.392316
# Iter 279 | Energy = 76.392325
# Iter 280 | Energy = 76.392334
# Iter 281 | Energy = 76.392343
# Iter 282 | Energy = 76.392351
# Iter 283 | Energy = 76.392359
# Iter 284 | Energy = 76.392367
# Iter 285 | Energy = 76.392375
# Iter 286 | Energy = 76.392382
# Iter 287 | Energy = 76.392389
# Iter 288 | Energy = 76.392396
# Iter 289 | Energy = 76.392402
# Iter 290 | Energy = 76.392409
# Iter 291 | Energy = 76.392415
# Iter 292 | Energy = 76.392421
# Iter 293 | Energy = 76.392426
# Iter 294 | Energy = 76.392432
# Iter 295 | Energy = 76.392437
# Iter 296 | Energy = 76.392443
# Iter 297 | Energy = 76.392447
# Iter 298 | Energy = 76.392452
# Iter 299 | Energy = 76.392457
# Iter 300 | Energy = 76.392461
# Iter 301 | Energy = 76.392466
# Iter 302 | Energy = 76.392470
# Iter 303 | Energy = 76.392474
# Iter 304 | Energy = 76.392478
# Iter 305 | Energy = 76.392482
# Iter 306 | Energy = 76.392485
# Iter 307 | Energy = 76.392489
# Iter 308 | Energy = 76.392492
# Iter 309 | Energy = 76.392496
# Iter 310 | Energy = 76.392499
# Iter 311 | Energy = 76.392502
# Iter 312 | Energy = 76.392505
# Iter 313 | Energy = 76.392508
# Iter 314 | Energy = 76.392511
# Iter 315 | Energy = 76.392513
# Iter 316 | Energy = 76.392516
# Iter 317 | Energy = 76.392518
# Iter 318 | Energy = 76.392521
# Iter 319 | Energy = 76.392523
# Iter 320 | Energy = 76.392525
# Iter 321 | Energy = 76.392528
# Iter 322 | Energy = 76.392530
# Iter 323 | Energy = 76.392532
# Iter 324 | Energy = 76.392534
# Iter 325 | Energy = 76.392536
# Iter 326 | Energy = 76.392537
# Iter 327 | Energy = 76.392539
# Iter 328 | Energy = 76.392541
# Iter 329 | Energy = 76.392543
# Iter 330 | Energy = 76.392544
# Iter 331 | Energy = 76.392546
# Iter 332 | Energy = 76.392547
# Iter 333 | Energy = 76.392549
# Iter 334 | Energy = 76.392550
# Iter 335 | Energy = 76.392551
# Iter 336 | Energy = 76.392553
# Iter 337 | Energy = 76.392554
# Iter 338 | Energy = 76.392555
# Iter 339 | Energy = 76.392556
# Iter 340 | Energy = 76.392557
# Iter 341 | Energy = 76.392559
# Iter 342 | Energy = 76.392560
# Iter 343 | Energy = 76.392561
# Iter 344 | Energy = 76.392562
# Iter 345 | Energy = 76.392563
# Iter 346 | Energy = 76.392564
# Iter 347 | Energy = 76.392564
# Iter 348 | Energy = 76.392565
# Iter 349 | Energy = 76.392566
# Iter 350 | Energy = 76.392567
# Iter 351 | Energy = 76.392568
# Iter 352 | Energy = 76.392568
# Iter 353 | Energy = 76.392569
# Iter 354 | Energy = 76.392570
# Iter 355 | Energy = 76.392571
# Iter 356 | Energy = 76.392571
# Iter 357 | Energy = 76.392572
# Iter 358 | Energy = 76.392572
# Iter 359 | Energy = 76.392573
# Iter 360 | Energy = 76.392574
# Iter 361 | Energy = 76.392574
# Iter 362 | Energy = 76.392575
# Iter 363 | Energy = 76.392575
# Iter 364 | Energy = 76.392576
# Iter 365 | Energy = 76.392576
# Iter 366 | Energy = 76.392577
# Iter 367 | Energy = 76.392577
# Iter 368 | Energy = 76.392578
# Iter 369 | Energy = 76.392578
# Iter 370 | Energy = 76.392578
# Iter 371 | Energy = 76.392579
# Iter 372 | Energy = 76.392579
# Iter 373 | Energy = 76.392579
# Iter 374 | Energy = 76.392580
# Iter 375 | Energy = 76.392580
# Iter 376 | Energy = 76.392580
# Iter 377 | Energy = 76.392581
# Iter 378 | Energy = 76.392581
# Iter 379 | Energy = 76.392581
# Iter 380 | Energy = 76.392582
# Iter 381 | Energy = 76.392582
# Iter 382 | Energy = 76.392582
# Iter 383 | Energy = 76.392582
# Iter 384 | Energy = 76.392583
# Iter 385 | Energy = 76.392583
# Iter 386 | Energy = 76.392583
# Iter 387 | Energy = 76.392583
# Iter 388 | Energy = 76.392584
# Iter 389 | Energy = 76.392584
# Iter 390 | Energy = 76.392584
# Iter 391 | Energy = 76.392584
# Iter 392 | Energy = 76.392584
# Iter 393 | Energy = 76.392585
# Iter 394 | Energy = 76.392585
# Iter 395 | Energy = 76.392585
# Iter 396 | Energy = 76.392585
# Iter 397 | Energy = 76.392585
# Iter 398 | Energy = 76.392585
# Iter 399 | Energy = 76.392586
# Iter 400 | Energy = 76.392586
# Iter 401 | Energy = 76.392586
# Iter 402 | Energy = 76.392586
# Iter 403 | Energy = 76.392586
# Iter 404 | Energy = 76.392586
# Iter 405 | Energy = 76.392586
# Iter 406 | Energy = 76.392587
# Iter 407 | Energy = 76.392587
# Iter 408 | Energy = 76.392587
# Iter 409 | Energy = 76.392587
# Iter 410 | Energy = 76.392587
# Iter 411 | Energy = 76.392587
# Iter 412 | Energy = 76.392587
# Iter 413 | Energy = 76.392587
# Iter 414 | Energy = 76.392587
# Iter 415 | Energy = 76.392587
# Iter 416 | Energy = 76.392587
# Iter 417 | Energy = 76.392588
# Iter 418 | Energy = 76.392588
# Iter 419 | Energy = 76.392588
# Iter 420 | Energy = 76.392588
# Iter 421 | Energy = 76.392588
# Iter 422 | Energy = 76.392588
# Iter 423 | Energy = 76.392588
# Iter 424 | Energy = 76.392588
# Iter 425 | Energy = 76.392588
# Iter 426 | Energy = 76.392588
# Iter 427 | Energy = 76.392588
# Iter 428 | Energy = 76.392588
# Iter 429 | Energy = 76.392588
# Iter 430 | Energy = 76.392588
# Iter 431 | Energy = 76.392588
# Iter 432 | Energy = 76.392588
# Iter 433 | Energy = 76.392589
# Iter 434 | Energy = 76.392589
# Iter 435 | Energy = 76.392589
# Iter 436 | Energy = 76.392589
# Iter 437 | Energy = 76.392589
# Iter 438 | Energy = 76.392589
# Iter 439 | Energy = 76.392589
# Iter 440 | Energy = 76.392589
# Iter 441 | Energy = 76.392589
# Iter 442 | Energy = 76.392589
# Iter 443 | Energy = 76.392589
# Iter 444 | Energy = 76.392589
# Iter 445 | Energy = 76.392589
# Iter 446 | Energy = 76.392589
# Iter 447 | Energy = 76.392589
# Iter 448 | Energy = 76.392589
# Iter 449 | Energy = 76.392589
# Iter 450 | Energy = 76.392589
# Iter 451 | Energy = 76.392589
# Iter 452 | Energy = 76.392589
# Iter 453 | Energy = 76.392589
# Iter 454 | Energy = 76.392589
# Iter 455 | Energy = 76.392589
# Iter 456 | Energy = 76.392589
# Iter 457 | Energy = 76.392589
# Iter 458 | Energy = 76.392589
# Iter 459 | Energy = 76.392589
# Iter 460 | Energy = 76.392589
# Iter 461 | Energy = 76.392589
# Iter 462 | Energy = 76.392589
# Iter 463 | Energy = 76.392589
# Iter 464 | Energy = 76.392589
# Iter 465 | Energy = 76.392589
# Iter 466 | Energy = 76.392589
# Iter 467 | Energy = 76.392589
# Iter 468 | Energy = 76.392589
# Iter 469 | Energy = 76.392589
# Iter 470 | Energy = 76.392589
# Iter 471 | Energy = 76.392590
# Iter 472 | Energy = 76.392590
# Iter 473 | Energy = 76.392590
# Iter 474 | Energy = 76.392590
# Iter 475 | Energy = 76.392590
# Iter 476 | Energy = 76.392590
# Iter 477 | Energy = 76.392590
# Iter 478 | Energy = 76.392590
# Iter 479 | Energy = 76.392590
# Iter 480 | Energy = 76.392590
# Iter 481 | Energy = 76.392590
# Iter 482 | Energy = 76.392590
# Iter 483 | Energy = 76.392590
# Iter 484 | Energy = 76.392590
# Iter 485 | Energy = 76.392590
# Iter 486 | Energy = 76.392590
# Iter 487 | Energy = 76.392590
# Iter 488 | Energy = 76.392590
# Iter 489 | Energy = 76.392590
# Iter 490 | Energy = 76.392590
# Iter 491 | Energy = 76.392590
# Iter 492 | Energy = 76.392590
# Iter 493 | Energy = 76.392590
# Iter 494 | Energy = 76.392590
# Iter 495 | Energy = 76.392590
# Iter 496 | Energy = 76.392590
# Iter 497 | Energy = 76.392590
# Iter 498 | Energy = 76.392590
# Iter 499 | Energy = 76.392590
# Iter 500 | Energy = 76.392590
# Iter 501 | Energy = 76.392590
# Iter 502 | Energy = 76.392590
# Iter 503 | Energy = 76.392590
# Iter 504 | Energy = 76.392590
# Iter 505 | Energy = 76.392590
# Iter 506 | Energy = 76.392590
# Iter 507 | Energy = 76.392590
# Iter 508 | Energy = 76.392590
# Iter 509 | Energy = 76.392590
# Iter 510 | Energy = 76.392590
# Iter 511 | Energy = 76.392590
# Iter 512 | Energy = 76.392590
# Iter 513 | Energy = 76.392590
# Iter 514 | Energy = 76.392590
# Iter 515 | Energy = 76.392590
# Iter 516 | Energy = 76.392590
# Iter 517 | Energy = 76.392590
# Iter 518 | Energy = 76.392590
# Iter 519 | Energy = 76.392590
# Iter 520 | Energy = 76.392590
# Iter 521 | Energy = 76.392590
# Iter 522 | Energy = 76.392590
# Iter 523 | Energy = 76.392590
# Iter 524 | Energy = 76.392590
# Iter 525 | Energy = 76.392590
# Iter 526 | Energy = 76.392590
# Iter 527 | Energy = 76.392590
# Iter 528 | Energy = 76.392590
# Iter 529 | Energy = 76.392590
# Iter 530 | Energy = 76.392590
# Iter 531 | Energy = 76.392590
# Iter 532 | Energy = 76.392590
# Iter 533 | Energy = 76.392590
# Iter 534 | Energy = 76.392590
# Iter 535 | Energy = 76.392590
# Iter 536 | Energy = 76.392590
# Iter 537 | Energy = 76.392590
# Iter 538 | Energy = 76.392590
# Iter 539 | Energy = 76.392590
# Iter 540 | Energy = 76.392590
# Iter 541 | Energy = 76.392590
# Iter 542 | Energy = 76.392590
# Iter 543 | Energy = 76.392590
# Iter 544 | Energy = 76.392590
# Iter 545 | Energy = 76.392590
# Iter 546 | Energy = 76.392590
# Iter 547 | Energy = 76.392590
# Iter 548 | Energy = 76.392590
# Iter 549 | Energy = 76.392590
# Iter 550 | Energy = 76.392590
# Iter 551 | Energy = 76.392590
# Iter 552 | Energy = 76.392590
# Iter 553 | Energy = 76.392590
# Iter 554 | Energy = 76.392590
# Iter 555 | Energy = 76.392590
# Iter 556 | Energy = 76.392590
# Iter 557 | Energy = 76.392590
# Iter 558 | Energy = 76.392590
# Iter 559 | Energy = 76.392590
# Iter 560 | Energy = 76.392590
# Iter 561 | Energy = 76.392590
# Iter 562 | Energy = 76.392590
# Iter 563 | Energy = 76.392590
# Iter 564 | Energy = 76.392590
# Iter 565 | Energy = 76.392590
# Iter 566 | Energy = 76.392590
# Iter 567 | Energy = 76.392590
# Iter 568 | Energy = 76.392590
# Iter 569 | Energy = 76.392590
# Iter 570 | Energy = 76.392590
# Iter 571 | Energy = 76.392590
# Iter 572 | Energy = 76.392590
# Iter 573 | Energy = 76.392590
# Iter 574 | Energy = 76.392590
# Iter 575 | Energy = 76.392590
# Iter 576 | Energy = 76.392590
# Iter 577 | Energy = 76.392590
# Iter 578 | Energy = 76.392590
# Iter 579 | Energy = 76.392590
# Iter 580 | Energy = 76.392590
# Iter 581 | Energy = 76.392590
# Iter 582 | Energy = 76.392590
# Iter 583 | Energy = 76.392590
# Iter 584 | Energy = 76.392590
# Iter 585 | Energy = 76.392590
# Iter 586 | Energy = 76.392590
# Iter 587 | Energy = 76.392590
# Iter 588 | Energy = 76.392590
# Iter 589 | Energy = 76.392590
# Iter 590 | Energy = 76.392590
# Iter 591 | Energy = 76.392590
# Iter 592 | Energy = 76.392590
# Iter 593 | Energy = 76.392590
# Iter 594 | Energy = 76.392590
# Iter 595 | Energy = 76.392590
# Iter 596 | Energy = 76.392590
# Iter 597 | Energy = 76.392590
# Iter 598 | Energy = 76.392590
# Iter 599 | Energy = 76.392590
# Iter 600 | Energy = 76.392590
# Iter 601 | Energy = 76.392590
# Iter 602 | Energy = 76.392590
# Iter 603 | Energy = 76.392590
# Iter 604 | Energy = 76.392590
# Iter 605 | Energy = 76.392590
# Iter 606 | Energy = 76.392590
# Iter 607 | Energy = 76.392590
# Iter 608 | Energy = 76.392590
# Iter 609 | Energy = 76.392590
# Iter 610 | Energy = 76.392590
# Iter 611 | Energy = 76.392590
# Iter 612 | Energy = 76.392590
# Iter 613 | Energy = 76.392590
# Iter 614 | Energy = 76.392590
# Iter 615 | Energy = 76.392590
# Iter 616 | Energy = 76.392590
# Iter 617 | Energy = 76.392590
# Iter 618 | Energy = 76.392590
# Iter 619 | Energy = 76.392590
# Iter 620 | Energy = 76.392590
# Iter 621 | Energy = 76.392590
# Iter 622 | Energy = 76.392590
# Iter 623 | Energy = 76.392590
# Iter 624 | Energy = 76.392590
# Iter 625 | Energy = 76.392590
# Iter 626 | Energy = 76.392590
# Iter 627 | Energy = 76.392590
# Iter 628 | Energy = 76.392590
# Iter 629 | Energy = 76.392590
# Iter 630 | Energy = 76.392590
# Iter 631 | Energy = 76.392590
# Iter 632 | Energy = 76.392590
# Iter 633 | Energy = 76.392590
# Iter 634 | Energy = 76.392590
# Iter 635 | Energy = 76.392590
# Iter 636 | Energy = 76.392590
# Iter 637 | Energy = 76.392590
# Iter 638 | Energy = 76.392590
# Iter 639 | Energy = 76.392590
# Iter 640 | Energy = 76.392590
# Iter 641 | Energy = 76.392590
# Iter 642 | Energy = 76.392590
# Iter 643 | Energy = 76.392590
# Iter 644 | Energy = 76.392590
# Iter 645 | Energy = 76.392590
# Iter 646 | Energy = 76.392590
# Iter 647 | Energy = 76.392590
# Iter 648 | Energy = 76.392590
# Iter 649 | Energy = 76.392590
# Iter 650 | Energy = 76.392590
# Iter 651 | Energy = 76.392590
# Iter 652 | Energy = 76.392590
# Iter 653 | Energy = 76.392590
# Iter 654 | Energy = 76.392590
# Iter 655 | Energy = 76.392590
# Iter 656 | Energy = 76.392590
# Iter 657 | Energy = 76.392590
# Iter 658 | Energy = 76.392590
# Iter 659 | Energy = 76.392590
# Iter 660 | Energy = 76.392590
# Iter 661 | Energy = 76.392590
# Iter 662 | Energy = 76.392590
# Iter 663 | Energy = 76.392590
# Iter 664 | Energy = 76.392590
# Iter 665 | Energy = 76.392590
# Iter 666 | Energy = 76.392590
# Iter 667 | Energy = 76.392590
# Iter 668 | Energy = 76.392590
# Iter 669 | Energy = 76.392590
# Iter 670 | Energy = 76.392590
# Iter 671 | Energy = 76.392590
# Iter 672 | Energy = 76.392590
# Iter 673 | Energy = 76.392590
# Iter 674 | Energy = 76.392590
# Iter 675 | Energy = 76.392590
# Iter 676 | Energy = 76.392590
# Iter 677 | Energy = 76.392590
# Iter 678 | Energy = 76.392590
# Iter 679 | Energy = 76.392590
# Iter 680 | Energy = 76.392590
# Iter 681 | Energy = 76.392590
# Iter 682 | Energy = 76.392590
# Iter 683 | Energy = 76.392590
# Iter 684 | Energy = 76.392590
# Iter 685 | Energy = 76.392590
# Iter 686 | Energy = 76.392590
# Iter 687 | Energy = 76.392590
# Iter 688 | Energy = 76.392590
# Iter 689 | Energy = 76.392590
# Iter 690 | Energy = 76.392590
# Iter 691 | Energy = 76.392590
# Iter 692 | Energy = 76.392590
# Iter 693 | Energy = 76.392590
# Iter 694 | Energy = 76.392590
# Iter 695 | Energy = 76.392590
# Iter 696 | Energy = 76.392590
# Iter 697 | Energy = 76.392590
# Iter 698 | Energy = 76.392590
# Iter 699 | Energy = 76.392590
# Iter 700 | Energy = 76.392590
# Iter 701 | Energy = 76.392590
# Iter 702 | Energy = 76.392590
# Iter 703 | Energy = 76.392590
# Iter 704 | Energy = 76.392590
# Iter 705 | Energy = 76.392590
# Iter 706 | Energy = 76.392590
# Iter 707 | Energy = 76.392590
# Iter 708 | Energy = 76.392590
# Iter 709 | Energy = 76.392590
# Iter 710 | Energy = 76.392590
# Iter 711 | Energy = 76.392590
# Iter 712 | Energy = 76.392590
# Iter 713 | Energy = 76.392590
# Iter 714 | Energy = 76.392590
# Iter 715 | Energy = 76.392590
# Iter 716 | Energy = 76.392590
# Iter 717 | Energy = 76.392590
# Iter 718 | Energy = 76.392590
# Iter 719 | Energy = 76.392590
# Iter 720 | Energy = 76.392590
# Iter 721 | Energy = 76.392590
# Iter 722 | Energy = 76.392590
# Iter 723 | Energy = 76.392590
# Iter 724 | Energy = 76.392590
# Iter 725 | Energy = 76.392590
# Iter 726 | Energy = 76.392590
# Iter 727 | Energy = 76.392590
# Iter 728 | Energy = 76.392590
# Iter 729 | Energy = 76.392590
# Iter 730 | Energy = 76.392590
# Iter 731 | Energy = 76.392590
# Iter 732 | Energy = 76.392590
# Iter 733 | Energy = 76.392590
# Iter 734 | Energy = 76.392590
# Iter 735 | Energy = 76.392590
# Iter 736 | Energy = 76.392590
# Iter 737 | Energy = 76.392590
# Iter 738 | Energy = 76.392590
# Iter 739 | Energy = 76.392590
# Iter 740 | Energy = 76.392590
# Iter 741 | Energy = 76.392590
# Iter 742 | Energy = 76.392590
# Iter 743 | Energy = 76.392590
# Iter 744 | Energy = 76.392590
# Iter 745 | Energy = 76.392590
# Iter 746 | Energy = 76.392590
# Iter 747 | Energy = 76.392590
# Iter 748 | Energy = 76.392590
# Iter 749 | Energy = 76.392590
# Iter 750 | Energy = 76.392590
# Iter 751 | Energy = 76.392590
# Iter 752 | Energy = 76.392590
# Iter 753 | Energy = 76.392590
# Iter 754 | Energy = 76.392590
# Iter 755 | Energy = 76.392590
# Iter 756 | Energy = 76.392590
# Iter 757 | Energy = 76.392590
# Iter 758 | Energy = 76.392590
# Iter 759 | Energy = 76.392590
# Iter 760 | Energy = 76.392590
# Iter 761 | Energy = 76.392590
# Iter 762 | Energy = 76.392590
# Iter 763 | Energy = 76.392590
# Iter 764 | Energy = 76.392590
# Iter 765 | Energy = 76.392590
# Iter 766 | Energy = 76.392590
# Iter 767 | Energy = 76.392590
# Iter 768 | Energy = 76.392590
# Iter 769 | Energy = 76.392590
# Iter 770 | Energy = 76.392590
# Iter 771 | Energy = 76.392590
# Iter 772 | Energy = 76.392590
# Iter 773 | Energy = 76.392590
# Iter 774 | Energy = 76.392590
# Iter 775 | Energy = 76.392590
# Iter 776 | Energy = 76.392590
# Iter 777 | Energy = 76.392590
# Iter 778 | Energy = 76.392590
# Iter 779 | Energy = 76.392590
# Iter 780 | Energy = 76.392590
# Iter 781 | Energy = 76.392590
# Iter 782 | Energy = 76.392590
# Iter 783 | Energy = 76.392590
# Iter 784 | Energy = 76.392590
# Iter 785 | Energy = 76.392590
# Iter 786 | Energy = 76.392590
# Iter 787 | Energy = 76.392590
# Iter 788 | Energy = 76.392590
# Iter 789 | Energy = 76.392590
# Iter 790 | Energy = 76.392590
# Iter 791 | Energy = 76.392590
# Iter 792 | Energy = 76.392590
# Iter 793 | Energy = 76.392590
# Iter 794 | Energy = 76.392590
# Iter 795 | Energy = 76.392590
# Iter 796 | Energy = 76.392590
# Iter 797 | Energy = 76.392590
# Iter 798 | Energy = 76.392590
# Iter 799 | Energy = 76.392590
# Iter 800 | Energy = 76.392590
# Iter 801 | Energy = 76.392590
# Iter 802 | Energy = 76.392590
# Iter 803 | Energy = 76.392590
# Iter 804 | Energy = 76.392590
# Iter 805 | Energy = 76.392590
# Iter 806 | Energy = 76.392590
# Iter 807 | Energy = 76.392590
# Iter 808 | Energy = 76.392590
# Iter 809 | Energy = 76.392590
# Iter 810 | Energy = 76.392590
# Iter 811 | Energy = 76.392590
# Iter 812 | Energy = 76.392590
# Iter 813 | Energy = 76.392590
# Iter 814 | Energy = 76.392590
# Iter 815 | Energy = 76.392590
# Iter 816 | Energy = 76.392590
# Iter 817 | Energy = 76.392590
# Iter 818 | Energy = 76.392590
# Iter 819 | Energy = 76.392590
# Iter 820 | Energy = 76.392590
# Iter 821 | Energy = 76.392590
# Iter 822 | Energy = 76.392590
# Iter 823 | Energy = 76.392590
# Iter 824 | Energy = 76.392590
# Iter 825 | Energy = 76.392590
# Iter 826 | Energy = 76.392590
# Iter 827 | Energy = 76.392590
# Iter 828 | Energy = 76.392590
# Iter 829 | Energy = 76.392590
# Iter 830 | Energy = 76.392590
# Iter 831 | Energy = 76.392590
# Iter 832 | Energy = 76.392590
# Iter 833 | Energy = 76.392590
# Iter 834 | Energy = 76.392590
# Iter 835 | Energy = 76.392590
# Iter 836 | Energy = 76.392590
# Iter 837 | Energy = 76.392590
# Iter 838 | Energy = 76.392590
# Iter 839 | Energy = 76.392590
# Iter 840 | Energy = 76.392590
# Iter 841 | Energy = 76.392590
# Iter 842 | Energy = 76.392590
# Iter 843 | Energy = 76.392590
# Iter 844 | Energy = 76.392590
# Iter 845 | Energy = 76.392590
# Iter 846 | Energy = 76.392590
# Iter 847 | Energy = 76.392590
# Iter 848 | Energy = 76.392590
# Iter 849 | Energy = 76.392590
# Iter 850 | Energy = 76.392590
# Iter 851 | Energy = 76.392590
# Iter 852 | Energy = 76.392590
# Iter 853 | Energy = 76.392590
# Iter 854 | Energy = 76.392590
# Iter 855 | Energy = 76.392590
# Iter 856 | Energy = 76.392590
# Iter 857 | Energy = 76.392590
# Iter 858 | Energy = 76.392590
# Iter 859 | Energy = 76.392590
# Iter 860 | Energy = 76.392590
# Iter 861 | Energy = 76.392590
# Iter 862 | Energy = 76.392590
# Iter 863 | Energy = 76.392590
# Iter 864 | Energy = 76.392590
# Iter 865 | Energy = 76.392590
# Iter 866 | Energy = 76.392590
# Iter 867 | Energy = 76.392590
# Iter 868 | Energy = 76.392590
# Iter 869 | Energy = 76.392590
# Iter 870 | Energy = 76.392590
# Iter 871 | Energy = 76.392590
# Iter 872 | Energy = 76.392590
# Iter 873 | Energy = 76.392590
# Iter 874 | Energy = 76.392590
# Iter 875 | Energy = 76.392590
# Iter 876 | Energy = 76.392590
# Iter 877 | Energy = 76.392590
# Iter 878 | Energy = 76.392590
# Iter 879 | Energy = 76.392590
# Iter 880 | Energy = 76.392590
# Iter 881 | Energy = 76.392590
# Iter 882 | Energy = 76.392590
# Iter 883 | Energy = 76.392590
# Iter 884 | Energy = 76.392590
# Iter 885 | Energy = 76.392590
# Iter 886 | Energy = 76.392590
# Iter 887 | Energy = 76.392590
# Iter 888 | Energy = 76.392590
# Iter 889 | Energy = 76.392590
# Iter 890 | Energy = 76.392590
# Iter 891 | Energy = 76.392590
# Iter 892 | Energy = 76.392590
# Iter 893 | Energy = 76.392590
# Iter 894 | Energy = 76.392590
# Iter 895 | Energy = 76.392590
# Iter 896 | Energy = 76.392590
# Iter 897 | Energy = 76.392590
# Iter 898 | Energy = 76.392590
# Iter 899 | Energy = 76.392590
# Iter 900 | Energy = 76.392590
# Iter 901 | Energy = 76.392590
# Iter 902 | Energy = 76.392590
# Iter 903 | Energy = 76.392590
# Iter 904 | Energy = 76.392590
# Iter 905 | Energy = 76.392590
# Iter 906 | Energy = 76.392590
# Iter 907 | Energy = 76.392590
# Iter 908 | Energy = 76.392590
# Iter 909 | Energy = 76.392590
# Iter 910 | Energy = 76.392590
# Iter 911 | Energy = 76.392590
# Iter 912 | Energy = 76.392590
# Iter 913 | Energy = 76.392590
# Iter 914 | Energy = 76.392590
# Iter 915 | Energy = 76.392590
# Iter 916 | Energy = 76.392590
# Iter 917 | Energy = 76.392590
# Iter 918 | Energy = 76.392590
# Iter 919 | Energy = 76.392590
# Iter 920 | Energy = 76.392590
# Iter 921 | Energy = 76.392590
# Iter 922 | Energy = 76.392590
# Iter 923 | Energy = 76.392590
# Iter 924 | Energy = 76.392590
# Iter 925 | Energy = 76.392590
# Iter 926 | Energy = 76.392590
# Iter 927 | Energy = 76.392590
# Iter 928 | Energy = 76.392590
# Iter 929 | Energy = 76.392590
# Iter 930 | Energy = 76.392590
# Iter 931 | Energy = 76.392590
# Iter 932 | Energy = 76.392590
# Iter 933 | Energy = 76.392590
# Iter 934 | Energy = 76.392590
# Iter 935 | Energy = 76.392590
# Iter 936 | Energy = 76.392590
# Iter 937 | Energy = 76.392590
# Iter 938 | Energy = 76.392590
# Iter 939 | Energy = 76.392590
# Iter 940 | Energy = 76.392590
# Iter 941 | Energy = 76.392590
# Iter 942 | Energy = 76.392590
# Iter 943 | Energy = 76.392590
# Iter 944 | Energy = 76.392590
# Iter 945 | Energy = 76.392590
# Iter 946 | Energy = 76.392590
# Iter 947 | Energy = 76.392590
# Iter 948 | Energy = 76.392590
# Iter 949 | Energy = 76.392590
# Iter 950 | Energy = 76.392590
# Iter 951 | Energy = 76.392590
# Iter 952 | Energy = 76.392590
# Iter 953 | Energy = 76.392590
# Iter 954 | Energy = 76.392590
# Iter 955 | Energy = 76.392590
# Iter 956 | Energy = 76.392590
# Iter 957 | Energy = 76.392590
# Iter 958 | Energy = 76.392590
# Iter 959 | Energy = 76.392590
# Iter 960 | Energy = 76.392590
# Iter 961 | Energy = 76.392590
# Iter 962 | Energy = 76.392590
# Iter 963 | Energy = 76.392590
# Iter 964 | Energy = 76.392590
# Iter 965 | Energy = 76.392590
# Iter 966 | Energy = 76.392590
# Iter 967 | Energy = 76.392590
# Iter 968 | Energy = 76.392590
# Iter 969 | Energy = 76.392590
# Iter 970 | Energy = 76.392590
# Iter 971 | Energy = 76.392590
# Iter 972 | Energy = 76.392590
# Iter 973 | Energy = 76.392590
# Iter 974 | Energy = 76.392590
# Iter 975 | Energy = 76.392590
# Iter 976 | Energy = 76.392590
# Iter 977 | Energy = 76.392590
# Iter 978 | Energy = 76.392590
# Iter 979 | Energy = 76.392590
# Iter 980 | Energy = 76.392590
# Iter 981 | Energy = 76.392590
# Iter 982 | Energy = 76.392590
# Iter 983 | Energy = 76.392590
# Iter 984 | Energy = 76.392590
# Iter 985 | Energy = 76.392590
# Iter 986 | Energy = 76.392590
# Iter 987 | Energy = 76.392590
# Iter 988 | Energy = 76.392590
# Iter 989 | Energy = 76.392590
# Iter 990 | Energy = 76.392590
# Iter 991 | Energy = 76.392590
# Iter 992 | Energy = 76.392590
# Iter 993 | Energy = 76.392590
# Iter 994 | Energy = 76.392590
# Iter 995 | Energy = 76.392590
# Iter 996 | Energy = 76.392590
# Iter 997 | Energy = 76.392590
# Iter 998 | Energy = 76.392590
# Iter 999 | Energy = 76.392590
# Iter 1000 | Energy = 76.392590

# %%
supergraph = layers[-1]["graph"]
for it in range(1000):
    supergraph.synchronous_iteration()
    energy = supergraph.energy_map(include_priors=True, include_factors=True)
    print(f"Iter {it+1:03d} | Energy = {energy:.6f}")
# Out:
# Iter 001 | Energy = nan
# Iter 002 | Energy = nan
# Iter 003 | Energy = nan
# Iter 004 | Energy = nan
# Iter 005 | Energy = nan
# Iter 006 | Energy = 75.213670
# Iter 007 | Energy = 71.740510
# Iter 008 | Energy = 73.051717
# Iter 009 | Energy = 73.466380
# Iter 010 | Energy = 73.663812
# Iter 011 | Energy = 73.704678
# Iter 012 | Energy = 73.654470
# Iter 013 | Energy = 73.796459
# Iter 014 | Energy = 73.937383
# Iter 015 | Energy = 74.067817
# Iter 016 | Energy = 74.155962
# Iter 017 | Energy = 74.238407
# Iter 018 | Energy = 74.317166
# Iter 019 | Energy = 74.390285
# Iter 020 | Energy = 74.458276
# Iter 021 | Energy = 74.524051
# Iter 022 | Energy = 74.587109
# Iter 023 | Energy = 74.647520
# Iter 024 | Energy = 74.705391
# Iter 025 | Energy = 74.761480
# Iter 026 | Energy = 74.815646
# Iter 027 | Energy = 74.868061
# Iter 028 | Energy = 74.918685
# Iter 029 | Energy = 74.967629
# Iter 030 | Energy = 75.014976
# Iter 031 | Energy = 75.060761
# Iter 032 | Energy = 75.105055
# Iter 033 | Energy = 75.147895
# Iter 034 | Energy = 75.189334
# Iter 035 | Energy = 75.229414
# Iter 036 | Energy = 75.268180
# Iter 037 | Energy = 75.305675
# Iter 038 | Energy = 75.341937
# Iter 039 | Energy = 75.377008
# Iter 040 | Energy = 75.410924
# Iter 041 | Energy = 75.443723
# Iter 042 | Energy = 75.475441
# Iter 043 | Energy = 75.506112
# Iter 044 | Energy = 75.535770
# Iter 045 | Energy = 75.564448
# Iter 046 | Energy = 75.592176
# Iter 047 | Energy = 75.618987
# Iter 048 | Energy = 75.644909
# Iter 049 | Energy = 75.669972
# Iter 050 | Energy = 75.694202
# Iter 051 | Energy = 75.717628
# Iter 052 | Energy = 75.740276
# Iter 053 | Energy = 75.762170
# Iter 054 | Energy = 75.783336
# Iter 055 | Energy = 75.803797
# Iter 056 | Energy = 75.823577
# Iter 057 | Energy = 75.842697
# Iter 058 | Energy = 75.861180
# Iter 059 | Energy = 75.879046
# Iter 060 | Energy = 75.896315
# Iter 061 | Energy = 75.913008
# Iter 062 | Energy = 75.929142
# Iter 063 | Energy = 75.944738
# Iter 064 | Energy = 75.959811
# Iter 065 | Energy = 75.974381
# Iter 066 | Energy = 75.988462
# Iter 067 | Energy = 76.002073
# Iter 068 | Energy = 76.015227
# Iter 069 | Energy = 76.027940
# Iter 070 | Energy = 76.040227
# Iter 071 | Energy = 76.052102
# Iter 072 | Energy = 76.063579
# Iter 073 | Energy = 76.074670
# Iter 074 | Energy = 76.085390
# Iter 075 | Energy = 76.095749
# Iter 076 | Energy = 76.105760
# Iter 077 | Energy = 76.115435
# Iter 078 | Energy = 76.124785
# Iter 079 | Energy = 76.133821
# Iter 080 | Energy = 76.142553
# Iter 081 | Energy = 76.150991
# Iter 082 | Energy = 76.159145
# Iter 083 | Energy = 76.167025
# Iter 084 | Energy = 76.174640
# Iter 085 | Energy = 76.181998
# Iter 086 | Energy = 76.189109
# Iter 087 | Energy = 76.195980
# Iter 088 | Energy = 76.202620
# Iter 089 | Energy = 76.209036
# Iter 090 | Energy = 76.215236
# Iter 091 | Energy = 76.221228
# Iter 092 | Energy = 76.227017
# Iter 093 | Energy = 76.232611
# Iter 094 | Energy = 76.238016
# Iter 095 | Energy = 76.243240
# Iter 096 | Energy = 76.248287
# Iter 097 | Energy = 76.253163
# Iter 098 | Energy = 76.257876
# Iter 099 | Energy = 76.262429
# Iter 100 | Energy = 76.266829
# Iter 101 | Energy = 76.271080
# Iter 102 | Energy = 76.275188
# Iter 103 | Energy = 76.279157
# Iter 104 | Energy = 76.282992
# Iter 105 | Energy = 76.286698
# Iter 106 | Energy = 76.290279
# Iter 107 | Energy = 76.293738
# Iter 108 | Energy = 76.297081
# Iter 109 | Energy = 76.300311
# Iter 110 | Energy = 76.303432
# Iter 111 | Energy = 76.306447
# Iter 112 | Energy = 76.309361
# Iter 113 | Energy = 76.312176
# Iter 114 | Energy = 76.314896
# Iter 115 | Energy = 76.317524
# Iter 116 | Energy = 76.320064
# Iter 117 | Energy = 76.322517
# Iter 118 | Energy = 76.324888
# Iter 119 | Energy = 76.327178
# Iter 120 | Energy = 76.329391
# Iter 121 | Energy = 76.331530
# Iter 122 | Energy = 76.333596
# Iter 123 | Energy = 76.335592
# Iter 124 | Energy = 76.337521
# Iter 125 | Energy = 76.339384
# Iter 126 | Energy = 76.341185
# Iter 127 | Energy = 76.342924
# Iter 128 | Energy = 76.344605
# Iter 129 | Energy = 76.346229
# Iter 130 | Energy = 76.347798
# Iter 131 | Energy = 76.349314
# Iter 132 | Energy = 76.350779
# Iter 133 | Energy = 76.352194
# Iter 134 | Energy = 76.353561
# Iter 135 | Energy = 76.354882
# Iter 136 | Energy = 76.356158
# Iter 137 | Energy = 76.357392
# Iter 138 | Energy = 76.358583
# Iter 139 | Energy = 76.359734
# Iter 140 | Energy = 76.360846
# Iter 141 | Energy = 76.361921
# Iter 142 | Energy = 76.362959
# Iter 143 | Energy = 76.363962
# Iter 144 | Energy = 76.364932
# Iter 145 | Energy = 76.365868
# Iter 146 | Energy = 76.366773
# Iter 147 | Energy = 76.367647
# Iter 148 | Energy = 76.368491
# Iter 149 | Energy = 76.369307
# Iter 150 | Energy = 76.370096
# Iter 151 | Energy = 76.370857
# Iter 152 | Energy = 76.371593
# Iter 153 | Energy = 76.372304
# Iter 154 | Energy = 76.372991
# Iter 155 | Energy = 76.373655
# Iter 156 | Energy = 76.374296
# Iter 157 | Energy = 76.374916
# Iter 158 | Energy = 76.375514
# Iter 159 | Energy = 76.376092
# Iter 160 | Energy = 76.376651
# Iter 161 | Energy = 76.377191
# Iter 162 | Energy = 76.377713
# Iter 163 | Energy = 76.378216
# Iter 164 | Energy = 76.378703
# Iter 165 | Energy = 76.379174
# Iter 166 | Energy = 76.379628
# Iter 167 | Energy = 76.380067
# Iter 168 | Energy = 76.380491
# Iter 169 | Energy = 76.380901
# Iter 170 | Energy = 76.381297
# Iter 171 | Energy = 76.381680
# Iter 172 | Energy = 76.382049
# Iter 173 | Energy = 76.382407
# Iter 174 | Energy = 76.382752
# Iter 175 | Energy = 76.383085
# Iter 176 | Energy = 76.383407
# Iter 177 | Energy = 76.383718
# Iter 178 | Energy = 76.384019
# Iter 179 | Energy = 76.384309
# Iter 180 | Energy = 76.384590
# Iter 181 | Energy = 76.384861
# Iter 182 | Energy = 76.385123
# Iter 183 | Energy = 76.385376
# Iter 184 | Energy = 76.385620
# Iter 185 | Energy = 76.385857
# Iter 186 | Energy = 76.386085
# Iter 187 | Energy = 76.386305
# Iter 188 | Energy = 76.386519
# Iter 189 | Energy = 76.386724
# Iter 190 | Energy = 76.386923
# Iter 191 | Energy = 76.387115
# Iter 192 | Energy = 76.387301
# Iter 193 | Energy = 76.387480
# Iter 194 | Energy = 76.387654
# Iter 195 | Energy = 76.387821
# Iter 196 | Energy = 76.387983
# Iter 197 | Energy = 76.388139
# Iter 198 | Energy = 76.388290
# Iter 199 | Energy = 76.388436
# Iter 200 | Energy = 76.388577
# Iter 201 | Energy = 76.388713
# Iter 202 | Energy = 76.388844
# Iter 203 | Energy = 76.388972
# Iter 204 | Energy = 76.389094
# Iter 205 | Energy = 76.389213
# Iter 206 | Energy = 76.389328
# Iter 207 | Energy = 76.389438
# Iter 208 | Energy = 76.389545
# Iter 209 | Energy = 76.389649
# Iter 210 | Energy = 76.389749
# Iter 211 | Energy = 76.389845
# Iter 212 | Energy = 76.389938
# Iter 213 | Energy = 76.390028
# Iter 214 | Energy = 76.390115
# Iter 215 | Energy = 76.390199
# Iter 216 | Energy = 76.390281
# Iter 217 | Energy = 76.390359
# Iter 218 | Energy = 76.390435
# Iter 219 | Energy = 76.390508
# Iter 220 | Energy = 76.390579
# Iter 221 | Energy = 76.390647
# Iter 222 | Energy = 76.390713
# Iter 223 | Energy = 76.390777
# Iter 224 | Energy = 76.390839
# Iter 225 | Energy = 76.390898
# Iter 226 | Energy = 76.390956
# Iter 227 | Energy = 76.391012
# Iter 228 | Energy = 76.391065
# Iter 229 | Energy = 76.391117
# Iter 230 | Energy = 76.391167
# Iter 231 | Energy = 76.391216
# Iter 232 | Energy = 76.391263
# Iter 233 | Energy = 76.391308
# Iter 234 | Energy = 76.391351
# Iter 235 | Energy = 76.391394
# Iter 236 | Energy = 76.391434
# Iter 237 | Energy = 76.391474
# Iter 238 | Energy = 76.391512
# Iter 239 | Energy = 76.391549
# Iter 240 | Energy = 76.391584
# Iter 241 | Energy = 76.391619
# Iter 242 | Energy = 76.391652
# Iter 243 | Energy = 76.391684
# Iter 244 | Energy = 76.391715
# Iter 245 | Energy = 76.391745
# Iter 246 | Energy = 76.391774
# Iter 247 | Energy = 76.391801
# Iter 248 | Energy = 76.391828
# Iter 249 | Energy = 76.391855
# Iter 250 | Energy = 76.391880
# Iter 251 | Energy = 76.391904
# Iter 252 | Energy = 76.391928
# Iter 253 | Energy = 76.391950
# Iter 254 | Energy = 76.391972
# Iter 255 | Energy = 76.391993
# Iter 256 | Energy = 76.392014
# Iter 257 | Energy = 76.392034
# Iter 258 | Energy = 76.392053
# Iter 259 | Energy = 76.392071
# Iter 260 | Energy = 76.392089
# Iter 261 | Energy = 76.392106
# Iter 262 | Energy = 76.392123
# Iter 263 | Energy = 76.392139
# Iter 264 | Energy = 76.392155
# Iter 265 | Energy = 76.392170
# Iter 266 | Energy = 76.392184
# Iter 267 | Energy = 76.392198
# Iter 268 | Energy = 76.392212
# Iter 269 | Energy = 76.392225
# Iter 270 | Energy = 76.392237
# Iter 271 | Energy = 76.392250
# Iter 272 | Energy = 76.392261
# Iter 273 | Energy = 76.392273
# Iter 274 | Energy = 76.392284
# Iter 275 | Energy = 76.392295
# Iter 276 | Energy = 76.392305
# Iter 277 | Energy = 76.392315
# Iter 278 | Energy = 76.392324
# Iter 279 | Energy = 76.392334
# Iter 280 | Energy = 76.392343
# Iter 281 | Energy = 76.392351
# Iter 282 | Energy = 76.392360
# Iter 283 | Energy = 76.392368
# Iter 284 | Energy = 76.392375
# Iter 285 | Energy = 76.392383
# Iter 286 | Energy = 76.392390
# Iter 287 | Energy = 76.392397
# Iter 288 | Energy = 76.392404
# Iter 289 | Energy = 76.392411
# Iter 290 | Energy = 76.392417
# Iter 291 | Energy = 76.392423
# Iter 292 | Energy = 76.392429
# Iter 293 | Energy = 76.392435
# Iter 294 | Energy = 76.392440
# Iter 295 | Energy = 76.392446
# Iter 296 | Energy = 76.392451
# Iter 297 | Energy = 76.392456
# Iter 298 | Energy = 76.392461
# Iter 299 | Energy = 76.392465
# Iter 300 | Energy = 76.392470
# Iter 301 | Energy = 76.392474
# Iter 302 | Energy = 76.392478
# Iter 303 | Energy = 76.392482
# Iter 304 | Energy = 76.392486
# Iter 305 | Energy = 76.392490
# Iter 306 | Energy = 76.392494
# Iter 307 | Energy = 76.392497
# Iter 308 | Energy = 76.392501
# Iter 309 | Energy = 76.392504
# Iter 310 | Energy = 76.392507
# Iter 311 | Energy = 76.392510
# Iter 312 | Energy = 76.392513
# Iter 313 | Energy = 76.392516
# Iter 314 | Energy = 76.392519
# Iter 315 | Energy = 76.392522
# Iter 316 | Energy = 76.392524
# Iter 317 | Energy = 76.392527
# Iter 318 | Energy = 76.392529
# Iter 319 | Energy = 76.392532
# Iter 320 | Energy = 76.392534
# Iter 321 | Energy = 76.392536
# Iter 322 | Energy = 76.392538
# Iter 323 | Energy = 76.392540
# Iter 324 | Energy = 76.392542
# Iter 325 | Energy = 76.392544
# Iter 326 | Energy = 76.392546
# Iter 327 | Energy = 76.392548
# Iter 328 | Energy = 76.392549
# Iter 329 | Energy = 76.392551
# Iter 330 | Energy = 76.392553
# Iter 331 | Energy = 76.392554
# Iter 332 | Energy = 76.392556
# Iter 333 | Energy = 76.392557
# Iter 334 | Energy = 76.392558
# Iter 335 | Energy = 76.392560
# Iter 336 | Energy = 76.392561
# Iter 337 | Energy = 76.392562
# Iter 338 | Energy = 76.392564
# Iter 339 | Energy = 76.392565
# Iter 340 | Energy = 76.392566
# Iter 341 | Energy = 76.392567
# Iter 342 | Energy = 76.392568
# Iter 343 | Energy = 76.392569
# Iter 344 | Energy = 76.392570
# Iter 345 | Energy = 76.392571
# Iter 346 | Energy = 76.392572
# Iter 347 | Energy = 76.392573
# Iter 348 | Energy = 76.392574
# Iter 349 | Energy = 76.392575
# Iter 350 | Energy = 76.392575
# Iter 351 | Energy = 76.392576
# Iter 352 | Energy = 76.392577
# Iter 353 | Energy = 76.392578
# Iter 354 | Energy = 76.392578
# Iter 355 | Energy = 76.392579
# Iter 356 | Energy = 76.392580
# Iter 357 | Energy = 76.392580
# Iter 358 | Energy = 76.392581
# Iter 359 | Energy = 76.392581
# Iter 360 | Energy = 76.392582
# Iter 361 | Energy = 76.392583
# Iter 362 | Energy = 76.392583
# Iter 363 | Energy = 76.392584
# Iter 364 | Energy = 76.392584
# Iter 365 | Energy = 76.392585
# Iter 366 | Energy = 76.392585
# Iter 367 | Energy = 76.392585
# Iter 368 | Energy = 76.392586
# Iter 369 | Energy = 76.392586
# Iter 370 | Energy = 76.392587
# Iter 371 | Energy = 76.392587
# Iter 372 | Energy = 76.392588
# Iter 373 | Energy = 76.392588
# Iter 374 | Energy = 76.392588
# Iter 375 | Energy = 76.392589
# Iter 376 | Energy = 76.392589
# Iter 377 | Energy = 76.392589
# Iter 378 | Energy = 76.392590
# Iter 379 | Energy = 76.392590
# Iter 380 | Energy = 76.392590
# Iter 381 | Energy = 76.392590
# Iter 382 | Energy = 76.392591
# Iter 383 | Energy = 76.392591
# Iter 384 | Energy = 76.392591
# Iter 385 | Energy = 76.392591
# Iter 386 | Energy = 76.392592
# Iter 387 | Energy = 76.392592
# Iter 388 | Energy = 76.392592
# Iter 389 | Energy = 76.392592
# Iter 390 | Energy = 76.392592
# Iter 391 | Energy = 76.392593
# Iter 392 | Energy = 76.392593
# Iter 393 | Energy = 76.392593
# Iter 394 | Energy = 76.392593
# Iter 395 | Energy = 76.392593
# Iter 396 | Energy = 76.392594
# Iter 397 | Energy = 76.392594
# Iter 398 | Energy = 76.392594
# Iter 399 | Energy = 76.392594
# Iter 400 | Energy = 76.392594
# Iter 401 | Energy = 76.392594
# Iter 402 | Energy = 76.392594
# Iter 403 | Energy = 76.392595
# Iter 404 | Energy = 76.392595
# Iter 405 | Energy = 76.392595
# Iter 406 | Energy = 76.392595
# Iter 407 | Energy = 76.392595
# Iter 408 | Energy = 76.392595
# Iter 409 | Energy = 76.392595
# Iter 410 | Energy = 76.392595
# Iter 411 | Energy = 76.392595
# Iter 412 | Energy = 76.392596
# Iter 413 | Energy = 76.392596
# Iter 414 | Energy = 76.392596
# Iter 415 | Energy = 76.392596
# Iter 416 | Energy = 76.392596
# Iter 417 | Energy = 76.392596
# Iter 418 | Energy = 76.392596
# Iter 419 | Energy = 76.392596
# Iter 420 | Energy = 76.392596
# Iter 421 | Energy = 76.392596
# Iter 422 | Energy = 76.392596
# Iter 423 | Energy = 76.392596
# Iter 424 | Energy = 76.392596
# Iter 425 | Energy = 76.392597
# Iter 426 | Energy = 76.392597
# Iter 427 | Energy = 76.392597
# Iter 428 | Energy = 76.392597
# Iter 429 | Energy = 76.392597
# Iter 430 | Energy = 76.392597
# Iter 431 | Energy = 76.392597
# Iter 432 | Energy = 76.392597
# Iter 433 | Energy = 76.392597
# Iter 434 | Energy = 76.392597
# Iter 435 | Energy = 76.392597
# Iter 436 | Energy = 76.392597
# Iter 437 | Energy = 76.392597
# Iter 438 | Energy = 76.392597
# Iter 439 | Energy = 76.392597
# Iter 440 | Energy = 76.392597
# Iter 441 | Energy = 76.392597
# Iter 442 | Energy = 76.392597
# Iter 443 | Energy = 76.392597
# Iter 444 | Energy = 76.392597
# Iter 445 | Energy = 76.392597
# Iter 446 | Energy = 76.392597
# Iter 447 | Energy = 76.392597
# Iter 448 | Energy = 76.392597
# Iter 449 | Energy = 76.392598
# Iter 450 | Energy = 76.392598
# Iter 451 | Energy = 76.392598
# Iter 452 | Energy = 76.392598
# Iter 453 | Energy = 76.392598
# Iter 454 | Energy = 76.392598
# Iter 455 | Energy = 76.392598
# Iter 456 | Energy = 76.392598
# Iter 457 | Energy = 76.392598
# Iter 458 | Energy = 76.392598
# Iter 459 | Energy = 76.392598
# Iter 460 | Energy = 76.392598
# Iter 461 | Energy = 76.392598
# Iter 462 | Energy = 76.392598
# Iter 463 | Energy = 76.392598
# Iter 464 | Energy = 76.392598
# Iter 465 | Energy = 76.392598
# Iter 466 | Energy = 76.392598
# Iter 467 | Energy = 76.392598
# Iter 468 | Energy = 76.392598
# Iter 469 | Energy = 76.392598
# Iter 470 | Energy = 76.392598
# Iter 471 | Energy = 76.392598
# Iter 472 | Energy = 76.392598
# Iter 473 | Energy = 76.392598
# Iter 474 | Energy = 76.392598
# Iter 475 | Energy = 76.392598
# Iter 476 | Energy = 76.392598
# Iter 477 | Energy = 76.392598
# Iter 478 | Energy = 76.392598
# Iter 479 | Energy = 76.392598
# Iter 480 | Energy = 76.392598
# Iter 481 | Energy = 76.392598
# Iter 482 | Energy = 76.392598
# Iter 483 | Energy = 76.392598
# Iter 484 | Energy = 76.392598
# Iter 485 | Energy = 76.392598
# Iter 486 | Energy = 76.392598
# Iter 487 | Energy = 76.392598
# Iter 488 | Energy = 76.392598
# Iter 489 | Energy = 76.392598
# Iter 490 | Energy = 76.392598
# Iter 491 | Energy = 76.392598
# Iter 492 | Energy = 76.392598
# Iter 493 | Energy = 76.392598
# Iter 494 | Energy = 76.392598
# Iter 495 | Energy = 76.392598
# Iter 496 | Energy = 76.392598
# Iter 497 | Energy = 76.392598
# Iter 498 | Energy = 76.392598
# Iter 499 | Energy = 76.392598
# Iter 500 | Energy = 76.392598
# Iter 501 | Energy = 76.392598
# Iter 502 | Energy = 76.392598
# Iter 503 | Energy = 76.392598
# Iter 504 | Energy = 76.392598
# Iter 505 | Energy = 76.392598
# Iter 506 | Energy = 76.392598
# Iter 507 | Energy = 76.392598
# Iter 508 | Energy = 76.392598
# Iter 509 | Energy = 76.392598
# Iter 510 | Energy = 76.392598
# Iter 511 | Energy = 76.392598
# Iter 512 | Energy = 76.392598
# Iter 513 | Energy = 76.392598
# Iter 514 | Energy = 76.392598
# Iter 515 | Energy = 76.392598
# Iter 516 | Energy = 76.392598
# Iter 517 | Energy = 76.392598
# Iter 518 | Energy = 76.392598
# Iter 519 | Energy = 76.392598
# Iter 520 | Energy = 76.392598
# Iter 521 | Energy = 76.392598
# Iter 522 | Energy = 76.392598
# Iter 523 | Energy = 76.392598
# Iter 524 | Energy = 76.392598
# Iter 525 | Energy = 76.392598
# Iter 526 | Energy = 76.392598
# Iter 527 | Energy = 76.392598
# Iter 528 | Energy = 76.392598
# Iter 529 | Energy = 76.392598
# Iter 530 | Energy = 76.392598
# Iter 531 | Energy = 76.392598
# Iter 532 | Energy = 76.392598
# Iter 533 | Energy = 76.392598
# Iter 534 | Energy = 76.392598
# Iter 535 | Energy = 76.392598
# Iter 536 | Energy = 76.392598
# Iter 537 | Energy = 76.392598
# Iter 538 | Energy = 76.392598
# Iter 539 | Energy = 76.392598
# Iter 540 | Energy = 76.392598
# Iter 541 | Energy = 76.392598
# Iter 542 | Energy = 76.392598
# Iter 543 | Energy = 76.392598
# Iter 544 | Energy = 76.392598
# Iter 545 | Energy = 76.392598
# Iter 546 | Energy = 76.392598
# Iter 547 | Energy = 76.392598
# Iter 548 | Energy = 76.392598
# Iter 549 | Energy = 76.392598
# Iter 550 | Energy = 76.392598
# Iter 551 | Energy = 76.392598
# Iter 552 | Energy = 76.392598
# Iter 553 | Energy = 76.392598
# Iter 554 | Energy = 76.392598
# Iter 555 | Energy = 76.392598
# Iter 556 | Energy = 76.392598
# Iter 557 | Energy = 76.392598
# Iter 558 | Energy = 76.392598
# Iter 559 | Energy = 76.392598
# Iter 560 | Energy = 76.392598
# Iter 561 | Energy = 76.392598
# Iter 562 | Energy = 76.392598
# Iter 563 | Energy = 76.392598
# Iter 564 | Energy = 76.392598
# Iter 565 | Energy = 76.392598
# Iter 566 | Energy = 76.392598
# Iter 567 | Energy = 76.392598
# Iter 568 | Energy = 76.392598
# Iter 569 | Energy = 76.392598
# Iter 570 | Energy = 76.392598
# Iter 571 | Energy = 76.392598
# Iter 572 | Energy = 76.392598
# Iter 573 | Energy = 76.392598
# Iter 574 | Energy = 76.392598
# Iter 575 | Energy = 76.392598
# Iter 576 | Energy = 76.392598
# Iter 577 | Energy = 76.392598
# Iter 578 | Energy = 76.392598
# Iter 579 | Energy = 76.392598
# Iter 580 | Energy = 76.392598
# Iter 581 | Energy = 76.392598
# Iter 582 | Energy = 76.392598
# Iter 583 | Energy = 76.392598
# Iter 584 | Energy = 76.392598
# Iter 585 | Energy = 76.392598
# Iter 586 | Energy = 76.392598
# Iter 587 | Energy = 76.392598
# Iter 588 | Energy = 76.392598
# Iter 589 | Energy = 76.392598
# Iter 590 | Energy = 76.392598
# Iter 591 | Energy = 76.392598
# Iter 592 | Energy = 76.392598
# Iter 593 | Energy = 76.392598
# Iter 594 | Energy = 76.392598
# Iter 595 | Energy = 76.392598
# Iter 596 | Energy = 76.392598
# Iter 597 | Energy = 76.392598
# Iter 598 | Energy = 76.392598
# Iter 599 | Energy = 76.392598
# Iter 600 | Energy = 76.392598
# Iter 601 | Energy = 76.392598
# Iter 602 | Energy = 76.392598
# Iter 603 | Energy = 76.392598
# Iter 604 | Energy = 76.392598
# Iter 605 | Energy = 76.392598
# Iter 606 | Energy = 76.392598
# Iter 607 | Energy = 76.392598
# Iter 608 | Energy = 76.392598
# Iter 609 | Energy = 76.392598
# Iter 610 | Energy = 76.392598
# Iter 611 | Energy = 76.392598
# Iter 612 | Energy = 76.392598
# Iter 613 | Energy = 76.392598
# Iter 614 | Energy = 76.392598
# Iter 615 | Energy = 76.392598
# Iter 616 | Energy = 76.392598
# Iter 617 | Energy = 76.392598
# Iter 618 | Energy = 76.392598
# Iter 619 | Energy = 76.392598
# Iter 620 | Energy = 76.392598
# Iter 621 | Energy = 76.392598
# Iter 622 | Energy = 76.392598
# Iter 623 | Energy = 76.392598
# Iter 624 | Energy = 76.392598
# Iter 625 | Energy = 76.392598
# Iter 626 | Energy = 76.392598
# Iter 627 | Energy = 76.392598
# Iter 628 | Energy = 76.392598
# Iter 629 | Energy = 76.392598
# Iter 630 | Energy = 76.392598
# Iter 631 | Energy = 76.392598
# Iter 632 | Energy = 76.392598
# Iter 633 | Energy = 76.392598
# Iter 634 | Energy = 76.392598
# Iter 635 | Energy = 76.392598
# Iter 636 | Energy = 76.392598
# Iter 637 | Energy = 76.392598
# Iter 638 | Energy = 76.392598
# Iter 639 | Energy = 76.392598
# Iter 640 | Energy = 76.392598
# Iter 641 | Energy = 76.392598
# Iter 642 | Energy = 76.392598
# Iter 643 | Energy = 76.392598
# Iter 644 | Energy = 76.392598
# Iter 645 | Energy = 76.392598
# Iter 646 | Energy = 76.392598
# Iter 647 | Energy = 76.392598
# Iter 648 | Energy = 76.392598
# Iter 649 | Energy = 76.392598
# Iter 650 | Energy = 76.392598
# Iter 651 | Energy = 76.392598
# Iter 652 | Energy = 76.392598
# Iter 653 | Energy = 76.392598
# Iter 654 | Energy = 76.392598
# Iter 655 | Energy = 76.392598
# Iter 656 | Energy = 76.392598
# Iter 657 | Energy = 76.392598
# Iter 658 | Energy = 76.392598
# Iter 659 | Energy = 76.392598
# Iter 660 | Energy = 76.392598
# Iter 661 | Energy = 76.392598
# Iter 662 | Energy = 76.392598
# Iter 663 | Energy = 76.392598
# Iter 664 | Energy = 76.392598
# Iter 665 | Energy = 76.392598
# Iter 666 | Energy = 76.392598
# Iter 667 | Energy = 76.392598
# Iter 668 | Energy = 76.392598
# Iter 669 | Energy = 76.392598
# Iter 670 | Energy = 76.392598
# Iter 671 | Energy = 76.392598
# Iter 672 | Energy = 76.392598
# Iter 673 | Energy = 76.392598
# Iter 674 | Energy = 76.392598
# Iter 675 | Energy = 76.392598
# Iter 676 | Energy = 76.392598
# Iter 677 | Energy = 76.392598
# Iter 678 | Energy = 76.392598
# Iter 679 | Energy = 76.392598
# Iter 680 | Energy = 76.392598
# Iter 681 | Energy = 76.392598
# Iter 682 | Energy = 76.392598
# Iter 683 | Energy = 76.392598
# Iter 684 | Energy = 76.392598
# Iter 685 | Energy = 76.392598
# Iter 686 | Energy = 76.392598
# Iter 687 | Energy = 76.392598
# Iter 688 | Energy = 76.392598
# Iter 689 | Energy = 76.392598
# Iter 690 | Energy = 76.392598
# Iter 691 | Energy = 76.392598
# Iter 692 | Energy = 76.392598
# Iter 693 | Energy = 76.392598
# Iter 694 | Energy = 76.392598
# Iter 695 | Energy = 76.392598
# Iter 696 | Energy = 76.392598
# Iter 697 | Energy = 76.392598
# Iter 698 | Energy = 76.392598
# Iter 699 | Energy = 76.392598
# Iter 700 | Energy = 76.392598
# Iter 701 | Energy = 76.392598
# Iter 702 | Energy = 76.392598
# Iter 703 | Energy = 76.392598
# Iter 704 | Energy = 76.392598
# Iter 705 | Energy = 76.392598
# Iter 706 | Energy = 76.392598
# Iter 707 | Energy = 76.392598
# Iter 708 | Energy = 76.392598
# Iter 709 | Energy = 76.392598
# Iter 710 | Energy = 76.392598
# Iter 711 | Energy = 76.392598
# Iter 712 | Energy = 76.392598
# Iter 713 | Energy = 76.392598
# Iter 714 | Energy = 76.392598
# Iter 715 | Energy = 76.392598
# Iter 716 | Energy = 76.392598
# Iter 717 | Energy = 76.392598
# Iter 718 | Energy = 76.392598
# Iter 719 | Energy = 76.392598
# Iter 720 | Energy = 76.392598
# Iter 721 | Energy = 76.392598
# Iter 722 | Energy = 76.392598
# Iter 723 | Energy = 76.392598
# Iter 724 | Energy = 76.392598
# Iter 725 | Energy = 76.392598
# Iter 726 | Energy = 76.392598
# Iter 727 | Energy = 76.392598
# Iter 728 | Energy = 76.392598
# Iter 729 | Energy = 76.392598
# Iter 730 | Energy = 76.392598
# Iter 731 | Energy = 76.392598
# Iter 732 | Energy = 76.392598
# Iter 733 | Energy = 76.392598
# Iter 734 | Energy = 76.392598
# Iter 735 | Energy = 76.392598
# Iter 736 | Energy = 76.392598
# Iter 737 | Energy = 76.392598
# Iter 738 | Energy = 76.392598
# Iter 739 | Energy = 76.392598
# Iter 740 | Energy = 76.392598
# Iter 741 | Energy = 76.392598
# Iter 742 | Energy = 76.392598
# Iter 743 | Energy = 76.392598
# Iter 744 | Energy = 76.392598
# Iter 745 | Energy = 76.392598
# Iter 746 | Energy = 76.392598
# Iter 747 | Energy = 76.392598
# Iter 748 | Energy = 76.392598
# Iter 749 | Energy = 76.392598
# Iter 750 | Energy = 76.392598
# Iter 751 | Energy = 76.392598
# Iter 752 | Energy = 76.392598
# Iter 753 | Energy = 76.392598
# Iter 754 | Energy = 76.392598
# Iter 755 | Energy = 76.392598
# Iter 756 | Energy = 76.392598
# Iter 757 | Energy = 76.392598
# Iter 758 | Energy = 76.392598
# Iter 759 | Energy = 76.392598
# Iter 760 | Energy = 76.392598
# Iter 761 | Energy = 76.392598
# Iter 762 | Energy = 76.392598
# Iter 763 | Energy = 76.392598
# Iter 764 | Energy = 76.392598
# Iter 765 | Energy = 76.392598
# Iter 766 | Energy = 76.392598
# Iter 767 | Energy = 76.392598
# Iter 768 | Energy = 76.392598
# Iter 769 | Energy = 76.392598
# Iter 770 | Energy = 76.392598
# Iter 771 | Energy = 76.392598
# Iter 772 | Energy = 76.392598
# Iter 773 | Energy = 76.392598
# Iter 774 | Energy = 76.392598
# Iter 775 | Energy = 76.392598
# Iter 776 | Energy = 76.392598
# Iter 777 | Energy = 76.392598
# Iter 778 | Energy = 76.392598
# Iter 779 | Energy = 76.392598
# Iter 780 | Energy = 76.392598
# Iter 781 | Energy = 76.392598
# Iter 782 | Energy = 76.392598
# Iter 783 | Energy = 76.392598
# Iter 784 | Energy = 76.392598
# Iter 785 | Energy = 76.392598
# Iter 786 | Energy = 76.392598
# Iter 787 | Energy = 76.392598
# Iter 788 | Energy = 76.392598
# Iter 789 | Energy = 76.392598
# Iter 790 | Energy = 76.392598
# Iter 791 | Energy = 76.392598
# Iter 792 | Energy = 76.392598
# Iter 793 | Energy = 76.392598
# Iter 794 | Energy = 76.392598
# Iter 795 | Energy = 76.392598
# Iter 796 | Energy = 76.392598
# Iter 797 | Energy = 76.392598
# Iter 798 | Energy = 76.392598
# Iter 799 | Energy = 76.392598
# Iter 800 | Energy = 76.392598
# Iter 801 | Energy = 76.392598
# Iter 802 | Energy = 76.392598
# Iter 803 | Energy = 76.392598
# Iter 804 | Energy = 76.392598
# Iter 805 | Energy = 76.392598
# Iter 806 | Energy = 76.392598
# Iter 807 | Energy = 76.392598
# Iter 808 | Energy = 76.392598
# Iter 809 | Energy = 76.392598
# Iter 810 | Energy = 76.392598
# Iter 811 | Energy = 76.392598
# Iter 812 | Energy = 76.392598
# Iter 813 | Energy = 76.392598
# Iter 814 | Energy = 76.392598
# Iter 815 | Energy = 76.392598
# Iter 816 | Energy = 76.392598
# Iter 817 | Energy = 76.392598
# Iter 818 | Energy = 76.392598
# Iter 819 | Energy = 76.392598
# Iter 820 | Energy = 76.392598
# Iter 821 | Energy = 76.392598
# Iter 822 | Energy = 76.392598
# Iter 823 | Energy = 76.392598
# Iter 824 | Energy = 76.392598
# Iter 825 | Energy = 76.392598
# Iter 826 | Energy = 76.392598
# Iter 827 | Energy = 76.392598
# Iter 828 | Energy = 76.392598
# Iter 829 | Energy = 76.392598
# Iter 830 | Energy = 76.392598
# Iter 831 | Energy = 76.392598
# Iter 832 | Energy = 76.392598
# Iter 833 | Energy = 76.392598
# Iter 834 | Energy = 76.392598
# Iter 835 | Energy = 76.392598
# Iter 836 | Energy = 76.392598
# Iter 837 | Energy = 76.392598
# Iter 838 | Energy = 76.392598
# Iter 839 | Energy = 76.392598
# Iter 840 | Energy = 76.392598
# Iter 841 | Energy = 76.392598
# Iter 842 | Energy = 76.392598
# Iter 843 | Energy = 76.392598
# Iter 844 | Energy = 76.392598
# Iter 845 | Energy = 76.392598
# Iter 846 | Energy = 76.392598
# Iter 847 | Energy = 76.392598
# Iter 848 | Energy = 76.392598
# Iter 849 | Energy = 76.392598
# Iter 850 | Energy = 76.392598
# Iter 851 | Energy = 76.392598
# Iter 852 | Energy = 76.392598
# Iter 853 | Energy = 76.392598
# Iter 854 | Energy = 76.392598
# Iter 855 | Energy = 76.392598
# Iter 856 | Energy = 76.392598
# Iter 857 | Energy = 76.392598
# Iter 858 | Energy = 76.392598
# Iter 859 | Energy = 76.392598
# Iter 860 | Energy = 76.392598
# Iter 861 | Energy = 76.392598
# Iter 862 | Energy = 76.392598
# Iter 863 | Energy = 76.392598
# Iter 864 | Energy = 76.392598
# Iter 865 | Energy = 76.392598
# Iter 866 | Energy = 76.392598
# Iter 867 | Energy = 76.392598
# Iter 868 | Energy = 76.392598
# Iter 869 | Energy = 76.392598
# Iter 870 | Energy = 76.392598
# Iter 871 | Energy = 76.392598
# Iter 872 | Energy = 76.392598
# Iter 873 | Energy = 76.392598
# Iter 874 | Energy = 76.392598
# Iter 875 | Energy = 76.392598
# Iter 876 | Energy = 76.392598
# Iter 877 | Energy = 76.392598
# Iter 878 | Energy = 76.392598
# Iter 879 | Energy = 76.392598
# Iter 880 | Energy = 76.392598
# Iter 881 | Energy = 76.392598
# Iter 882 | Energy = 76.392598
# Iter 883 | Energy = 76.392598
# Iter 884 | Energy = 76.392598
# Iter 885 | Energy = 76.392598
# Iter 886 | Energy = 76.392598
# Iter 887 | Energy = 76.392598
# Iter 888 | Energy = 76.392598
# Iter 889 | Energy = 76.392598
# Iter 890 | Energy = 76.392598
# Iter 891 | Energy = 76.392598
# Iter 892 | Energy = 76.392598
# Iter 893 | Energy = 76.392598
# Iter 894 | Energy = 76.392598
# Iter 895 | Energy = 76.392598
# Iter 896 | Energy = 76.392598
# Iter 897 | Energy = 76.392598
# Iter 898 | Energy = 76.392598
# Iter 899 | Energy = 76.392598
# Iter 900 | Energy = 76.392598
# Iter 901 | Energy = 76.392598
# Iter 902 | Energy = 76.392598
# Iter 903 | Energy = 76.392598
# Iter 904 | Energy = 76.392598
# Iter 905 | Energy = 76.392598
# Iter 906 | Energy = 76.392598
# Iter 907 | Energy = 76.392598
# Iter 908 | Energy = 76.392598
# Iter 909 | Energy = 76.392598
# Iter 910 | Energy = 76.392598
# Iter 911 | Energy = 76.392598
# Iter 912 | Energy = 76.392598
# Iter 913 | Energy = 76.392598
# Iter 914 | Energy = 76.392598
# Iter 915 | Energy = 76.392598
# Iter 916 | Energy = 76.392598
# Iter 917 | Energy = 76.392598
# Iter 918 | Energy = 76.392598
# Iter 919 | Energy = 76.392598
# Iter 920 | Energy = 76.392598
# Iter 921 | Energy = 76.392598
# Iter 922 | Energy = 76.392598
# Iter 923 | Energy = 76.392598
# Iter 924 | Energy = 76.392598
# Iter 925 | Energy = 76.392598
# Iter 926 | Energy = 76.392598
# Iter 927 | Energy = 76.392598
# Iter 928 | Energy = 76.392598
# Iter 929 | Energy = 76.392598
# Iter 930 | Energy = 76.392598
# Iter 931 | Energy = 76.392598
# Iter 932 | Energy = 76.392598
# Iter 933 | Energy = 76.392598
# Iter 934 | Energy = 76.392598
# Iter 935 | Energy = 76.392598
# Iter 936 | Energy = 76.392598
# Iter 937 | Energy = 76.392598
# Iter 938 | Energy = 76.392598
# Iter 939 | Energy = 76.392598
# Iter 940 | Energy = 76.392598
# Iter 941 | Energy = 76.392598
# Iter 942 | Energy = 76.392598
# Iter 943 | Energy = 76.392598
# Iter 944 | Energy = 76.392598
# Iter 945 | Energy = 76.392598
# Iter 946 | Energy = 76.392598
# Iter 947 | Energy = 76.392598
# Iter 948 | Energy = 76.392598
# Iter 949 | Energy = 76.392598
# Iter 950 | Energy = 76.392598
# Iter 951 | Energy = 76.392598
# Iter 952 | Energy = 76.392598
# Iter 953 | Energy = 76.392598
# Iter 954 | Energy = 76.392598
# Iter 955 | Energy = 76.392598
# Iter 956 | Energy = 76.392598
# Iter 957 | Energy = 76.392598
# Iter 958 | Energy = 76.392598
# Iter 959 | Energy = 76.392598
# Iter 960 | Energy = 76.392598
# Iter 961 | Energy = 76.392598
# Iter 962 | Energy = 76.392598
# Iter 963 | Energy = 76.392598
# Iter 964 | Energy = 76.392598
# Iter 965 | Energy = 76.392598
# Iter 966 | Energy = 76.392598
# Iter 967 | Energy = 76.392598
# Iter 968 | Energy = 76.392598
# Iter 969 | Energy = 76.392598
# Iter 970 | Energy = 76.392598
# Iter 971 | Energy = 76.392598
# Iter 972 | Energy = 76.392598
# Iter 973 | Energy = 76.392598
# Iter 974 | Energy = 76.392598
# Iter 975 | Energy = 76.392598
# Iter 976 | Energy = 76.392598
# Iter 977 | Energy = 76.392598
# Iter 978 | Energy = 76.392598
# Iter 979 | Energy = 76.392598
# Iter 980 | Energy = 76.392598
# Iter 981 | Energy = 76.392598
# Iter 982 | Energy = 76.392598
# Iter 983 | Energy = 76.392598
# Iter 984 | Energy = 76.392598
# Iter 985 | Energy = 76.392598
# Iter 986 | Energy = 76.392598
# Iter 987 | Energy = 76.392598
# Iter 988 | Energy = 76.392598
# Iter 989 | Energy = 76.392598
# Iter 990 | Energy = 76.392598
# Iter 991 | Energy = 76.392598
# Iter 992 | Energy = 76.392598
# Iter 993 | Energy = 76.392598
# Iter 994 | Energy = 76.392598
# Iter 995 | Energy = 76.392598
# Iter 996 | Energy = 76.392598
# Iter 997 | Energy = 76.392598
# Iter 998 | Energy = 76.392598
# Iter 999 | Energy = 76.392598
# Iter 1000 | Energy = 76.392598

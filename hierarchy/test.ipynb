# %%
import numpy as np
from gbp.gbp import FactorGraph, VariableNode, Factor

# -----------------------
# SLAM-like base graph
# -----------------------
def make_slam_like_graph(N=100, step_size=25, loop_prob=0.05, loop_radius=50, prior_prop=0.0, rng=None,):
    nodes, edges = [], []
    positions = []
    x, y = 0.0, 0.0
    positions.append((x, y))
    for _ in range(1, int(N)):
        dx, dy = np.random.randn(2)
        norm = np.sqrt(dx**2 + dy**2) + 1e-6
        dx, dy = dx / norm * float(step_size), dy / norm * float(step_size)
        x, y = x + dx, y + dy
        positions.append((x, y))
    for i, (px, py) in enumerate(positions):
        nodes.append({
            "data": {"id": f"{i}", "layer": 0, "dim": 2},
            "position": {"x": float(px), "y": float(py)}
        })
    for i in range(int(N) - 1):
        edges.append({"data": {"source": f"{i}", "target": f"{i+1}"}})
    for i in range(int(N)):
        for j in range(i + 5, int(N)):
            if np.random.rand() < float(loop_prob):
                xi, yi = positions[i]; xj, yj = positions[j]
                if np.hypot(xi-xj, yi-yj) < float(loop_radius):
                    edges.append({"data": {"source": f"{i}", "target": f"{j}"}})

    # 确定强先验的节点集合
    if rng is None:
        rng = np.random.default_rng()

    if prior_prop <= 0.0:
        strong_ids = {0}
    elif prior_prop >= 1.0:
        strong_ids = set(range(N))
    else:
        k = max(1, int(np.floor(prior_prop * N)))
        strong_ids = set(rng.choice(N, size=k, replace=False).tolist())

    # 给 strong prior 节点加 edge
    for i in strong_ids:
        edges.append({
            "data": {"source": f"{i}", "target": "prior"}
        })


    return nodes, edges

# -----------------------
# GBP Graph 构建
# -----------------------
def build_noisy_pose_graph(
    nodes,
    edges,
    prior_sigma: float = 10,
    odom_sigma: float = 10,
    tiny_prior: float = 1e-10,
    rng=None,
):
    
    """
    构造二维 pose-only 因子图（线性，高斯），并注入噪声。
    参数:
      prior_sigma : 强先验的标准差（小=强）
      odom_sigma  : 里程计测量噪声标准差
      prior_prop  : 0.0=仅 anchor；(0,1)=按比例随机选；>=1.0=全体
      tiny_prior  : 所有节点默认加的极小先验，防止奇异
      seed        : 随机种子（可复现）
    """

    fg = FactorGraph(nonlinear_factors=False, eta_damping=0)

    var_nodes = []
    I2 = np.eye(2, dtype=float)
    N = len(nodes)

    # ---- 预生成噪声 ----
    prior_noises = {}
    odom_noises = {}

    if rng is None:
        rng = np.random.default_rng()

    # 为所有边生成噪声
    for e in edges:
        src = e["data"]["source"]; dst = e["data"]["target"]
        # 二元边
        if dst != "prior":
            odom_noises[(int(src[:]), int(dst[:]))] = rng.normal(0.0, odom_sigma, size=2)
        # 一元边（强先验）
        elif dst == "prior":
            prior_noises[int(src[:])] = rng.normal(0.0, prior_sigma, size=2)


    # ---- variable nodes ----
    for i, n in enumerate(nodes):
        v = VariableNode(i, dofs=2)
        v.GT = np.array([n["position"]["x"], n["position"]["y"]], dtype=float)

        # 极小先验
        v.prior.lam = tiny_prior * I2
        v.prior.eta = np.zeros(2, dtype=float)

        var_nodes.append(v)

    fg.var_nodes = var_nodes
    fg.n_var_nodes = len(var_nodes)


    # ---- prior factors ----
    def meas_fn_unary(x, *args):
        return x
    def jac_fn_unary(x, *args):
        return np.eye(2)
    # ---- odometry factors ----
    def meas_fn(xy, *args):
        return xy[2:] - xy[:2]
    def jac_fn(xy, *args):
        return np.array([[-1, 0, 1, 0],
                         [ 0,-1, 0, 1]], dtype=float)
    
    factors = []
    fid = 0

    for e in edges:
        src = e["data"]["source"]; dst = e["data"]["target"]
        if dst != "prior":
            i, j = int(src[:]), int(dst[:])
            vi, vj = var_nodes[i], var_nodes[j]

            meas = (vj.GT - vi.GT) + odom_noises[(i, j)]

            f = Factor(fid, [vi, vj], meas, odom_sigma, meas_fn, jac_fn)
            f.type = "base"
            linpoint = np.r_[vi.GT, vj.GT]
            f.compute_factor(linpoint=linpoint, update_self=True)

            factors.append(f)
            vi.adj_factors.append(f)
            vj.adj_factors.append(f)
            fid += 1

        else:
            i = int(src[:])
            vi = var_nodes[i]
            z = vi.GT + prior_noises[i]

            f = Factor(fid, [vi], z, prior_sigma, meas_fn_unary, jac_fn_unary)
            f.type = "prior"
            f.compute_factor(linpoint=z, update_self=True)

            factors.append(f)
            vi.adj_factors.append(f)
            fid += 1

    fg.factors = factors
    fg.n_factor_nodes = len(factors)
    return fg


# -----------------------
# 主程序：跑 100 次迭代
# -----------------------
if __name__ == "__main__":
    rng = np.random.default_rng(42)  # 固定随机种子

    # 1. 造一个图
    nodes, edges = make_slam_like_graph(N=50, step_size=25, loop_prob=0.1, loop_radius=50, prior_prop=0.1, rng=rng)

    # 2. 构建 GBP 图
    fg = build_noisy_pose_graph(nodes, edges, prior_sigma=10.0, odom_sigma=10.0, rng=rng)

    # 3. 跑迭代
    for it in range(1000):
        fg.synchronous_iteration()
        energy = fg.energy_map(include_priors=True, include_factors=True)
        print(f"Iter {it+1:03d} | Energy = {energy:.6f}")
# Out:
# Iter 001 | Energy = 774.130549
# Iter 002 | Energy = 709.981416
# Iter 003 | Energy = 556.189571
# Iter 004 | Energy = 508.090565
# Iter 005 | Energy = 473.331254
# Iter 006 | Energy = 457.934329
# Iter 007 | Energy = 25.867008
# Iter 008 | Energy = 17.956291
# Iter 009 | Energy = 15.984974
# Iter 010 | Energy = 14.781472
# Iter 011 | Energy = 13.736504
# Iter 012 | Energy = 13.018778
# Iter 013 | Energy = 12.545911
# Iter 014 | Energy = 12.357473
# Iter 015 | Energy = 12.347305
# Iter 016 | Energy = 12.327396
# Iter 017 | Energy = 12.319373
# Iter 018 | Energy = 12.312751
# Iter 019 | Energy = 12.310353
# Iter 020 | Energy = 12.309470
# Iter 021 | Energy = 12.308735
# Iter 022 | Energy = 12.308173
# Iter 023 | Energy = 12.307672
# Iter 024 | Energy = 12.307270
# Iter 025 | Energy = 12.306936
# Iter 026 | Energy = 12.306633
# Iter 027 | Energy = 12.306382
# Iter 028 | Energy = 12.306174
# Iter 029 | Energy = 12.305996
# Iter 030 | Energy = 12.305842
# Iter 031 | Energy = 12.305710
# Iter 032 | Energy = 12.305598
# Iter 033 | Energy = 12.305501
# Iter 034 | Energy = 12.305417
# Iter 035 | Energy = 12.305346
# Iter 036 | Energy = 12.305284
# Iter 037 | Energy = 12.305231
# Iter 038 | Energy = 12.305185
# Iter 039 | Energy = 12.305146
# Iter 040 | Energy = 12.305112
# Iter 041 | Energy = 12.305083
# Iter 042 | Energy = 12.305058
# Iter 043 | Energy = 12.305037
# Iter 044 | Energy = 12.305018
# Iter 045 | Energy = 12.305002
# Iter 046 | Energy = 12.304989
# Iter 047 | Energy = 12.304977
# Iter 048 | Energy = 12.304967
# Iter 049 | Energy = 12.304958
# Iter 050 | Energy = 12.304951
# Iter 051 | Energy = 12.304944
# Iter 052 | Energy = 12.304939
# Iter 053 | Energy = 12.304934
# Iter 054 | Energy = 12.304930
# Iter 055 | Energy = 12.304926
# Iter 056 | Energy = 12.304923
# Iter 057 | Energy = 12.304921
# Iter 058 | Energy = 12.304918
# Iter 059 | Energy = 12.304916
# Iter 060 | Energy = 12.304915
# Iter 061 | Energy = 12.304913
# Iter 062 | Energy = 12.304912
# Iter 063 | Energy = 12.304911
# Iter 064 | Energy = 12.304910
# Iter 065 | Energy = 12.304909
# Iter 066 | Energy = 12.304909
# Iter 067 | Energy = 12.304908
# Iter 068 | Energy = 12.304908
# Iter 069 | Energy = 12.304907
# Iter 070 | Energy = 12.304907
# Iter 071 | Energy = 12.304907
# Iter 072 | Energy = 12.304906
# Iter 073 | Energy = 12.304906
# Iter 074 | Energy = 12.304906
# Iter 075 | Energy = 12.304906
# Iter 076 | Energy = 12.304905
# Iter 077 | Energy = 12.304905
# Iter 078 | Energy = 12.304905
# Iter 079 | Energy = 12.304905
# Iter 080 | Energy = 12.304905
# Iter 081 | Energy = 12.304905
# Iter 082 | Energy = 12.304905
# Iter 083 | Energy = 12.304905
# Iter 084 | Energy = 12.304905
# Iter 085 | Energy = 12.304905
# Iter 086 | Energy = 12.304905
# Iter 087 | Energy = 12.304905
# Iter 088 | Energy = 12.304905
# Iter 089 | Energy = 12.304905
# Iter 090 | Energy = 12.304905
# Iter 091 | Energy = 12.304905
# Iter 092 | Energy = 12.304905
# Iter 093 | Energy = 12.304905
# Iter 094 | Energy = 12.304905
# Iter 095 | Energy = 12.304905
# Iter 096 | Energy = 12.304905
# Iter 097 | Energy = 12.304905
# Iter 098 | Energy = 12.304905
# Iter 099 | Energy = 12.304905
# Iter 100 | Energy = 12.304905
# Iter 101 | Energy = 12.304905
# Iter 102 | Energy = 12.304905
# Iter 103 | Energy = 12.304905
# Iter 104 | Energy = 12.304905
# Iter 105 | Energy = 12.304905
# Iter 106 | Energy = 12.304905
# Iter 107 | Energy = 12.304905
# Iter 108 | Energy = 12.304905
# Iter 109 | Energy = 12.304905
# Iter 110 | Energy = 12.304905
# Iter 111 | Energy = 12.304905
# Iter 112 | Energy = 12.304905
# Iter 113 | Energy = 12.304905
# Iter 114 | Energy = 12.304905
# Iter 115 | Energy = 12.304905
# Iter 116 | Energy = 12.304905
# Iter 117 | Energy = 12.304905
# Iter 118 | Energy = 12.304905
# Iter 119 | Energy = 12.304905
# Iter 120 | Energy = 12.304905
# Iter 121 | Energy = 12.304905
# Iter 122 | Energy = 12.304905
# Iter 123 | Energy = 12.304905
# Iter 124 | Energy = 12.304905
# Iter 125 | Energy = 12.304905
# Iter 126 | Energy = 12.304905
# Iter 127 | Energy = 12.304905
# Iter 128 | Energy = 12.304905
# Iter 129 | Energy = 12.304905
# Iter 130 | Energy = 12.304905
# Iter 131 | Energy = 12.304905
# Iter 132 | Energy = 12.304905
# Iter 133 | Energy = 12.304905
# Iter 134 | Energy = 12.304905
# Iter 135 | Energy = 12.304905
# Iter 136 | Energy = 12.304905
# Iter 137 | Energy = 12.304905
# Iter 138 | Energy = 12.304905
# Iter 139 | Energy = 12.304905
# Iter 140 | Energy = 12.304905
# Iter 141 | Energy = 12.304905
# Iter 142 | Energy = 12.304905
# Iter 143 | Energy = 12.304905
# Iter 144 | Energy = 12.304905
# Iter 145 | Energy = 12.304905
# Iter 146 | Energy = 12.304905
# Iter 147 | Energy = 12.304905
# Iter 148 | Energy = 12.304905
# Iter 149 | Energy = 12.304905
# Iter 150 | Energy = 12.304905
# Iter 151 | Energy = 12.304905
# Iter 152 | Energy = 12.304905
# Iter 153 | Energy = 12.304905
# Iter 154 | Energy = 12.304905
# Iter 155 | Energy = 12.304905
# Iter 156 | Energy = 12.304905
# Iter 157 | Energy = 12.304905
# Iter 158 | Energy = 12.304905
# Iter 159 | Energy = 12.304905
# Iter 160 | Energy = 12.304905
# Iter 161 | Energy = 12.304905
# Iter 162 | Energy = 12.304905
# Iter 163 | Energy = 12.304905
# Iter 164 | Energy = 12.304905
# Iter 165 | Energy = 12.304905
# Iter 166 | Energy = 12.304905
# Iter 167 | Energy = 12.304905
# Iter 168 | Energy = 12.304905
# Iter 169 | Energy = 12.304905
# Iter 170 | Energy = 12.304905
# Iter 171 | Energy = 12.304905
# Iter 172 | Energy = 12.304905
# Iter 173 | Energy = 12.304905
# Iter 174 | Energy = 12.304905
# Iter 175 | Energy = 12.304905
# Iter 176 | Energy = 12.304905
# Iter 177 | Energy = 12.304905
# Iter 178 | Energy = 12.304905
# Iter 179 | Energy = 12.304905
# Iter 180 | Energy = 12.304905
# Iter 181 | Energy = 12.304905
# Iter 182 | Energy = 12.304905
# Iter 183 | Energy = 12.304905
# Iter 184 | Energy = 12.304905
# Iter 185 | Energy = 12.304905
# Iter 186 | Energy = 12.304905
# Iter 187 | Energy = 12.304905
# Iter 188 | Energy = 12.304905
# Iter 189 | Energy = 12.304905
# Iter 190 | Energy = 12.304905
# Iter 191 | Energy = 12.304905
# Iter 192 | Energy = 12.304905
# Iter 193 | Energy = 12.304905
# Iter 194 | Energy = 12.304905
# Iter 195 | Energy = 12.304905
# Iter 196 | Energy = 12.304905
# Iter 197 | Energy = 12.304905
# Iter 198 | Energy = 12.304905
# Iter 199 | Energy = 12.304905
# Iter 200 | Energy = 12.304905
# Iter 201 | Energy = 12.304905
# Iter 202 | Energy = 12.304905
# Iter 203 | Energy = 12.304905
# Iter 204 | Energy = 12.304905
# Iter 205 | Energy = 12.304905
# Iter 206 | Energy = 12.304905
# Iter 207 | Energy = 12.304905
# Iter 208 | Energy = 12.304905
# Iter 209 | Energy = 12.304905
# Iter 210 | Energy = 12.304905
# Iter 211 | Energy = 12.304905
# Iter 212 | Energy = 12.304905
# Iter 213 | Energy = 12.304905
# Iter 214 | Energy = 12.304905
# Iter 215 | Energy = 12.304905
# Iter 216 | Energy = 12.304905
# Iter 217 | Energy = 12.304905
# Iter 218 | Energy = 12.304905
# Iter 219 | Energy = 12.304905
# Iter 220 | Energy = 12.304905
# Iter 221 | Energy = 12.304905
# Iter 222 | Energy = 12.304905
# Iter 223 | Energy = 12.304905
# Iter 224 | Energy = 12.304905
# Iter 225 | Energy = 12.304905
# Iter 226 | Energy = 12.304905
# Iter 227 | Energy = 12.304905
# Iter 228 | Energy = 12.304905
# Iter 229 | Energy = 12.304905
# Iter 230 | Energy = 12.304905
# Iter 231 | Energy = 12.304905
# Iter 232 | Energy = 12.304905
# Iter 233 | Energy = 12.304905
# Iter 234 | Energy = 12.304905
# Iter 235 | Energy = 12.304905
# Iter 236 | Energy = 12.304905
# Iter 237 | Energy = 12.304905
# Iter 238 | Energy = 12.304905
# Iter 239 | Energy = 12.304905
# Iter 240 | Energy = 12.304905
# Iter 241 | Energy = 12.304905
# Iter 242 | Energy = 12.304905
# Iter 243 | Energy = 12.304905
# Iter 244 | Energy = 12.304905
# Iter 245 | Energy = 12.304905
# Iter 246 | Energy = 12.304905
# Iter 247 | Energy = 12.304905
# Iter 248 | Energy = 12.304905
# Iter 249 | Energy = 12.304905
# Iter 250 | Energy = 12.304905
# Iter 251 | Energy = 12.304905
# Iter 252 | Energy = 12.304905
# Iter 253 | Energy = 12.304905
# Iter 254 | Energy = 12.304905
# Iter 255 | Energy = 12.304905
# Iter 256 | Energy = 12.304905
# Iter 257 | Energy = 12.304905
# Iter 258 | Energy = 12.304905
# Iter 259 | Energy = 12.304905
# Iter 260 | Energy = 12.304905
# Iter 261 | Energy = 12.304905
# Iter 262 | Energy = 12.304905
# Iter 263 | Energy = 12.304905
# Iter 264 | Energy = 12.304905
# Iter 265 | Energy = 12.304905
# Iter 266 | Energy = 12.304905
# Iter 267 | Energy = 12.304905
# Iter 268 | Energy = 12.304905
# Iter 269 | Energy = 12.304905
# Iter 270 | Energy = 12.304905
# Iter 271 | Energy = 12.304905
# Iter 272 | Energy = 12.304905
# Iter 273 | Energy = 12.304905
# Iter 274 | Energy = 12.304905
# Iter 275 | Energy = 12.304905
# Iter 276 | Energy = 12.304905
# Iter 277 | Energy = 12.304905
# Iter 278 | Energy = 12.304905
# Iter 279 | Energy = 12.304905
# Iter 280 | Energy = 12.304905
# Iter 281 | Energy = 12.304905
# Iter 282 | Energy = 12.304905
# Iter 283 | Energy = 12.304905
# Iter 284 | Energy = 12.304905
# Iter 285 | Energy = 12.304905
# Iter 286 | Energy = 12.304905
# Iter 287 | Energy = 12.304905
# Iter 288 | Energy = 12.304905
# Iter 289 | Energy = 12.304905
# Iter 290 | Energy = 12.304905
# Iter 291 | Energy = 12.304905
# Iter 292 | Energy = 12.304905
# Iter 293 | Energy = 12.304905
# Iter 294 | Energy = 12.304905
# Iter 295 | Energy = 12.304905
# Iter 296 | Energy = 12.304905
# Iter 297 | Energy = 12.304905
# Iter 298 | Energy = 12.304905
# Iter 299 | Energy = 12.304905
# Iter 300 | Energy = 12.304905
# Iter 301 | Energy = 12.304905
# Iter 302 | Energy = 12.304905
# Iter 303 | Energy = 12.304905
# Iter 304 | Energy = 12.304905
# Iter 305 | Energy = 12.304905
# Iter 306 | Energy = 12.304905
# Iter 307 | Energy = 12.304905
# Iter 308 | Energy = 12.304905
# Iter 309 | Energy = 12.304905
# Iter 310 | Energy = 12.304905
# Iter 311 | Energy = 12.304905
# Iter 312 | Energy = 12.304905
# Iter 313 | Energy = 12.304905
# Iter 314 | Energy = 12.304905
# Iter 315 | Energy = 12.304905
# Iter 316 | Energy = 12.304905
# Iter 317 | Energy = 12.304905
# Iter 318 | Energy = 12.304905
# Iter 319 | Energy = 12.304905
# Iter 320 | Energy = 12.304905
# Iter 321 | Energy = 12.304905
# Iter 322 | Energy = 12.304905
# Iter 323 | Energy = 12.304905
# Iter 324 | Energy = 12.304905
# Iter 325 | Energy = 12.304905
# Iter 326 | Energy = 12.304905
# Iter 327 | Energy = 12.304905
# Iter 328 | Energy = 12.304905
# Iter 329 | Energy = 12.304905
# Iter 330 | Energy = 12.304905
# Iter 331 | Energy = 12.304905
# Iter 332 | Energy = 12.304905
# Iter 333 | Energy = 12.304905
# Iter 334 | Energy = 12.304905
# Iter 335 | Energy = 12.304905
# Iter 336 | Energy = 12.304905
# Iter 337 | Energy = 12.304905
# Iter 338 | Energy = 12.304905
# Iter 339 | Energy = 12.304905
# Iter 340 | Energy = 12.304905
# Iter 341 | Energy = 12.304905
# Iter 342 | Energy = 12.304905
# Iter 343 | Energy = 12.304905
# Iter 344 | Energy = 12.304905
# Iter 345 | Energy = 12.304905
# Iter 346 | Energy = 12.304905
# Iter 347 | Energy = 12.304905
# Iter 348 | Energy = 12.304905
# Iter 349 | Energy = 12.304905
# Iter 350 | Energy = 12.304905
# Iter 351 | Energy = 12.304905
# Iter 352 | Energy = 12.304905
# Iter 353 | Energy = 12.304905
# Iter 354 | Energy = 12.304905
# Iter 355 | Energy = 12.304905
# Iter 356 | Energy = 12.304905
# Iter 357 | Energy = 12.304905
# Iter 358 | Energy = 12.304905
# Iter 359 | Energy = 12.304905
# Iter 360 | Energy = 12.304905
# Iter 361 | Energy = 12.304905
# Iter 362 | Energy = 12.304905
# Iter 968 | Energy = 12.304905
# Iter 969 | Energy = 12.304905
# Iter 970 | Energy = 12.304905
# Iter 971 | Energy = 12.304905
# Iter 972 | Energy = 12.304905
# Iter 973 | Energy = 12.304905
# Iter 974 | Energy = 12.304905
# Iter 975 | Energy = 12.304905
# Iter 976 | Energy = 12.304905
# Iter 977 | Energy = 12.304905
# Iter 978 | Energy = 12.304905
# Iter 979 | Energy = 12.304905
# Iter 980 | Energy = 12.304905
# Iter 981 | Energy = 12.304905
# Iter 982 | Energy = 12.304905
# Iter 983 | Energy = 12.304905
# Iter 984 | Energy = 12.304905
# Iter 985 | Energy = 12.304905
# Iter 986 | Energy = 12.304905
# Iter 987 | Energy = 12.304905
# Iter 988 | Energy = 12.304905
# Iter 989 | Energy = 12.304905
# Iter 990 | Energy = 12.304905
# Iter 991 | Energy = 12.304905
# Iter 992 | Energy = 12.304905
# Iter 993 | Energy = 12.304905
# Iter 994 | Energy = 12.304905
# Iter 995 | Energy = 12.304905
# Iter 996 | Energy = 12.304905
# Iter 997 | Energy = 12.304905
# Iter 998 | Energy = 12.304905
# Iter 999 | Energy = 12.304905
# Iter 1000 | Energy = 12.304905

# %%
# -----------------------
# 初始化 & 边界
# -----------------------
def init_layers(N=100, step_size=25, loop_prob=0.05, loop_radius=50, prior_prop=0.0):
    base_nodes, base_edges = make_slam_like_graph(N, step_size, loop_prob, loop_radius, prior_prop)
    return [{"name": "base", "nodes": base_nodes, "edges": base_edges}]

# %%
layers = []


N=50, step=25, prob=0.1, radius=50, prior_prop=0.1
layers = init_layers(N, step, prob, radius, prior_prop)
pair_idx = 0


prior_sigma=10.0, odom_sigma=10.0

# 构建 GBP 图
gbp_graph = build_noisy_pose_graph(layers[0]["nodes"], layers[0]["edges"],
                                    prior_sigma=prior_sigma,
                                    odom_sigma=odom_sigma
                                    )
layers[0]["graph"] = gbp_graph
opts=[{"label":"base","value":"base"}]


if triggered == "add-layer":
    idx = next(i for i,L in enumerate(layers) if L["name"] == current_value)
    layers = layers[:idx+1]
    last = layers[-1]
    kind, k = parse_layer_name(last["name"])
    pair_idx = highest_pair_idx([L["name"] for L in layers])
    if kind == "super":
        abs_layer_idx = k*2
        abs_nodes, abs_edges = copy_to_abs(last["nodes"], last["edges"], abs_layer_idx)
        layers.append({"name":f"abs{k}", "nodes":abs_nodes, "edges":abs_edges})
    else:
        k_next = pair_idx + 1
        super_layer_idx = k_next*2 - 1
        if mode == "grid":
            super_nodes, super_edges, node_map = fuse_to_super_grid(last["nodes"], last["edges"], int(gx or 2), int(gy or 2), super_layer_idx)
        else:
            super_nodes, super_edges, node_map = fuse_to_super_knn(last["nodes"], last["edges"], int(kk or 8), super_layer_idx)
        layers.append({"name":f"super{k_next}", "nodes":super_nodes, "edges":super_edges, "node_map":node_map})
        layers[super_layer_idx]["graph"] = build_super_graph(layers)

        pair_idx = k_next

# %%
import numpy as np
from gbp.gbp import FactorGraph, VariableNode, Factor

# -----------------------
# SLAM-like base graph
# -----------------------
def make_slam_like_graph(N=100, step_size=25, loop_prob=0.2, loop_radius=50, rng=None):
    if rng is None:
        rng = np.random.default_rng()

    nodes, edges = [], []
    positions = []
    x, y = 0.0, 0.0
    positions.append((x, y))

    # 随机游走生成轨迹
    for _ in range(1, int(N)):
        dx, dy = rng.normal(size=2)
        norm = np.sqrt(dx**2 + dy**2) + 1e-6
        dx, dy = dx / norm * float(step_size), dy / norm * float(step_size)
        x, y = x + dx, y + dy
        positions.append((x, y))

    # 节点
    for i, (px, py) in enumerate(positions):
        nodes.append({
            "data": {"id": f"b{i}", "layer": 0, "dim": 2},
            "position": {"x": float(px), "y": float(py)}
        })

    # 顺序边
    for i in range(int(N) - 1):
        edges.append({"data": {"source": f"b{i}", "target": f"b{i+1}"}})

    # 随机回环
    for i in range(int(N)):
        for j in range(i + 5, int(N)):
            if rng.random() < float(loop_prob):
                xi, yi = positions[i]; xj, yj = positions[j]
                if np.hypot(xi-xj, yi-yj) < float(loop_radius):
                    edges.append({"data": {"source": f"b{i}", "target": f"b{j}"}})
    return nodes, edges




def build_noisy_pose_graph(
    nodes,
    edges,
    prior_sigma: float = 10,
    odom_sigma: float = 10,
    prior_prop: float = 0.0,
    tiny_prior: float = 1e-10,
    rng=None,
):
    if rng is None:
        rng = np.random.default_rng()

    fg = FactorGraph(nonlinear_factors=False, eta_damping=0)

    var_nodes = []
    I2 = np.eye(2, dtype=float)
    N = len(nodes)

    # ---- 预生成噪声 ----
    prior_noises = {}
    odom_noises = {}

    # 确定强先验的节点集合
    if prior_prop <= 0.0:
        strong_ids = {0}
    elif prior_prop >= 1.0:
        strong_ids = set(range(N))
    else:
        k = max(1, int(np.floor(prior_prop * N)))
        strong_ids = set(rng.choice(N, size=k, replace=False).tolist())

    # 为 strong prior 节点生成噪声
    for i in strong_ids:
        prior_noises[i] = rng.normal(0.0, prior_sigma, size=2)

    # 为所有边生成噪声
    for e in edges:
        src = e["data"]["source"]; dst = e["data"]["target"]
        if src.startswith("b") and dst.startswith("b"):
            odom_noises[(int(src[1:]), int(dst[1:]))] = rng.normal(0.0, odom_sigma, size=2)

    # ---- 变量节点 ----
    for i, n in enumerate(nodes):
        v = VariableNode(i, dofs=2)
        v.GT = np.array([n["position"]["x"], n["position"]["y"]], dtype=float)

        # 极小先验
        v.prior.lam = tiny_prior * I2
        v.prior.eta = np.zeros(2, dtype=float)

        var_nodes.append(v)

    fg.var_nodes = var_nodes
    fg.n_var_nodes = len(var_nodes)

    # ---- prior factors ----
    factors = []
    fid = 0
    for i in strong_ids:
        vi = var_nodes[i]
        lam_strong = I2 / (prior_sigma ** 2)
        z = vi.GT + prior_noises[i]

        def meas_fn_unary(x, *args):
            return x
        def jac_fn_unary(x, *args):
            return np.eye(2)

        f = Factor(fid, [vi], z, prior_sigma, meas_fn_unary, jac_fn_unary)
        f.type = "prior"
        f.compute_factor(linpoint=z, update_self=True)

        factors.append(f)
        vi.adj_factors.append(f)
        fid += 1

    # ---- odometry factors ----
    def meas_fn(xy, *args):
        return xy[2:] - xy[:2]
    def jac_fn(xy, *args):
        return np.array([[-1, 0, 1, 0],
                         [ 0,-1, 0, 1]], dtype=float)

    for e in edges:
        src = e["data"]["source"]; dst = e["data"]["target"]
        if not (src.startswith("b") and dst.startswith("b")):
            continue
        i, j = int(src[1:]), int(dst[1:])
        vi, vj = var_nodes[i], var_nodes[j]

        meas = (vj.GT - vi.GT) + odom_noises[(i, j)]

        f = Factor(fid, [vi, vj], meas, odom_sigma, meas_fn, jac_fn)
        f.type = "base"
        linpoint = np.r_[vi.GT, vj.GT]
        f.compute_factor(linpoint=linpoint, update_self=True)

        factors.append(f)
        vi.adj_factors.append(f)
        vj.adj_factors.append(f)
        fid += 1

    fg.factors = factors
    fg.n_factor_nodes = len(factors)
    return fg



# -----------------------
# 主程序：跑 100 次迭代
# -----------------------
if __name__ == "__main__":
    rng = np.random.default_rng(42)  # 固定随机种子

    # 1. 造一个图
    nodes, edges = make_slam_like_graph(N=50, step_size=25, loop_prob=0.1, loop_radius=50, rng=rng)

    # 2. 构建 GBP 图
    fg = build_noisy_pose_graph(nodes, edges, prior_sigma=10.0, odom_sigma=10.0, prior_prop=0.1, rng=rng)

    # 3. 跑迭代
    for it in range(1000):
        fg.synchronous_iteration()
        energy = fg.energy_map(include_priors=True, include_factors=True)
        print(f"Iter {it+1:03d} | Energy = {energy:.6f}")
# Out:
# Iter 001 | Energy = 736.609303
# Iter 002 | Energy = 875.120492
# Iter 003 | Energy = 1010.758653
# Iter 004 | Energy = 613.047975
# Iter 005 | Energy = 198.667459
# Iter 006 | Energy = 48.870660
# Iter 007 | Energy = 34.180285
# Iter 008 | Energy = 26.933797
# Iter 009 | Energy = 24.075363
# Iter 010 | Energy = 23.071562
# Iter 011 | Energy = 22.035149
# Iter 012 | Energy = 21.511796
# Iter 013 | Energy = 21.224165
# Iter 014 | Energy = 21.028798
# Iter 015 | Energy = 20.874596
# Iter 016 | Energy = 20.773675
# Iter 017 | Energy = 20.700691
# Iter 018 | Energy = 20.652154
# Iter 019 | Energy = 20.611446
# Iter 020 | Energy = 20.579389
# Iter 021 | Energy = 20.555237
# Iter 022 | Energy = 20.535371
# Iter 023 | Energy = 20.518726
# Iter 024 | Energy = 20.504865
# Iter 025 | Energy = 20.493166
# Iter 026 | Energy = 20.483322
# Iter 027 | Energy = 20.474894
# Iter 028 | Energy = 20.467642
# Iter 029 | Energy = 20.461428
# Iter 030 | Energy = 20.456041
# Iter 031 | Energy = 20.451377
# Iter 032 | Energy = 20.447349
# Iter 033 | Energy = 20.443859
# Iter 034 | Energy = 20.440838
# Iter 035 | Energy = 20.438216
# Iter 036 | Energy = 20.435940
# Iter 037 | Energy = 20.433967
# Iter 038 | Energy = 20.432252
# Iter 039 | Energy = 20.430765
# Iter 040 | Energy = 20.429474
# Iter 041 | Energy = 20.428353
# Iter 042 | Energy = 20.427379
# Iter 043 | Energy = 20.426534
# Iter 044 | Energy = 20.425800
# Iter 045 | Energy = 20.425162
# Iter 046 | Energy = 20.424609
# Iter 047 | Energy = 20.424128
# Iter 048 | Energy = 20.423710
# Iter 049 | Energy = 20.423348
# Iter 050 | Energy = 20.423033
# Iter 051 | Energy = 20.422759
# Iter 052 | Energy = 20.422521
# Iter 053 | Energy = 20.422315
# Iter 054 | Energy = 20.422136
# Iter 055 | Energy = 20.421980
# Iter 056 | Energy = 20.421845
# Iter 057 | Energy = 20.421728
# Iter 058 | Energy = 20.421626
# Iter 059 | Energy = 20.421537
# Iter 060 | Energy = 20.421460
# Iter 061 | Energy = 20.421394
# Iter 062 | Energy = 20.421336
# Iter 063 | Energy = 20.421285
# Iter 064 | Energy = 20.421241
# Iter 065 | Energy = 20.421203
# Iter 066 | Energy = 20.421170
# Iter 067 | Energy = 20.421142
# Iter 068 | Energy = 20.421117
# Iter 069 | Energy = 20.421095
# Iter 070 | Energy = 20.421076
# Iter 071 | Energy = 20.421060
# Iter 072 | Energy = 20.421046
# Iter 073 | Energy = 20.421034
# Iter 074 | Energy = 20.421023
# Iter 075 | Energy = 20.421014
# Iter 076 | Energy = 20.421005
# Iter 077 | Energy = 20.420998
# Iter 078 | Energy = 20.420992
# Iter 079 | Energy = 20.420987
# Iter 080 | Energy = 20.420983
# Iter 081 | Energy = 20.420979
# Iter 082 | Energy = 20.420975
# Iter 083 | Energy = 20.420972
# Iter 084 | Energy = 20.420969
# Iter 085 | Energy = 20.420967
# Iter 086 | Energy = 20.420965
# Iter 087 | Energy = 20.420964
# Iter 088 | Energy = 20.420962
# Iter 089 | Energy = 20.420961
# Iter 090 | Energy = 20.420960
# Iter 091 | Energy = 20.420959
# Iter 092 | Energy = 20.420958
# Iter 093 | Energy = 20.420957
# Iter 094 | Energy = 20.420956
# Iter 095 | Energy = 20.420956
# Iter 096 | Energy = 20.420955
# Iter 097 | Energy = 20.420955
# Iter 098 | Energy = 20.420955
# Iter 099 | Energy = 20.420954
# Iter 100 | Energy = 20.420954
# Iter 101 | Energy = 20.420954
# Iter 102 | Energy = 20.420954
# Iter 103 | Energy = 20.420953
# Iter 104 | Energy = 20.420953
# Iter 105 | Energy = 20.420953
# Iter 106 | Energy = 20.420953
# Iter 107 | Energy = 20.420953
# Iter 108 | Energy = 20.420953
# Iter 109 | Energy = 20.420953
# Iter 110 | Energy = 20.420953
# Iter 111 | Energy = 20.420953
# Iter 112 | Energy = 20.420953
# Iter 113 | Energy = 20.420952
# Iter 114 | Energy = 20.420952
# Iter 115 | Energy = 20.420952
# Iter 116 | Energy = 20.420952
# Iter 117 | Energy = 20.420952
# Iter 118 | Energy = 20.420952
# Iter 119 | Energy = 20.420952
# Iter 120 | Energy = 20.420952
# Iter 121 | Energy = 20.420952
# Iter 122 | Energy = 20.420952
# Iter 123 | Energy = 20.420952
# Iter 124 | Energy = 20.420952
# Iter 125 | Energy = 20.420952
# Iter 126 | Energy = 20.420952
# Iter 127 | Energy = 20.420952
# Iter 128 | Energy = 20.420952
# Iter 129 | Energy = 20.420952
# Iter 130 | Energy = 20.420952
# Iter 131 | Energy = 20.420952
# Iter 132 | Energy = 20.420952
# Iter 133 | Energy = 20.420952
# Iter 134 | Energy = 20.420952
# Iter 135 | Energy = 20.420952
# Iter 136 | Energy = 20.420952
# Iter 137 | Energy = 20.420952
# Iter 138 | Energy = 20.420952
# Iter 139 | Energy = 20.420952
# Iter 140 | Energy = 20.420952
# Iter 141 | Energy = 20.420952
# Iter 142 | Energy = 20.420952
# Iter 143 | Energy = 20.420952
# Iter 144 | Energy = 20.420952
# Iter 145 | Energy = 20.420952
# Iter 146 | Energy = 20.420952
# Iter 147 | Energy = 20.420952
# Iter 148 | Energy = 20.420952
# Iter 149 | Energy = 20.420952
# Iter 150 | Energy = 20.420952
# Iter 151 | Energy = 20.420952
# Iter 152 | Energy = 20.420952
# Iter 153 | Energy = 20.420952
# Iter 154 | Energy = 20.420952
# Iter 155 | Energy = 20.420952
# Iter 156 | Energy = 20.420952
# Iter 157 | Energy = 20.420952
# Iter 158 | Energy = 20.420952
# Iter 159 | Energy = 20.420952
# Iter 160 | Energy = 20.420952
# Iter 161 | Energy = 20.420952
# Iter 162 | Energy = 20.420952
# Iter 163 | Energy = 20.420952
# Iter 164 | Energy = 20.420952
# Iter 165 | Energy = 20.420952
# Iter 166 | Energy = 20.420952
# Iter 167 | Energy = 20.420952
# Iter 168 | Energy = 20.420952
# Iter 169 | Energy = 20.420952
# Iter 170 | Energy = 20.420952
# Iter 171 | Energy = 20.420952
# Iter 172 | Energy = 20.420952
# Iter 173 | Energy = 20.420952
# Iter 174 | Energy = 20.420952
# Iter 175 | Energy = 20.420952
# Iter 176 | Energy = 20.420952
# Iter 177 | Energy = 20.420952
# Iter 178 | Energy = 20.420952
# Iter 179 | Energy = 20.420952
# Iter 180 | Energy = 20.420952
# Iter 181 | Energy = 20.420952
# Iter 182 | Energy = 20.420952
# Iter 183 | Energy = 20.420952
# Iter 184 | Energy = 20.420952
# Iter 185 | Energy = 20.420952
# Iter 186 | Energy = 20.420952
# Iter 187 | Energy = 20.420952
# Iter 188 | Energy = 20.420952
# Iter 189 | Energy = 20.420952
# Iter 190 | Energy = 20.420952
# Iter 191 | Energy = 20.420952
# Iter 192 | Energy = 20.420952
# Iter 193 | Energy = 20.420952
# Iter 194 | Energy = 20.420952
# Iter 195 | Energy = 20.420952
# Iter 196 | Energy = 20.420952
# Iter 197 | Energy = 20.420952
# Iter 198 | Energy = 20.420952
# Iter 199 | Energy = 20.420952
# Iter 200 | Energy = 20.420952
# Iter 201 | Energy = 20.420952
# Iter 202 | Energy = 20.420952
# Iter 203 | Energy = 20.420952
# Iter 204 | Energy = 20.420952
# Iter 205 | Energy = 20.420952
# Iter 206 | Energy = 20.420952
# Iter 207 | Energy = 20.420952
# Iter 208 | Energy = 20.420952
# Iter 209 | Energy = 20.420952
# Iter 210 | Energy = 20.420952
# Iter 211 | Energy = 20.420952
# Iter 212 | Energy = 20.420952
# Iter 213 | Energy = 20.420952
# Iter 214 | Energy = 20.420952
# Iter 215 | Energy = 20.420952
# Iter 216 | Energy = 20.420952
# Iter 217 | Energy = 20.420952
# Iter 218 | Energy = 20.420952
# Iter 219 | Energy = 20.420952
# Iter 220 | Energy = 20.420952
# Iter 221 | Energy = 20.420952
# Iter 222 | Energy = 20.420952
# Iter 223 | Energy = 20.420952
# Iter 224 | Energy = 20.420952
# Iter 225 | Energy = 20.420952
# Iter 226 | Energy = 20.420952
# Iter 227 | Energy = 20.420952
# Iter 228 | Energy = 20.420952
# Iter 229 | Energy = 20.420952
# Iter 230 | Energy = 20.420952
# Iter 231 | Energy = 20.420952
# Iter 232 | Energy = 20.420952
# Iter 233 | Energy = 20.420952
# Iter 234 | Energy = 20.420952
# Iter 235 | Energy = 20.420952
# Iter 236 | Energy = 20.420952
# Iter 237 | Energy = 20.420952
# Iter 238 | Energy = 20.420952
# Iter 239 | Energy = 20.420952
# Iter 240 | Energy = 20.420952
# Iter 241 | Energy = 20.420952
# Iter 242 | Energy = 20.420952
# Iter 243 | Energy = 20.420952
# Iter 244 | Energy = 20.420952
# Iter 245 | Energy = 20.420952
# Iter 246 | Energy = 20.420952
# Iter 247 | Energy = 20.420952
# Iter 248 | Energy = 20.420952
# Iter 249 | Energy = 20.420952
# Iter 250 | Energy = 20.420952
# Iter 251 | Energy = 20.420952
# Iter 252 | Energy = 20.420952
# Iter 253 | Energy = 20.420952
# Iter 254 | Energy = 20.420952
# Iter 255 | Energy = 20.420952
# Iter 256 | Energy = 20.420952
# Iter 257 | Energy = 20.420952
# Iter 258 | Energy = 20.420952
# Iter 259 | Energy = 20.420952
# Iter 260 | Energy = 20.420952
# Iter 261 | Energy = 20.420952
# Iter 262 | Energy = 20.420952
# Iter 263 | Energy = 20.420952
# Iter 264 | Energy = 20.420952
# Iter 265 | Energy = 20.420952
# Iter 266 | Energy = 20.420952
# Iter 267 | Energy = 20.420952
# Iter 268 | Energy = 20.420952
# Iter 269 | Energy = 20.420952
# Iter 270 | Energy = 20.420952
# Iter 271 | Energy = 20.420952
# Iter 272 | Energy = 20.420952
# Iter 273 | Energy = 20.420952
# Iter 274 | Energy = 20.420952
# Iter 275 | Energy = 20.420952
# Iter 276 | Energy = 20.420952
# Iter 277 | Energy = 20.420952
# Iter 278 | Energy = 20.420952
# Iter 279 | Energy = 20.420952
# Iter 280 | Energy = 20.420952
# Iter 281 | Energy = 20.420952
# Iter 282 | Energy = 20.420952
# Iter 283 | Energy = 20.420952
# Iter 284 | Energy = 20.420952
# Iter 285 | Energy = 20.420952
# Iter 286 | Energy = 20.420952
# Iter 287 | Energy = 20.420952
# Iter 288 | Energy = 20.420952
# Iter 289 | Energy = 20.420952
# Iter 290 | Energy = 20.420952
# Iter 291 | Energy = 20.420952
# Iter 292 | Energy = 20.420952
# Iter 293 | Energy = 20.420952
# Iter 294 | Energy = 20.420952
# Iter 295 | Energy = 20.420952
# Iter 296 | Energy = 20.420952
# Iter 297 | Energy = 20.420952
# Iter 298 | Energy = 20.420952
# Iter 299 | Energy = 20.420952
# Iter 300 | Energy = 20.420952
# Iter 301 | Energy = 20.420952
# Iter 302 | Energy = 20.420952
# Iter 303 | Energy = 20.420952
# Iter 304 | Energy = 20.420952
# Iter 305 | Energy = 20.420952
# Iter 306 | Energy = 20.420952
# Iter 307 | Energy = 20.420952
# Iter 308 | Energy = 20.420952
# Iter 309 | Energy = 20.420952
# Iter 310 | Energy = 20.420952
# Iter 311 | Energy = 20.420952
# Iter 312 | Energy = 20.420952
# Iter 313 | Energy = 20.420952
# Iter 314 | Energy = 20.420952
# Iter 315 | Energy = 20.420952
# Iter 316 | Energy = 20.420952
# Iter 317 | Energy = 20.420952
# Iter 318 | Energy = 20.420952
# Iter 319 | Energy = 20.420952
# Iter 320 | Energy = 20.420952
# Iter 321 | Energy = 20.420952
# Iter 322 | Energy = 20.420952
# Iter 323 | Energy = 20.420952
# Iter 324 | Energy = 20.420952
# Iter 325 | Energy = 20.420952
# Iter 326 | Energy = 20.420952
# Iter 327 | Energy = 20.420952
# Iter 328 | Energy = 20.420952
# Iter 329 | Energy = 20.420952
# Iter 330 | Energy = 20.420952
# Iter 331 | Energy = 20.420952
# Iter 332 | Energy = 20.420952
# Iter 333 | Energy = 20.420952
# Iter 334 | Energy = 20.420952
# Iter 335 | Energy = 20.420952
# Iter 336 | Energy = 20.420952
# Iter 337 | Energy = 20.420952
# Iter 338 | Energy = 20.420952
# Iter 339 | Energy = 20.420952
# Iter 340 | Energy = 20.420952
# Iter 341 | Energy = 20.420952
# Iter 342 | Energy = 20.420952
# Iter 343 | Energy = 20.420952
# Iter 344 | Energy = 20.420952
# Iter 345 | Energy = 20.420952
# Iter 346 | Energy = 20.420952
# Iter 347 | Energy = 20.420952
# Iter 348 | Energy = 20.420952
# Iter 349 | Energy = 20.420952
# Iter 350 | Energy = 20.420952
# Iter 351 | Energy = 20.420952
# Iter 352 | Energy = 20.420952
# Iter 353 | Energy = 20.420952
# Iter 354 | Energy = 20.420952
# Iter 355 | Energy = 20.420952
# Iter 356 | Energy = 20.420952
# Iter 357 | Energy = 20.420952
# Iter 358 | Energy = 20.420952
# Iter 359 | Energy = 20.420952
# Iter 360 | Energy = 20.420952
# Iter 361 | Energy = 20.420952
# Iter 362 | Energy = 20.420952
# Iter 363 | Energy = 20.420952
# Iter 364 | Energy = 20.420952
# Iter 365 | Energy = 20.420952
# Iter 366 | Energy = 20.420952
# Iter 367 | Energy = 20.420952
# Iter 368 | Energy = 20.420952
# Iter 369 | Energy = 20.420952
# Iter 370 | Energy = 20.420952
# Iter 371 | Energy = 20.420952
# Iter 372 | Energy = 20.420952
# Iter 373 | Energy = 20.420952
# Iter 374 | Energy = 20.420952
# Iter 375 | Energy = 20.420952
# Iter 376 | Energy = 20.420952
# Iter 377 | Energy = 20.420952
# Iter 378 | Energy = 20.420952
# Iter 379 | Energy = 20.420952
# Iter 380 | Energy = 20.420952
# Iter 381 | Energy = 20.420952
# Iter 382 | Energy = 20.420952
# Iter 383 | Energy = 20.420952
# Iter 384 | Energy = 20.420952
# Iter 385 | Energy = 20.420952
# Iter 386 | Energy = 20.420952
# Iter 387 | Energy = 20.420952
# Iter 388 | Energy = 20.420952
# Iter 389 | Energy = 20.420952
# Iter 390 | Energy = 20.420952
# Iter 391 | Energy = 20.420952
# Iter 392 | Energy = 20.420952
# Iter 393 | Energy = 20.420952
# Iter 394 | Energy = 20.420952
# Iter 395 | Energy = 20.420952
# Iter 396 | Energy = 20.420952
# Iter 397 | Energy = 20.420952
# Iter 398 | Energy = 20.420952
# Iter 399 | Energy = 20.420952
# Iter 400 | Energy = 20.420952
# Iter 401 | Energy = 20.420952
# Iter 402 | Energy = 20.420952
# Iter 403 | Energy = 20.420952
# Iter 404 | Energy = 20.420952
# Iter 405 | Energy = 20.420952
# Iter 406 | Energy = 20.420952
# Iter 407 | Energy = 20.420952
# Iter 408 | Energy = 20.420952
# Iter 409 | Energy = 20.420952
# Iter 410 | Energy = 20.420952
# Iter 411 | Energy = 20.420952
# Iter 412 | Energy = 20.420952
# Iter 413 | Energy = 20.420952
# Iter 414 | Energy = 20.420952
# Iter 415 | Energy = 20.420952
# Iter 416 | Energy = 20.420952
# Iter 417 | Energy = 20.420952
# Iter 418 | Energy = 20.420952
# Iter 419 | Energy = 20.420952
# Iter 420 | Energy = 20.420952
# Iter 421 | Energy = 20.420952
# Iter 422 | Energy = 20.420952
# Iter 423 | Energy = 20.420952
# Iter 424 | Energy = 20.420952
# Iter 425 | Energy = 20.420952
# Iter 426 | Energy = 20.420952
# Iter 427 | Energy = 20.420952
# Iter 428 | Energy = 20.420952
# Iter 429 | Energy = 20.420952
# Iter 430 | Energy = 20.420952
# Iter 431 | Energy = 20.420952
# Iter 432 | Energy = 20.420952
# Iter 433 | Energy = 20.420952
# Iter 434 | Energy = 20.420952
# Iter 435 | Energy = 20.420952
# Iter 436 | Energy = 20.420952
# Iter 437 | Energy = 20.420952
# Iter 438 | Energy = 20.420952
# Iter 439 | Energy = 20.420952
# Iter 440 | Energy = 20.420952
# Iter 441 | Energy = 20.420952
# Iter 442 | Energy = 20.420952
# Iter 443 | Energy = 20.420952
# Iter 444 | Energy = 20.420952
# Iter 445 | Energy = 20.420952
# Iter 446 | Energy = 20.420952
# Iter 447 | Energy = 20.420952
# Iter 448 | Energy = 20.420952
# Iter 449 | Energy = 20.420952
# Iter 450 | Energy = 20.420952
# Iter 451 | Energy = 20.420952
# Iter 452 | Energy = 20.420952
# Iter 453 | Energy = 20.420952
# Iter 454 | Energy = 20.420952
# Iter 455 | Energy = 20.420952
# Iter 456 | Energy = 20.420952
# Iter 457 | Energy = 20.420952
# Iter 458 | Energy = 20.420952
# Iter 459 | Energy = 20.420952
# Iter 460 | Energy = 20.420952
# Iter 461 | Energy = 20.420952
# Iter 462 | Energy = 20.420952
# Iter 463 | Energy = 20.420952
# Iter 464 | Energy = 20.420952
# Iter 465 | Energy = 20.420952
# Iter 466 | Energy = 20.420952
# Iter 467 | Energy = 20.420952
# Iter 468 | Energy = 20.420952
# Iter 469 | Energy = 20.420952
# Iter 470 | Energy = 20.420952
# Iter 471 | Energy = 20.420952
# Iter 472 | Energy = 20.420952
# Iter 473 | Energy = 20.420952
# Iter 474 | Energy = 20.420952
# Iter 475 | Energy = 20.420952
# Iter 476 | Energy = 20.420952
# Iter 477 | Energy = 20.420952
# Iter 478 | Energy = 20.420952
# Iter 479 | Energy = 20.420952
# Iter 480 | Energy = 20.420952
# Iter 481 | Energy = 20.420952
# Iter 482 | Energy = 20.420952
# Iter 483 | Energy = 20.420952
# Iter 484 | Energy = 20.420952
# Iter 485 | Energy = 20.420952
# Iter 486 | Energy = 20.420952
# Iter 487 | Energy = 20.420952
# Iter 488 | Energy = 20.420952
# Iter 489 | Energy = 20.420952
# Iter 490 | Energy = 20.420952
# Iter 491 | Energy = 20.420952
# Iter 492 | Energy = 20.420952
# Iter 493 | Energy = 20.420952
# Iter 494 | Energy = 20.420952
# Iter 495 | Energy = 20.420952
# Iter 496 | Energy = 20.420952
# Iter 497 | Energy = 20.420952
# Iter 498 | Energy = 20.420952
# Iter 499 | Energy = 20.420952
# Iter 500 | Energy = 20.420952
# Iter 501 | Energy = 20.420952
# Iter 502 | Energy = 20.420952
# Iter 503 | Energy = 20.420952
# Iter 504 | Energy = 20.420952
# Iter 505 | Energy = 20.420952
# Iter 506 | Energy = 20.420952
# Iter 507 | Energy = 20.420952
# Iter 508 | Energy = 20.420952
# Iter 509 | Energy = 20.420952
# Iter 510 | Energy = 20.420952
# Iter 511 | Energy = 20.420952
# Iter 512 | Energy = 20.420952
# Iter 513 | Energy = 20.420952
# Iter 514 | Energy = 20.420952
# Iter 515 | Energy = 20.420952
# Iter 516 | Energy = 20.420952
# Iter 517 | Energy = 20.420952
# Iter 518 | Energy = 20.420952
# Iter 519 | Energy = 20.420952
# Iter 520 | Energy = 20.420952
# Iter 521 | Energy = 20.420952
# Iter 522 | Energy = 20.420952
# Iter 523 | Energy = 20.420952
# Iter 524 | Energy = 20.420952
# Iter 525 | Energy = 20.420952
# Iter 526 | Energy = 20.420952
# Iter 527 | Energy = 20.420952
# Iter 528 | Energy = 20.420952
# Iter 529 | Energy = 20.420952
# Iter 530 | Energy = 20.420952
# Iter 531 | Energy = 20.420952
# Iter 532 | Energy = 20.420952
# Iter 533 | Energy = 20.420952
# Iter 534 | Energy = 20.420952
# Iter 535 | Energy = 20.420952
# Iter 536 | Energy = 20.420952
# Iter 537 | Energy = 20.420952
# Iter 538 | Energy = 20.420952
# Iter 539 | Energy = 20.420952
# Iter 540 | Energy = 20.420952
# Iter 541 | Energy = 20.420952
# Iter 542 | Energy = 20.420952
# Iter 543 | Energy = 20.420952
# Iter 544 | Energy = 20.420952
# Iter 545 | Energy = 20.420952
# Iter 546 | Energy = 20.420952
# Iter 547 | Energy = 20.420952
# Iter 548 | Energy = 20.420952
# Iter 549 | Energy = 20.420952
# Iter 550 | Energy = 20.420952
# Iter 551 | Energy = 20.420952
# Iter 552 | Energy = 20.420952
# Iter 553 | Energy = 20.420952
# Iter 554 | Energy = 20.420952
# Iter 555 | Energy = 20.420952
# Iter 556 | Energy = 20.420952
# Iter 557 | Energy = 20.420952
# Iter 558 | Energy = 20.420952
# Iter 559 | Energy = 20.420952
# Iter 560 | Energy = 20.420952
# Iter 561 | Energy = 20.420952
# Iter 562 | Energy = 20.420952
# Iter 563 | Energy = 20.420952
# Iter 564 | Energy = 20.420952
# Iter 565 | Energy = 20.420952
# Iter 566 | Energy = 20.420952
# Iter 567 | Energy = 20.420952
# Iter 568 | Energy = 20.420952
# Iter 569 | Energy = 20.420952
# Iter 570 | Energy = 20.420952
# Iter 571 | Energy = 20.420952
# Iter 572 | Energy = 20.420952
# Iter 573 | Energy = 20.420952
# Iter 574 | Energy = 20.420952
# Iter 575 | Energy = 20.420952
# Iter 576 | Energy = 20.420952
# Iter 577 | Energy = 20.420952
# Iter 578 | Energy = 20.420952
# Iter 579 | Energy = 20.420952
# Iter 580 | Energy = 20.420952
# Iter 581 | Energy = 20.420952
# Iter 582 | Energy = 20.420952
# Iter 583 | Energy = 20.420952
# Iter 584 | Energy = 20.420952
# Iter 585 | Energy = 20.420952
# Iter 586 | Energy = 20.420952
# Iter 587 | Energy = 20.420952
# Iter 588 | Energy = 20.420952
# Iter 589 | Energy = 20.420952
# Iter 590 | Energy = 20.420952
# Iter 591 | Energy = 20.420952
# Iter 592 | Energy = 20.420952
# Iter 593 | Energy = 20.420952
# Iter 594 | Energy = 20.420952
# Iter 595 | Energy = 20.420952
# Iter 596 | Energy = 20.420952
# Iter 597 | Energy = 20.420952
# Iter 598 | Energy = 20.420952
# Iter 599 | Energy = 20.420952
# Iter 600 | Energy = 20.420952
# Iter 601 | Energy = 20.420952
# Iter 602 | Energy = 20.420952
# Iter 603 | Energy = 20.420952
# Iter 604 | Energy = 20.420952
# Iter 605 | Energy = 20.420952
# Iter 606 | Energy = 20.420952
# Iter 607 | Energy = 20.420952
# Iter 608 | Energy = 20.420952
# Iter 609 | Energy = 20.420952
# Iter 610 | Energy = 20.420952
# Iter 611 | Energy = 20.420952
# Iter 612 | Energy = 20.420952
# Iter 613 | Energy = 20.420952
# Iter 614 | Energy = 20.420952
# Iter 615 | Energy = 20.420952
# Iter 616 | Energy = 20.420952
# Iter 617 | Energy = 20.420952
# Iter 618 | Energy = 20.420952
# Iter 619 | Energy = 20.420952
# Iter 620 | Energy = 20.420952
# Iter 621 | Energy = 20.420952
# Iter 622 | Energy = 20.420952
# Iter 623 | Energy = 20.420952
# Iter 624 | Energy = 20.420952
# Iter 625 | Energy = 20.420952
# Iter 626 | Energy = 20.420952
# Iter 627 | Energy = 20.420952
# Iter 628 | Energy = 20.420952
# Iter 629 | Energy = 20.420952
# Iter 630 | Energy = 20.420952
# Iter 631 | Energy = 20.420952
# Iter 632 | Energy = 20.420952
# Iter 633 | Energy = 20.420952
# Iter 634 | Energy = 20.420952
# Iter 635 | Energy = 20.420952
# Iter 636 | Energy = 20.420952
# Iter 637 | Energy = 20.420952
# Iter 638 | Energy = 20.420952
# Iter 639 | Energy = 20.420952
# Iter 640 | Energy = 20.420952
# Iter 641 | Energy = 20.420952
# Iter 642 | Energy = 20.420952
# Iter 643 | Energy = 20.420952
# Iter 644 | Energy = 20.420952
# Iter 645 | Energy = 20.420952
# Iter 646 | Energy = 20.420952
# Iter 647 | Energy = 20.420952
# Iter 648 | Energy = 20.420952
# Iter 649 | Energy = 20.420952
# Iter 650 | Energy = 20.420952
# Iter 651 | Energy = 20.420952
# Iter 652 | Energy = 20.420952
# Iter 653 | Energy = 20.420952
# Iter 654 | Energy = 20.420952
# Iter 655 | Energy = 20.420952
# Iter 656 | Energy = 20.420952
# Iter 657 | Energy = 20.420952
# Iter 658 | Energy = 20.420952
# Iter 659 | Energy = 20.420952
# Iter 660 | Energy = 20.420952
# Iter 661 | Energy = 20.420952
# Iter 662 | Energy = 20.420952
# Iter 663 | Energy = 20.420952
# Iter 664 | Energy = 20.420952
# Iter 665 | Energy = 20.420952
# Iter 666 | Energy = 20.420952
# Iter 667 | Energy = 20.420952
# Iter 668 | Energy = 20.420952
# Iter 669 | Energy = 20.420952
# Iter 670 | Energy = 20.420952
# Iter 671 | Energy = 20.420952
# Iter 672 | Energy = 20.420952
# Iter 673 | Energy = 20.420952
# Iter 674 | Energy = 20.420952
# Iter 675 | Energy = 20.420952
# Iter 676 | Energy = 20.420952
# Iter 677 | Energy = 20.420952
# Iter 678 | Energy = 20.420952
# Iter 679 | Energy = 20.420952
# Iter 680 | Energy = 20.420952
# Iter 681 | Energy = 20.420952
# Iter 682 | Energy = 20.420952
# Iter 683 | Energy = 20.420952
# Iter 684 | Energy = 20.420952
# Iter 685 | Energy = 20.420952
# Iter 686 | Energy = 20.420952
# Iter 687 | Energy = 20.420952
# Iter 688 | Energy = 20.420952
# Iter 689 | Energy = 20.420952
# Iter 690 | Energy = 20.420952
# Iter 691 | Energy = 20.420952
# Iter 692 | Energy = 20.420952
# Iter 693 | Energy = 20.420952
# Iter 694 | Energy = 20.420952
# Iter 695 | Energy = 20.420952
# Iter 696 | Energy = 20.420952
# Iter 697 | Energy = 20.420952
# Iter 698 | Energy = 20.420952
# Iter 699 | Energy = 20.420952
# Iter 700 | Energy = 20.420952
# Iter 701 | Energy = 20.420952
# Iter 702 | Energy = 20.420952
# Iter 703 | Energy = 20.420952
# Iter 704 | Energy = 20.420952
# Iter 705 | Energy = 20.420952
# Iter 706 | Energy = 20.420952
# Iter 707 | Energy = 20.420952
# Iter 708 | Energy = 20.420952
# Iter 709 | Energy = 20.420952
# Iter 710 | Energy = 20.420952
# Iter 711 | Energy = 20.420952
# Iter 712 | Energy = 20.420952
# Iter 713 | Energy = 20.420952
# Iter 714 | Energy = 20.420952
# Iter 715 | Energy = 20.420952
# Iter 716 | Energy = 20.420952
# Iter 717 | Energy = 20.420952
# Iter 718 | Energy = 20.420952
# Iter 719 | Energy = 20.420952
# Iter 720 | Energy = 20.420952
# Iter 721 | Energy = 20.420952
# Iter 722 | Energy = 20.420952
# Iter 723 | Energy = 20.420952
# Iter 724 | Energy = 20.420952
# Iter 725 | Energy = 20.420952
# Iter 726 | Energy = 20.420952
# Iter 727 | Energy = 20.420952
# Iter 728 | Energy = 20.420952
# Iter 729 | Energy = 20.420952
# Iter 730 | Energy = 20.420952
# Iter 731 | Energy = 20.420952
# Iter 732 | Energy = 20.420952
# Iter 733 | Energy = 20.420952
# Iter 734 | Energy = 20.420952
# Iter 735 | Energy = 20.420952
# Iter 736 | Energy = 20.420952
# Iter 737 | Energy = 20.420952
# Iter 738 | Energy = 20.420952
# Iter 739 | Energy = 20.420952
# Iter 740 | Energy = 20.420952
# Iter 741 | Energy = 20.420952
# Iter 742 | Energy = 20.420952
# Iter 743 | Energy = 20.420952
# Iter 744 | Energy = 20.420952
# Iter 745 | Energy = 20.420952
# Iter 746 | Energy = 20.420952
# Iter 747 | Energy = 20.420952
# Iter 748 | Energy = 20.420952
# Iter 749 | Energy = 20.420952
# Iter 750 | Energy = 20.420952
# Iter 751 | Energy = 20.420952
# Iter 752 | Energy = 20.420952
# Iter 753 | Energy = 20.420952
# Iter 754 | Energy = 20.420952
# Iter 755 | Energy = 20.420952
# Iter 756 | Energy = 20.420952
# Iter 757 | Energy = 20.420952
# Iter 758 | Energy = 20.420952
# Iter 759 | Energy = 20.420952
# Iter 760 | Energy = 20.420952
# Iter 761 | Energy = 20.420952
# Iter 762 | Energy = 20.420952
# Iter 763 | Energy = 20.420952
# Iter 764 | Energy = 20.420952
# Iter 765 | Energy = 20.420952
# Iter 766 | Energy = 20.420952
# Iter 767 | Energy = 20.420952
# Iter 768 | Energy = 20.420952
# Iter 769 | Energy = 20.420952
# Iter 770 | Energy = 20.420952
# Iter 771 | Energy = 20.420952
# Iter 772 | Energy = 20.420952
# Iter 773 | Energy = 20.420952
# Iter 774 | Energy = 20.420952
# Iter 775 | Energy = 20.420952
# Iter 776 | Energy = 20.420952
# Iter 777 | Energy = 20.420952
# Iter 778 | Energy = 20.420952
# Iter 779 | Energy = 20.420952
# Iter 780 | Energy = 20.420952
# Iter 781 | Energy = 20.420952
# Iter 782 | Energy = 20.420952
# Iter 783 | Energy = 20.420952
# Iter 784 | Energy = 20.420952
# Iter 785 | Energy = 20.420952
# Iter 786 | Energy = 20.420952
# Iter 787 | Energy = 20.420952
# Iter 788 | Energy = 20.420952
# Iter 789 | Energy = 20.420952
# Iter 790 | Energy = 20.420952
# Iter 791 | Energy = 20.420952
# Iter 792 | Energy = 20.420952
# Iter 793 | Energy = 20.420952
# Iter 794 | Energy = 20.420952
# Iter 795 | Energy = 20.420952
# Iter 796 | Energy = 20.420952
# Iter 797 | Energy = 20.420952
# Iter 798 | Energy = 20.420952
# Iter 799 | Energy = 20.420952
# Iter 800 | Energy = 20.420952
# Iter 801 | Energy = 20.420952
# Iter 802 | Energy = 20.420952
# Iter 803 | Energy = 20.420952
# Iter 804 | Energy = 20.420952
# Iter 805 | Energy = 20.420952
# Iter 806 | Energy = 20.420952
# Iter 807 | Energy = 20.420952
# Iter 808 | Energy = 20.420952
# Iter 809 | Energy = 20.420952
# Iter 810 | Energy = 20.420952
# Iter 811 | Energy = 20.420952
# Iter 812 | Energy = 20.420952
# Iter 813 | Energy = 20.420952
# Iter 814 | Energy = 20.420952
# Iter 815 | Energy = 20.420952
# Iter 816 | Energy = 20.420952
# Iter 817 | Energy = 20.420952
# Iter 818 | Energy = 20.420952
# Iter 819 | Energy = 20.420952
# Iter 820 | Energy = 20.420952
# Iter 821 | Energy = 20.420952
# Iter 822 | Energy = 20.420952
# Iter 823 | Energy = 20.420952
# Iter 824 | Energy = 20.420952
# Iter 825 | Energy = 20.420952
# Iter 826 | Energy = 20.420952
# Iter 827 | Energy = 20.420952
# Iter 828 | Energy = 20.420952
# Iter 829 | Energy = 20.420952
# Iter 830 | Energy = 20.420952
# Iter 831 | Energy = 20.420952
# Iter 832 | Energy = 20.420952
# Iter 833 | Energy = 20.420952
# Iter 834 | Energy = 20.420952
# Iter 835 | Energy = 20.420952
# Iter 836 | Energy = 20.420952
# Iter 837 | Energy = 20.420952
# Iter 838 | Energy = 20.420952
# Iter 839 | Energy = 20.420952
# Iter 840 | Energy = 20.420952
# Iter 841 | Energy = 20.420952
# Iter 842 | Energy = 20.420952
# Iter 843 | Energy = 20.420952
# Iter 844 | Energy = 20.420952
# Iter 845 | Energy = 20.420952
# Iter 846 | Energy = 20.420952
# Iter 847 | Energy = 20.420952
# Iter 848 | Energy = 20.420952
# Iter 849 | Energy = 20.420952
# Iter 850 | Energy = 20.420952
# Iter 851 | Energy = 20.420952
# Iter 852 | Energy = 20.420952
# Iter 853 | Energy = 20.420952
# Iter 854 | Energy = 20.420952
# Iter 855 | Energy = 20.420952
# Iter 856 | Energy = 20.420952
# Iter 857 | Energy = 20.420952
# Iter 858 | Energy = 20.420952
# Iter 859 | Energy = 20.420952
# Iter 860 | Energy = 20.420952
# Iter 861 | Energy = 20.420952
# Iter 862 | Energy = 20.420952
# Iter 863 | Energy = 20.420952
# Iter 864 | Energy = 20.420952
# Iter 865 | Energy = 20.420952
# Iter 866 | Energy = 20.420952
# Iter 867 | Energy = 20.420952
# Iter 868 | Energy = 20.420952
# Iter 869 | Energy = 20.420952
# Iter 870 | Energy = 20.420952
# Iter 871 | Energy = 20.420952
# Iter 872 | Energy = 20.420952
# Iter 873 | Energy = 20.420952
# Iter 874 | Energy = 20.420952
# Iter 875 | Energy = 20.420952
# Iter 876 | Energy = 20.420952
# Iter 877 | Energy = 20.420952
# Iter 878 | Energy = 20.420952
# Iter 879 | Energy = 20.420952
# Iter 880 | Energy = 20.420952
# Iter 881 | Energy = 20.420952
# Iter 882 | Energy = 20.420952
# Iter 883 | Energy = 20.420952
# Iter 884 | Energy = 20.420952
# Iter 885 | Energy = 20.420952
# Iter 886 | Energy = 20.420952
# Iter 887 | Energy = 20.420952
# Iter 888 | Energy = 20.420952
# Iter 889 | Energy = 20.420952
# Iter 890 | Energy = 20.420952
# Iter 891 | Energy = 20.420952
# Iter 892 | Energy = 20.420952
# Iter 893 | Energy = 20.420952
# Iter 894 | Energy = 20.420952
# Iter 895 | Energy = 20.420952
# Iter 896 | Energy = 20.420952
# Iter 897 | Energy = 20.420952
# Iter 898 | Energy = 20.420952
# Iter 899 | Energy = 20.420952
# Iter 900 | Energy = 20.420952
# Iter 901 | Energy = 20.420952
# Iter 902 | Energy = 20.420952
# Iter 903 | Energy = 20.420952
# Iter 904 | Energy = 20.420952
# Iter 905 | Energy = 20.420952
# Iter 906 | Energy = 20.420952
# Iter 907 | Energy = 20.420952
# Iter 908 | Energy = 20.420952
# Iter 909 | Energy = 20.420952
# Iter 910 | Energy = 20.420952
# Iter 911 | Energy = 20.420952
# Iter 912 | Energy = 20.420952
# Iter 913 | Energy = 20.420952
# Iter 914 | Energy = 20.420952
# Iter 915 | Energy = 20.420952
# Iter 916 | Energy = 20.420952
# Iter 917 | Energy = 20.420952
# Iter 918 | Energy = 20.420952
# Iter 919 | Energy = 20.420952
# Iter 920 | Energy = 20.420952
# Iter 921 | Energy = 20.420952
# Iter 922 | Energy = 20.420952
# Iter 923 | Energy = 20.420952
# Iter 924 | Energy = 20.420952
# Iter 925 | Energy = 20.420952
# Iter 926 | Energy = 20.420952
# Iter 927 | Energy = 20.420952
# Iter 928 | Energy = 20.420952
# Iter 929 | Energy = 20.420952
# Iter 930 | Energy = 20.420952
# Iter 931 | Energy = 20.420952
# Iter 932 | Energy = 20.420952
# Iter 933 | Energy = 20.420952
# Iter 934 | Energy = 20.420952
# Iter 935 | Energy = 20.420952
# Iter 936 | Energy = 20.420952
# Iter 937 | Energy = 20.420952
# Iter 938 | Energy = 20.420952
# Iter 939 | Energy = 20.420952
# Iter 940 | Energy = 20.420952
# Iter 941 | Energy = 20.420952
# Iter 942 | Energy = 20.420952
# Iter 943 | Energy = 20.420952
# Iter 944 | Energy = 20.420952
# Iter 945 | Energy = 20.420952
# Iter 946 | Energy = 20.420952
# Iter 947 | Energy = 20.420952
# Iter 948 | Energy = 20.420952
# Iter 949 | Energy = 20.420952
# Iter 950 | Energy = 20.420952
# Iter 951 | Energy = 20.420952
# Iter 952 | Energy = 20.420952
# Iter 953 | Energy = 20.420952
# Iter 954 | Energy = 20.420952
# Iter 955 | Energy = 20.420952
# Iter 956 | Energy = 20.420952
# Iter 957 | Energy = 20.420952
# Iter 958 | Energy = 20.420952
# Iter 959 | Energy = 20.420952
# Iter 960 | Energy = 20.420952
# Iter 961 | Energy = 20.420952
# Iter 962 | Energy = 20.420952
# Iter 963 | Energy = 20.420952
# Iter 964 | Energy = 20.420952
# Iter 965 | Energy = 20.420952
# Iter 966 | Energy = 20.420952
# Iter 967 | Energy = 20.420952
# Iter 968 | Energy = 20.420952
# Iter 969 | Energy = 20.420952
# Iter 970 | Energy = 20.420952
# Iter 971 | Energy = 20.420952
# Iter 972 | Energy = 20.420952
# Iter 973 | Energy = 20.420952
# Iter 974 | Energy = 20.420952
# Iter 975 | Energy = 20.420952
# Iter 976 | Energy = 20.420952
# Iter 977 | Energy = 20.420952
# Iter 978 | Energy = 20.420952
# Iter 979 | Energy = 20.420952
# Iter 980 | Energy = 20.420952
# Iter 981 | Energy = 20.420952
# Iter 982 | Energy = 20.420952
# Iter 983 | Energy = 20.420952
# Iter 984 | Energy = 20.420952
# Iter 985 | Energy = 20.420952
# Iter 986 | Energy = 20.420952
# Iter 987 | Energy = 20.420952
# Iter 988 | Energy = 20.420952
# Iter 989 | Energy = 20.420952
# Iter 990 | Energy = 20.420952
# Iter 991 | Energy = 20.420952
# Iter 992 | Energy = 20.420952
# Iter 993 | Energy = 20.420952
# Iter 994 | Energy = 20.420952
# Iter 995 | Energy = 20.420952
# Iter 996 | Energy = 20.420952
# Iter 997 | Energy = 20.420952
# Iter 998 | Energy = 20.420952
# Iter 999 | Energy = 20.420952
# Iter 1000 | Energy = 20.420952

# %%
def build_super_graph(layers, prior_sigma=1.0, odom_sigma=1.0):
    """
    基于 layers[-2] 的 base graph, 和 layers[-1] 的 super 分组，构造 super graph。
    要求: layers[-2]["graph"] 已经是构建好的基图（含 unary/binary 因子）。
    layers[-1]["node_map"]: { base_node_id(str, 如 'b12') -> super_node_id(str) }
    """
    # ---------- 取出 base & super ----------
    base_graph = layers[-2]["graph"]
    super_nodes = layers[-1]["nodes"]
    super_edges = layers[-1]["edges"]
    node_map    = layers[-1]["node_map"]   # 'bN' -> 'sX_...'

    # base: id(int)->VariableNode，方便查 dofs 和 mu
    id2var = {vn.variableID: vn for vn in base_graph.var_nodes}

    # ---------- super_id -> [base_id(int)] ----------
    super_groups = {}
    for b_str, s_id in node_map.items():
        if not b_str.startswith("b"):
            continue
        b_int = int(b_str[1:])
        super_groups.setdefault(s_id, []).append(b_int)

    # ---------- 为每个 super 组建立 (start, dofs) 表 ----------
    # local_idx[sid][bid] = (start, dofs), total_dofs[sid] = sum(dofs)
    local_idx   = {}
    total_dofs  = {}
    for sid, group in super_groups.items():
        off = 0
        local_idx[sid] = {}
        for bid in group:
            d = id2var[bid].dofs
            local_idx[sid][bid] = (off, d)
            off += d
        total_dofs[sid] = off

    # ---------- 创建 super VariableNodes ----------
    from gbp.gbp import FactorGraph, VariableNode, Factor
    fg = FactorGraph(nonlinear_factors=False, eta_damping=0)

    super_var_nodes = {}
    for i, sn in enumerate(super_nodes):
        sid = sn["data"]["id"]
        dofs = total_dofs.get(sid, 0)
        v = VariableNode(i, dofs=dofs)
        super_var_nodes[sid] = v
        fg.var_nodes.append(v)
    fg.n_var_nodes = len(fg.var_nodes)

    # ---------- 工具：拼接某组的 linpoint（用 base belief 均值） ----------
    def make_linpoint_for_group(sid):
        x = np.zeros(total_dofs[sid])
        for bid, (st, d) in local_idx[sid].items():
            mu = getattr(id2var[bid], "mu", None)
            if mu is None or len(mu) != d:
                mu = np.zeros(d)
            x[st:st+d] = mu
        return x

    # ---------- 3) super prior（组内 unary + 组内 binary） ----------
    def make_super_prior_factor(sid, base_factors):
        group = super_groups[sid]
        idx_map = local_idx[sid]
        ncols = total_dofs[sid]

        # 选出：所有变量都在组内的因子（unary 或 binary）
        in_group = []
        for f in base_factors:
            vids = [v.ID for v in f.adj_var_nodes]
            if all(vid in group for vid in vids):
                in_group.append(f)

        def meas_fn_super_prior(x_super, *args):
            resids = []
            for f in in_group:
                vids = [v.ID for v in f.adj_var_nodes]
                # 拼本因子的局部 x
                x_loc_list = []
                for vid in vids:
                    st, d = idx_map[vid]
                    x_loc_list.append(x_super[st:st+d])
                x_loc = np.concatenate(x_loc_list) if x_loc_list else np.zeros(0)
                resids.append(f.meas_fn(x_loc) - f.z)
            return np.concatenate(resids) if resids else np.zeros(0)

        def jac_fn_super_prior(x_super, *args):
            Jrows = []
            for f in in_group:
                vids = [v.ID for v in f.adj_var_nodes]
                # 构造本因子的局部 x，用于（潜在）非线性雅可比
                x_loc_list = []
                dims = []
                for vid in vids:
                    st, d = idx_map[vid]
                    dims.append(d)
                    x_loc_list.append(x_super[st:st+d])
                x_loc = np.concatenate(x_loc_list) if x_loc_list else np.zeros(0)

                Jloc = f.jac_fn(x_loc)
                # 将 Jloc 列块映射回 super 变量的列
                row = np.zeros((Jloc.shape[0], ncols))
                c0 = 0
                for vid, d in zip(vids, dims):
                    st, _ = idx_map[vid]
                    row[:, st:st+d] = Jloc[:, c0:c0+d]
                    c0 += d
                Jrows.append(row)
            return np.vstack(Jrows) if Jrows else np.zeros((0, ncols))

        # z_super：拼各 base 因子的 z
        z_list = [f.z for f in in_group]
        z_super = np.concatenate(z_list) if z_list else np.zeros(0)

        return meas_fn_super_prior, jac_fn_super_prior, z_super

    # 为每个 super node 加 prior 因子
    for sid in super_groups.keys():
        meas_fn, jac_fn, z = make_super_prior_factor(sid, base_graph.factors)
        f = Factor(len(fg.factors), [super_var_nodes[sid]], z, prior_sigma, meas_fn, jac_fn)
        f.type = "super_prior"
        lin0 = make_linpoint_for_group(sid)
        f.compute_factor(linpoint=lin0, update_self=True)
        fg.factors.append(f)
        super_var_nodes[sid].adj_factors.append(f)

    # ---------- 4) super between（只取跨组 binary） ----------
    def make_super_between_factor(sidA, sidB, base_factors):
        groupA, groupB = super_groups[sidA], super_groups[sidB]
        idxA, idxB = local_idx[sidA], local_idx[sidB]
        nA, nB = total_dofs[sidA], total_dofs[sidB]

        cross = []
        for f in base_factors:
            vids = [v.ID for v in f.adj_var_nodes]
            if len(vids) != 2:
                continue
            i, j = vids
            # 恰有一端在 A，一端在 B
            if (i in groupA and j in groupB) or (i in groupB and j in groupA):
                cross.append(f)

        def meas_fn_super_between(xAB, *args):
            xA, xB = xAB[:nA], xAB[nA:]
            resids = []
            for f in cross:
                i, j = [v.ID for v in f.adj_var_nodes]
                if i in groupA:
                    si, di = idxA[i]
                    sj, dj = idxB[j]
                    xi = xA[si:si+di]
                    xj = xB[sj:sj+dj]
                else:
                    si, di = idxB[i]
                    sj, dj = idxA[j]
                    xi = xB[si:si+di]
                    xj = xA[sj:sj+dj]
                x_loc = np.concatenate([xi, xj])
                resids.append(f.meas_fn(x_loc) - f.z)
            return np.concatenate(resids) if resids else np.zeros(0)

        def jac_fn_super_between(xAB, *args):
            xA, xB = xAB[:nA], xAB[nA:]
            Jrows = []
            for f in cross:
                i, j = [v.ID for v in f.adj_var_nodes]
                if i in groupA:
                    si, di = idxA[i]
                    sj, dj = idxB[j]
                    xi = xA[si:si+di]
                    xj = xB[sj:sj+dj]
                    left_start, right_start = si, nA + sj
                else:
                    si, di = idxB[i]
                    sj, dj = idxA[j]
                    xi = xB[si:si+di]
                    xj = xA[sj:sj+dj]
                    left_start, right_start = nA + si, sj
                x_loc = np.concatenate([xi, xj])
                Jloc = f.jac_fn(x_loc)

                row = np.zeros((Jloc.shape[0], nA + nB))
                row[:, left_start:left_start+di]   = Jloc[:, :di]
                row[:, right_start:right_start+dj] = Jloc[:, di:di+dj]
                Jrows.append(row)
            return np.vstack(Jrows) if Jrows else np.zeros((0, nA + nB))

        z_super = np.concatenate([f.z for f in cross]) if cross else np.zeros(0)
        return meas_fn_super_between, jac_fn_super_between, z_super

    for e in super_edges:
        u, v = e["data"]["source"], e["data"]["target"]
        if u == "prior" or v == "prior":
            continue
        if (u not in super_groups) or (v not in super_groups):
            continue
        meas_fn, jac_fn, z = make_super_between_factor(u, v, base_graph.factors)
        f = Factor(len(fg.factors), [super_var_nodes[u], super_var_nodes[v]], z, odom_sigma, meas_fn, jac_fn)
        f.type = "super_between"
        lin0 = np.concatenate([make_linpoint_for_group(u), make_linpoint_for_group(v)])
        f.compute_factor(linpoint=lin0, update_self=True)
        fg.factors.append(f)
        super_var_nodes[u].adj_factors.append(f)
        super_var_nodes[v].adj_factors.append(f)

    fg.n_factor_nodes = len(fg.factors)
    return fg
